# %% [markdown]
# # 导入工具包

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
import lightgbm as lgb

# %% [markdown]
# # 读取数据

# %%
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")
results = pd.read_csv("../data/results.csv")

# %% [markdown]
# # 查看训练数据

# %%
train.head()
# Out:
#    id            level_1  level_2           level_3  \
# 0   0  工业/危化品类（现场）—2016版  （二）电气安全  6、移动用电产品、电动工具及照明
# 1   1  工业/危化品类（现场）—2016版  （一）消防检查            1、防火巡查
# 2   2  工业/危化品类（现场）—2016版  （一）消防检查            2、防火检查
# 3   3  工业/危化品类（现场）—2016版  （一）消防检查            1、防火巡查
# 4   4  工业/危化品类（现场）—2016版  （一）消防检查            1、防火巡查
#
#                                              level_4  \
# 0  1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。
# 1                           3、消防设施、器材和消防安全标志是否在位、完整；
# 2                           6、重点工种人员以及其他员工消防知识的掌握情况；
# 3                           3、消防设施、器材和消防安全标志是否在位、完整；
# 4                  4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；
#
#                       content  label
# 0  使用移动手动电动工具,外接线绝缘皮破损,应停止使用.      0
# 1                          一般      1
# 2                     消防知识要加强      0
# 3             消防通道有货物摆放 清理不及时      0
# 4                     防火门打开状态      0

# %% [markdown]
# # 查看训练数据条数

# %%
train.shape
# Out:
# (12000, 7)

# %% [markdown]
# # 查看测试数据

# %%
test.head()
# Out:
#    id             level_1  level_2        level_3  \
# 0   0     交通运输类（现场）—2016版  （一）消防安全         2、防火检查
# 1   1   工业/危化品类（选项）—2016版    （二）仓库         1、一般要求
# 2   2   工业/危化品类（现场）—2016版  （一）消防检查         1、防火巡查
# 3   3  商贸服务教文卫类（现场）—2016版  （二）电气安全  3、电气线路及电源插头插座
# 4   4  商贸服务教文卫类（现场）—2016版  （一）消防检查         1、防火巡查
#
#                         level_4                content
# 0  2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。         RB1洗地机占用堵塞安全通道
# 1         1、库房内储存物品应分类、分堆、限额存放。                  未分类堆放
# 2      3、消防设施、器材和消防安全标志是否在位、完整；  消防设施、器材和消防安全标志是否在位、完整
# 3          3、电源插座、电源插头应按规定正确接线。             插座随意放在电器旁边
# 4                   6、其他消防安全情况。           检查中发现一瓶灭火器过期

# %%
a = set(train['level_1'])
a,len(a)
# Out:
# ({'三小场所（基础）—2016版',
#   '三小场所（现场）—2016版',
#   '交通运输类（基础）—2016版',
#   '交通运输类（现场）—2016版',
#   '交通运输类（选项）—2016版',
#   '商贸服务教文卫类（基础）—2016版',
#   '商贸服务教文卫类（现场）—2016版',
#   '商贸服务教文卫类（选项）—2016版',
#   '工业/危化品 （现场）',
#   '工业/危化品类（基础）—2016版',
#   '工业/危化品类（现场）—2016版',
#   '工业/危化品类（选项）—2016版',
#   '建筑施工类（基础）—2016版',
#   '建筑施工类（现场）—2016版',
#   '建筑施工类（选项）—2016版',
#   '纯办公场所（基础）—2016版',
#   '纯办公场所（现场）—2016版'},
#  17)

# %%
train['level_1'].map(lambda x:dict(zip(a,range(len(a))))[x])
# Out:
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
#          ..
# 11995     3
# 11996     4
# 11997     4
# 11998     4
# 11999    15
# Name: level_1, Length: 12000, dtype: int64

# %% [markdown]
# # 训练集去重

# %%
train = train.drop_duplicates(['level_1', 'level_2', 'level_3', 'level_4', 'content', 'label'])

# %% [markdown]
# # 查看去重训练数据条数

# %%
train.shape
# Out:
# (10619, 7)

# %%
# !pip install textvec

# %% [markdown]
# # 构建特征

# %%
# train['text'] = (train['level_1'] + train['level_2'] + train['level_3'] + train['level_4'] + train['content']
#               ).map(lambda x:' '.join(list(str(x))))
# test['text'] = (test['level_1'] + test['level_2'] + test['level_3'] + test['level_4'] + test['content']
#              ).map(lambda x:' '.join(list(str(x))))

# %%
train['text'] = ( train['content']
              ).map(lambda x:' '.join(list(str(x))))
test['text'] = (test['content']
             ).map(lambda x:' '.join(list(str(x))))

# %%
vectorizer = TfidfVectorizer(analyzer='char')

# %%
train_X = vectorizer.fit_transform(train['text']).toarray()
test_X = vectorizer.transform(test['text']).toarray()

# %%
train_X
# Out:
# array([[0.        , 0.62734117, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.12762877, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.4413386 , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.80122334, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.68095895, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.63086452, 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
train_y = train['label'].astype(int).values

# %%
vectorizer.get_feature_names()[-10:]
# Out:
# ['！', '（', '）', '，', '．', '：', '；', 'ａ', 'ｂ', '🔌']

# %%
train_X.shape
# Out:
# (10619, 1684)

# %%
test_X.shape
# Out:
# (18000, 1684)

# %% [markdown]
# # 五折交叉验证

# %%
params = {
        'task':'train',
        'boosting_type':'gbdt',
        'num_leaves': 31,
        'objective': 'binary', 
        'learning_rate': 0.05, 
        'bagging_freq': 2, 
        'max_bin':256,
        'num_threads': 32,
#         'metric':['binary_logloss','binary_error']
    }

# %%
skf = StratifiedKFold(n_splits=5)

# %%
for index,(train_index, test_index) in enumerate(skf.split(train_X, train_y)):
    X_train, X_test = train_X[train_index], train_X[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)
    
    gbm = lgb.train(params,
                lgb_train,
                num_boost_round=1000,
                valid_sets=lgb_eval,
                early_stopping_rounds=10)
    y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
    pred = gbm.predict(test_X, num_iteration=gbm.best_iteration)
    if index == 0:
        pred_y_check, true_y_check = list(y_pred), list(y_test)
        pred_out=pred
    else:
        pred_y_check += list(y_pred)
        true_y_check += list(y_test)
        pred_out += pred
# Out:
# [LightGBM] [Info] Number of positive: 611, number of negative: 7884
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.080057 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 30417
# [LightGBM] [Info] Number of data points in the train set: 8495, number of used features: 531
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.071925 -> initscore=-2.557494
# [LightGBM] [Info] Start training from score -2.557494
# [1]	valid_0's binary_logloss: 0.236181
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's binary_logloss: 0.221872
# [3]	valid_0's binary_logloss: 0.211844
# [4]	valid_0's binary_logloss: 0.203738
# [5]	valid_0's binary_logloss: 0.196271
# [6]	valid_0's binary_logloss: 0.190022
# [7]	valid_0's binary_logloss: 0.185008
# [8]	valid_0's binary_logloss: 0.180307
# [9]	valid_0's binary_logloss: 0.176008
# [10]	valid_0's binary_logloss: 0.171944
# [11]	valid_0's binary_logloss: 0.168245
# [12]	valid_0's binary_logloss: 0.164442
# [13]	valid_0's binary_logloss: 0.16062
# [14]	valid_0's binary_logloss: 0.155636
# [15]	valid_0's binary_logloss: 0.15084
# [16]	valid_0's binary_logloss: 0.14766
# [17]	valid_0's binary_logloss: 0.14417
# [18]	valid_0's binary_logloss: 0.140428
# [19]	valid_0's binary_logloss: 0.13669
# [20]	valid_0's binary_logloss: 0.133242
# [21]	valid_0's binary_logloss: 0.13145
# [22]	valid_0's binary_logloss: 0.128541
# [23]	valid_0's binary_logloss: 0.12659
# [24]	valid_0's binary_logloss: 0.123807
# [25]	valid_0's binary_logloss: 0.121206
# [26]	valid_0's binary_logloss: 0.119504
# [27]	valid_0's binary_logloss: 0.117069
# [28]	valid_0's binary_logloss: 0.114815
# [29]	valid_0's binary_logloss: 0.112844
# [30]	valid_0's binary_logloss: 0.110844
# [31]	valid_0's binary_logloss: 0.109078
# [32]	valid_0's binary_logloss: 0.107561
# [33]	valid_0's binary_logloss: 0.106109
# [34]	valid_0's binary_logloss: 0.104497
# [35]	valid_0's binary_logloss: 0.10287
# [36]	valid_0's binary_logloss: 0.101272
# [37]	valid_0's binary_logloss: 0.0997183
# [38]	valid_0's binary_logloss: 0.0979946
# [39]	valid_0's binary_logloss: 0.0963788
# [40]	valid_0's binary_logloss: 0.0954922
# [41]	valid_0's binary_logloss: 0.0941043
# [42]	valid_0's binary_logloss: 0.0928615
# [43]	valid_0's binary_logloss: 0.0915459
# [44]	valid_0's binary_logloss: 0.0906089
# [45]	valid_0's binary_logloss: 0.0894937
# [46]	valid_0's binary_logloss: 0.0886675
# [47]	valid_0's binary_logloss: 0.0874294
# [48]	valid_0's binary_logloss: 0.086737
# [49]	valid_0's binary_logloss: 0.0863436
# [50]	valid_0's binary_logloss: 0.0854225
# [51]	valid_0's binary_logloss: 0.084612
# [52]	valid_0's binary_logloss: 0.0836683
# [53]	valid_0's binary_logloss: 0.083282
# [54]	valid_0's binary_logloss: 0.08256
# [55]	valid_0's binary_logloss: 0.0818659
# [56]	valid_0's binary_logloss: 0.0815574
# [57]	valid_0's binary_logloss: 0.0807918
# [58]	valid_0's binary_logloss: 0.0802644
# [59]	valid_0's binary_logloss: 0.0797812
# [60]	valid_0's binary_logloss: 0.0791495
# [61]	valid_0's binary_logloss: 0.0788161
# [62]	valid_0's binary_logloss: 0.0785
# [63]	valid_0's binary_logloss: 0.0781271
# [64]	valid_0's binary_logloss: 0.0775499
# [65]	valid_0's binary_logloss: 0.0773992
# [66]	valid_0's binary_logloss: 0.076964
# [67]	valid_0's binary_logloss: 0.0764669
# [68]	valid_0's binary_logloss: 0.0760967
# [69]	valid_0's binary_logloss: 0.0757285
# [70]	valid_0's binary_logloss: 0.0754252
# [71]	valid_0's binary_logloss: 0.0751432
# [72]	valid_0's binary_logloss: 0.0749338
# [73]	valid_0's binary_logloss: 0.0745129
# [74]	valid_0's binary_logloss: 0.074048
# [75]	valid_0's binary_logloss: 0.0736908
# [76]	valid_0's binary_logloss: 0.0733709
# [77]	valid_0's binary_logloss: 0.0732476
# [78]	valid_0's binary_logloss: 0.0728812
# [79]	valid_0's binary_logloss: 0.0724576
# [80]	valid_0's binary_logloss: 0.0719808
# [81]	valid_0's binary_logloss: 0.0716697
# [82]	valid_0's binary_logloss: 0.0716153
# [83]	valid_0's binary_logloss: 0.0711918
# [84]	valid_0's binary_logloss: 0.0710677
# [85]	valid_0's binary_logloss: 0.0709076
# [86]	valid_0's binary_logloss: 0.0707094
# [87]	valid_0's binary_logloss: 0.0706286
# [88]	valid_0's binary_logloss: 0.0704004
# [89]	valid_0's binary_logloss: 0.0701964
# [90]	valid_0's binary_logloss: 0.0700687
# [91]	valid_0's binary_logloss: 0.0698083
# [92]	valid_0's binary_logloss: 0.0696992
# [93]	valid_0's binary_logloss: 0.0695069
# [94]	valid_0's binary_logloss: 0.0692898
# [95]	valid_0's binary_logloss: 0.0692112
# [96]	valid_0's binary_logloss: 0.0691329
# [97]	valid_0's binary_logloss: 0.0690176
# [98]	valid_0's binary_logloss: 0.0687961
# [99]	valid_0's binary_logloss: 0.0687011
# [100]	valid_0's binary_logloss: 0.0685495
# [101]	valid_0's binary_logloss: 0.0683141
# [102]	valid_0's binary_logloss: 0.0681886
# [103]	valid_0's binary_logloss: 0.0681373
# [104]	valid_0's binary_logloss: 0.0681122
# [105]	valid_0's binary_logloss: 0.0679182
# [106]	valid_0's binary_logloss: 0.0678844
# [107]	valid_0's binary_logloss: 0.0676572
# [108]	valid_0's binary_logloss: 0.0676742
# [109]	valid_0's binary_logloss: 0.067626
# [110]	valid_0's binary_logloss: 0.0674752
# [111]	valid_0's binary_logloss: 0.0672049
# [112]	valid_0's binary_logloss: 0.0669782
# [113]	valid_0's binary_logloss: 0.067027
# [114]	valid_0's binary_logloss: 0.06688
# [115]	valid_0's binary_logloss: 0.0667279
# [116]	valid_0's binary_logloss: 0.0665524
# [117]	valid_0's binary_logloss: 0.0664858
# [118]	valid_0's binary_logloss: 0.066352
# [119]	valid_0's binary_logloss: 0.0663803
# [120]	valid_0's binary_logloss: 0.0662162
# [121]	valid_0's binary_logloss: 0.0661448
# [122]	valid_0's binary_logloss: 0.0661523
# [123]	valid_0's binary_logloss: 0.066143
# [124]	valid_0's binary_logloss: 0.0659615
# [125]	valid_0's binary_logloss: 0.0657368
# [126]	valid_0's binary_logloss: 0.065684
# [127]	valid_0's binary_logloss: 0.0657167
# [128]	valid_0's binary_logloss: 0.0657298
# [129]	valid_0's binary_logloss: 0.0657435
# [130]	valid_0's binary_logloss: 0.0657258
# [131]	valid_0's binary_logloss: 0.0656514
# [132]	valid_0's binary_logloss: 0.0655978
# [133]	valid_0's binary_logloss: 0.0654982
# [134]	valid_0's binary_logloss: 0.0655384
# [135]	valid_0's binary_logloss: 0.0655678
# [136]	valid_0's binary_logloss: 0.0655589
# [137]	valid_0's binary_logloss: 0.0655105
# [138]	valid_0's binary_logloss: 0.0654524
# [139]	valid_0's binary_logloss: 0.0653465
# [140]	valid_0's binary_logloss: 0.0653997
# [141]	valid_0's binary_logloss: 0.0652515
# [142]	valid_0's binary_logloss: 0.0651821
# [143]	valid_0's binary_logloss: 0.065238
# [144]	valid_0's binary_logloss: 0.0652207
# [145]	valid_0's binary_logloss: 0.0652896
# [146]	valid_0's binary_logloss: 0.0652985
# [147]	valid_0's binary_logloss: 0.0653947
# [148]	valid_0's binary_logloss: 0.0653157
# [149]	valid_0's binary_logloss: 0.065155
# [150]	valid_0's binary_logloss: 0.0650716
# [151]	valid_0's binary_logloss: 0.0650252
# [152]	valid_0's binary_logloss: 0.0650004
# [153]	valid_0's binary_logloss: 0.0651039
# [154]	valid_0's binary_logloss: 0.0649415
# [155]	valid_0's binary_logloss: 0.0649495
# [156]	valid_0's binary_logloss: 0.0649872
# [157]	valid_0's binary_logloss: 0.0649884
# [158]	valid_0's binary_logloss: 0.0648346
# [159]	valid_0's binary_logloss: 0.0646856
# [160]	valid_0's binary_logloss: 0.0647777
# [161]	valid_0's binary_logloss: 0.0648006
# [162]	valid_0's binary_logloss: 0.0648471
# [163]	valid_0's binary_logloss: 0.0648316
# [164]	valid_0's binary_logloss: 0.0648297
# [165]	valid_0's binary_logloss: 0.0649904
# [166]	valid_0's binary_logloss: 0.0650746
# [167]	valid_0's binary_logloss: 0.0650493
# [168]	valid_0's binary_logloss: 0.0649807
# [169]	valid_0's binary_logloss: 0.0650871
# Early stopping, best iteration is:
# [159]	valid_0's binary_logloss: 0.0646856
# [LightGBM] [Info] Number of positive: 611, number of negative: 7884
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.064795 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 30077
# [LightGBM] [Info] Number of data points in the train set: 8495, number of used features: 525
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.071925 -> initscore=-2.557494
# [LightGBM] [Info] Start training from score -2.557494
# [1]	valid_0's binary_logloss: 0.238579
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's binary_logloss: 0.226712
# [3]	valid_0's binary_logloss: 0.21838
# [4]	valid_0's binary_logloss: 0.211568
# [5]	valid_0's binary_logloss: 0.205667
# [6]	valid_0's binary_logloss: 0.200398
# [7]	valid_0's binary_logloss: 0.195783
# [8]	valid_0's binary_logloss: 0.191334
# [9]	valid_0's binary_logloss: 0.187551
# [10]	valid_0's binary_logloss: 0.184068
# [11]	valid_0's binary_logloss: 0.180909
# [12]	valid_0's binary_logloss: 0.177564
# [13]	valid_0's binary_logloss: 0.174423
# [14]	valid_0's binary_logloss: 0.169853
# [15]	valid_0's binary_logloss: 0.166089
# [16]	valid_0's binary_logloss: 0.161656
# [17]	valid_0's binary_logloss: 0.15706
# [18]	valid_0's binary_logloss: 0.153015
# [19]	valid_0's binary_logloss: 0.149203
# [20]	valid_0's binary_logloss: 0.14548
# [21]	valid_0's binary_logloss: 0.142202
# [22]	valid_0's binary_logloss: 0.139359
# [23]	valid_0's binary_logloss: 0.136612
# [24]	valid_0's binary_logloss: 0.133259
# [25]	valid_0's binary_logloss: 0.131222
# [26]	valid_0's binary_logloss: 0.128579
# [27]	valid_0's binary_logloss: 0.126602
# [28]	valid_0's binary_logloss: 0.124407
# [29]	valid_0's binary_logloss: 0.122789
# [30]	valid_0's binary_logloss: 0.121064
# [31]	valid_0's binary_logloss: 0.119105
# [32]	valid_0's binary_logloss: 0.117109
# [33]	valid_0's binary_logloss: 0.115789
# [34]	valid_0's binary_logloss: 0.11436
# [35]	valid_0's binary_logloss: 0.113143
# [36]	valid_0's binary_logloss: 0.11164
# [37]	valid_0's binary_logloss: 0.110161
# [38]	valid_0's binary_logloss: 0.108297
# [39]	valid_0's binary_logloss: 0.107299
# [40]	valid_0's binary_logloss: 0.106097
# [41]	valid_0's binary_logloss: 0.104766
# [42]	valid_0's binary_logloss: 0.103614
# [43]	valid_0's binary_logloss: 0.102661
# [44]	valid_0's binary_logloss: 0.101222
# [45]	valid_0's binary_logloss: 0.100187
# [46]	valid_0's binary_logloss: 0.0992804
# [47]	valid_0's binary_logloss: 0.0980712
# [48]	valid_0's binary_logloss: 0.0969939
# [49]	valid_0's binary_logloss: 0.0961149
# [50]	valid_0's binary_logloss: 0.095222
# [51]	valid_0's binary_logloss: 0.0943688
# [52]	valid_0's binary_logloss: 0.0935683
# [53]	valid_0's binary_logloss: 0.0925152
# [54]	valid_0's binary_logloss: 0.0914503
# [55]	valid_0's binary_logloss: 0.0907268
# [56]	valid_0's binary_logloss: 0.0900362
# [57]	valid_0's binary_logloss: 0.0892458
# [58]	valid_0's binary_logloss: 0.0887424
# [59]	valid_0's binary_logloss: 0.0880081
# [60]	valid_0's binary_logloss: 0.0874566
# [61]	valid_0's binary_logloss: 0.0869027
# [62]	valid_0's binary_logloss: 0.0862123
# [63]	valid_0's binary_logloss: 0.085832
# [64]	valid_0's binary_logloss: 0.0854207
# [65]	valid_0's binary_logloss: 0.0847819
# [66]	valid_0's binary_logloss: 0.0846053
# [67]	valid_0's binary_logloss: 0.0840036
# [68]	valid_0's binary_logloss: 0.083707
# [69]	valid_0's binary_logloss: 0.083042
# [70]	valid_0's binary_logloss: 0.0826343
# [71]	valid_0's binary_logloss: 0.0820332
# [72]	valid_0's binary_logloss: 0.0816334
# [73]	valid_0's binary_logloss: 0.0812314
# [74]	valid_0's binary_logloss: 0.0806982
# [75]	valid_0's binary_logloss: 0.080453
# [76]	valid_0's binary_logloss: 0.0799364
# [77]	valid_0's binary_logloss: 0.0798008
# [78]	valid_0's binary_logloss: 0.0793951
# [79]	valid_0's binary_logloss: 0.0790755
# [80]	valid_0's binary_logloss: 0.0789292
# [81]	valid_0's binary_logloss: 0.0787392
# [82]	valid_0's binary_logloss: 0.0785229
# [83]	valid_0's binary_logloss: 0.0783035
# [84]	valid_0's binary_logloss: 0.0780378
# [85]	valid_0's binary_logloss: 0.0776222
# [86]	valid_0's binary_logloss: 0.0775244
# [87]	valid_0's binary_logloss: 0.0773129
# [88]	valid_0's binary_logloss: 0.0771909
# [89]	valid_0's binary_logloss: 0.0768967
# [90]	valid_0's binary_logloss: 0.0767477
# [91]	valid_0's binary_logloss: 0.0766264
# [92]	valid_0's binary_logloss: 0.0764021
# [93]	valid_0's binary_logloss: 0.0762423
# [94]	valid_0's binary_logloss: 0.0760921
# [95]	valid_0's binary_logloss: 0.0757111
# [96]	valid_0's binary_logloss: 0.0755046
# [97]	valid_0's binary_logloss: 0.0753418
# [98]	valid_0's binary_logloss: 0.0751155
# [99]	valid_0's binary_logloss: 0.0749983
# [100]	valid_0's binary_logloss: 0.0746546
# [101]	valid_0's binary_logloss: 0.0746377
# [102]	valid_0's binary_logloss: 0.0746368
# [103]	valid_0's binary_logloss: 0.0746142
# [104]	valid_0's binary_logloss: 0.0744111
# [105]	valid_0's binary_logloss: 0.074426
# [106]	valid_0's binary_logloss: 0.0741686
# [107]	valid_0's binary_logloss: 0.0740997
# [108]	valid_0's binary_logloss: 0.074123
# [109]	valid_0's binary_logloss: 0.0739535
# [110]	valid_0's binary_logloss: 0.0739395
# [111]	valid_0's binary_logloss: 0.0738467
# [112]	valid_0's binary_logloss: 0.0739193
# [113]	valid_0's binary_logloss: 0.0738149
# [114]	valid_0's binary_logloss: 0.0737103
# [115]	valid_0's binary_logloss: 0.0736779
# [116]	valid_0's binary_logloss: 0.0736725
# [117]	valid_0's binary_logloss: 0.0737362
# [118]	valid_0's binary_logloss: 0.0735631
# [119]	valid_0's binary_logloss: 0.0734206
# [120]	valid_0's binary_logloss: 0.0732728
# [121]	valid_0's binary_logloss: 0.0733288
# [122]	valid_0's binary_logloss: 0.0732844
# [123]	valid_0's binary_logloss: 0.0732948
# [124]	valid_0's binary_logloss: 0.0731663
# [125]	valid_0's binary_logloss: 0.0730968
# [126]	valid_0's binary_logloss: 0.0730581
# [127]	valid_0's binary_logloss: 0.0732226
# [128]	valid_0's binary_logloss: 0.0731009
# [129]	valid_0's binary_logloss: 0.0729219
# [130]	valid_0's binary_logloss: 0.0727264
# [131]	valid_0's binary_logloss: 0.0725386
# [132]	valid_0's binary_logloss: 0.0725443
# [133]	valid_0's binary_logloss: 0.0724863
# [134]	valid_0's binary_logloss: 0.0725323
# [135]	valid_0's binary_logloss: 0.072425
# [136]	valid_0's binary_logloss: 0.0723551
# [137]	valid_0's binary_logloss: 0.0722071
# [138]	valid_0's binary_logloss: 0.0720131
# [139]	valid_0's binary_logloss: 0.0720342
# [140]	valid_0's binary_logloss: 0.0719488
# [141]	valid_0's binary_logloss: 0.0719728
# [142]	valid_0's binary_logloss: 0.0718715
# [143]	valid_0's binary_logloss: 0.0717253
# [144]	valid_0's binary_logloss: 0.071625
# [145]	valid_0's binary_logloss: 0.0715444
# [146]	valid_0's binary_logloss: 0.0714689
# [147]	valid_0's binary_logloss: 0.071545
# [148]	valid_0's binary_logloss: 0.0715325
# [149]	valid_0's binary_logloss: 0.0714543
# [150]	valid_0's binary_logloss: 0.071353
# [151]	valid_0's binary_logloss: 0.0713659
# [152]	valid_0's binary_logloss: 0.0713235
# [153]	valid_0's binary_logloss: 0.0713184
# [154]	valid_0's binary_logloss: 0.0713517
# [155]	valid_0's binary_logloss: 0.0711659
# [156]	valid_0's binary_logloss: 0.0711627
# [157]	valid_0's binary_logloss: 0.0710702
# [158]	valid_0's binary_logloss: 0.0711294
# [159]	valid_0's binary_logloss: 0.0711831
# [160]	valid_0's binary_logloss: 0.0710911
# [161]	valid_0's binary_logloss: 0.0710939
# [162]	valid_0's binary_logloss: 0.0711003
# [163]	valid_0's binary_logloss: 0.07108
# [164]	valid_0's binary_logloss: 0.0710701
# [165]	valid_0's binary_logloss: 0.071095
# [166]	valid_0's binary_logloss: 0.0711375
# [167]	valid_0's binary_logloss: 0.0711054
# [168]	valid_0's binary_logloss: 0.0711862
# [169]	valid_0's binary_logloss: 0.0713183
# [170]	valid_0's binary_logloss: 0.0713151
# [171]	valid_0's binary_logloss: 0.0712148
# [172]	valid_0's binary_logloss: 0.071367
# [173]	valid_0's binary_logloss: 0.0713076
# [174]	valid_0's binary_logloss: 0.0711964
# Early stopping, best iteration is:
# [164]	valid_0's binary_logloss: 0.0710701
# [LightGBM] [Info] Number of positive: 611, number of negative: 7884
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.064948 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 30212
# [LightGBM] [Info] Number of data points in the train set: 8495, number of used features: 525
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.071925 -> initscore=-2.557494
# [LightGBM] [Info] Start training from score -2.557494
# [1]	valid_0's binary_logloss: 0.239022
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's binary_logloss: 0.227172
# [3]	valid_0's binary_logloss: 0.218296
# [4]	valid_0's binary_logloss: 0.211247
# [5]	valid_0's binary_logloss: 0.204608
# [6]	valid_0's binary_logloss: 0.19872
# [7]	valid_0's binary_logloss: 0.193812
# [8]	valid_0's binary_logloss: 0.18941
# [9]	valid_0's binary_logloss: 0.185609
# [10]	valid_0's binary_logloss: 0.181644
# [11]	valid_0's binary_logloss: 0.178505
# [12]	valid_0's binary_logloss: 0.174738
# [13]	valid_0's binary_logloss: 0.171098
# [14]	valid_0's binary_logloss: 0.167894
# [15]	valid_0's binary_logloss: 0.163147
# [16]	valid_0's binary_logloss: 0.158586
# [17]	valid_0's binary_logloss: 0.154465
# [18]	valid_0's binary_logloss: 0.150894
# [19]	valid_0's binary_logloss: 0.147654
# [20]	valid_0's binary_logloss: 0.144021
# [21]	valid_0's binary_logloss: 0.141191
# [22]	valid_0's binary_logloss: 0.138691
# [23]	valid_0's binary_logloss: 0.13632
# [24]	valid_0's binary_logloss: 0.133986
# [25]	valid_0's binary_logloss: 0.131447
# [26]	valid_0's binary_logloss: 0.129099
# [27]	valid_0's binary_logloss: 0.127214
# [28]	valid_0's binary_logloss: 0.124789
# [29]	valid_0's binary_logloss: 0.123144
# [30]	valid_0's binary_logloss: 0.121376
# [31]	valid_0's binary_logloss: 0.119423
# [32]	valid_0's binary_logloss: 0.117523
# [33]	valid_0's binary_logloss: 0.116179
# [34]	valid_0's binary_logloss: 0.114579
# [35]	valid_0's binary_logloss: 0.113351
# [36]	valid_0's binary_logloss: 0.112021
# [37]	valid_0's binary_logloss: 0.11081
# [38]	valid_0's binary_logloss: 0.109485
# [39]	valid_0's binary_logloss: 0.108587
# [40]	valid_0's binary_logloss: 0.107707
# [41]	valid_0's binary_logloss: 0.106591
# [42]	valid_0's binary_logloss: 0.105493
# [43]	valid_0's binary_logloss: 0.104254
# [44]	valid_0's binary_logloss: 0.102992
# [45]	valid_0's binary_logloss: 0.101514
# [46]	valid_0's binary_logloss: 0.100475
# [47]	valid_0's binary_logloss: 0.0992788
# [48]	valid_0's binary_logloss: 0.0981208
# [49]	valid_0's binary_logloss: 0.0969307
# [50]	valid_0's binary_logloss: 0.0959031
# [51]	valid_0's binary_logloss: 0.0951927
# [52]	valid_0's binary_logloss: 0.094244
# [53]	valid_0's binary_logloss: 0.0932709
# [54]	valid_0's binary_logloss: 0.0925327
# [55]	valid_0's binary_logloss: 0.0919465
# [56]	valid_0's binary_logloss: 0.0912113
# [57]	valid_0's binary_logloss: 0.090574
# [58]	valid_0's binary_logloss: 0.0901692
# [59]	valid_0's binary_logloss: 0.0894816
# [60]	valid_0's binary_logloss: 0.0890458
# [61]	valid_0's binary_logloss: 0.0885748
# [62]	valid_0's binary_logloss: 0.0880958
# [63]	valid_0's binary_logloss: 0.0874844
# [64]	valid_0's binary_logloss: 0.0872141
# [65]	valid_0's binary_logloss: 0.086674
# [66]	valid_0's binary_logloss: 0.0862014
# [67]	valid_0's binary_logloss: 0.0858597
# [68]	valid_0's binary_logloss: 0.0854662
# [69]	valid_0's binary_logloss: 0.0851792
# [70]	valid_0's binary_logloss: 0.084645
# [71]	valid_0's binary_logloss: 0.0842532
# [72]	valid_0's binary_logloss: 0.0839237
# [73]	valid_0's binary_logloss: 0.0834371
# [74]	valid_0's binary_logloss: 0.0830779
# [75]	valid_0's binary_logloss: 0.0828246
# [76]	valid_0's binary_logloss: 0.0823337
# [77]	valid_0's binary_logloss: 0.081895
# [78]	valid_0's binary_logloss: 0.0818708
# [79]	valid_0's binary_logloss: 0.081586
# [80]	valid_0's binary_logloss: 0.0813167
# [81]	valid_0's binary_logloss: 0.0810193
# [82]	valid_0's binary_logloss: 0.080857
# [83]	valid_0's binary_logloss: 0.0806786
# [84]	valid_0's binary_logloss: 0.0805401
# [85]	valid_0's binary_logloss: 0.0802085
# [86]	valid_0's binary_logloss: 0.0799235
# [87]	valid_0's binary_logloss: 0.0794915
# [88]	valid_0's binary_logloss: 0.0792928
# [89]	valid_0's binary_logloss: 0.0791763
# [90]	valid_0's binary_logloss: 0.078912
# [91]	valid_0's binary_logloss: 0.078673
# [92]	valid_0's binary_logloss: 0.0783675
# [93]	valid_0's binary_logloss: 0.0779679
# [94]	valid_0's binary_logloss: 0.0779254
# [95]	valid_0's binary_logloss: 0.0777656
# [96]	valid_0's binary_logloss: 0.0776606
# [97]	valid_0's binary_logloss: 0.0775692
# [98]	valid_0's binary_logloss: 0.0772729
# [99]	valid_0's binary_logloss: 0.0770841
# [100]	valid_0's binary_logloss: 0.0769891
# [101]	valid_0's binary_logloss: 0.0767397
# [102]	valid_0's binary_logloss: 0.0765177
# [103]	valid_0's binary_logloss: 0.076512
# [104]	valid_0's binary_logloss: 0.0763657
# [105]	valid_0's binary_logloss: 0.0763014
# [106]	valid_0's binary_logloss: 0.076138
# [107]	valid_0's binary_logloss: 0.075886
# [108]	valid_0's binary_logloss: 0.0757247
# [109]	valid_0's binary_logloss: 0.075685
# [110]	valid_0's binary_logloss: 0.0754828
# [111]	valid_0's binary_logloss: 0.0753587
# [112]	valid_0's binary_logloss: 0.0752729
# [113]	valid_0's binary_logloss: 0.0751238
# [114]	valid_0's binary_logloss: 0.0750831
# [115]	valid_0's binary_logloss: 0.0748991
# [116]	valid_0's binary_logloss: 0.0748086
# [117]	valid_0's binary_logloss: 0.0748286
# [118]	valid_0's binary_logloss: 0.0746157
# [119]	valid_0's binary_logloss: 0.074505
# [120]	valid_0's binary_logloss: 0.0744543
# [121]	valid_0's binary_logloss: 0.0744448
# [122]	valid_0's binary_logloss: 0.0742672
# [123]	valid_0's binary_logloss: 0.0740193
# [124]	valid_0's binary_logloss: 0.0739613
# [125]	valid_0's binary_logloss: 0.0739056
# [126]	valid_0's binary_logloss: 0.073914
# [127]	valid_0's binary_logloss: 0.073948
# [128]	valid_0's binary_logloss: 0.0738643
# [129]	valid_0's binary_logloss: 0.0737886
# [130]	valid_0's binary_logloss: 0.0736959
# [131]	valid_0's binary_logloss: 0.0734942
# [132]	valid_0's binary_logloss: 0.0733552
# [133]	valid_0's binary_logloss: 0.0733592
# [134]	valid_0's binary_logloss: 0.0733416
# [135]	valid_0's binary_logloss: 0.0732936
# [136]	valid_0's binary_logloss: 0.0731045
# [137]	valid_0's binary_logloss: 0.0729973
# [138]	valid_0's binary_logloss: 0.0730062
# [139]	valid_0's binary_logloss: 0.0730818
# [140]	valid_0's binary_logloss: 0.0730164
# [141]	valid_0's binary_logloss: 0.0728569
# [142]	valid_0's binary_logloss: 0.072757
# [143]	valid_0's binary_logloss: 0.0727535
# [144]	valid_0's binary_logloss: 0.0727908
# [145]	valid_0's binary_logloss: 0.0727394
# [146]	valid_0's binary_logloss: 0.0726671
# [147]	valid_0's binary_logloss: 0.0725729
# [148]	valid_0's binary_logloss: 0.0725706
# [149]	valid_0's binary_logloss: 0.0724286
# [150]	valid_0's binary_logloss: 0.0724635
# [151]	valid_0's binary_logloss: 0.072582
# [152]	valid_0's binary_logloss: 0.0725894
# [153]	valid_0's binary_logloss: 0.072629
# [154]	valid_0's binary_logloss: 0.0725243
# [155]	valid_0's binary_logloss: 0.072542
# [156]	valid_0's binary_logloss: 0.0724555
# [157]	valid_0's binary_logloss: 0.0724959
# [158]	valid_0's binary_logloss: 0.0725458
# [159]	valid_0's binary_logloss: 0.0725997
# Early stopping, best iteration is:
# [149]	valid_0's binary_logloss: 0.0724286
# [LightGBM] [Info] Number of positive: 611, number of negative: 7884
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.032815 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 30110
# [LightGBM] [Info] Number of data points in the train set: 8495, number of used features: 529
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.071925 -> initscore=-2.557494
# [LightGBM] [Info] Start training from score -2.557494
# [1]	valid_0's binary_logloss: 0.239471
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's binary_logloss: 0.227114
# [3]	valid_0's binary_logloss: 0.21764
# [4]	valid_0's binary_logloss: 0.210197
# [5]	valid_0's binary_logloss: 0.203949
# [6]	valid_0's binary_logloss: 0.198493
# [7]	valid_0's binary_logloss: 0.192646
# [8]	valid_0's binary_logloss: 0.187476
# [9]	valid_0's binary_logloss: 0.182648
# [10]	valid_0's binary_logloss: 0.178498
# [11]	valid_0's binary_logloss: 0.174753
# [12]	valid_0's binary_logloss: 0.171316
# [13]	valid_0's binary_logloss: 0.166787
# [14]	valid_0's binary_logloss: 0.163319
# [15]	valid_0's binary_logloss: 0.158279
# [16]	valid_0's binary_logloss: 0.153786
# [17]	valid_0's binary_logloss: 0.150538
# [18]	valid_0's binary_logloss: 0.146999
# [19]	valid_0's binary_logloss: 0.143405
# [20]	valid_0's binary_logloss: 0.140078
# [21]	valid_0's binary_logloss: 0.136818
# [22]	valid_0's binary_logloss: 0.13371
# [23]	valid_0's binary_logloss: 0.131096
# [24]	valid_0's binary_logloss: 0.128433
# [25]	valid_0's binary_logloss: 0.125989
# [26]	valid_0's binary_logloss: 0.123561
# [27]	valid_0's binary_logloss: 0.121295
# [28]	valid_0's binary_logloss: 0.11906
# [29]	valid_0's binary_logloss: 0.117046
# [30]	valid_0's binary_logloss: 0.115128
# [31]	valid_0's binary_logloss: 0.113455
# [32]	valid_0's binary_logloss: 0.111644
# [33]	valid_0's binary_logloss: 0.109942
# [34]	valid_0's binary_logloss: 0.10849
# [35]	valid_0's binary_logloss: 0.106865
# [36]	valid_0's binary_logloss: 0.105789
# [37]	valid_0's binary_logloss: 0.104393
# [38]	valid_0's binary_logloss: 0.102962
# [39]	valid_0's binary_logloss: 0.101479
# [40]	valid_0's binary_logloss: 0.100211
# [41]	valid_0's binary_logloss: 0.0992751
# [42]	valid_0's binary_logloss: 0.0981071
# [43]	valid_0's binary_logloss: 0.0970457
# [44]	valid_0's binary_logloss: 0.0958903
# [45]	valid_0's binary_logloss: 0.0951125
# [46]	valid_0's binary_logloss: 0.0943399
# [47]	valid_0's binary_logloss: 0.0934809
# [48]	valid_0's binary_logloss: 0.0927402
# [49]	valid_0's binary_logloss: 0.0916815
# [50]	valid_0's binary_logloss: 0.0909941
# [51]	valid_0's binary_logloss: 0.0901697
# [52]	valid_0's binary_logloss: 0.0891423
# [53]	valid_0's binary_logloss: 0.0886952
# [54]	valid_0's binary_logloss: 0.0878824
# [55]	valid_0's binary_logloss: 0.0872165
# [56]	valid_0's binary_logloss: 0.086467
# [57]	valid_0's binary_logloss: 0.0859334
# [58]	valid_0's binary_logloss: 0.0852024
# [59]	valid_0's binary_logloss: 0.0847102
# [60]	valid_0's binary_logloss: 0.0839278
# [61]	valid_0's binary_logloss: 0.0834364
# [62]	valid_0's binary_logloss: 0.082924
# [63]	valid_0's binary_logloss: 0.0826656
# [64]	valid_0's binary_logloss: 0.0824756
# [65]	valid_0's binary_logloss: 0.0820546
# [66]	valid_0's binary_logloss: 0.081543
# [67]	valid_0's binary_logloss: 0.0810301
# [68]	valid_0's binary_logloss: 0.0806769
# [69]	valid_0's binary_logloss: 0.0806002
# [70]	valid_0's binary_logloss: 0.080272
# [71]	valid_0's binary_logloss: 0.0800765
# [72]	valid_0's binary_logloss: 0.0799577
# [73]	valid_0's binary_logloss: 0.079543
# [74]	valid_0's binary_logloss: 0.0794337
# [75]	valid_0's binary_logloss: 0.079327
# [76]	valid_0's binary_logloss: 0.0789351
# [77]	valid_0's binary_logloss: 0.0787511
# [78]	valid_0's binary_logloss: 0.0783336
# [79]	valid_0's binary_logloss: 0.0781406
# [80]	valid_0's binary_logloss: 0.077906
# [81]	valid_0's binary_logloss: 0.077604
# [82]	valid_0's binary_logloss: 0.0774814
# [83]	valid_0's binary_logloss: 0.0773708
# [84]	valid_0's binary_logloss: 0.0773252
# [85]	valid_0's binary_logloss: 0.0772067
# [86]	valid_0's binary_logloss: 0.0770673
# [87]	valid_0's binary_logloss: 0.0769886
# [88]	valid_0's binary_logloss: 0.076811
# [89]	valid_0's binary_logloss: 0.0765633
# [90]	valid_0's binary_logloss: 0.0762338
# [91]	valid_0's binary_logloss: 0.0761712
# [92]	valid_0's binary_logloss: 0.0759914
# [93]	valid_0's binary_logloss: 0.0760025
# [94]	valid_0's binary_logloss: 0.0760123
# [95]	valid_0's binary_logloss: 0.0760498
# [96]	valid_0's binary_logloss: 0.0760344
# [97]	valid_0's binary_logloss: 0.0759457
# [98]	valid_0's binary_logloss: 0.0759368
# [99]	valid_0's binary_logloss: 0.0757458
# [100]	valid_0's binary_logloss: 0.0757353
# [101]	valid_0's binary_logloss: 0.0756892
# [102]	valid_0's binary_logloss: 0.0755281
# [103]	valid_0's binary_logloss: 0.0753802
# [104]	valid_0's binary_logloss: 0.0753379
# [105]	valid_0's binary_logloss: 0.0754022
# [106]	valid_0's binary_logloss: 0.0753058
# [107]	valid_0's binary_logloss: 0.0753555
# [108]	valid_0's binary_logloss: 0.075231
# [109]	valid_0's binary_logloss: 0.0752717
# [110]	valid_0's binary_logloss: 0.0753609
# [111]	valid_0's binary_logloss: 0.0752549
# [112]	valid_0's binary_logloss: 0.0751837
# [113]	valid_0's binary_logloss: 0.0751048
# [114]	valid_0's binary_logloss: 0.0751344
# [115]	valid_0's binary_logloss: 0.0751922
# [116]	valid_0's binary_logloss: 0.0750523
# [117]	valid_0's binary_logloss: 0.0752433
# [118]	valid_0's binary_logloss: 0.0752176
# [119]	valid_0's binary_logloss: 0.0749803
# [120]	valid_0's binary_logloss: 0.074907
# [121]	valid_0's binary_logloss: 0.0749253
# [122]	valid_0's binary_logloss: 0.0749316
# [123]	valid_0's binary_logloss: 0.0749328
# [124]	valid_0's binary_logloss: 0.0749391
# [125]	valid_0's binary_logloss: 0.0750384
# [126]	valid_0's binary_logloss: 0.0749228
# [127]	valid_0's binary_logloss: 0.0749525
# [128]	valid_0's binary_logloss: 0.0748753
# [129]	valid_0's binary_logloss: 0.0749601
# [130]	valid_0's binary_logloss: 0.0750782
# [131]	valid_0's binary_logloss: 0.0749901
# [132]	valid_0's binary_logloss: 0.0751941
# [133]	valid_0's binary_logloss: 0.0752588
# [134]	valid_0's binary_logloss: 0.0752234
# [135]	valid_0's binary_logloss: 0.0752112
# [136]	valid_0's binary_logloss: 0.0751842
# [137]	valid_0's binary_logloss: 0.0752028
# [138]	valid_0's binary_logloss: 0.0753625
# Early stopping, best iteration is:
# [128]	valid_0's binary_logloss: 0.0748753
# [LightGBM] [Info] Number of positive: 612, number of negative: 7884
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.044125 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30117
# [LightGBM] [Info] Number of data points in the train set: 8496, number of used features: 521
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.072034 -> initscore=-2.555858
# [LightGBM] [Info] Start training from score -2.555858
# [1]	valid_0's binary_logloss: 0.236749
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's binary_logloss: 0.224787
# [3]	valid_0's binary_logloss: 0.215411
# [4]	valid_0's binary_logloss: 0.207238
# [5]	valid_0's binary_logloss: 0.200648
# [6]	valid_0's binary_logloss: 0.19483
# [7]	valid_0's binary_logloss: 0.189967
# [8]	valid_0's binary_logloss: 0.185271
# [9]	valid_0's binary_logloss: 0.181261
# [10]	valid_0's binary_logloss: 0.177244
# [11]	valid_0's binary_logloss: 0.173692
# [12]	valid_0's binary_logloss: 0.16909
# [13]	valid_0's binary_logloss: 0.165007
# [14]	valid_0's binary_logloss: 0.160865
# [15]	valid_0's binary_logloss: 0.156896
# [16]	valid_0's binary_logloss: 0.153486
# [17]	valid_0's binary_logloss: 0.150176
# [18]	valid_0's binary_logloss: 0.147199
# [19]	valid_0's binary_logloss: 0.144191
# [20]	valid_0's binary_logloss: 0.140778
# [21]	valid_0's binary_logloss: 0.137796
# [22]	valid_0's binary_logloss: 0.135198
# [23]	valid_0's binary_logloss: 0.133106
# [24]	valid_0's binary_logloss: 0.130765
# [25]	valid_0's binary_logloss: 0.12898
# [26]	valid_0's binary_logloss: 0.126976
# [27]	valid_0's binary_logloss: 0.124622
# [28]	valid_0's binary_logloss: 0.123066
# [29]	valid_0's binary_logloss: 0.120994
# [30]	valid_0's binary_logloss: 0.119538
# [31]	valid_0's binary_logloss: 0.117766
# [32]	valid_0's binary_logloss: 0.116466
# [33]	valid_0's binary_logloss: 0.114917
# [34]	valid_0's binary_logloss: 0.113397
# [35]	valid_0's binary_logloss: 0.112232
# [36]	valid_0's binary_logloss: 0.1106
# [37]	valid_0's binary_logloss: 0.108959
# [38]	valid_0's binary_logloss: 0.107674
# [39]	valid_0's binary_logloss: 0.106561
# [40]	valid_0's binary_logloss: 0.105641
# [41]	valid_0's binary_logloss: 0.104735
# [42]	valid_0's binary_logloss: 0.103752
# [43]	valid_0's binary_logloss: 0.102781
# [44]	valid_0's binary_logloss: 0.101871
# [45]	valid_0's binary_logloss: 0.10077
# [46]	valid_0's binary_logloss: 0.100266
# [47]	valid_0's binary_logloss: 0.0995768
# [48]	valid_0's binary_logloss: 0.0988916
# [49]	valid_0's binary_logloss: 0.0982586
# [50]	valid_0's binary_logloss: 0.0975088
# [51]	valid_0's binary_logloss: 0.0968649
# [52]	valid_0's binary_logloss: 0.0963343
# [53]	valid_0's binary_logloss: 0.0956379
# [54]	valid_0's binary_logloss: 0.0948783
# [55]	valid_0's binary_logloss: 0.0944925
# [56]	valid_0's binary_logloss: 0.0939162
# [57]	valid_0's binary_logloss: 0.0933617
# [58]	valid_0's binary_logloss: 0.0927641
# [59]	valid_0's binary_logloss: 0.092279
# [60]	valid_0's binary_logloss: 0.091535
# [61]	valid_0's binary_logloss: 0.0908878
# [62]	valid_0's binary_logloss: 0.0903811
# [63]	valid_0's binary_logloss: 0.0899282
# [64]	valid_0's binary_logloss: 0.0894865
# [65]	valid_0's binary_logloss: 0.0888009
# [66]	valid_0's binary_logloss: 0.0884574
# [67]	valid_0's binary_logloss: 0.0881102
# [68]	valid_0's binary_logloss: 0.0875444
# [69]	valid_0's binary_logloss: 0.0869923
# [70]	valid_0's binary_logloss: 0.0866577
# [71]	valid_0's binary_logloss: 0.086464
# [72]	valid_0's binary_logloss: 0.0859006
# [73]	valid_0's binary_logloss: 0.0853223
# [74]	valid_0's binary_logloss: 0.0850962
# [75]	valid_0's binary_logloss: 0.0847679
# [76]	valid_0's binary_logloss: 0.0843673
# [77]	valid_0's binary_logloss: 0.0841688
# [78]	valid_0's binary_logloss: 0.0838498
# [79]	valid_0's binary_logloss: 0.0836293
# [80]	valid_0's binary_logloss: 0.0832953
# [81]	valid_0's binary_logloss: 0.0830566
# [82]	valid_0's binary_logloss: 0.0827909
# [83]	valid_0's binary_logloss: 0.0826274
# [84]	valid_0's binary_logloss: 0.0823157
# [85]	valid_0's binary_logloss: 0.0819919
# [86]	valid_0's binary_logloss: 0.0818493
# [87]	valid_0's binary_logloss: 0.0814853
# [88]	valid_0's binary_logloss: 0.0812557
# [89]	valid_0's binary_logloss: 0.0809659
# [90]	valid_0's binary_logloss: 0.0807063
# [91]	valid_0's binary_logloss: 0.080547
# [92]	valid_0's binary_logloss: 0.080226
# [93]	valid_0's binary_logloss: 0.0800829
# [94]	valid_0's binary_logloss: 0.0797737
# [95]	valid_0's binary_logloss: 0.079818
# [96]	valid_0's binary_logloss: 0.0795061
# [97]	valid_0's binary_logloss: 0.0793141
# [98]	valid_0's binary_logloss: 0.0790364
# [99]	valid_0's binary_logloss: 0.0788487
# [100]	valid_0's binary_logloss: 0.0786188
# [101]	valid_0's binary_logloss: 0.0785151
# [102]	valid_0's binary_logloss: 0.0784037
# [103]	valid_0's binary_logloss: 0.0783231
# [104]	valid_0's binary_logloss: 0.0782107
# [105]	valid_0's binary_logloss: 0.0780506
# [106]	valid_0's binary_logloss: 0.0778654
# [107]	valid_0's binary_logloss: 0.0778446
# [108]	valid_0's binary_logloss: 0.0778976
# [109]	valid_0's binary_logloss: 0.0778792
# [110]	valid_0's binary_logloss: 0.0778107
# [111]	valid_0's binary_logloss: 0.0778356
# [112]	valid_0's binary_logloss: 0.0777782
# [113]	valid_0's binary_logloss: 0.0778799
# [114]	valid_0's binary_logloss: 0.0779355
# [115]	valid_0's binary_logloss: 0.0778015
# [116]	valid_0's binary_logloss: 0.0778149
# [117]	valid_0's binary_logloss: 0.0777763
# [118]	valid_0's binary_logloss: 0.0776748
# [119]	valid_0's binary_logloss: 0.0775547
# [120]	valid_0's binary_logloss: 0.0774288
# [121]	valid_0's binary_logloss: 0.0772332
# [122]	valid_0's binary_logloss: 0.0771438
# [123]	valid_0's binary_logloss: 0.0770367
# [124]	valid_0's binary_logloss: 0.076909
# [125]	valid_0's binary_logloss: 0.0768653
# [126]	valid_0's binary_logloss: 0.0766346
# [127]	valid_0's binary_logloss: 0.0765829
# [128]	valid_0's binary_logloss: 0.0766537
# [129]	valid_0's binary_logloss: 0.0767671
# [130]	valid_0's binary_logloss: 0.0766232
# [131]	valid_0's binary_logloss: 0.0764493
# [132]	valid_0's binary_logloss: 0.0763815
# [133]	valid_0's binary_logloss: 0.0763178
# [134]	valid_0's binary_logloss: 0.0763742
# [135]	valid_0's binary_logloss: 0.0762515
# [136]	valid_0's binary_logloss: 0.0762012
# [137]	valid_0's binary_logloss: 0.0760443
# [138]	valid_0's binary_logloss: 0.075998
# [139]	valid_0's binary_logloss: 0.0760482
# [140]	valid_0's binary_logloss: 0.0760124
# [141]	valid_0's binary_logloss: 0.0760004
# [142]	valid_0's binary_logloss: 0.0759924
# [143]	valid_0's binary_logloss: 0.0760713
# [144]	valid_0's binary_logloss: 0.0760327
# [145]	valid_0's binary_logloss: 0.0759796
# [146]	valid_0's binary_logloss: 0.0759384
# [147]	valid_0's binary_logloss: 0.0758333
# [148]	valid_0's binary_logloss: 0.0757428
# [149]	valid_0's binary_logloss: 0.0757334
# [150]	valid_0's binary_logloss: 0.0756112
# [151]	valid_0's binary_logloss: 0.0757297
# [152]	valid_0's binary_logloss: 0.0757556
# [153]	valid_0's binary_logloss: 0.075603
# [154]	valid_0's binary_logloss: 0.0755357
# [155]	valid_0's binary_logloss: 0.0754742
# [156]	valid_0's binary_logloss: 0.0756448
# [157]	valid_0's binary_logloss: 0.0756564
# [158]	valid_0's binary_logloss: 0.0755356
# [159]	valid_0's binary_logloss: 0.0754935
# [160]	valid_0's binary_logloss: 0.0755938
# [161]	valid_0's binary_logloss: 0.0756384
# [162]	valid_0's binary_logloss: 0.075543
# [163]	valid_0's binary_logloss: 0.0754745
# [164]	valid_0's binary_logloss: 0.0753363
# [165]	valid_0's binary_logloss: 0.0752091
# [166]	valid_0's binary_logloss: 0.0752535
# [167]	valid_0's binary_logloss: 0.0751115
# [168]	valid_0's binary_logloss: 0.0751417
# [169]	valid_0's binary_logloss: 0.0750476
# [170]	valid_0's binary_logloss: 0.0750556
# [171]	valid_0's binary_logloss: 0.0751503
# [172]	valid_0's binary_logloss: 0.0752425
# [173]	valid_0's binary_logloss: 0.0752184
# [174]	valid_0's binary_logloss: 0.0751875
# [175]	valid_0's binary_logloss: 0.0751248
# [176]	valid_0's binary_logloss: 0.0751503
# [177]	valid_0's binary_logloss: 0.075111
# [178]	valid_0's binary_logloss: 0.0751837
# [179]	valid_0's binary_logloss: 0.0750736
# Early stopping, best iteration is:
# [169]	valid_0's binary_logloss: 0.0750476

# %% [markdown]
# # 线下验证

# %%
for i in range(10):
    pred = [int(x) for x in np.where(np.array(pred_y_check) >= i/10.0,1,0)]
    scores = f1_score(true_y_check,pred)
    print(i, scores)
# Out:
# 0 0.13423526311165773
# 1 0.7694915254237288
# 2 0.7989886219974716
# 3 0.8128772635814889
# 4 0.8114525139664804
# 5 0.7932797662527392
# 6 0.7805243445692884
# 7 0.7602792862684251
# 8 0.7135842880523732
# 9 0.6159355416293644

# %%
for i in range(10):
    pred = [int(x) for x in np.where(np.array(pred_y_check) >= i/10.0,1,0)]
    scores = f1_score(true_y_check,pred)
    print(i/10.0, scores)
# Out:
# 0.0 0.13423526311165773
# 0.1 0.7694915254237288
# 0.2 0.7989886219974716
# 0.3 0.8128772635814889
# 0.4 0.8114525139664804
# 0.5 0.7932797662527392
# 0.6 0.7805243445692884
# 0.7 0.7602792862684251
# 0.8 0.7135842880523732
# 0.9 0.6159355416293644

# %%
pred_y_check
# Out:
# [0.0032345727761327616,
#  0.9884558851957882,
#  0.8104581945975711,
#  0.0005730862931690259,
#  0.03921585515500031,
#  0.07008035357071751,
#  0.9954434549443654,
#  0.0007125613039335475,
#  0.9957619646769831,
#  0.0005030465697981762,
#  0.0006981610000848268,
#  0.0005448086213494328,
#  0.06899294208695088,
#  0.00046021057924613957,
#  0.0008252584370914179,
#  0.00042735897488710867,
#  0.0010917208531155758,
#  0.002637456620549911,
#  0.006543256702594257,
#  0.0012154519257235642,
#  0.00045596414307771824,
#  0.0013699487805427664,
#  0.0057835684396571226,
#  0.0009012502597672886,
#  0.03380109774391483,
#  0.018685107862311447,
#  0.5531085931191551,
#  0.0014206987649586322,
#  0.9773905802537705,
#  0.007559113146079031,
#  0.00042515859045689824,
#  0.0010662321702193606,
#  0.9929531080430652,
#  0.0005558161885551026,
#  0.08165493309672987,
#  0.0006899774024536996,
#  0.0002744959252014447,
#  0.00024006646971945302,
#  0.004678873184845266,
#  0.3815409100070065,
#  0.005047915550335809,
#  0.9658926342208741,
#  0.0003860178445033244,
#  0.00016586831229581785,
#  0.040637156137836625,
#  0.0009579199444004351,
#  0.0012251562302495818,
#  0.00037079151615451413,
#  0.0012152522065108562,
#  0.0012390720433608864,
#  0.006459439781462398,
#  0.0016819703104422846,
#  0.0008064686575399466,
#  0.0030800254061753777,
#  0.006297902590673759,
#  0.003072830767962206,
#  0.0006574637703000271,
#  0.0019480359911399662,
#  0.0030800254061753777,
#  0.0022419013424944956,
#  0.0013210260179177897,
#  0.018626588200527837,
#  0.962299001256182,
#  0.004722357029801263,
#  0.001253666842722985,
#  0.06488654657214901,
#  0.15567325621381786,
#  0.008658214992785076,
#  0.0018518374023676343,
#  0.001624228917469799,
#  0.002487687425111495,
#  0.0006296729699189739,
#  0.0006713719818826639,
#  0.0007823135001231067,
#  0.000995979720402063,
#  0.020305399952968747,
#  0.0008746335276075847,
#  0.0011222649393224436,
#  0.04957949024168926,
#  0.0161856014753242,
#  0.00016187214770715228,
#  0.9957619646769831,
#  0.000634632179524685,
#  0.9238266664056174,
#  0.005177547302206067,
#  0.001981821928213605,
#  0.003038694840853543,
#  0.0024827662805619495,
#  0.004497815726131404,
#  0.0017832550819427552,
#  0.0008533691498319277,
#  0.034019524238876366,
#  0.00044081823356352913,
#  0.0003805775372541,
#  0.008705188978178093,
#  0.001159826091038679,
#  0.003260045851263531,
#  0.018626588200527837,
#  0.0016555279338984076,
#  0.0008001603332230138,
#  0.0006517407445827102,
#  0.0019525529604089151,
#  0.0029513351823909897,
#  0.0016014125314674455,
#  0.007323035571397853,
#  0.06604014291599429,
#  0.00035682936909659776,
#  0.01698483460944852,
#  0.0005812522094549133,
#  0.015430982591510376,
#  0.0024299692501341293,
#  0.0016950054323217048,
#  0.0016203730192340968,
#  0.00025208663552334873,
#  0.0007968207177102413,
#  0.008960536521190016,
#  0.0006773650075102579,
#  0.0037145349634995634,
#  0.0004124190651924915,
#  0.0021493944503184594,
#  0.0033604023512722398,
#  0.0012267457274918994,
#  0.00029373502643081196,
#  0.00610455426385422,
#  0.9719845279621406,
#  0.002754877124334186,
#  0.14951141578843993,
#  0.0012389199315555766,
#  0.000163435083132732,
#  0.015258240772116105,
#  0.0005359200223467502,
#  0.9063586584436485,
#  0.0010121782117977725,
#  0.0003382656357565009,
#  0.0007190648043328111,
#  0.033191941422735606,
#  0.002622524188230771,
#  0.2135141760672986,
#  0.3060086893423452,
#  0.0021160751944647696,
#  0.00030328723534354816,
#  0.00803827861633388,
#  0.0011677920307372005,
#  0.06849587761958605,
#  0.0002447302920407261,
#  0.0006503435635768195,
#  0.0015047933142086714,
#  0.00016006093328770096,
#  0.0016649374724571962,
#  0.05630429854398011,
#  0.0032784599770285987,
#  0.0015496789931817652,
#  0.0005707143078070774,
#  0.0017399398936418496,
#  0.00024901485977747896,
#  0.0007077093162689786,
#  0.002292060141565145,
#  0.0032899712981650105,
#  0.00019646743555797145,
#  0.0007189446041429078,
#  0.00043013583915037245,
#  0.006911486405224857,
#  0.00029464105128378554,
#  0.0003471076304975809,
#  0.0007468955861123839,
#  0.00150154961245145,
#  0.00023376662254790274,
#  0.9957619646769831,
#  0.0004427198319105199,
#  0.0004007241473886425,
#  0.0016258175628436676,
#  0.0019449978519760613,
#  0.0007560557008458618,
#  0.0018705468515474444,
#  0.005657644297491189,
#  0.0014254113381111106,
#  0.27976202045265874,
#  0.0047508353933375025,
#  0.0003967039213472591,
#  0.004281183791880987,
#  0.000630538254924013,
#  0.0009251407086562506,
#  0.0004235581203569876,
#  0.0004272566700588018,
#  0.006454417546922693,
#  0.000536040236426208,
#  0.00019410211201326057,
#  0.00043970676873982033,
#  0.00043169567169744415,
#  0.01694840499504007,
#  0.0009860830433102903,
#  0.00432652826268107,
#  0.052008080479684964,
#  0.0097368756218384,
#  0.0027750030280078164,
#  0.0008589623375727893,
#  0.00048312068289801897,
#  0.0005191668999710382,
#  0.9954434549443654,
#  0.0005352834822339063,
#  0.0007223758297510448,
#  0.047817257941055964,
#  0.0008977963846557555,
#  0.0016444687987632618,
#  0.0005741079128447907,
#  0.0006127785275132754,
#  0.002767662963029447,
#  0.009675792416519927,
#  0.0016285919522934034,
#  0.01787608740212274,
#  0.7624083459520268,
#  0.9043783662079928,
#  0.000330382897729073,
#  0.0042333486680170025,
#  0.005600436748055576,
#  0.0003756629724877679,
#  0.003936054706293607,
#  0.5989318193522932,
#  0.0013339109818259437,
#  0.00018474479616415265,
#  0.003174818488853957,
#  0.01600727027318876,
#  0.00047849531215863667,
#  0.0001403988879486466,
#  0.000812973282424159,
#  0.0008225370626372584,
#  0.011388519167877493,
#  0.002709295931047197,
#  0.005006269659796268,
#  0.005338332325368565,
#  0.0005417097866096567,
#  0.000320663001642871,
#  0.0012200618648737654,
#  0.0012924274100600886,
#  0.000252168621104078,
#  0.0027371319617947813,
#  0.0010296989409648754,
#  0.00022365794453054727,
#  0.003753065905525344,
#  0.0006503435635768195,
#  0.000767153766820774,
#  0.9954434549443654,
#  0.0020264281563279643,
#  0.0030632237082323065,
#  0.001527436971377842,
#  0.002124339156000775,
#  0.002121609973948679,
#  0.00827824302673942,
#  0.00037953672307887415,
#  0.0061246769936354455,
#  0.00015071540021274112,
#  0.003959453356345474,
#  0.0004142609555641586,
#  0.03136663738093761,
#  0.0003482197895905166,
#  0.6858177897338656,
#  0.03686265619048598,
#  0.000458045272793499,
#  0.0021469572649658185,
#  0.0017729661768376278,
#  0.6847006270411716,
#  0.10798057234092248,
#  0.25539542248446667,
#  0.0011059844646174708,
#  0.016426364295107847,
#  0.006188149967458815,
#  0.0004677347888495528,
#  0.0022748129405181926,
#  0.0050642338881014435,
#  0.0004110695788973887,
#  0.00037178841243723287,
#  0.9957619646769831,
#  0.0005620385532389728,
#  0.005238519706443942,
#  0.0001289970519022557,
#  0.0008936452955598796,
#  0.0015058842271147726,
#  ...]

# %%
train['content'].map(lambda x:len(list(str(x))))
# Out:
# 0        26
# 1         2
# 2         7
# 3        15
# 4         7
#          ..
# 11993    19
# 11995    15
# 11996    62
# 11997    16
# 11998    17
# Name: content, Length: 10619, dtype: int64

# %%
a = set(train['level_1'])

# %%
zip(a, range(len(a)))

# %%
# 类别 cat 特征
train['level_1'].map(lambda x: dict(zip(a, range(len(a))))[x])
# Out:
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 11993    5
# 11995    3
# 11996    4
# 11997    4
# 11998    4
# Name: level_1, Length: 10619, dtype: int64
