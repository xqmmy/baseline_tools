# %%
import json
import random
import numpy as np
from bert4keras.backend import keras, search_layer, K
from bert4keras.tokenizers import Tokenizer
from bert4keras.models import build_transformer_model
from bert4keras.optimizers import Adam
from bert4keras.snippets import sequence_padding, DataGenerator
from bert4keras.snippets import open
from keras.layers import Lambda, Dense
from keras.utils import to_categorical
import pandas as pd
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %%
num_classes = 2
maxlen = 128
batch_size = 32
config_path = '../model/chinese_wwm_ext_L-12_H-768_A-12/bert_config.json'
checkpoint_path = '../model/chinese_wwm_ext_L-12_H-768_A-12/bert_model.ckpt'
dict_path = '../model/chinese_wwm_ext_L-12_H-768_A-12/vocab.txt'


train_frac = 0.01  # 标注数据的比例
use_vat = True  # 可以比较True/False的效果

# %%
def load_data(valid_rate=0.3):
    train_file = "../data/train.csv"
    test_file = "../data/test.csv"
    
    df_train_data = pd.read_csv("../data/train.csv")
    df_test_data = pd.read_csv("../data/test.csv")
    
    train_data, valid_data, test_data = [], [], []
    
    for row_i, data in df_train_data.iterrows():
        id, level_1, level_2, level_3, level_4, content, label = data
        
        id, text, label = id, str(level_1) + '\t' + str(level_2) + '\t' + \
        str(level_3) + '\t' + str(level_4) + '\t' + str(content), label
        
        if random.random() > valid_rate:
            train_data.append( (id, text, int(label)) )
        else:
            valid_data.append( (id, text, int(label)) )
            
    for row_i, data in df_test_data.iterrows():
        id, level_1, level_2, level_3, level_4, content = data
        
        id, text, label = id, str(level_1) + '\t' + str(level_2) + '\t' + \
        str(level_3) + '\t' + str(level_4) + '\t' + str(content), 0
        
        test_data.append( (id, text, int(label)) )
    return train_data, valid_data, test_data

# %%
train_data, valid_data, test_data = load_data(valid_rate=0.3)

# %%
train_data
# Out:
# [(0,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\t使用移动手动电动工具,外接线绝缘皮破损,应停止使用.',
#   0),
#  (1, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t一般', 1),
#  (2,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t消防知识要加强',
#   0),
#  (3,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防通道有货物摆放 清理不及时',
#   0),
#  (4,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门打开状态',
#   0),
#  (5,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t防爆柜里面稀释剂，机油费混装',
#   0),
#  (6,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已经整改',
#   1),
#  (7,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t逃生通道有货物阻挡。',
#   0),
#  (8,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t已整改',
#   1),
#  (9,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道黄色线标脱落，已及时重新标好线标。',
#   0),
#  (11,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道有堆放货物',
#   0),
#  (12, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t灭火器没检查，已检查，已整改', 0),
#  (17,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堆满货物',
#   0),
#  (18, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t未进行消防演练', 0),
#  (19,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t新员工不能熟练掌握消防安全知识，已培训教育',
#   0),
#  (21,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t巡查中发现紧急疏散指示灯故障，已经更换',
#   0),
#  (22,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散指示灯故障',
#   0),
#  (23,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散标志没有',
#   0),
#  (24,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t未组织员工进行应急逃生培训                         整改措施：组织员工进行安全消防、应急逃生、消防器材的实际使用培训并做记录。',
#   0),
#  (25,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t冲压5号机插座存在烧浇现象，及时更换。',
#   0),
#  (26,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插头应按规定正确接线',
#   1),
#  (28,
#   '交通运输类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t一般隐患',
#   1),
#  (29,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t一楼四号常闭式防火门，经常被杂物堆放，责令清洁部，清理干净保持防火门关闭状态',
#   0),
#  (33,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t仓库门上安全指示没有灯，已更换安装完毕。',
#   0),
#  (34,
#   '工业/危化品类（选项）—2016版\t（七）重点监管工艺及场所\t5、涉爆粉尘作业\t20、粉尘爆炸危险场所除尘系统、金属设备，以及金属管道、支架、构件、部件等防静电措施应符合GB12158的要求，电气设备的保护接地应符合GB50058的要求，除尘系统的风管不得作为电气设备的接地导体。\t风管已安装火花探测仪及喷淋',
#   1),
#  (35, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t没有安装防爆灯，已整改。', 0),
#  (36, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器压力不足', 0),
#  (38,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堆积杂物，已清理',
#   0),
#  (41,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施、器材和消防安全标志是否在位、完整；',
#   1),
#  (44,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源乱拉乱接',
#   0),
#  (45,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况。\t干粉灭火器有失压，过期。',
#   0),
#  (46,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t部分安全出口指示标志脱落。',
#   0),
#  (47,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防栓门口被桶装水堵塞。',
#   0),
#  (49,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t12号机后边通道有一卡板货压线',
#   0),
#  (52,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t一栋四楼B消防通道堆放杂物',
#   0),
#  (53,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t灭火器过期',
#   0),
#  (54,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t生产车间通道具占用',
#   0),
#  (55,
#   '商贸服务教文卫类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育\t1、制定安全教育培训计划，确保全员参与培训，并建立安全培训档案。\t没有制定安全教育培训计划',
#   0),
#  (56,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防标志不明晰',
#   0),
#  (57,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t2个有过期，已清理，重新补上新的',
#   0),
#  (58, '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器过期', 0),
#  (60,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t有杂物',
#   0),
#  (61,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t临时堆放货物，已整改',
#   0),
#  (65,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t地标不亮，立即整改。',
#   0),
#  (66,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道临时堆放杂物',
#   0),
#  (67,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道堵塞',
#   0),
#  (68,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t应急灯不亮，换新',
#   0),
#  (71,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道有货物',
#   0),
#  (72,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t未设放老鼠贴',
#   0),
#  (75,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t2、配电箱内裸露带电体应设置屏护板，电气开关应安装在不燃材料上。\t电箱绝缘盖板缺失：已安排电工及时整改',
#   0),
#  (76,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t整改完毕',
#   1),
#  (78,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t有一盏应急照明灯故障，需更换',
#   0),
#  (81,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\tG1栋2楼车间内工作台照明电源线套管破损（已整改）。',
#   0),
#  (82,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t有两个配电箱门未张贴“当心触电”安全警示标志。立即张贴',
#   0),
#  (84,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t三车间一电箱上摆放杂物',
#   0),
#  (85,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t疏散通道。',
#   1),
#  (86,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t1、安全警示标志\t1、应当在易燃、易爆、腐蚀、粉尘、高温、毒物、辐射、电力设施、可能发生坠落、挤压以及其他各类有较大危险因素的工作场所和设备、设施上设置明显的安全警示标志。\t安全警示标志不清晰，已整改',
#   0),
#  (87,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (88,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t配电室门未关闭，',
#   0),
#  (89,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t安全警示标志太糊，有损坏',
#   0),
#  (91,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有杂物堵塞，已经清理，通道畅通',
#   0),
#  (92,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\t员工没配戴眼罩，已整改',
#   0),
#  (93, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期', 0),
#  (95,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱附近有杂物，需清理，搬离，',
#   0),
#  (96,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t检查馥轩厨房防毒面具过期。北区三楼精英教育城喷淋头破裂。',
#   0),
#  (97, '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t一般隐患', 1),
#  (98,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t立式注塑机旁墙壁排气扇无末端漏电保护开关',
#   0),
#  (99, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防通道不畅通 ', 0),
#  (100,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t消防栓缺少消防管接头',
#   0),
#  (101,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道货车架子堵塞，已经清理走',
#   0),
#  (102,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (103,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t机器设备放置纸板属于已燃物品',
#   0),
#  (104,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\tABC灭火器压力不足，修理后正常',
#   0),
#  (108,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t货物比较多，来不及上架，通道有点堵',
#   0),
#  (109,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t三楼保安室方向防火门处于半敞开状态，责令立即整改',
#   0),
#  (110, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器过期已更换新', 0),
#  (111,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t经巡查三栋4楼安全出口灯撞坏，相关人员立即通知维修人员重新更换新的安全出口灯。',
#   0),
#  (112,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况。\t危化品分装瓶未张贴安全标签',
#   0),
#  (114,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t未及时填写消防器材点检表',
#   0),
#  (116,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t乐群楼17楼应急灯无电源',
#   0),
#  (117, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t现已规定仓库几能放几跺，否则开除', 0),
#  (118, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t下雨，厂房墙面垮倒', 0),
#  (119,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t仓库门口应急灯不亮',
#   0),
#  (120,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口堵塞',
#   0),
#  (121,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t有3个灭火器压力偏底，要更换',
#   0),
#  (122,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有一处未见指示灯',
#   0),
#  (123,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t占用、堵塞、封闭',
#   0),
#  (125,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t5月份灭火器没有检查。',
#   0),
#  (126,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电箱上有杂物',
#   0),
#  (128,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱旁放了几个纸箱',
#   0),
#  (129,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物乱堆放，阻塞逃生通道',
#   0),
#  (130,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\t未安装漏电保护开关',
#   0),
#  (131,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t缺安全出口标识',
#   0),
#  (132,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t车间照明灯有一根不亮，影响工作视线',
#   0),
#  (133,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改',
#   1),
#  (134,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散通道有占用',
#   0),
#  (135,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口无指示标志，已经整改',
#   0),
#  (136,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全标志掉落；立即整改，张贴完好。',
#   0),
#  (137, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器压力不足，现已更换', 0),
#  (138,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t照明灯不亮',
#   0),
#  (139,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道不畅通，堆放杂物\n消防灭火器未正确放置\n消防水管没安装好',
#   0),
#  (140, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器记录卡片未及时检查', 0),
#  (142,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t电池仓库货架接地不规范，需螺栓连接或焊接 压接',
#   0),
#  (143,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；',
#   1),
#  (145,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道有货物堆放',
#   0),
#  (146,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t一楼A4区灭火器下面堆放杂物',
#   0),
#  (148,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t安全出口堵塞',
#   0),
#  (149,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有两个灭火器过期，已重新更换新的。',
#   0),
#  (150, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火气配备不足', 0),
#  (152,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t有',
#   1),
#  (153,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t标志',
#   1),
#  (154,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t有些地标线磨损不清楚',
#   0),
#  (155,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t部分灭火器材过期未能正常使用。',
#   0),
#  (156,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防安全通道堵塞',
#   0),
#  (158,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t灭火器失交效',
#   0),
#  (159,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t周转车堵塞消防通道',
#   0),
#  (160,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t货物阻挡通道',
#   0),
#  (161,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t本单元重新整改装修，装修后消防门摆放了较大的绿植物',
#   0),
#  (162,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t标识有脱落',
#   0),
#  (163,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道应急灯未连通电源',
#   0),
#  (164,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有障碍',
#   0),
#  (167, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器未合理分布', 0),
#  (170,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t1楼应急灯坏，已更换',
#   0),
#  (172,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓漏水',
#   0),
#  (173,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t三楼仓库一具灭火器已过期失效',
#   0),
#  (174,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t临时用电没有安装漏电保护装置，立即安装',
#   0),
#  (175,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t一年级办公室照明灯有损坏',
#   0),
#  (176,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵塞消防通道',
#   0),
#  (177,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t用电安全警示标志已经张贴',
#   0),
#  (178,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口堵塞',
#   0),
#  (179,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器有损坏，立即购买新的更换。',
#   0),
#  (180, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t已整改', 1),
#  (181,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t没有保存完整的事故隐患排查治理档案',
#   0),
#  (183,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (184,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t2019年全员安全再教育未实施。',
#   0),
#  (185, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t排查中发现有一个灭火器失效', 0),
#  (186, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器失效', 0),
#  (187,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道有隐患',
#   0),
#  (188,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间消防通道有被货物堵塞，现已作出整改',
#   0),
#  (190,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t大厦东面外围楼梯角落有杂物堆放，即时叫人搬离',
#   0),
#  (191,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t楼梯口堆有杂物,立即清除.',
#   0),
#  (192,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯损坏',
#   0),
#  (193,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000\t宿舍楼下临时停放电车',
#   0),
#  (194,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t补充2个新的灭火器',
#   0),
#  (195,
#   '商贸服务教文卫类（基础）—2016版\t（三）安全管理规章制度\t1、安全管理责任制\t1、建立、健全安全管理责任制，明确各岗位的责任人员、责任范围和考核标准等内容。\t建立、健全安全管理责任制，明确各岗位的责任人员、责任范围和考核标准等内容。',
#   1),
#  (196,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道堵塞，现已整改。',
#   0),
#  (199, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t消防检查表未及时填写', 0),
#  (200,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t有货物堆放',
#   0),
#  (201, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器未点检', 0),
#  (203, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t9层东区放杂物', 0),
#  (205,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线线皮破损',
#   0),
#  (206,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道货物已清理已畅通',
#   1),
#  (208,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t新员工有一人未完成班组级安全教育，就安排上岗。',
#   0),
#  (209,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况。\t电线裸露，已整改',
#   0),
#  (210,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t没有张贴安全标识',
#   0),
#  (212,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\tA栋五楼吹樽部1号吹瓶机维修未挂警示牌，现场已整改。',
#   0),
#  (215,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t指示灯不亮',
#   0),
#  (216,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。',
#   1),
#  (218,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱未张贴“当心触电”安全警示标志',
#   0),
#  (221,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\tC型钢压型机器轴承破、购新轴承更换',
#   0),
#  (222,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火卷帘下堆放物品',
#   0),
#  (223, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t安全出口上锁', 0),
#  (224,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器被遮挡，已整改；消防栓底下和周围堆积物品，已整改。',
#   0),
#  (225,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门门锁故障',
#   0),
#  (226,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t发现的问题：安全通道放有小推车  解决办法：马上移走小推车，并告诫员工物品堵消防通道的隐患风险',
#   0),
#  (227,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t应急照明灯坏了，已经更换',
#   0),
#  (228,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t已整改完毕。',
#   1),
#  (229,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间通道不畅通',
#   0),
#  (230,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t楼梯消防门闭门器损坏',
#   0),
#  (231,
#   '交通运输类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心有电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t普天充电站一处配电箱生锈破损线路存在漏电隐患，现已按要求整改完成。',
#   0),
#  (232,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t增加标志触电安全，和检查设备线端。',
#   0),
#  (233,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t安全生产管理制度、培训演练、职责书、隐患整改制度及应急方案，均已完善',
#   0),
#  (234, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t发现2个灭火器气压不足。', 0),
#  (235,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道堆放杂物',
#   0),
#  (237,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口堵塞',
#   0),
#  (238,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t没有疏散通道、安全出口设置应急照明灯和疏散指示标志',
#   0),
#  (239,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未制定2019年年度培训计划',
#   0),
#  (240,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急通道上有临时堆放货物，阻碍通道，造成隐患。',
#   0),
#  (241,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t应急照明灯不亮     己整改',
#   0),
#  (242,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t有两个电源开关接触不良，已购买更换',
#   0),
#  (243,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火卷帘处堆放纸箱及货物',
#   0),
#  (244,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t办公室走廊安全通道有堆放货物现象，存在安全隐患，已现场整改。',
#   0),
#  (245,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t设备作业区域废料未清扫',
#   0),
#  (247,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t消防栓的玻璃门没有密合好',
#   0),
#  (248,
#   '三小场所（现场）—2016版\t（二）电气安全\t2、电气设备、设施的金属接地或接零\t1、电气设备金属外壳需接地保护。\t有一处电线裸露,将裸露电线套管。',
#   0),
#  (249,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯修理效果不佳',
#   0),
#  (250,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t堵塞',
#   0),
#  (253,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t点检表欠缺，未点检。',
#   0),
#  (255,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道堵塞，通道堆放物品',
#   0),
#  (256,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t二楼包装车间有一通道货物压黄线',
#   0),
#  (257, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t用火、用电有违章情况', 0),
#  (258,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t插头坏',
#   0),
#  (259,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t全安通道堆放有杂物',
#   0),
#  (260,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t9、消防（控制室）值班情况和设施运行、记录情况；\t落实安全记录',
#   1),
#  (263,
#   '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t9、消防（控制室）值班情况和设施运行、记录情况。\t消防控制室无人值班',
#   0),
#  (264,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t注塑部一楼车间消防通道被临时堆放的货物堵塞，马上整改完成。',
#   0),
#  (266,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电房内有少许杂物。',
#   0),
#  (267,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\tD仓库配电箱下方堆放杂物',
#   0),
#  (269,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t9:35 宿舍区域多个灭火器箱上 放有鞋子',
#   0),
#  (271,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t仓库货物堆放不够有条理，存在隐患',
#   0),
#  (272, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改', 1),
#  (274,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；\t配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；',
#   1),
#  (275,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t知识掌握较少',
#   0),
#  (277,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散应急灯不亮',
#   0),
#  (278,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t空压机皮带以受损，立即更换。',
#   0),
#  (279,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t更换新的灭火器，检查灭火器的作用',
#   0),
#  (281,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯不亮，立即整改',
#   0),
#  (282,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口被货物堆积',
#   0),
#  (283,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t二楼安全出口被阻塞',
#   0),
#  (284,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t员工安全教育没有及时培训，已整改',
#   0),
#  (285,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t个别标识掉落',
#   0),
#  (286,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有隐患',
#   1),
#  (288,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t气瓶防倾倒设施未使用',
#   0),
#  (289,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道上摆放有产品，存有安全隐患。已整改。',
#   0),
#  (290, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改', 1),
#  (291,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t未建立建全事故隐患排查治理纪录档案',
#   0),
#  (292,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全出口堵塞',
#   0),
#  (293,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯不亮   已重新按装新的应急照明灯   已整改',
#   0),
#  (295,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t一楼车间裁床电箱内放有废手套等杂物',
#   0),
#  (296, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防车通道有杂物堆积', 0),
#  (298,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下、周围堆放杂物',
#   0),
#  (299,
#   '工业/危化品类（选项）—2016版\t（五）特种设备\t5、起重机械\t3、设备上应悬挂安全操作规程、交接班记录和安全检查记录。\t操作行车处未见安全操作规程',
#   0),
#  (301,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下有杂物，现已清除',
#   0),
#  (304,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全标志不完整',
#   0),
#  (305,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯失效',
#   0),
#  (306,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t砂带机安全防护装置螺丝脱落',
#   0),
#  (310,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱没有贴危险标识',
#   0),
#  (311,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t线头没包好',
#   0),
#  (312,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t未安装漏电开关',
#   0),
#  (313,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t安全通道堆放货物，存在安全隐患',
#   0),
#  (315,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t2、手持式电动工具、移动电器等设备应优先选用额定剩余动作电流不大于30mA、一般型（无延时）的剩余电流保护装置；潮湿场所的电气设备使用16-30mA动作电流、无延时；在金属物件上作业的手持电动工具使用10mA动作电流、无延时漏电保护开关。\t电池随处进行充电，未按照公司《电池安全防护规范》进行充电及记录。',
#   0),
#  (317,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一楼全贴合，饮用水空桶挡住灭火器箱',
#   0),
#  (318,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施位置被占用',
#   0),
#  (319,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防水龙头破损',
#   0),
#  (320, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t个别灭火器过期', 0),
#  (321,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电盒上没有“注意有电”安全提示标识',
#   0),
#  (323,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t因老化原因部分通电式安全出口标志不亮',
#   0),
#  (326,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急指示灯损坏，已更换',
#   0),
#  (328,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口通道后门卷闸门不能关闭',
#   0),
#  (329,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不畅通',
#   0),
#  (330,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有临时堆放货物   ',
#   0),
#  (331,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器停放过长粉不足，已充足，',
#   0),
#  (332,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t有1瓶灭火器过期，已更换。',
#   0),
#  (334,
#   '工业/危化品类（选项）—2016版\t（五）特种设备\t2、压力容器\t3、安全阀有有效的检验报告及铅封标记。压力表有有效的检定证书及标记。\t有车间压力表快到期/及时安排人员在有效期内进行更换',
#   0),
#  (337,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t检查发现朝阳市场A座综合楼楼梯大门灭火器位置摆放杂物，防碍其正常使用，要求管理人员立即整改（当天已整改完毕）。',
#   0),
#  (338,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t安全疏散通道堵塞',
#   0),
#  (339,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t ',
#   1),
#  (341,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t消房通道放物品',
#   0),
#  (342,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道有杂物',
#   0),
#  (343,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t观海楼三楼通道有一个疏散指示，出现故障报警。',
#   0),
#  (345,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道被档住；',
#   0),
#  (346,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t现场插座松动',
#   0),
#  (347,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防器材。以整改',
#   1),
#  (348,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t缺警示标识牌',
#   0),
#  (349,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t配电室长度超过7m时，没有设有两个出口',
#   0),
#  (350,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\tC栋一楼封边机操作人员未佩戴劳动防护用品（耳塞）',
#   0),
#  (351,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯不亮',
#   0),
#  (352,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (353, '商贸服务教文卫类（选项）—2016版\t（九）特种设备\t2、压力容器\t1、安全阀有有效的检验报告及铅封标记。\t检查记录不完善', 0),
#  (355,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t消防安全标志不全',
#   0),
#  (357,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t电动车挡住消防器材',
#   0),
#  (358,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t地库防火门，，，有杂物，已清理、',
#   0),
#  (359,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器配备不足',
#   0),
#  (361,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道划线模糊',
#   0),
#  (362,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道，疏散指示标志不明确',
#   0),
#  (363, '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t会议记录', 1),
#  (364,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t应急照明灯损坏',
#   0),
#  (367,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t个别应急灯不亮，已及时修复',
#   0),
#  (368,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t安全通道门未打开',
#   0),
#  (369,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t“当心触电”安全警示标志脱落',
#   0),
#  (370,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器已过期，现场已更换。',
#   0),
#  (371,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有物品占用。',
#   0),
#  (374, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t无定期进行应急演练', 0),
#  (377,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓玻璃门破损',
#   0),
#  (378,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堆放货物',
#   0),
#  (379,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t2、配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。\t配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。',
#   1),
#  (380,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t19年2月份的灭火器点检表未点检。立即点检。',
#   0),
#  (383,
#   '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t没有系统的安全培训记录',
#   0),
#  (384,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\t水吧旁边一个插座没有接地线',
#   0),
#  (385,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵住安全通道',
#   0),
#  (386, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器未定期检查', 0),
#  (387,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门关闭',
#   0),
#  (388,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t配电箱内控制开关无标示器件标明被控设备编号及名称，配电箱金属箱门与箱体无采用软铜线做电气连接',
#   0),
#  (389,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门未常闭',
#   0),
#  (390, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t通风状态有待改善', 0),
#  (391,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防水带捆绑不正确且老化，需更新',
#   0),
#  (392,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道出口堵塞。',
#   0),
#  (393,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t四楼作业通道堆放货物疏散通道不畅通',
#   0),
#  (394,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t一个应急灯不亮，一个安全出口指示灯不亮',
#   0),
#  (396,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t安全警示标志少',
#   0),
#  (397, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器不够，新增几个', 0),
#  (399,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有一灭火器指针已到下限',
#   0),
#  (400,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道放货物',
#   0),
#  (401,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间通道被货物堵塞',
#   0),
#  (402,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间包装台部分区域未接地线存在安全隐患，已及时处理并整改完成。',
#   0),
#  (403,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材未按规定位置摆放',
#   0),
#  (404,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有物品挡在消防通道口，立即清走',
#   0),
#  (405,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t有隐患',
#   1),
#  (406,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱(柜)门未张贴有“当心触电”安全警示标志',
#   0),
#  (407,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t仓库安装防爆风机',
#   0),
#  (408, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防箱下有杂物', 0),
#  (409,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t电梯出口有货物存放，已立即整改',
#   0),
#  (410, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志', 1),
#  (414,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有及时组织应急演练，2019年11月25日组织了应急演练',
#   0),
#  (417, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t ', 1),
#  (421,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t地面安全通道标识有缺损，',
#   0),
#  (423,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t进出口通道堵塞，已责令相关厂商立即清疏。',
#   0),
#  (424, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t己整改', 1),
#  (425,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t7月灭火器，没检查',
#   0),
#  (427,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有一盏应急照明灯损坏，已立即更换整改。',
#   0),
#  (428, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改', 1),
#  (429, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t车间个别灭火器被挡', 0),
#  (431,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t出口应急灯坏，已更新',
#   0),
#  (432,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (433,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (435,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t未建立应急预案',
#   0),
#  (436,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门没关上',
#   0),
#  (437, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t未仔细检查', 0),
#  (438,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道临时堆放货物',
#   0),
#  (439,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t设置的当心触电标志脱落，立即更换新的标志',
#   0),
#  (441,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间1个插座未装漏电保护装置',
#   0),
#  (444,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t1、特种设备档案\t1、特种设备(及安全附件)检测报告齐全，并在有效期内。运行记录和维修保养记录齐全。\t设备保养未及时做记录',
#   0),
#  (445,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t每日防火巡查不全面，需要立即整改',
#   0),
#  (446,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (447,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t个别楼层防火门闭门器坏，及时联系工程部更换新品',
#   0),
#  (449,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不畅通',
#   0),
#  (450,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t车间一处安全疏散指示标志脱落，需重新张贴固定到位以示警醒。',
#   0),
#  (451,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t车间工业风扇未接地保护',
#   0),
#  (452,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有一安全疏散标识模糊不清',
#   0),
#  (453,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t金属电箱与箱子门无软铜线连接，已安装编织软铜线做电气连接，已完成整改。',
#   0),
#  (454, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t没有演了', 0),
#  (456,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t2019年8月14日检查报警器未及时点检！',
#   0),
#  (459,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防出口灯损坏',
#   0),
#  (461,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物挡住通道',
#   0),
#  (462,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t一处落地扇电源线未使用双层绝缘电线。',
#   0),
#  (463,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t未张贴安全警示标志',
#   0),
#  (465,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t插座相接，用电有隐患',
#   0),
#  (466,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器翻倒',
#   0),
#  (467,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t常闭式防火门没有处于关闭状态',
#   0),
#  (468,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t未检查灭火器材配置及有效情况；',
#   0),
#  (469,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱、开关箱内有放置任何杂物，电器元件不可安装在可燃材料上',
#   0),
#  (470,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有即将过有效期，要求定期更换ABC干粉灭火器',
#   0),
#  (471,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t档案不建全',
#   0),
#  (473, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有一处失效', 0),
#  (474,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材被挡住',
#   0),
#  (475,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t没有召开复工安全例会',
#   0),
#  (477,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t物料摆放堵塞消防栓',
#   0),
#  (478,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散指示标志不合规，已更换。',
#   0),
#  (479,
#   '工业/危化品类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t3、安全管理机构和管理人员履职情况\t1、安全生产管理机构、安全生产管理人员依法履行安全生产管理职责（存在职业健康危害的单位，包括职卫管理机构及职卫管理人员）。\t人员变动从新签安全生产主体公示牌',
#   0),
#  (481,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼的右边楼梯口的应急灯损坏',
#   0),
#  (483,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t未保存安全会议记录',
#   0),
#  (484,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t赤湾港区21#小叉车灭火器点检表缺少8月份的检点记录',
#   0),
#  (486,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t办公室走道挂墙放置灭火器脱落。',
#   0),
#  (487,
#   '建筑施工类（选项）—2016版\t（十七）起重吊装\t2、实体安全\t5、起重吊装作业是否符合要求。\tB座二十三层铝模未使用料斗吊装',
#   0),
#  (488,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t技术部转角门口堆放了纸箱',
#   0),
#  (489,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t南区球车库消防栓水带腐蚀',
#   0),
#  (490,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有堆放杂物',
#   0),
#  (495,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t地上有坑',
#   0),
#  (496,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t产品堆放阻碍通道',
#   0),
#  (497,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t没有设置“当心触电”安全警示标志。',
#   0),
#  (498,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t部分开关盒无张贴“当心触电”安全警示标识牌，需立即整治。',
#   0),
#  (499,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全疏散指示标志',
#   1),
#  (500,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t老厂5栋2楼披锋房操作台防护挡板损坏',
#   0),
#  (501, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t卸油口盖静电接地线线头脱落', 0),
#  (502,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有废弃物阻挡部分通道，现已清理；有安全通道地标损坏，现已更换',
#   0),
#  (503,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防灭火器检查清洗',
#   1),
#  (504, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器内压不足', 0),
#  (507,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t紧急出口灯不亮了',
#   0),
#  (508,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散通道不畅通',
#   0),
#  (509,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t侧小门未安排安全出品指示标识，经整改后已经安装安全出口、应急灯标识。',
#   0),
#  (510,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t三楼镭射机没有安装红外线防护。',
#   0),
#  (511,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t16个消防安全应急灯故障，已及时更换。',
#   0),
#  (512,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接。\t已整改',
#   1),
#  (513,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t当心触电标志掉落',
#   0),
#  (514,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材过期，立即更换。',
#   0),
#  (515,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t已培训建档',
#   1),
#  (516,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物',
#   0),
#  (518,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t后楼梯口堆放临时货物。',
#   0),
#  (519,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t消防通道停放自行车',
#   0),
#  (520,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器失效',
#   0),
#  (521,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材大部分已过期或失效，立即购买新的灭火器。',
#   0),
#  (522, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t危化品暂放仓储存过量', 0),
#  (523,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道有时候有清洁阿姨堆砌了一些纸箱杂物，未及时挪开，已告知阿姨不要堆杂物。',
#   0),
#  (525,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好',
#   1),
#  (526,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t生产车间消防通道一处被物料占用。',
#   0),
#  (527,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物堵住前台通道',
#   0),
#  (528,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t卫生大扫除时挪动了灭火器，没有放回原来位置',
#   0),
#  (529,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t多余线未处理',
#   0),
#  (530,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t未能按时检查及签名记录',
#   0),
#  (531,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t杂物已全部清除整改',
#   1),
#  (532,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t通道标识线有磨损现象',
#   0),
#  (534,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t更衣室有一个烟感探头故障，已及时更换。',
#   0),
#  (535,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有一个灭火器过期，即购买',
#   0),
#  (536,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t有一个没有标示当心触电',
#   0),
#  (538, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t以学习，演练。', 1),
#  (539,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓阀门漏水（图1是消防栓漏水阀门，图2是已整改完毕）',
#   0),
#  (540,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\tB区2109房门口一个灭火器压力不够',
#   0),
#  (541,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有一瓶灭火器气压不够，已经更换',
#   0),
#  (545,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t公司经理上班发现本企业逃生通道货物堵塞，立即整改',
#   0),
#  (547,
#   '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t12、其他需要检查的内容。防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t筒仓消防设施维保记录卡缺少记录',
#   0),
#  (548,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t安全通道堆放货物',
#   0),
#  (549,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防通道有杂物',
#   0),
#  (550,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口堆有杂物。现已清理。',
#   0),
#  (551,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t已整改',
#   1),
#  (552,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防设施，器材安全标志不完整',
#   0),
#  (553,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口指示灯不亮。',
#   0),
#  (554, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t5、消防安全重点部位的人员在岗情况；\t消防设施阻塞', 0),
#  (555,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t焊锡工作台采用接线板接线，改为长期固定的电源插座。',
#   0),
#  (556,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全警示未到位   现已安排',
#   0),
#  (557,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t本月内的灭火器自检记录没有做，已补上。',
#   0),
#  (558,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t堆放杂物',
#   0),
#  (560,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t检查安全出口，疏散通道标志为荧光的，现已更换为通电带灯罩形。',
#   0),
#  (561,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t在些灭火器过期了',
#   0),
#  (563,
#   '建筑施工类（基础）—2016版\t（五）安全管理档案\t4、特种设备及操作人员管理记录\t3、各种特种设备的运行记录和维修保养记录齐全。\t1.4号塔吊运行记录填写过于简单。',
#   0),
#  (564,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t仓库人员将EC30款机柜放置于安全通道上',
#   0),
#  (566, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期', 0),
#  (569,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道安全出口指示牌故障，已经更换新的安全出口指示牌。',
#   0),
#  (573,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t偶尔会临时堆放货物',
#   0),
#  (574,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t2、设备设施的局部照明和移动照明工作灯使用安全电压，潮湿狭窄场所、金属容器内照明使用特低电压。\t仓库无灯 ，新安装防爆灯',
#   0),
#  (576,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t有占用',
#   0),
#  (579,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t已整改',
#   1),
#  (580,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t彩钢压瓦机电控箱未设置醒目的“小心有电”安全警示标志',
#   0),
#  (585,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t卸油区有树叶，已立即清理。',
#   0),
#  (586,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道有堵,已清理',
#   0),
#  (588,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物已整改',
#   0),
#  (589,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防栓堵塞',
#   0),
#  (590,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电度表安装在木板可燃物上面。',
#   0),
#  (591,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道黄色线标明不明显。',
#   0),
#  (592,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道堵塞变窄。',
#   0),
#  (593,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t灯坏，已修复',
#   0),
#  (595,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t消火栓前放置杂物，影响消防器材使用',
#   0),
#  (597,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t2、无铠装电缆在屋内明敷，水平敷设时，其至地面的距离不应小于2.5m；垂直敷设时，其至地面的距离不应小于1.8m。当不能满足上述要求时应有防止电缆机械损伤的措施。沿地敷设的电缆应穿钢管保护。穿管的内径不应小于电缆外径的1.5倍。\t砂轮机上方电源线裸露无套管保护。',
#   0),
#  (598,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t通道堆放货物，堵塞疏散通道',
#   0),
#  (599,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防疏散指示灯坏，需换新。',
#   0),
#  (600,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线三通盖损坏，立即整改',
#   0),
#  (603, '三小场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t员工未组织参加应急演练', 0),
#  (604, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器换新', 0),
#  (605,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t老化车间化学品未张贴安全标签；且未放置化学品专用仓库内',
#   0),
#  (606,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t检查电箱无防护栏，并更新警示标示，整改',
#   0),
#  (607,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道有货物堆积',
#   0),
#  (608,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t电箱无张贴有点危险标示',
#   0),
#  (610,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t用电插座距离货物太近，需拆除插座',
#   0),
#  (611,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t皮带轮未加防护照',
#   0),
#  (612,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间插座有破损现象',
#   0),
#  (615,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道堆放货物',
#   0),
#  (616,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t疏散通道有被占用情况，提出后已整改！',
#   0),
#  (617,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t常闭防火门一边未关闭',
#   0),
#  (618,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改',
#   1),
#  (619,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱上有杂物。',
#   0),
#  (620, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t未进行有限空间的演练', 0),
#  (624,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t3、消防设施、器材和消防安全标志是否在位、完整；',
#   1),
#  (625,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t巡查发现仓库外墙人行通道偏窗户处放了两叉板货，影响消防安全通道畅通事项，立即整改OK.',
#   0),
#  (626,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t员工安全培训会议，讲解用电安全，操机安全，防火安全，正确使用灭火器，站好年前最后一班安全岗',
#   1),
#  (627,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t插排电源没有放好 太乱 ',
#   0),
#  (628,
# ...
#   0),
#  (1188,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t车床操作无防护罩，不符合危险设备的安全，需整改',
#   0),
#  (1189,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\tB区3楼一单元的一个插座存在“一拖 N”情况，已整改。',
#   0),
#  (1190,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t大一班班级门口应急灯坏了',
#   0),
#  (1193,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t发现一个应急灯坏了，已更换',
#   0),
#  (1195, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t货物堆放不整齐，容易堵塞通道', 0),
#  (1196,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t电箱盖脱落',
#   0),
#  (1197,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t2、手持式电动工具、移动电器等设备应优先选用额定剩余动作电流不大于30mA、一般型（无延时）的剩余电流保护装置；潮湿场所的电气设备使用16-30mA动作电流、无延时；在金属物件上作业的手持电动工具使用10mA动作电流、无延时漏电保护开关。\t一处插座未安装漏电保护器。',
#   0),
#  (1198,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t部分插座老化，已经更换新插座',
#   0),
#  (1199,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t部分灭火器未按固定位置摆放',
#   0),
#  (1200,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t消防安全标志损坏',
#   0),
#  (1201,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改',
#   1),
#  (1202,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯不亮',
#   0),
#  (1203,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t机器安装漏电保护开关',
#   0),
#  (1204,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t例行检查时，发现能增加两个灭火器更好，就马上买回两个，已经补充到相应位置。',
#   0),
#  (1205,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散指示未整顿好',
#   0),
#  (1206,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口灯坏了',
#   0),
#  (1209,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t定期组织员工培训，消防安全培训',
#   0),
#  (1210,
#   '交通运输类（选项）—2016版\t（十）客运码头企业\t2、安全管理机构和人员\t1、设置安全生产管理机构或配备专职安全生产管理人员。\t安全处口为安装',
#   1),
#  (1212,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t已更换新的',
#   1),
#  (1213,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散指示标志    掉落',
#   0),
#  (1214,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道被小推车堵塞',
#   0),
#  (1215,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t杂物堆放',
#   0),
#  (1216,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t漏电开关损坏',
#   0),
#  (1217,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t仓库一个应急照明灯断电不亮，已经整改完毕。',
#   0),
#  (1218,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t照明损坏已修理',
#   0),
#  (1220,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t物品堵塞消防栓',
#   0),
#  (1222,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼与二楼厂房各有一处应急灯不灯，已马上更换',
#   0),
#  (1223, '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t1、临时用电必须经过审批。\t已整改', 1),
#  (1224,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t照明灯停电不亮，通道放置物品',
#   0),
#  (1225, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t未点检', 0),
#  (1227,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t安全生产记录不全',
#   0),
#  (1228,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t有地方没有地线',
#   0),
#  (1229,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t一楼机器档护没有安装',
#   0),
#  (1231,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急照明灯出现故障',
#   0),
#  (1232,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间有一个插座坏了，已现场整改。',
#   0),
#  (1233,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t2、无铠装电缆在屋内明敷，水平敷设时，其至地面的距离不应小于2.5m；垂直敷设时，其至地面的距离不应小于1.8m。当不能满足上述要求时应有防止电缆机械损伤的措施。沿地敷设的电缆应穿钢管保护。穿管的内径不应小于电缆外径的1.5倍。\t甲类仓库后可燃气体探测器电源线管脱落',
#   0),
#  (1235,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t新员工没有消防演练培训，存在隐患，园区联合进行消防演习培训，让所有员工掌握消防知识、灭火器的使用等',
#   0),
#  (1236,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t物品挡住灭火器箱',
#   0),
#  (1237,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t生产车间按安全出口指示牌数量不够，需加装；',
#   0),
#  (1238,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物堵塞安全出口通道',
#   0),
#  (1239,
#   '建筑施工类（基础）—2016版\t（九）安全检查\t1、定期检查\t1、日常巡查：工程项目部每天应结合施工动态，实行安全巡查。2、每周检查：总承包工程项目部应组织各分包单位每周进行安全检查。3、每月检查：总承包工程项目部应组织各分包单位每月对照《建筑施工安全检查标准》，至少进行一次定量检查。企业每月应对工程项目施工现场安全职责落实情况至少进行一次检查，并针对检查中发现的倾向性问题、安全生产状况较差的工程项目，组织专项检查。\t现场木锯电缆线拖地，未按要求架空。',
#   0),
#  (1241,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t2、灭火器应合理分布，无固定摆放并定期校验。',
#   1),
#  (1242,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t收发室前疏散指示灯故障，需更新。',
#   0),
#  (1243,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t防爆灯掉落',
#   0),
#  (1244, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t消防巡查记录更新延迟', 1),
#  (1245,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有隐患',
#   1),
#  (1247,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口，过道有货物堆积。当场已整改。',
#   0),
#  (1248,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t酒精瓶没有告知卡',
#   0),
#  (1251,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器材配置及有效情况。',
#   1),
#  (1253,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t货物堆放挡住前门消防灭火器',
#   0),
#  (1256,
#   '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t堆垛堆距没符合要求。宽度只有1.7米，实际要求宽度为2米',
#   0),
#  (1257,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防专用电话损坏',
#   0),
#  (1258, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t不符合五距要求', 0),
#  (1259,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不畅通',
#   0),
#  (1261,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堵塞',
#   0),
#  (1262,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼7号楼梯模板堵塞安全口处，人员无法正常迅速疏散逃生。',
#   0),
#  (1263,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t未在电池仓库内粘贴“严禁烟火 ”标志',
#   0),
#  (1265,
#   '商贸服务教文卫类（选项）—2016版\t（二）餐饮单位\t1、餐饮场所操作间\t1、灶具与可燃或难燃的墙壁、地板、家具之间应采取有效的防火隔热措施。\t灭火器未定期检查',
#   0),
#  (1266,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t货物撞倒灭火器，未及时放置原位。',
#   0),
#  (1267, '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t灯管损坏', 0),
#  (1268,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器已过期，已申请购买新灭火器',
#   0),
#  (1269,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道未使用黄色线表明，已经整改',
#   0),
#  (1270,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t春节长假后，后门口的应急照明灯坏了',
#   0),
#  (1271,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t火灾隐患的整改情况以及防范措施的落实情况不到位',
#   0),
#  (1273,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t放有杂物，已清理',
#   0),
#  (1274,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t三楼有一疏散指示牌不亮；已及时更换整改；',
#   0),
#  (1276,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t机床按钮损坏',
#   0),
#  (1277,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t部分新入人员未产加安全教育培训计划',
#   0),
#  (1278, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t已购置完毕', 1),
#  (1279, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线裸露', 0),
#  (1280,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t常闭式防火门闭门器失效，应更换新的闭门器',
#   0),
#  (1281,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞，立即处理',
#   0),
#  (1283,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t电房增加防火标识',
#   1),
#  (1284,
#   '工业/危化品类（基础）—2016版\t（一）消防验收\t1、消防验收文件\t1、取得消防验收文件意见书。\t厂房由于历史遗留问题，无消防验收批文；',
#   0),
#  (1286,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱未张贴“当心触电”安全标志，已经整改',
#   0),
#  (1287,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志不全',
#   0),
#  (1288,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改完成',
#   1),
#  (1289, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器量不足，已整改', 0),
#  (1290,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器没有定期校验',
#   0),
#  (1292,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t堆放纸箱处的防爆灯损坏',
#   0),
#  (1293,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t3、职业卫生培训\t1、对职业病危害严重的岗位的劳动者，进行专门的职业卫生培训，经培训合格后方可上岗作业。\t焊锡岗位无戴防尘口罩',
#   0),
#  (1294,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞  ',
#   0),
#  (1295, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t插头无地线，立即整改', 0),
#  (1296, '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器缺失一个，已立即整改', 0),
#  (1297,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散指示标志、应急照明设置不规范',
#   0),
#  (1299, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况', 1),
#  (1301,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t1、危险化学品从业单位通用要求\t5、可能产生易燃易爆气体的场所，必须设置可燃气体的检测和自动报警装置。\t没有自动报警装置',
#   0),
#  (1302,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t整改',
#   1),
#  (1303,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道不畅通',
#   0),
#  (1306,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t仓库里的灭火器被移动了，已整改',
#   0),
#  (1307,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t应急指示灯不亮',
#   0),
#  (1308,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t微波炉更改漏电插座',
#   0),
#  (1309,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯一个不亮，已整改',
#   0),
#  (1310,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t个别标识片贴的位置不合适，已重新贴到相应位置。',
#   0),
#  (1311,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施',
#   1),
#  (1312,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000\t五楼东，应急灯损坏',
#   0),
#  (1313,
#   '商贸服务教文卫类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t3、安全管理机构和管理人员配备及履职情况\t1、安全管理机构、安全管理人员配备及依法履行安全管理职责\t无安全主任',
#   0),
#  (1314,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t注塑技工未穿劳保鞋',
#   0),
#  (1315,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t4、职业卫生管理档案\t1、存在职业病危害的生产经营单位，须建立健全职业卫生档案资料。\t没有建立健全职业卫生档案资料',
#   0),
#  (1317,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处于打开状态',
#   0),
#  (1318,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t标识不清楚/脱落',
#   0),
#  (1319,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t部分通道堆放货物',
#   0),
#  (1320, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器压力不足。', 0),
#  (1321,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志不清楚，已整 改',
#   0),
#  (1322,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t没有建立事故隐患排查治理档案',
#   0),
#  (1323,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口、疏散通道旁堆放杂物',
#   0),
#  (1324,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t玻璃门不是防火\n\n现已安装防火门',
#   0),
#  (1325,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线裸露',
#   0),
#  (1326,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t没有',
#   1),
#  (1327,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散指示标志不清晰',
#   0),
#  (1328,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t二幢车间楼梯应急照明已坏',
#   0),
#  (1334,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t安全警示脱落   重新固定',
#   0),
#  (1335,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t1、建立并保存事故隐患排查治理档案。',
#   1),
#  (1336,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯坏',
#   0),
#  (1337,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器数量不足',
#   0),
#  (1338,
#   '工业/危化品类（选项）—2016版\t（七）重点监管工艺及场所\t7、锂电池生产或储存\t8、每块电池（电芯）的正（负）极位置必须有绝缘防止短路保护措施。\t不良品电池未归回入不良品区域',
#   0),
#  (1339,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱内掉有螺丝',
#   0),
#  (1340,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t1-2楼目前还处于装修阶段，暂未配备灭火器材',
#   0),
#  (1341,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t开关箱内放置了杂物',
#   0),
#  (1342,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t油漆部有台风扇连接线中间有接头，需要更换',
#   0),
#  (1343, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器老化', 0),
#  (1346,
#   '工业/危化品类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t2、分管负责人履职情况\t1、分管负责人依法履行安全管理职责（存在职业健康危害的单位需自查职业卫生履职情况）。\t最近一个季度没有组织安全演练',
#   0),
#  (1347,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道上有货物',
#   0),
#  (1348,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急照明灯有一个坏了',
#   0),
#  (1349, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器压力不正常', 0),
#  (1350, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期，存在隐患', 0),
#  (1351,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t未张贴安全告知卡',
#   0),
#  (1353,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t未检查消防安全重点部位的管理情况；',
#   0),
#  (1354, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器干粉用尽，已充满', 0),
#  (1355,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t吊机和员工车位都重新安装自动跳闸开关。',
#   0),
#  (1356,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t楼道口停放电动车，堆放货物。  发现后，立即通知相关人员处理。',
#   0),
#  (1358,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t2、危险作业\t1、凡涉及动火、高空、有限空间、密闭容器、起重、施工动土、临时用电等危险作业，应明确危险作业的申请、审批权限、职责和程序，办理作业票证；安排专门人员进行现场安全管理。\t有限空间作业，水池清洗作业与操作单位未签到安全管理协议，近期着手完善。',
#   0),
#  (1359,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端',
#   1),
#  (1361,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t2、危险作业\t1、凡涉及动火、高空、有限空间、密闭容器、起重、施工动土、临时用电等危险作业，应明确危险作业的申请、审批权限、职责和程序，办理作业票证，安排专门人员进行现场安全管理。\t1. :5栋1楼登高梯台处无“当心坠落”警示标志；2. :5栋1楼部分配电盒处无“当心触电”警示标志；',
#   0),
#  (1362,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急照明灯不亮，已更换新的',
#   0),
#  (1363,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵塞消防通道，已整改',
#   0),
#  (1364,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t巡查发现后门消防门闭门器损坏，指示牌缺失。现已处理好',
#   0),
#  (1365,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t1栋8楼常闭式防火门未关闭，已现在整改',
#   0),
#  (1367,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有一个应急照明灯坏了',
#   0),
#  (1368,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器没有进行检查，查验是否合格，有一个失效',
#   0),
#  (1370,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t抛光机，砂轮机，铣床没有安全防护装置',
#   0),
#  (1371,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道被货物堵塞',
#   0),
#  (1372,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t封口机用后未拔电源',
#   0),
#  (1373,
#   '商贸服务教文卫类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育\t1、制定安全教育培训计划，确保全员参与培训，并建立安全培训档案。\t没有经过安全教育培训',
#   0),
#  (1375,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有杂物',
#   0),
#  (1376,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t消防灭火器周围没有挂检查标签',
#   0),
#  (1379,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t桥架插座走线不规范',
#   0),
#  (1380,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有货物摆放',
#   0),
#  (1381,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有隐患',
#   1),
#  (1382, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器', 1),
#  ...]

# %%
num_labeled = int(len(train_data) * train_frac)
unlabeled_data = [(m,n,0) for m,n,l in train_data[num_labeled:]]
train_data = train_data[:num_labeled]

# %%
num_labeled
# Out:
# 84

# %%
# 建立分词器
tokenizer = Tokenizer(dict_path, do_lower_case=True)

# %%
# class data_generator(DataGenerator):
#     """数据生成器
#     """
#     def __iter__(self, random=False):
#         batch_token_ids, batch_segment_ids, batch_labels = [], [], []
#         for is_end, (text, label) in self.sample(random):
#             token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
#             batch_token_ids.append(token_ids)
#             batch_segment_ids.append(segment_ids)
#             batch_labels.append(label)
#             if len(batch_token_ids) == self.batch_size or is_end:
#                 batch_token_ids = sequence_padding(batch_token_ids)
#                 batch_segment_ids = sequence_padding(batch_segment_ids)
#                 batch_labels = to_categorical(batch_labels, num_classes)
#                 yield [batch_token_ids, batch_segment_ids], batch_labels
#                 batch_token_ids, batch_segment_ids, batch_labels = [], [], []
class data_generator(DataGenerator):
    """数据生成器
    """
    def __iter__(self, random=False):
        batch_token_ids, batch_segment_ids, batch_labels = [], [], []
        for is_end, (id, text, label) in self.sample(random):
            token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
            batch_token_ids.append(token_ids)
            batch_segment_ids.append(segment_ids)
            batch_labels.append([label])
            if len(batch_token_ids) == self.batch_size or is_end:
                batch_token_ids = sequence_padding(batch_token_ids)
                batch_segment_ids = sequence_padding(batch_segment_ids)
                batch_labels = sequence_padding(batch_labels)
                yield [batch_token_ids, batch_segment_ids], batch_labels
                batch_token_ids, batch_segment_ids, batch_labels = [], [], []

# 转换数据集
train_generator = data_generator(train_data, batch_size)
valid_generator = data_generator(valid_data, batch_size)
test_generator = data_generator(test_data, batch_size)

# %%
# 加载预训练模型
bert = build_transformer_model(
    config_path=config_path,
    checkpoint_path=checkpoint_path,
    return_keras_model=False,
)

output = Lambda(lambda x: x[:, 0])(bert.model.output)
output = Dense(
    units=num_classes,
    activation='softmax',
    kernel_initializer=bert.initializer
)(output)

# 用于正常训练的模型
model = keras.models.Model(bert.model.input, output)
model.summary()

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=Adam(1e-5),
    metrics=['categorical_accuracy'],
)

# 用于虚拟对抗训练的模型
model_vat = keras.models.Model(bert.model.input, output)
model_vat.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=Adam(1e-5),
    metrics=['categorical_accuracy'],
)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input-Token (InputLayer)        (None, None)         0
# __________________________________________________________________________________________________
# Input-Segment (InputLayer)      (None, None)         0
# __________________________________________________________________________________________________
# Embedding-Token (Embedding)     (None, None, 768)    16226304    Input-Token[0][0]
# __________________________________________________________________________________________________
# Embedding-Segment (Embedding)   (None, None, 768)    1536        Input-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Token-Segment (Add)   (None, None, 768)    0           Embedding-Token[0][0]
#                                                                  Embedding-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Position (PositionEmb (None, None, 768)    393216      Embedding-Token-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Norm (LayerNormalizat (None, None, 768)    1536        Embedding-Position[0][0]
# __________________________________________________________________________________________________
# Embedding-Dropout (Dropout)     (None, None, 768)    0           Embedding-Norm[0][0]
# __________________________________________________________________________________________________
# Transformer-0-MultiHeadSelfAtte (None, None, 768)    2362368     Embedding-Dropout[0][0]
#                                                                  Embedding-Dropout[0][0]
#                                                                  Embedding-Dropout[0][0]
# __________________________________________________________________________________________________
# Transformer-0-MultiHeadSelfAtte (None, None, 768)    0           Transformer-0-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-0-MultiHeadSelfAtte (None, None, 768)    0           Embedding-Dropout[0][0]
#                                                                  Transformer-0-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-0-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-0-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-0-FeedForward (Feed (None, None, 768)    4722432     Transformer-0-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-0-FeedForward-Dropo (None, None, 768)    0           Transformer-0-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-0-FeedForward-Add ( (None, None, 768)    0           Transformer-0-MultiHeadSelfAttent
#                                                                  Transformer-0-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-0-FeedForward-Norm  (None, None, 768)    1536        Transformer-0-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-1-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-0-FeedForward-Norm[0]
#                                                                  Transformer-0-FeedForward-Norm[0]
#                                                                  Transformer-0-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-1-MultiHeadSelfAtte (None, None, 768)    0           Transformer-1-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-1-MultiHeadSelfAtte (None, None, 768)    0           Transformer-0-FeedForward-Norm[0]
#                                                                  Transformer-1-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-1-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-1-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-1-FeedForward (Feed (None, None, 768)    4722432     Transformer-1-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-1-FeedForward-Dropo (None, None, 768)    0           Transformer-1-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-1-FeedForward-Add ( (None, None, 768)    0           Transformer-1-MultiHeadSelfAttent
#                                                                  Transformer-1-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-1-FeedForward-Norm  (None, None, 768)    1536        Transformer-1-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-2-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-1-FeedForward-Norm[0]
#                                                                  Transformer-1-FeedForward-Norm[0]
#                                                                  Transformer-1-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-2-MultiHeadSelfAtte (None, None, 768)    0           Transformer-2-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-2-MultiHeadSelfAtte (None, None, 768)    0           Transformer-1-FeedForward-Norm[0]
#                                                                  Transformer-2-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-2-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-2-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-2-FeedForward (Feed (None, None, 768)    4722432     Transformer-2-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-2-FeedForward-Dropo (None, None, 768)    0           Transformer-2-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-2-FeedForward-Add ( (None, None, 768)    0           Transformer-2-MultiHeadSelfAttent
#                                                                  Transformer-2-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-2-FeedForward-Norm  (None, None, 768)    1536        Transformer-2-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-3-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-2-FeedForward-Norm[0]
#                                                                  Transformer-2-FeedForward-Norm[0]
#                                                                  Transformer-2-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-3-MultiHeadSelfAtte (None, None, 768)    0           Transformer-3-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-3-MultiHeadSelfAtte (None, None, 768)    0           Transformer-2-FeedForward-Norm[0]
#                                                                  Transformer-3-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-3-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-3-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-3-FeedForward (Feed (None, None, 768)    4722432     Transformer-3-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-3-FeedForward-Dropo (None, None, 768)    0           Transformer-3-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-3-FeedForward-Add ( (None, None, 768)    0           Transformer-3-MultiHeadSelfAttent
#                                                                  Transformer-3-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-3-FeedForward-Norm  (None, None, 768)    1536        Transformer-3-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-4-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-3-FeedForward-Norm[0]
#                                                                  Transformer-3-FeedForward-Norm[0]
#                                                                  Transformer-3-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-4-MultiHeadSelfAtte (None, None, 768)    0           Transformer-4-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-4-MultiHeadSelfAtte (None, None, 768)    0           Transformer-3-FeedForward-Norm[0]
#                                                                  Transformer-4-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-4-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-4-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-4-FeedForward (Feed (None, None, 768)    4722432     Transformer-4-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-4-FeedForward-Dropo (None, None, 768)    0           Transformer-4-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-4-FeedForward-Add ( (None, None, 768)    0           Transformer-4-MultiHeadSelfAttent
#                                                                  Transformer-4-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-4-FeedForward-Norm  (None, None, 768)    1536        Transformer-4-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-5-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-4-FeedForward-Norm[0]
#                                                                  Transformer-4-FeedForward-Norm[0]
#                                                                  Transformer-4-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-5-MultiHeadSelfAtte (None, None, 768)    0           Transformer-5-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-5-MultiHeadSelfAtte (None, None, 768)    0           Transformer-4-FeedForward-Norm[0]
#                                                                  Transformer-5-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-5-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-5-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-5-FeedForward (Feed (None, None, 768)    4722432     Transformer-5-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-5-FeedForward-Dropo (None, None, 768)    0           Transformer-5-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-5-FeedForward-Add ( (None, None, 768)    0           Transformer-5-MultiHeadSelfAttent
#                                                                  Transformer-5-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-5-FeedForward-Norm  (None, None, 768)    1536        Transformer-5-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-6-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-5-FeedForward-Norm[0]
#                                                                  Transformer-5-FeedForward-Norm[0]
#                                                                  Transformer-5-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-6-MultiHeadSelfAtte (None, None, 768)    0           Transformer-6-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-6-MultiHeadSelfAtte (None, None, 768)    0           Transformer-5-FeedForward-Norm[0]
#                                                                  Transformer-6-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-6-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-6-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-6-FeedForward (Feed (None, None, 768)    4722432     Transformer-6-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-6-FeedForward-Dropo (None, None, 768)    0           Transformer-6-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-6-FeedForward-Add ( (None, None, 768)    0           Transformer-6-MultiHeadSelfAttent
#                                                                  Transformer-6-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-6-FeedForward-Norm  (None, None, 768)    1536        Transformer-6-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-7-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-6-FeedForward-Norm[0]
#                                                                  Transformer-6-FeedForward-Norm[0]
#                                                                  Transformer-6-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-7-MultiHeadSelfAtte (None, None, 768)    0           Transformer-7-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-7-MultiHeadSelfAtte (None, None, 768)    0           Transformer-6-FeedForward-Norm[0]
#                                                                  Transformer-7-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-7-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-7-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-7-FeedForward (Feed (None, None, 768)    4722432     Transformer-7-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-7-FeedForward-Dropo (None, None, 768)    0           Transformer-7-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-7-FeedForward-Add ( (None, None, 768)    0           Transformer-7-MultiHeadSelfAttent
#                                                                  Transformer-7-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-7-FeedForward-Norm  (None, None, 768)    1536        Transformer-7-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-8-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-7-FeedForward-Norm[0]
#                                                                  Transformer-7-FeedForward-Norm[0]
#                                                                  Transformer-7-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-8-MultiHeadSelfAtte (None, None, 768)    0           Transformer-8-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-8-MultiHeadSelfAtte (None, None, 768)    0           Transformer-7-FeedForward-Norm[0]
#                                                                  Transformer-8-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-8-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-8-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-8-FeedForward (Feed (None, None, 768)    4722432     Transformer-8-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-8-FeedForward-Dropo (None, None, 768)    0           Transformer-8-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-8-FeedForward-Add ( (None, None, 768)    0           Transformer-8-MultiHeadSelfAttent
#                                                                  Transformer-8-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-8-FeedForward-Norm  (None, None, 768)    1536        Transformer-8-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-9-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-8-FeedForward-Norm[0]
#                                                                  Transformer-8-FeedForward-Norm[0]
#                                                                  Transformer-8-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-9-MultiHeadSelfAtte (None, None, 768)    0           Transformer-9-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-9-MultiHeadSelfAtte (None, None, 768)    0           Transformer-8-FeedForward-Norm[0]
#                                                                  Transformer-9-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-9-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-9-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-9-FeedForward (Feed (None, None, 768)    4722432     Transformer-9-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-9-FeedForward-Dropo (None, None, 768)    0           Transformer-9-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-9-FeedForward-Add ( (None, None, 768)    0           Transformer-9-MultiHeadSelfAttent
#                                                                  Transformer-9-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-9-FeedForward-Norm  (None, None, 768)    1536        Transformer-9-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-10-MultiHeadSelfAtt (None, None, 768)    2362368     Transformer-9-FeedForward-Norm[0]
#                                                                  Transformer-9-FeedForward-Norm[0]
#                                                                  Transformer-9-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-10-MultiHeadSelfAtt (None, None, 768)    0           Transformer-10-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-10-MultiHeadSelfAtt (None, None, 768)    0           Transformer-9-FeedForward-Norm[0]
#                                                                  Transformer-10-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-10-MultiHeadSelfAtt (None, None, 768)    1536        Transformer-10-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-10-FeedForward (Fee (None, None, 768)    4722432     Transformer-10-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-10-FeedForward-Drop (None, None, 768)    0           Transformer-10-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-10-FeedForward-Add  (None, None, 768)    0           Transformer-10-MultiHeadSelfAtten
#                                                                  Transformer-10-FeedForward-Dropou
# __________________________________________________________________________________________________
# Transformer-10-FeedForward-Norm (None, None, 768)    1536        Transformer-10-FeedForward-Add[0]
# __________________________________________________________________________________________________
# Transformer-11-MultiHeadSelfAtt (None, None, 768)    2362368     Transformer-10-FeedForward-Norm[0
#                                                                  Transformer-10-FeedForward-Norm[0
#                                                                  Transformer-10-FeedForward-Norm[0
# __________________________________________________________________________________________________
# Transformer-11-MultiHeadSelfAtt (None, None, 768)    0           Transformer-11-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-11-MultiHeadSelfAtt (None, None, 768)    0           Transformer-10-FeedForward-Norm[0
#                                                                  Transformer-11-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-11-MultiHeadSelfAtt (None, None, 768)    1536        Transformer-11-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-11-FeedForward (Fee (None, None, 768)    4722432     Transformer-11-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-11-FeedForward-Drop (None, None, 768)    0           Transformer-11-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-11-FeedForward-Add  (None, None, 768)    0           Transformer-11-MultiHeadSelfAtten
#                                                                  Transformer-11-FeedForward-Dropou
# __________________________________________________________________________________________________
# Transformer-11-FeedForward-Norm (None, None, 768)    1536        Transformer-11-FeedForward-Add[0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 768)          0           Transformer-11-FeedForward-Norm[0
# __________________________________________________________________________________________________
# dense_146 (Dense)               (None, 2)            1538        lambda_2[0][0]
# ==================================================================================================
# Total params: 101,678,594
# Trainable params: 101,678,594
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def virtual_adversarial_training(
    model, embedding_name, epsilon=1, xi=10, iters=1
):
    """给模型添加虚拟对抗训练
    其中model是需要添加对抗训练的keras模型，embedding_name
    则是model里边Embedding层的名字。要在模型compile之后使用。
    """
    if model.train_function is None:  # 如果还没有训练函数
        model._make_train_function()  # 手动make
    old_train_function = model.train_function  # 备份旧的训练函数

    # 查找Embedding层
    for output in model.outputs:
        embedding_layer = search_layer(output, embedding_name)
        if embedding_layer is not None:
            break
    if embedding_layer is None:
        raise Exception('Embedding layer not found')

    # 求Embedding梯度
    embeddings = embedding_layer.embeddings  # Embedding矩阵
    gradients = K.gradients(model.total_loss, [embeddings])  # Embedding梯度
    gradients = K.zeros_like(embeddings) + gradients[0]  # 转为dense tensor

    # 封装为函数
    inputs = (
        model._feed_inputs + model._feed_targets + model._feed_sample_weights
    )  # 所有输入层
    model_outputs = K.function(
        inputs=inputs,
        outputs=model.outputs,
        name='model_outputs',
    )  # 模型输出函数
    embedding_gradients = K.function(
        inputs=inputs,
        outputs=[gradients],
        name='embedding_gradients',
    )  # 模型梯度函数

    def l2_normalize(x):
        return x / (np.sqrt((x**2).sum()) + 1e-8)

    def train_function(inputs):  # 重新定义训练函数
        outputs = model_outputs(inputs)
        inputs = inputs[:2] + outputs + inputs[3:]
        delta1, delta2 = 0.0, np.random.randn(*K.int_shape(embeddings))
        for _ in range(iters):  # 迭代求扰动
            delta2 = xi * l2_normalize(delta2)
            K.set_value(embeddings, K.eval(embeddings) - delta1 + delta2)
            delta1 = delta2
            delta2 = embedding_gradients(inputs)[0]  # Embedding梯度
        delta2 = epsilon * l2_normalize(delta2)
        K.set_value(embeddings, K.eval(embeddings) - delta1 + delta2)
        outputs = old_train_function(inputs)  # 梯度下降
        K.set_value(embeddings, K.eval(embeddings) - delta2)  # 删除扰动
        return outputs

    model.train_function = train_function  # 覆盖原训练函数

# %%
# 写好函数后，启用对抗训练只需要一行代码
virtual_adversarial_training(model_vat, 'Embedding-Token')

# %%
unlabeled_data
# Out:
# [(121,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t有3个灭火器压力偏底，要更换',
#   0),
#  (122,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有一处未见指示灯',
#   0),
#  (123,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t占用、堵塞、封闭',
#   0),
#  (125,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t5月份灭火器没有检查。',
#   0),
#  (126,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电箱上有杂物',
#   0),
#  (128,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱旁放了几个纸箱',
#   0),
#  (129,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物乱堆放，阻塞逃生通道',
#   0),
#  (130,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\t未安装漏电保护开关',
#   0),
#  (131,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t缺安全出口标识',
#   0),
#  (132,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t车间照明灯有一根不亮，影响工作视线',
#   0),
#  (133,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改',
#   0),
#  (134,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散通道有占用',
#   0),
#  (135,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口无指示标志，已经整改',
#   0),
#  (136,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全标志掉落；立即整改，张贴完好。',
#   0),
#  (137, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器压力不足，现已更换', 0),
#  (138,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t照明灯不亮',
#   0),
#  (139,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道不畅通，堆放杂物\n消防灭火器未正确放置\n消防水管没安装好',
#   0),
#  (140, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器记录卡片未及时检查', 0),
#  (142,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t电池仓库货架接地不规范，需螺栓连接或焊接 压接',
#   0),
#  (143,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；',
#   0),
#  (145,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道有货物堆放',
#   0),
#  (146,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t一楼A4区灭火器下面堆放杂物',
#   0),
#  (148,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t安全出口堵塞',
#   0),
#  (149,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有两个灭火器过期，已重新更换新的。',
#   0),
#  (150, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火气配备不足', 0),
#  (152,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t有',
#   0),
#  (153,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t标志',
#   0),
#  (154,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t有些地标线磨损不清楚',
#   0),
#  (155,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t部分灭火器材过期未能正常使用。',
#   0),
#  (156,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防安全通道堵塞',
#   0),
#  (158,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t灭火器失交效',
#   0),
#  (159,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t周转车堵塞消防通道',
#   0),
#  (160,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t货物阻挡通道',
#   0),
#  (161,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t本单元重新整改装修，装修后消防门摆放了较大的绿植物',
#   0),
#  (162,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t标识有脱落',
#   0),
#  (163,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道应急灯未连通电源',
#   0),
#  (164,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有障碍',
#   0),
#  (167, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器未合理分布', 0),
#  (170,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t1楼应急灯坏，已更换',
#   0),
#  (172,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓漏水',
#   0),
#  (173,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t三楼仓库一具灭火器已过期失效',
#   0),
#  (174,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t临时用电没有安装漏电保护装置，立即安装',
#   0),
#  (175,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t一年级办公室照明灯有损坏',
#   0),
#  (176,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵塞消防通道',
#   0),
#  (177,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t用电安全警示标志已经张贴',
#   0),
#  (178,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口堵塞',
#   0),
#  (179,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器有损坏，立即购买新的更换。',
#   0),
#  (180, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t已整改', 0),
#  (181,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t没有保存完整的事故隐患排查治理档案',
#   0),
#  (183,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (184,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t2019年全员安全再教育未实施。',
#   0),
#  (185, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t排查中发现有一个灭火器失效', 0),
#  (186, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器失效', 0),
#  (187,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道有隐患',
#   0),
#  (188,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间消防通道有被货物堵塞，现已作出整改',
#   0),
#  (190,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t大厦东面外围楼梯角落有杂物堆放，即时叫人搬离',
#   0),
#  (191,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t楼梯口堆有杂物,立即清除.',
#   0),
#  (192,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯损坏',
#   0),
#  (193,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000\t宿舍楼下临时停放电车',
#   0),
#  (194,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t补充2个新的灭火器',
#   0),
#  (195,
#   '商贸服务教文卫类（基础）—2016版\t（三）安全管理规章制度\t1、安全管理责任制\t1、建立、健全安全管理责任制，明确各岗位的责任人员、责任范围和考核标准等内容。\t建立、健全安全管理责任制，明确各岗位的责任人员、责任范围和考核标准等内容。',
#   0),
#  (196,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道堵塞，现已整改。',
#   0),
#  (199, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t消防检查表未及时填写', 0),
#  (200,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t有货物堆放',
#   0),
#  (201, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器未点检', 0),
#  (203, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t9层东区放杂物', 0),
#  (205,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线线皮破损',
#   0),
#  (206,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道货物已清理已畅通',
#   0),
#  (208,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t新员工有一人未完成班组级安全教育，就安排上岗。',
#   0),
#  (209,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况。\t电线裸露，已整改',
#   0),
#  (210,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t没有张贴安全标识',
#   0),
#  (212,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\tA栋五楼吹樽部1号吹瓶机维修未挂警示牌，现场已整改。',
#   0),
#  (215,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t指示灯不亮',
#   0),
#  (216,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。',
#   0),
#  (218,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱未张贴“当心触电”安全警示标志',
#   0),
#  (221,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\tC型钢压型机器轴承破、购新轴承更换',
#   0),
#  (222,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火卷帘下堆放物品',
#   0),
#  (223, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t安全出口上锁', 0),
#  (224,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器被遮挡，已整改；消防栓底下和周围堆积物品，已整改。',
#   0),
#  (225,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门门锁故障',
#   0),
#  (226,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t发现的问题：安全通道放有小推车  解决办法：马上移走小推车，并告诫员工物品堵消防通道的隐患风险',
#   0),
#  (227,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t应急照明灯坏了，已经更换',
#   0),
#  (228,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t已整改完毕。',
#   0),
#  (229,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间通道不畅通',
#   0),
#  (230,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t楼梯消防门闭门器损坏',
#   0),
#  (231,
#   '交通运输类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心有电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t普天充电站一处配电箱生锈破损线路存在漏电隐患，现已按要求整改完成。',
#   0),
#  (232,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t增加标志触电安全，和检查设备线端。',
#   0),
#  (233,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t安全生产管理制度、培训演练、职责书、隐患整改制度及应急方案，均已完善',
#   0),
#  (234, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t发现2个灭火器气压不足。', 0),
#  (235,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道堆放杂物',
#   0),
#  (237,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口堵塞',
#   0),
#  (238,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t没有疏散通道、安全出口设置应急照明灯和疏散指示标志',
#   0),
#  (239,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未制定2019年年度培训计划',
#   0),
#  (240,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急通道上有临时堆放货物，阻碍通道，造成隐患。',
#   0),
#  (241,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t应急照明灯不亮     己整改',
#   0),
#  (242,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t有两个电源开关接触不良，已购买更换',
#   0),
#  (243,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火卷帘处堆放纸箱及货物',
#   0),
#  (244,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t办公室走廊安全通道有堆放货物现象，存在安全隐患，已现场整改。',
#   0),
#  (245,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t设备作业区域废料未清扫',
#   0),
#  (247,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t消防栓的玻璃门没有密合好',
#   0),
#  (248,
#   '三小场所（现场）—2016版\t（二）电气安全\t2、电气设备、设施的金属接地或接零\t1、电气设备金属外壳需接地保护。\t有一处电线裸露,将裸露电线套管。',
#   0),
#  (249,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯修理效果不佳',
#   0),
#  (250,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t堵塞',
#   0),
#  (253,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t点检表欠缺，未点检。',
#   0),
#  (255,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道堵塞，通道堆放物品',
#   0),
#  (256,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t二楼包装车间有一通道货物压黄线',
#   0),
#  (257, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t用火、用电有违章情况', 0),
#  (258,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t插头坏',
#   0),
#  (259,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t全安通道堆放有杂物',
#   0),
#  (260,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t9、消防（控制室）值班情况和设施运行、记录情况；\t落实安全记录',
#   0),
#  (263,
#   '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t9、消防（控制室）值班情况和设施运行、记录情况。\t消防控制室无人值班',
#   0),
#  (264,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t注塑部一楼车间消防通道被临时堆放的货物堵塞，马上整改完成。',
#   0),
#  (266,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电房内有少许杂物。',
#   0),
#  (267,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\tD仓库配电箱下方堆放杂物',
#   0),
#  (269,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t9:35 宿舍区域多个灭火器箱上 放有鞋子',
#   0),
#  (271,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t仓库货物堆放不够有条理，存在隐患',
#   0),
#  (272, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改', 0),
#  (274,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；\t配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；',
#   0),
#  (275,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t知识掌握较少',
#   0),
#  (277,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散应急灯不亮',
#   0),
#  (278,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t空压机皮带以受损，立即更换。',
#   0),
#  (279,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t更换新的灭火器，检查灭火器的作用',
#   0),
#  (281,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯不亮，立即整改',
#   0),
#  (282,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口被货物堆积',
#   0),
#  (283,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t二楼安全出口被阻塞',
#   0),
#  (284,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t员工安全教育没有及时培训，已整改',
#   0),
#  (285,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t个别标识掉落',
#   0),
#  (286,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有隐患',
#   0),
#  (288,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t气瓶防倾倒设施未使用',
#   0),
#  (289,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道上摆放有产品，存有安全隐患。已整改。',
#   0),
#  (290, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改', 0),
#  (291,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t未建立建全事故隐患排查治理纪录档案',
#   0),
#  (292,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全出口堵塞',
#   0),
#  (293,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯不亮   已重新按装新的应急照明灯   已整改',
#   0),
#  (295,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t一楼车间裁床电箱内放有废手套等杂物',
#   0),
#  (296, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防车通道有杂物堆积', 0),
#  (298,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下、周围堆放杂物',
#   0),
#  (299,
#   '工业/危化品类（选项）—2016版\t（五）特种设备\t5、起重机械\t3、设备上应悬挂安全操作规程、交接班记录和安全检查记录。\t操作行车处未见安全操作规程',
#   0),
#  (301,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下有杂物，现已清除',
#   0),
#  (304,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全标志不完整',
#   0),
#  (305,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯失效',
#   0),
#  (306,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t砂带机安全防护装置螺丝脱落',
#   0),
#  (310,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱没有贴危险标识',
#   0),
#  (311,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t线头没包好',
#   0),
#  (312,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t未安装漏电开关',
#   0),
#  (313,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t安全通道堆放货物，存在安全隐患',
#   0),
#  (315,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t2、手持式电动工具、移动电器等设备应优先选用额定剩余动作电流不大于30mA、一般型（无延时）的剩余电流保护装置；潮湿场所的电气设备使用16-30mA动作电流、无延时；在金属物件上作业的手持电动工具使用10mA动作电流、无延时漏电保护开关。\t电池随处进行充电，未按照公司《电池安全防护规范》进行充电及记录。',
#   0),
#  (317,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一楼全贴合，饮用水空桶挡住灭火器箱',
#   0),
#  (318,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施位置被占用',
#   0),
#  (319,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防水龙头破损',
#   0),
#  (320, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t个别灭火器过期', 0),
#  (321,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电盒上没有“注意有电”安全提示标识',
#   0),
#  (323,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t因老化原因部分通电式安全出口标志不亮',
#   0),
#  (326,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急指示灯损坏，已更换',
#   0),
#  (328,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口通道后门卷闸门不能关闭',
#   0),
#  (329,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不畅通',
#   0),
#  (330,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有临时堆放货物   ',
#   0),
#  (331,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器停放过长粉不足，已充足，',
#   0),
#  (332,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t有1瓶灭火器过期，已更换。',
#   0),
#  (334,
#   '工业/危化品类（选项）—2016版\t（五）特种设备\t2、压力容器\t3、安全阀有有效的检验报告及铅封标记。压力表有有效的检定证书及标记。\t有车间压力表快到期/及时安排人员在有效期内进行更换',
#   0),
#  (337,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t检查发现朝阳市场A座综合楼楼梯大门灭火器位置摆放杂物，防碍其正常使用，要求管理人员立即整改（当天已整改完毕）。',
#   0),
#  (338,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t安全疏散通道堵塞',
#   0),
#  (339,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t ',
#   0),
#  (341,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t消房通道放物品',
#   0),
#  (342,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道有杂物',
#   0),
#  (343,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t观海楼三楼通道有一个疏散指示，出现故障报警。',
#   0),
#  (345,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道被档住；',
#   0),
#  (346,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t现场插座松动',
#   0),
#  (347,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防器材。以整改',
#   0),
#  (348,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t缺警示标识牌',
#   0),
#  (349,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t配电室长度超过7m时，没有设有两个出口',
#   0),
#  (350,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\tC栋一楼封边机操作人员未佩戴劳动防护用品（耳塞）',
#   0),
#  (351,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯不亮',
#   0),
#  (352,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (353, '商贸服务教文卫类（选项）—2016版\t（九）特种设备\t2、压力容器\t1、安全阀有有效的检验报告及铅封标记。\t检查记录不完善', 0),
#  (355,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t消防安全标志不全',
#   0),
#  (357,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t电动车挡住消防器材',
#   0),
#  (358,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t地库防火门，，，有杂物，已清理、',
#   0),
#  (359,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器配备不足',
#   0),
#  (361,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道划线模糊',
#   0),
#  (362,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道，疏散指示标志不明确',
#   0),
#  (363, '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t会议记录', 0),
#  (364,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t应急照明灯损坏',
#   0),
#  (367,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t个别应急灯不亮，已及时修复',
#   0),
#  (368,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t安全通道门未打开',
#   0),
#  (369,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t“当心触电”安全警示标志脱落',
#   0),
#  (370,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器已过期，现场已更换。',
#   0),
#  (371,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有物品占用。',
#   0),
#  (374, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t无定期进行应急演练', 0),
#  (377,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓玻璃门破损',
#   0),
#  (378,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堆放货物',
#   0),
#  (379,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t2、配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。\t配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。',
#   0),
#  (380,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t19年2月份的灭火器点检表未点检。立即点检。',
#   0),
#  (383,
#   '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t没有系统的安全培训记录',
#   0),
#  (384,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\t水吧旁边一个插座没有接地线',
#   0),
#  (385,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵住安全通道',
#   0),
#  (386, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器未定期检查', 0),
#  (387,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门关闭',
#   0),
#  (388,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t配电箱内控制开关无标示器件标明被控设备编号及名称，配电箱金属箱门与箱体无采用软铜线做电气连接',
#   0),
#  (389,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门未常闭',
#   0),
#  (390, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t通风状态有待改善', 0),
#  (391,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防水带捆绑不正确且老化，需更新',
#   0),
#  (392,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道出口堵塞。',
#   0),
#  (393,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t四楼作业通道堆放货物疏散通道不畅通',
#   0),
#  (394,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t一个应急灯不亮，一个安全出口指示灯不亮',
#   0),
#  (396,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t安全警示标志少',
#   0),
#  (397, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器不够，新增几个', 0),
#  (399,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有一灭火器指针已到下限',
#   0),
#  (400,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道放货物',
#   0),
#  (401,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间通道被货物堵塞',
#   0),
#  (402,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间包装台部分区域未接地线存在安全隐患，已及时处理并整改完成。',
#   0),
#  (403,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材未按规定位置摆放',
#   0),
#  (404,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有物品挡在消防通道口，立即清走',
#   0),
#  (405,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t有隐患',
#   0),
#  (406,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱(柜)门未张贴有“当心触电”安全警示标志',
#   0),
#  (407,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t仓库安装防爆风机',
#   0),
#  (408, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防箱下有杂物', 0),
#  (409,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t电梯出口有货物存放，已立即整改',
#   0),
#  (410, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志', 0),
#  (414,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有及时组织应急演练，2019年11月25日组织了应急演练',
#   0),
#  (417, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t ', 0),
#  (421,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t地面安全通道标识有缺损，',
#   0),
#  (423,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t进出口通道堵塞，已责令相关厂商立即清疏。',
#   0),
#  (424, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t己整改', 0),
#  (425,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t7月灭火器，没检查',
#   0),
#  (427,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有一盏应急照明灯损坏，已立即更换整改。',
#   0),
#  (428, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改', 0),
#  (429, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t车间个别灭火器被挡', 0),
#  (431,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t出口应急灯坏，已更新',
#   0),
#  (432,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (433,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (435,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t未建立应急预案',
#   0),
#  (436,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门没关上',
#   0),
#  (437, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t未仔细检查', 0),
#  (438,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道临时堆放货物',
#   0),
#  (439,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t设置的当心触电标志脱落，立即更换新的标志',
#   0),
#  (441,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间1个插座未装漏电保护装置',
#   0),
#  (444,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t1、特种设备档案\t1、特种设备(及安全附件)检测报告齐全，并在有效期内。运行记录和维修保养记录齐全。\t设备保养未及时做记录',
#   0),
#  (445,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t每日防火巡查不全面，需要立即整改',
#   0),
#  (446,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (447,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t个别楼层防火门闭门器坏，及时联系工程部更换新品',
#   0),
#  (449,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不畅通',
#   0),
#  (450,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t车间一处安全疏散指示标志脱落，需重新张贴固定到位以示警醒。',
#   0),
#  (451,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t车间工业风扇未接地保护',
#   0),
#  (452,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有一安全疏散标识模糊不清',
#   0),
#  (453,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t金属电箱与箱子门无软铜线连接，已安装编织软铜线做电气连接，已完成整改。',
#   0),
#  (454, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t没有演了', 0),
#  (456,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t2019年8月14日检查报警器未及时点检！',
#   0),
#  (459,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防出口灯损坏',
#   0),
#  (461,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物挡住通道',
#   0),
#  (462,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t一处落地扇电源线未使用双层绝缘电线。',
#   0),
#  (463,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t未张贴安全警示标志',
#   0),
#  (465,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t插座相接，用电有隐患',
#   0),
#  (466,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器翻倒',
#   0),
#  (467,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t常闭式防火门没有处于关闭状态',
#   0),
#  (468,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t未检查灭火器材配置及有效情况；',
#   0),
#  (469,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱、开关箱内有放置任何杂物，电器元件不可安装在可燃材料上',
#   0),
#  (470,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有即将过有效期，要求定期更换ABC干粉灭火器',
#   0),
#  (471,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t档案不建全',
#   0),
#  (473, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有一处失效', 0),
#  (474,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材被挡住',
#   0),
#  (475,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t没有召开复工安全例会',
#   0),
#  (477,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t物料摆放堵塞消防栓',
#   0),
#  (478,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散指示标志不合规，已更换。',
#   0),
#  (479,
#   '工业/危化品类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t3、安全管理机构和管理人员履职情况\t1、安全生产管理机构、安全生产管理人员依法履行安全生产管理职责（存在职业健康危害的单位，包括职卫管理机构及职卫管理人员）。\t人员变动从新签安全生产主体公示牌',
#   0),
#  (481,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼的右边楼梯口的应急灯损坏',
#   0),
#  (483,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t未保存安全会议记录',
#   0),
#  (484,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t赤湾港区21#小叉车灭火器点检表缺少8月份的检点记录',
#   0),
#  (486,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t办公室走道挂墙放置灭火器脱落。',
#   0),
#  (487,
#   '建筑施工类（选项）—2016版\t（十七）起重吊装\t2、实体安全\t5、起重吊装作业是否符合要求。\tB座二十三层铝模未使用料斗吊装',
#   0),
#  (488,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t技术部转角门口堆放了纸箱',
#   0),
#  (489,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t南区球车库消防栓水带腐蚀',
#   0),
#  (490,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有堆放杂物',
#   0),
#  (495,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t地上有坑',
#   0),
#  (496,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t产品堆放阻碍通道',
#   0),
#  (497,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t没有设置“当心触电”安全警示标志。',
#   0),
#  (498,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t部分开关盒无张贴“当心触电”安全警示标识牌，需立即整治。',
#   0),
#  (499,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全疏散指示标志',
#   0),
#  (500,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t老厂5栋2楼披锋房操作台防护挡板损坏',
#   0),
#  (501, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t卸油口盖静电接地线线头脱落', 0),
#  (502,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有废弃物阻挡部分通道，现已清理；有安全通道地标损坏，现已更换',
#   0),
#  (503,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防灭火器检查清洗',
#   0),
#  (504, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器内压不足', 0),
#  (507,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t紧急出口灯不亮了',
#   0),
#  (508,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散通道不畅通',
#   0),
#  (509,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t侧小门未安排安全出品指示标识，经整改后已经安装安全出口、应急灯标识。',
#   0),
#  (510,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t三楼镭射机没有安装红外线防护。',
#   0),
#  (511,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t16个消防安全应急灯故障，已及时更换。',
#   0),
#  (512,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接。\t已整改',
#   0),
#  (513,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t当心触电标志掉落',
#   0),
#  (514,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材过期，立即更换。',
#   0),
#  (515,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t已培训建档',
#   0),
#  (516,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物',
#   0),
#  (518,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t后楼梯口堆放临时货物。',
#   0),
#  (519,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t消防通道停放自行车',
#   0),
#  (520,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器失效',
#   0),
#  (521,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材大部分已过期或失效，立即购买新的灭火器。',
#   0),
#  (522, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t危化品暂放仓储存过量', 0),
#  (523,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道有时候有清洁阿姨堆砌了一些纸箱杂物，未及时挪开，已告知阿姨不要堆杂物。',
#   0),
#  (525,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好',
#   0),
#  (526,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t生产车间消防通道一处被物料占用。',
#   0),
#  (527,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物堵住前台通道',
#   0),
#  (528,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t卫生大扫除时挪动了灭火器，没有放回原来位置',
#   0),
#  (529,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t多余线未处理',
#   0),
#  (530,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t未能按时检查及签名记录',
#   0),
#  (531,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t杂物已全部清除整改',
#   0),
#  (532,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t通道标识线有磨损现象',
#   0),
#  (534,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t更衣室有一个烟感探头故障，已及时更换。',
#   0),
#  (535,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有一个灭火器过期，即购买',
#   0),
#  (536,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t有一个没有标示当心触电',
#   0),
#  (538, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t以学习，演练。', 0),
#  (539,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓阀门漏水（图1是消防栓漏水阀门，图2是已整改完毕）',
#   0),
#  (540,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\tB区2109房门口一个灭火器压力不够',
#   0),
#  (541,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有一瓶灭火器气压不够，已经更换',
#   0),
#  (545,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t公司经理上班发现本企业逃生通道货物堵塞，立即整改',
#   0),
#  (547,
#   '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t12、其他需要检查的内容。防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t筒仓消防设施维保记录卡缺少记录',
#   0),
#  (548,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t安全通道堆放货物',
#   0),
#  (549,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防通道有杂物',
#   0),
#  (550,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口堆有杂物。现已清理。',
#   0),
#  (551,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t已整改',
#   0),
#  (552,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防设施，器材安全标志不完整',
#   0),
#  (553,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口指示灯不亮。',
#   0),
#  (554, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t5、消防安全重点部位的人员在岗情况；\t消防设施阻塞', 0),
#  (555,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t焊锡工作台采用接线板接线，改为长期固定的电源插座。',
#   0),
#  (556,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全警示未到位   现已安排',
#   0),
#  (557,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t本月内的灭火器自检记录没有做，已补上。',
#   0),
#  (558,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t堆放杂物',
#   0),
#  (560,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t检查安全出口，疏散通道标志为荧光的，现已更换为通电带灯罩形。',
#   0),
#  (561,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t在些灭火器过期了',
#   0),
#  (563,
#   '建筑施工类（基础）—2016版\t（五）安全管理档案\t4、特种设备及操作人员管理记录\t3、各种特种设备的运行记录和维修保养记录齐全。\t1.4号塔吊运行记录填写过于简单。',
#   0),
#  (564,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t仓库人员将EC30款机柜放置于安全通道上',
#   0),
#  (566, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期', 0),
#  (569,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道安全出口指示牌故障，已经更换新的安全出口指示牌。',
#   0),
#  (573,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t偶尔会临时堆放货物',
#   0),
#  (574,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t2、设备设施的局部照明和移动照明工作灯使用安全电压，潮湿狭窄场所、金属容器内照明使用特低电压。\t仓库无灯 ，新安装防爆灯',
#   0),
#  (576,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t有占用',
#   0),
#  (579,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t已整改',
#   0),
#  (580,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t彩钢压瓦机电控箱未设置醒目的“小心有电”安全警示标志',
#   0),
#  (585,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t卸油区有树叶，已立即清理。',
#   0),
#  (586,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道有堵,已清理',
#   0),
#  (588,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物已整改',
#   0),
#  (589,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防栓堵塞',
#   0),
#  (590,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电度表安装在木板可燃物上面。',
#   0),
#  (591,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道黄色线标明不明显。',
#   0),
#  (592,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道堵塞变窄。',
#   0),
#  (593,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t灯坏，已修复',
#   0),
#  (595,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t消火栓前放置杂物，影响消防器材使用',
#   0),
#  (597,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t2、无铠装电缆在屋内明敷，水平敷设时，其至地面的距离不应小于2.5m；垂直敷设时，其至地面的距离不应小于1.8m。当不能满足上述要求时应有防止电缆机械损伤的措施。沿地敷设的电缆应穿钢管保护。穿管的内径不应小于电缆外径的1.5倍。\t砂轮机上方电源线裸露无套管保护。',
#   0),
#  (598,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t通道堆放货物，堵塞疏散通道',
#   0),
#  (599,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防疏散指示灯坏，需换新。',
#   0),
#  (600,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线三通盖损坏，立即整改',
#   0),
#  (603, '三小场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t员工未组织参加应急演练', 0),
#  (604, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器换新', 0),
#  (605,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t老化车间化学品未张贴安全标签；且未放置化学品专用仓库内',
#   0),
#  (606,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t检查电箱无防护栏，并更新警示标示，整改',
#   0),
#  (607,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道有货物堆积',
#   0),
#  (608,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t电箱无张贴有点危险标示',
#   0),
#  (610,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t用电插座距离货物太近，需拆除插座',
#   0),
#  (611,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t皮带轮未加防护照',
#   0),
#  (612,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间插座有破损现象',
#   0),
#  (615,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道堆放货物',
#   0),
#  (616,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t疏散通道有被占用情况，提出后已整改！',
#   0),
#  (617,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t常闭防火门一边未关闭',
#   0),
#  (618,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改',
#   0),
#  (619,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱上有杂物。',
#   0),
#  (620, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t未进行有限空间的演练', 0),
#  (624,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t3、消防设施、器材和消防安全标志是否在位、完整；',
#   0),
#  (625,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t巡查发现仓库外墙人行通道偏窗户处放了两叉板货，影响消防安全通道畅通事项，立即整改OK.',
#   0),
#  (626,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t员工安全培训会议，讲解用电安全，操机安全，防火安全，正确使用灭火器，站好年前最后一班安全岗',
#   0),
#  (627,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t插排电源没有放好 太乱 ',
#   0),
#  (628,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞，无安全出口指示标志',
#   0),
#  (629, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t管道漏液结晶', 0),
#  (630,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门未关闭',
#   0),
#  (631,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t杂物已清理。',
#   0),
#  (632,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t未贴消防指示标识  已整改',
#   0),
#  (635, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t用插座拉电吹风扇', 0),
#  (636,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t仓库的危险品没有贴严禁烟火标识。立马改善OK',
#   0),
#  (637,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t必须及时更新安全记录，并存档',
#   0),
#  (639, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t消防器材没按规定摆放', 0),
#  (641,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线未安装线巢',
#   0),
#  (642,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t灭火器过期更换',
#   0),
#  (643,
#   '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t无定期进行应急演练，只是偶尔。',
#   0),
#  (644,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明不亮。已坏新的应急照明灯。已保证通道畅通，',
#   0),
#  (645,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t消防通道堵塞',
#   0),
#  (646,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防器材通道被遮挡',
#   0),
#  (648,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t2、危险作业\t1、凡涉及动火、高空、有限空间、密闭容器、起重、施工动土、临时用电等危险作业，应明确危险作业的申请、审批权限、职责和程序，办理作业票证，安排专门人员进行现场安全管理。\t危险作业审批不严格。',
#   0),
#  (650,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器没点检',
#   0),
#  (652,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t配电房门窗未安装防鼠措施',
#   0),
#  (653,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t部分灭火器过期.',
#   0),
#  (654,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t一车间消防器材被周转车及物料堵住，已整改。',
#   0),
#  (655,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道放了东西，已移走',
#   0),
#  (657,
#   '三小场所（现场）—2016版\t（二）电气安全\t3、电气线路\t1、电气线路应穿金属管或阻燃型PVC管保护，不得使用双绞线（俗称花线）。\t线管风化，漏花线',
#   0),
#  (659, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t车间灭火器配备的数量不足', 0),
#  (661, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t消防设施周围有杂物。', 0),
#  (662,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间有杂物堵住通道，已整改',
#   0),
#  (663, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t车间过道有少量杂物放置', 0),
#  (664,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口旁堆有少量水桶，已整改拿开。',
#   0),
#  (665,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志模糊不清',
#   0),
#  (667, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t已整改', 0),
#  (668,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t部分老旧安全指示标志脱落破损，更换新的安全指示标志',
#   0),
#  (670,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t ',
#   0),
#  (671,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (672,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t照明灯不亮',
#   0),
#  (674,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t三楼顶气泵干燥机不制冷，维修更换干燥机风扇线圈。',
#   0),
#  (675,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t巡查时发现消防栓下有杂物堆积',
#   0),
#  (680,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器有四个气压过低已更换。',
#   0),
#  (682,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器不合格',
#   0),
#  (685,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口堵塞',
#   0),
#  (687,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散指示标志补磨损，已更换。',
#   0),
#  (688, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电箱遮挡缺失', 0),
#  (689,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t车间移动风扇网格间隙过大',
#   0),
#  (690,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间部分插座未接地线',
#   0),
#  (691,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t年初未组织应急演练，立即组织演练。',
#   0),
#  (692,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电室杂物堆放',
#   0),
#  (694,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t影响使用，不能及时的灭火',
#   0),
#  (696,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道上有物品堆积，立即移走，恢复通畅',
#   0),
#  (698,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t饮水机水桶霸占消防通道，已经整理完毕。',
#   0),
#  (700,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t碰焊机用的插座未接地线',
#   0),
#  (701,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器没有摆放到指定位置，立即整改。',
#   0),
#  (702,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t疏散指示标志灯不亮，应急照明灯不亮，已更换',
#   0),
#  (703,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防器材自检漏检',
#   0),
#  (704,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t灭火器配备不齐全，已添加新的灭火器·',
#   0),
#  (705,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t有纸堵门，马上清理，立畅通',
#   0),
#  (706,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堆放部分杂物，已即刻整改',
#   0),
#  (707,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t值班室有一灭火器合格标签上有效期已过，已责令维护人员更换并进行安全教育。',
#   0),
#  (708,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t未定期校验，隐患整改时间选定不了，未整改',
#   0),
#  (709, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t立刻整改', 0),
#  (710,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t半成品仓灭火器配置不足。',
#   0),
#  (711,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道被堵塞',
#   0),
#  (712,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t15栋北侧消防车通道被车辆堵塞，现场立即疏通',
#   0),
#  (713,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t厨房电箱开关无警示标识',
#   0),
#  (714,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (715,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处打开状态',
#   0),
#  (716,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防出口指示灯坏',
#   0),
#  (718,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t宿舍区有两处应急疏散指示灯故障——已报修',
#   0),
#  (719, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t没有记录，', 0),
#  (721, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t防火巡查情况；', 0),
#  (725,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t电源开关正下方堆放可燃物品',
#   0),
#  (726,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t八栋一楼车间有一个应急灯冲不了电，断电2分钟后不亮，已立即通知工程部维修。',
#   0),
#  (727,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t开关箱下面堆放杂物',
#   0),
#  (728,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。',
#   0),
#  (729,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t增加地面通道标线，安全出口指示灯',
#   0),
#  (730,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t安全管理人员未持证（已报名学习）',
#   0),
#  (733, '三小场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t无演练记录', 0),
#  (737,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道堵塞',
#   0),
#  (738,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t二楼展厅缺少安全疏散逃生指示牌（立即加装安全逃生疏散牌）',
#   0),
#  (740,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全标识不到位，厂内没有设置禁止吸烟标志，立即整改',
#   0),
#  (741,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t应急灯坏了，没有及时更换',
#   0),
#  (742,
#   '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t三瓶灭火器压力低，已统一送去加压',
#   0),
#  (743,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t灭火器未定期检查',
#   0),
#  (745,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全门未打开',
#   0),
#  (746,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t三楼有一个疏散指示灯不亮了',
#   0),
#  (747,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t二办公室应急灯不正常，已经立即购买新的更换。',
#   0),
#  (749,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器需充粉',
#   0),
#  (750, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t消防栓下面堆放物品，已及时清理', 0),
#  (751,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t9楼946房门口消火栓贴纸脱落，现场更换，已整改',
#   0),
#  (752,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口不明显',
#   0),
#  (753, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t9、消防（控制室）值班情况和设施运行、记录情况；\t无此项', 0),
#  (754,
# ...
#  (1297,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散指示标志、应急照明设置不规范',
#   0),
#  (1299, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况', 0),
#  (1301,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t1、危险化学品从业单位通用要求\t5、可能产生易燃易爆气体的场所，必须设置可燃气体的检测和自动报警装置。\t没有自动报警装置',
#   0),
#  (1302,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t整改',
#   0),
#  (1303,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道不畅通',
#   0),
#  (1306,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t仓库里的灭火器被移动了，已整改',
#   0),
#  (1307,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t应急指示灯不亮',
#   0),
#  (1308,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t微波炉更改漏电插座',
#   0),
#  (1309,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯一个不亮，已整改',
#   0),
#  (1310,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t个别标识片贴的位置不合适，已重新贴到相应位置。',
#   0),
#  (1311,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施',
#   0),
#  (1312,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000\t五楼东，应急灯损坏',
#   0),
#  (1313,
#   '商贸服务教文卫类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t3、安全管理机构和管理人员配备及履职情况\t1、安全管理机构、安全管理人员配备及依法履行安全管理职责\t无安全主任',
#   0),
#  (1314,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t注塑技工未穿劳保鞋',
#   0),
#  (1315,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t4、职业卫生管理档案\t1、存在职业病危害的生产经营单位，须建立健全职业卫生档案资料。\t没有建立健全职业卫生档案资料',
#   0),
#  (1317,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处于打开状态',
#   0),
#  (1318,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t标识不清楚/脱落',
#   0),
#  (1319,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t部分通道堆放货物',
#   0),
#  (1320, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器压力不足。', 0),
#  (1321,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志不清楚，已整 改',
#   0),
#  (1322,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t没有建立事故隐患排查治理档案',
#   0),
#  (1323,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口、疏散通道旁堆放杂物',
#   0),
#  (1324,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t玻璃门不是防火\n\n现已安装防火门',
#   0),
#  (1325,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线裸露',
#   0),
#  (1326,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t没有',
#   0),
#  (1327,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散指示标志不清晰',
#   0),
#  (1328,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t二幢车间楼梯应急照明已坏',
#   0),
#  (1334,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t安全警示脱落   重新固定',
#   0),
#  (1335,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t1、建立并保存事故隐患排查治理档案。',
#   0),
#  (1336,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯坏',
#   0),
#  (1337,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器数量不足',
#   0),
#  (1338,
#   '工业/危化品类（选项）—2016版\t（七）重点监管工艺及场所\t7、锂电池生产或储存\t8、每块电池（电芯）的正（负）极位置必须有绝缘防止短路保护措施。\t不良品电池未归回入不良品区域',
#   0),
#  (1339,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱内掉有螺丝',
#   0),
#  (1340,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t1-2楼目前还处于装修阶段，暂未配备灭火器材',
#   0),
#  (1341,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t开关箱内放置了杂物',
#   0),
#  (1342,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t油漆部有台风扇连接线中间有接头，需要更换',
#   0),
#  (1343, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器老化', 0),
#  (1346,
#   '工业/危化品类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t2、分管负责人履职情况\t1、分管负责人依法履行安全管理职责（存在职业健康危害的单位需自查职业卫生履职情况）。\t最近一个季度没有组织安全演练',
#   0),
#  (1347,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道上有货物',
#   0),
#  (1348,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急照明灯有一个坏了',
#   0),
#  (1349, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器压力不正常', 0),
#  (1350, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期，存在隐患', 0),
#  (1351,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t未张贴安全告知卡',
#   0),
#  (1353,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t未检查消防安全重点部位的管理情况；',
#   0),
#  (1354, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器干粉用尽，已充满', 0),
#  (1355,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t吊机和员工车位都重新安装自动跳闸开关。',
#   0),
#  (1356,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t楼道口停放电动车，堆放货物。  发现后，立即通知相关人员处理。',
#   0),
#  (1358,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t2、危险作业\t1、凡涉及动火、高空、有限空间、密闭容器、起重、施工动土、临时用电等危险作业，应明确危险作业的申请、审批权限、职责和程序，办理作业票证；安排专门人员进行现场安全管理。\t有限空间作业，水池清洗作业与操作单位未签到安全管理协议，近期着手完善。',
#   0),
#  (1359,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端',
#   0),
#  (1361,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t2、危险作业\t1、凡涉及动火、高空、有限空间、密闭容器、起重、施工动土、临时用电等危险作业，应明确危险作业的申请、审批权限、职责和程序，办理作业票证，安排专门人员进行现场安全管理。\t1. :5栋1楼登高梯台处无“当心坠落”警示标志；2. :5栋1楼部分配电盒处无“当心触电”警示标志；',
#   0),
#  (1362,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急照明灯不亮，已更换新的',
#   0),
#  (1363,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵塞消防通道，已整改',
#   0),
#  (1364,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t巡查发现后门消防门闭门器损坏，指示牌缺失。现已处理好',
#   0),
#  (1365,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t1栋8楼常闭式防火门未关闭，已现在整改',
#   0),
#  (1367,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有一个应急照明灯坏了',
#   0),
#  (1368,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器没有进行检查，查验是否合格，有一个失效',
#   0),
#  (1370,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t抛光机，砂轮机，铣床没有安全防护装置',
#   0),
#  (1371,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道被货物堵塞',
#   0),
#  (1372,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t封口机用后未拔电源',
#   0),
#  (1373,
#   '商贸服务教文卫类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育\t1、制定安全教育培训计划，确保全员参与培训，并建立安全培训档案。\t没有经过安全教育培训',
#   0),
#  (1375,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有杂物',
#   0),
#  (1376,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t消防灭火器周围没有挂检查标签',
#   0),
#  (1379,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t桥架插座走线不规范',
#   0),
#  (1380,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有货物摆放',
#   0),
#  (1381,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有隐患',
#   0),
#  (1382, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器', 0),
#  (1383,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t1.現場塗料桶未夾靜電接地夾。2.電器線路上面有易燃物。3.開關蓋板沒鎖好。',
#   0),
#  (1384,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000\t“禁止吸烟“标识破损 ，已更新。                                                                    ',
#   0),
#  (1385,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t电风扇电线没有装套管',
#   0),
#  (1387, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器材失效情况', 0),
#  (1389,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散标识线路不通',
#   0),
#  (1390, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t部分区域未设置烟感', 0),
#  (1391,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t消防通道堵塞',
#   0),
#  (1393,
#   '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t1、库房内储存物品应分类、分堆、限额存放。\t成品仓库堆放混乱，没有分类叠放，已经通知仓库单日内整改完成。',
#   0),
#  (1394,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t新来员工之前未接受安全教育，现正在接受安全教育培训',
#   0),
#  (1395,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t新员工来，没有培训',
#   0),
#  (1396, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t有两瓶干粉灭火器过期。', 0),
#  (1397, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t没有进行演练及记录', 0),
#  (1398, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t消防演练，暂未开展。因新搬过来', 0),
#  (1399,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一个灭火器支架铆钉松脱，现已加固稳定',
#   0),
#  (1400,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t无指示标识',
#   0),
#  (1402,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器已过使用期',
#   0),
#  (1403,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道应保持畅通，禁止临时堆放货物；通道无以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。',
#   0),
#  (1404,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况。\t电线有裸漏部分  立即整改',
#   0),
#  (1406,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t没按规定安装',
#   0),
#  (1407,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000\t实验台东西堆放比较杂乱',
#   0),
#  (1409,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道是否畅通',
#   0),
#  (1410,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道堵塞已立即整改',
#   0),
#  (1411,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t修理车间使用的手持砂轮机防护板松动。',
#   0),
#  (1413,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t指示标识不明显',
#   0),
#  (1414,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t啤机电源连接线无保护套管，可能会破损漏电，现场已加装电线套管固定好。',
#   0),
#  (1415, '商贸服务教文卫类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t个别员工演练不熟。加强培训', 0),
#  (1416,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t大会议室一个灭火器压力位为红色区域',
#   0),
#  (1417,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t有两个灭火器失压，已经更换好',
#   0),
#  (1418, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t饮水机旁边有电线外露。', 0),
#  (1419,
#   '三小场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、生产经营场所应按规定配备足够、性能适用的灭火器；不得使用淘汰及禁止使用的灭火器；灭火器固定摆放，定期校验，过期必须及时更换\t灭火器摆放不当',
#   0),
#  (1422, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防通道占用', 0),
#  (1424,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未对员工进行安全教育',
#   0),
#  (1425,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t仓库已更换换乙级防火门',
#   0),
#  (1427,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t电动自行车随意放置办公室',
#   0),
#  (1428,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t、安全出口、疏散通道不畅通，安全疏散指示标志、应急照明不完好。',
#   0),
#  (1429,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t封闭门没及时关上',
#   0),
#  (1430,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有杂物',
#   0),
#  (1431,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t无',
#   0),
#  (1432,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t一台设备防护罩未装好',
#   0),
#  (1433,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t铣床作业区未张贴“严禁戴手套操作”“必须戴防护眼镜”“当心机械伤害”安全标志',
#   0),
#  (1434,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t一个安全出口处消防门损坏，需换新',
#   0),
#  (1435,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t缺少治理档案。',
#   0),
#  (1436,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线有裸露情况，立即整改！           整改完成！',
#   0),
#  (1437,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t事故隐患排查治理档案不够全面',
#   0),
#  (1438,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；',
#   0),
#  (1442,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座、电源插头应按规定正确接线。',
#   0),
#  (1443,
#   '工业/危化品类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t3、安全管理机构和管理人员履职情况\t1、安全生产管理机构、安全生产管理人员依法履行安全生产管理职责（存在职业健康危害的单位，包括职卫管理机构及职卫管理人员）。\t切纸机打油后（切纸机，机器退进位打机油，磨损致使机械无法正常工作，经过师傅维修清洗打油，可以正常工作！',
#   0),
#  (1444,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t1、特种设备档案\t1、特种设备(及安全附件)检测报告齐全，并在有效期内。运行记录和维修保养记录齐全。\t空压机安全检查维护记录表被雨淋湿，重新放置，已整改',
#   0),
#  (1445,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下堆放货物，有安全隐患',
#   0),
#  (1446,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t未建立全员安全生产责任制',
#   0),
#  (1447,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全标志缺失',
#   0),
#  (1448,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t仓库一楼B区消防电话分机和风机启动开关货物遮挡，已立即整改，把货物移走',
#   0),
#  (1449,
#   '建筑施工类（基础）—2016版\t（五）安全管理档案\t6、安全生产奖惩记录\t1、建立安全生产奖惩记录。\t检查时发现安全资料并不太完善，已作整改',
#   0),
#  (1450, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t部分灭火器已失效，已更换', 0),
#  (1451,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器部分过期',
#   0),
#  (1452,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t车间照明控制漏电开关坏，已更换 ',
#   0),
#  (1456,
#   '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。',
#   0),
#  (1457,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t常闭式防火门，闭门器损坏，已更换',
#   0),
#  (1459,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t没有安全疏通指示标志，没有应急照明灯',
#   0),
#  (1460,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t1、特种设备档案\t1、特种设备(及安全附件)检测报告齐全，并在有效期内。运行记录和维修保养记录齐全。\t电箱没有挡板，需要增加挡板',
#   0),
#  (1462,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t个别应急照明灯损坏',
#   0),
#  (1464, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t9、消防（控制室）值班情况和设施运行、记录情况；\t无', 0),
#  (1465,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门坏，立即整改',
#   0),
#  (1466,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t仓库堆放不整齐',
#   0),
#  (1468,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t无记录',
#   0),
#  (1469, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t ', 0),
#  (1470,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材需要定期检查贴有效标识，计划本月完成所有灭火器的检测与更换。',
#   0),
#  (1472,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱门张贴“当心触电”安全警示标志脱落',
#   0),
#  (1473, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有定期消防消防演习', 0),
#  (1474,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t年底地面黄色警戒线已经模糊不清，计划在春节放假期间重刷油漆。',
#   0),
#  (1475,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有杂物',
#   0),
#  (1477,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t防火门末及时关闭',
#   0),
#  (1478,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\t移动插座电线破损',
#   0),
#  (1480, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况；', 0),
#  (1481,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱前放有杂物',
#   0),
#  (1485,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t在木工车间存在物料堆放在疏散通道上',
#   0),
#  (1486,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道被货堵住，已把货物移走',
#   0),
#  (1488,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t遮挡消防器材',
#   0),
#  (1489,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t啤机通道内放货',
#   0),
#  (1491,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口处未设置安全出口标志，已整改',
#   0),
#  (1492,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t未及时更新',
#   0),
#  (1493,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (1496,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道轻微堵塞，立即整改后恢复正常',
#   0),
#  (1498,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  ...]

# %%
def evaluate(data):
    total, right = 0., 0.
    for x_true, y_true in data:
        y_pred = model.predict(x_true).argmax(axis=1)
        y_true = y_true.argmax(axis=1)
        total += len(y_true)
        right += (y_true == y_pred).sum()
    return right / total


class Evaluator(keras.callbacks.Callback):
    """评估与保存
    """
    def __init__(self):
        self.best_val_acc = 0.
        self.data = data_generator(unlabeled_data, batch_size).forfit()

    def on_epoch_end(self, epoch, logs=None):
        val_acc = evaluate(valid_generator)
        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            model.save_weights('best_model.weights')
        test_acc = evaluate(test_generator)
        print(
            u'val_acc: %.5f, best_val_acc: %.5f, test_acc: %.5f\n' %
            (val_acc, self.best_val_acc, test_acc)
        )

    def on_batch_end(self, batch, logs=None):
        if use_vat:
            id,dx,dy = next(self.data)
            model_vat.train_on_batch(id,dx, dy)
            
# class Evaluator(keras.callbacks.Callback):
#     """评估与保存
#     """
#     def __init__(self):
#         self.best_val_acc = 0.

#     def on_epoch_end(self, epoch, logs=None):
#         val_acc = evaluate(valid_generator)
#         if val_acc > self.best_val_acc:
#             self.best_val_acc = val_acc
#             model.save_weights('best_model.weights')
# #         test_acc = evaluate(test_generator)
# #         print(
# #             u'val_acc: %.5f, best_val_acc: %.5f, test_acc: %.5f\n' %
# #             (val_acc, self.best_val_acc, test_acc)
# #         )
#         test_acc = evaluate(valid_generator)
#         print(
#             u'val_acc: %.5f, best_val_acc: %.5f, test_acc: %.5f\n' %
#             (val_acc, self.best_val_acc, test_acc)
#         )

# %%
len(train_generator)
# Out:
# 3

# %%
evaluator = Evaluator()

# %%
model.fit(
        train_generator.forfit(),
        steps_per_epoch=30,
        epochs=10,
        callbacks=[evaluator]
    )
# Out:
# Epoch 1/10
#  1/30 [>.............................] - ETA: 14s - loss: 0.0042 - categorical_accuracy: 0.8438
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-58-d673013e8999> in <module>
# ----> 1 model.fit(
#       2         train_generator.forfit(),
#       3         steps_per_epoch=30,
#       4         epochs=10,
#       5         callbacks=[evaluator]
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1131             training_utils.check_generator_arguments(
#    1132                 y, sample_weight, validation_split=validation_split)
# -> 1133             return self.fit_generator(
#    1134                 x,
#    1135                 steps_per_epoch=steps_per_epoch,
#
# ~/anaconda3/lib/python3.8/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1716         ```
#    1717         """
# -> 1718         return training_generator.fit_generator(
#    1719             self, generator,
#    1720             steps_per_epoch=steps_per_epoch,
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     224                     batch_logs[l] = o
#     225
# --> 226                 callbacks._call_batch_hook('train', 'end', batch_index, batch_logs)
#     227
#     228                 batch_index += 1
#
# ~/anaconda3/lib/python3.8/site-packages/keras/callbacks/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#      83         for callback in self.callbacks:
#      84             batch_hook = getattr(callback, hook_name)
# ---> 85             batch_hook(batch, logs)
#      86         self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#      87
#
# ~/anaconda3/lib/python3.8/site-packages/keras/callbacks/callbacks.py in on_train_batch_end(self, batch, logs)
#     364         """
#     365         # For backwards compatibility
# --> 366         self.on_batch_end(batch, logs=logs)
#     367
#     368     def on_test_batch_begin(self, batch, logs=None):
#
# <ipython-input-55-142615a1893d> in on_batch_end(self, batch, logs)
#      30         if use_vat:
#      31             dx, dy = next(self.data)
# ---> 32             model_vat.train_on_batch(dx, dy)
#      33
#      34 # class Evaluator(keras.callbacks.Callback):
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# <ipython-input-36-ff9c3c0b8179> in train_function(inputs)
#      49             K.set_value(embeddings, K.eval(embeddings) - delta1 + delta2)
#      50             delta1 = delta2
# ---> 51             delta2 = embedding_gradients(inputs)[0]  # Embedding梯度
#      52         delta2 = epsilon * l2_normalize(delta2)
#      53         K.set_value(embeddings, K.eval(embeddings) - delta1 + delta2)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3790         value = math_ops.cast(value, tensor.dtype)
#    3791       converted_inputs.append(value)
# -> 3792     outputs = self._graph_fn(*converted_inputs)
#    3793
#    3794     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    1603       TypeError: For invalid positional/keyword argument combinations.
#    1604     """
# -> 1605     return self._call_impl(args, kwargs)
#    1606
#    1607   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1643       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1644           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1645     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1646
#    1647   def _filtered_call(self, args, kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# InvalidArgumentError:  logits and labels must have the same first dimension, got logits shape [32,2] and labels shape [64]
# 	 [[node loss_3/dense_146_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits (defined at /root/anaconda3/lib/python3.8/site-packages/keras/backend/tensorflow_backend.py:3007) ]] [Op:__inference_keras_scratch_graph_140595]
#
# Function call stack:
# keras_scratch_graph

# %%
model.load_weights('best_model.weights')
# print(u'final test acc: %05f\n' % (evaluate(test_generator)))
print(u'final test acc: %05f\n' % (evaluate(valid_generator)))

# %%
print(u'final test acc: %05f\n' % (evaluate(train_generator)))

# %%
def data_pred3(test_data):
    id_ids, y_pred_ids = [], []
    for id, text, label in test_data:
        token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
        token_ids = sequence_padding([token_ids])
        segment_ids = sequence_padding([segment_ids])
        y_pred = int(model.predict([token_ids, segment_ids]).argmax(axis=1)[0])
        id_ids.append(id)
        y_pred_ids.append(y_pred)
    return id_ids, y_pred_ids

# %%
id_ids, y_pred_ids = data_pred3(test_data)

# %%
df_save = pd.DataFrame()
df_save['id'] = id_ids
df_save['label'] = y_pred_ids

# %%
df_save.to_csv('result.csv')
