# %% [markdown]
# # 导入工具包

# %%
import random
import numpy as np
import pandas as pd
from bert4keras.backend import keras, set_gelu
from bert4keras.tokenizers import Tokenizer
from bert4keras.models import build_transformer_model
from bert4keras.optimizers import Adam, extend_with_piecewise_linear_lr
from bert4keras.snippets import sequence_padding, DataGenerator
from bert4keras.snippets import open
from keras.layers import Lambda, Dense
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 设置参数

# %%
set_gelu('tanh')  # 切换gelu版本

# %%
num_classes = 2
maxlen = 128
batch_size = 32
config_path = '../model/albert_small_zh_google/albert_config_small_google.json'
checkpoint_path = '../model/albert_small_zh_google/albert_model.ckpt'
dict_path = '../model/albert_small_zh_google/vocab.txt'

# 建立分词器
tokenizer = Tokenizer(dict_path, do_lower_case=True)

# %% [markdown]
# # 定义模型

# %%
# 加载预训练模型
bert = build_transformer_model(
    config_path=config_path,
    checkpoint_path=checkpoint_path,
    model='albert',
    return_keras_model=False,
)

# %%
output = Lambda(lambda x: x[:, 0], name='CLS-token')(bert.model.output)
output = Dense(
    units=num_classes,
    activation='softmax',
    kernel_initializer=bert.initializer
)(output)

model = keras.models.Model(bert.model.input, output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input-Token (InputLayer)        (None, None)         0
# __________________________________________________________________________________________________
# Input-Segment (InputLayer)      (None, None)         0
# __________________________________________________________________________________________________
# Embedding-Token (Embedding)     (None, None, 128)    2704384     Input-Token[0][0]
# __________________________________________________________________________________________________
# Embedding-Segment (Embedding)   (None, None, 128)    256         Input-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Token-Segment (Add)   (None, None, 128)    0           Embedding-Token[0][0]
#                                                                  Embedding-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Position (PositionEmb (None, None, 128)    65536       Embedding-Token-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Norm (LayerNormalizat (None, None, 128)    256         Embedding-Position[0][0]
# __________________________________________________________________________________________________
# Embedding-Mapping (Dense)       (None, None, 384)    49536       Embedding-Norm[0][0]
# __________________________________________________________________________________________________
# Transformer-MultiHeadSelfAttent (None, None, 384)    591360      Embedding-Mapping[0][0]
#                                                                  Embedding-Mapping[0][0]
#                                                                  Embedding-Mapping[0][0]
#                                                                  Transformer-FeedForward-Norm[0][0
#                                                                  Transformer-FeedForward-Norm[0][0
#                                                                  Transformer-FeedForward-Norm[0][0
#                                                                  Transformer-FeedForward-Norm[1][0
#                                                                  Transformer-FeedForward-Norm[1][0
#                                                                  Transformer-FeedForward-Norm[1][0
#                                                                  Transformer-FeedForward-Norm[2][0
#                                                                  Transformer-FeedForward-Norm[2][0
#                                                                  Transformer-FeedForward-Norm[2][0
#                                                                  Transformer-FeedForward-Norm[3][0
#                                                                  Transformer-FeedForward-Norm[3][0
#                                                                  Transformer-FeedForward-Norm[3][0
#                                                                  Transformer-FeedForward-Norm[4][0
#                                                                  Transformer-FeedForward-Norm[4][0
#                                                                  Transformer-FeedForward-Norm[4][0
# __________________________________________________________________________________________________
# Transformer-MultiHeadSelfAttent (None, None, 384)    0           Embedding-Mapping[0][0]
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward-Norm[0][0
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward-Norm[1][0
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward-Norm[2][0
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward-Norm[3][0
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward-Norm[4][0
#                                                                  Transformer-MultiHeadSelfAttentio
# __________________________________________________________________________________________________
# Transformer-MultiHeadSelfAttent (None, None, 384)    768         Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
# __________________________________________________________________________________________________
# Transformer-FeedForward (FeedFo (None, None, 384)    1181568     Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
# __________________________________________________________________________________________________
# Transformer-FeedForward-Add (Ad (None, None, 384)    0           Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward[0][0]
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward[1][0]
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward[2][0]
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward[3][0]
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward[4][0]
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward[5][0]
# __________________________________________________________________________________________________
# Transformer-FeedForward-Norm (L (None, None, 384)    768         Transformer-FeedForward-Add[0][0]
#                                                                  Transformer-FeedForward-Add[1][0]
#                                                                  Transformer-FeedForward-Add[2][0]
#                                                                  Transformer-FeedForward-Add[3][0]
#                                                                  Transformer-FeedForward-Add[4][0]
#                                                                  Transformer-FeedForward-Add[5][0]
# __________________________________________________________________________________________________
# CLS-token (Lambda)              (None, 384)          0           Transformer-FeedForward-Norm[5][0
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            770         CLS-token[0][0]
# ==================================================================================================
# Total params: 4,595,202
# Trainable params: 4,595,202
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 派生为带分段线性学习率的优化器。
# 其中name参数可选，但最好填入，以区分不同的派生优化器。
# AdamLR = extend_with_piecewise_linear_lr(Adam, name='AdamLR')

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=Adam(1e-5),  # 用足够小的学习率
#     optimizer=AdamLR(learning_rate=1e-4, lr_schedule={
#         1000: 1,
#         2000: 0.1
#     }),
    metrics=['accuracy'],
)

# %% [markdown]
# # 生成数据

# %%
def load_data(valid_rate=0.3):
    train_file = "../data/train.csv"
    test_file = "../data/test.csv"
    
    df_train_data = pd.read_csv("../data/train.csv")
    df_test_data = pd.read_csv("../data/test.csv")
    
    train_data, valid_data, test_data = [], [], []
    
    for row_i, data in df_train_data.iterrows():
        id, level_1, level_2, level_3, level_4, content, label = data
        
        id, text, label = id, str(level_1) + '\t' + str(level_2) + '\t' + \
        str(level_3) + '\t' + str(level_4) + '\t' + str(content), label
        
        if random.random() > valid_rate:
            train_data.append( (id, text, int(label)) )
        else:
            valid_data.append( (id, text, int(label)) )
            
    for row_i, data in df_test_data.iterrows():
        id, level_1, level_2, level_3, level_4, content = data
        
        id, text, label = id, str(level_1) + '\t' + str(level_2) + '\t' + \
        str(level_3) + '\t' + str(level_4) + '\t' + str(content), 0
        
        test_data.append( (id, text, int(label)) )
    return train_data, valid_data, test_data

# %%
train_data, valid_data, test_data = load_data(valid_rate=0.3)

# %%
valid_data
# Out:
# [(5,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t防爆柜里面稀释剂，机油费混装',
#   0),
#  (8,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t已整改',
#   1),
#  (17,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堆满货物',
#   0),
#  (20,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t走廊通道有一个灭火器到期，立即整改',
#   0),
#  (22,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散指示灯故障',
#   0),
#  (29,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t一楼四号常闭式防火门，经常被杂物堆放，责令清洁部，清理干净保持防火门关闭状态',
#   0),
#  (30,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t上月检查时灭火器表并未及时更新，现已更新完毕，整改完成。',
#   0),
#  (31, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器未点检', 0),
#  (35, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t没有安装防爆灯，已整改。', 0),
#  (37,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t尾部和车间的消防通道堵塞，要马上清理；成品箱码的超高不安全要调整。',
#   0),
#  (39,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t配电室的门、窗关闭应密合',
#   1),
#  (46,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t部分安全出口指示标志脱落。',
#   0),
#  (47,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防栓门口被桶装水堵塞。',
#   0),
#  (49,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t12号机后边通道有一卡板货压线',
#   0),
#  (56,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防标志不明晰',
#   0),
#  (58, '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器过期', 0),
#  (61,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t临时堆放货物，已整改',
#   0),
#  (62,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t杂物堆放消防通道，已马上整改。',
#   0),
#  (63,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道指示线不清晰',
#   0),
#  (64,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t公司三楼办公楼走北侧楼梯间灭火器标志脱落，已贴好。',
#   0),
#  (70,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t未放置防爆柜子里',
#   0),
#  (73,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t28栋7楼安全出口堵塞，现场已整改',
#   0),
#  (77,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散通道堆放杂物',
#   0),
#  (79,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t4、插拔插头时，应保证电气设备和电气装置处于非工作状态，同时人体不得接触及插头的导电极，并避免对电源线施加外力。\t立式空调电源无地线',
#   0),
#  (81,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\tG1栋2楼车间内工作台照明电源线套管破损（已整改）。',
#   0),
#  (82,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t有两个配电箱门未张贴“当心触电”安全警示标志。立即张贴',
#   0),
#  (87,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (102,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (103,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t机器设备放置纸板属于已燃物品',
#   0),
#  (110, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器过期已更换新', 0),
#  (116,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t乐群楼17楼应急灯无电源',
#   0),
#  (118, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t下雨，厂房墙面垮倒', 0),
#  (120,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口堵塞',
#   0),
#  (121,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t有3个灭火器压力偏底，要更换',
#   0),
#  (123,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t占用、堵塞、封闭',
#   0),
#  (126,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电箱上有杂物',
#   0),
#  (127,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t缺少本季度安全生产会议记录，已整改。',
#   0),
#  (128,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱旁放了几个纸箱',
#   0),
#  (129,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物乱堆放，阻塞逃生通道',
#   0),
#  (133,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改',
#   1),
#  (136,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全标志掉落；立即整改，张贴完好。',
#   0),
#  (141,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t甩干机没有作业指导书',
#   0),
#  (142,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t电池仓库货架接地不规范，需螺栓连接或焊接 压接',
#   0),
#  (143,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；',
#   1),
#  (146,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t一楼A4区灭火器下面堆放杂物',
#   0),
#  (147,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t下沙新村潮歌苑4栋1单元1楼防火门敞开',
#   1),
#  (151,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口有堆放货物，隐患已整改，通道货物已挪开',
#   0),
#  (152,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t有',
#   1),
#  (153,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t标志',
#   1),
#  (155,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t部分灭火器材过期未能正常使用。',
#   0),
#  (157,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t作业场所通风不好',
#   0),
#  (161,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t本单元重新整改装修，装修后消防门摆放了较大的绿植物',
#   0),
#  (164,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有障碍',
#   0),
#  (165,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t仓库通道一个灭火器被移动位置',
#   0),
#  (174,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t临时用电没有安装漏电保护装置，立即安装',
#   0),
#  (176,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵塞消防通道',
#   0),
#  (179,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器有损坏，立即购买新的更换。',
#   0),
#  (186, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器失效', 0),
#  (187,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道有隐患',
#   0),
#  (188,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间消防通道有被货物堵塞，现已作出整改',
#   0),
#  (189,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t9楼，一防火门上“安全出口”标识非常亮状态',
#   0),
#  (190,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t大厦东面外围楼梯角落有杂物堆放，即时叫人搬离',
#   0),
#  (192,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯损坏',
#   0),
#  (193,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000\t宿舍楼下临时停放电车',
#   0),
#  (194,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t补充2个新的灭火器',
#   0),
#  (201, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器未点检', 0),
#  (203, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t9层东区放杂物', 0),
#  (205,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线线皮破损',
#   0),
#  (206,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道货物已清理已畅通',
#   1),
#  (208,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t新员工有一人未完成班组级安全教育，就安排上岗。',
#   0),
#  (210,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t没有张贴安全标识',
#   0),
#  (213,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t办公室灭火器没有定期检查签字',
#   0),
#  (215,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t指示灯不亮',
#   0),
#  (218,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱未张贴“当心触电”安全警示标志',
#   0),
#  (221,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\tC型钢压型机器轴承破、购新轴承更换',
#   0),
#  (222,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火卷帘下堆放物品',
#   0),
#  (230,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t楼梯消防门闭门器损坏',
#   0),
#  (235,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道堆放杂物',
#   0),
#  (238,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t没有疏散通道、安全出口设置应急照明灯和疏散指示标志',
#   0),
#  (239,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未制定2019年年度培训计划',
#   0),
#  (242,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t有两个电源开关接触不良，已购买更换',
#   0),
#  (243,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火卷帘处堆放纸箱及货物',
#   0),
#  (251,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t     ',
#   1),
#  (252,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t没有经过安全教育培训',
#   0),
#  (253,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t点检表欠缺，未点检。',
#   0),
#  (254,
#   '交通运输类（选项）—2016版\t（六）普通货运企业\t6、集装箱运输\t1、在集装箱运输车辆上安装有导航系统功能的行驶记录仪。\t未见装行车记录仪，马上配备装上。确保安全记录。',
#   0),
#  (261,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有障碍物',
#   0),
#  (264,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t注塑部一楼车间消防通道被临时堆放的货物堵塞，马上整改完成。',
#   0),
#  (268,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口指示牌故障。已更换。',
#   0),
#  (273,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t走廊消防通道被货物堵塞',
#   0),
#  (277,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散应急灯不亮',
#   0),
#  (279,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t更换新的灭火器，检查灭火器的作用',
#   0),
#  (286,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有隐患',
#   1),
#  (289,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道上摆放有产品，存有安全隐患。已整改。',
#   0),
#  (295,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t一楼车间裁床电箱内放有废手套等杂物',
#   0),
#  (296, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防车通道有杂物堆积', 0),
#  (299,
#   '工业/危化品类（选项）—2016版\t（五）特种设备\t5、起重机械\t3、设备上应悬挂安全操作规程、交接班记录和安全检查记录。\t操作行车处未见安全操作规程',
#   0),
#  (300,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口堵',
#   0),
#  (302,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t工厂内有一配电箱未安装防护板',
#   0),
#  (304,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全标志不完整',
#   0),
#  (308,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t2019年02月起，未建立隐患排查档案',
#   0),
#  (313,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t安全通道堆放货物，存在安全隐患',
#   0),
#  (315,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t2、手持式电动工具、移动电器等设备应优先选用额定剩余动作电流不大于30mA、一般型（无延时）的剩余电流保护装置；潮湿场所的电气设备使用16-30mA动作电流、无延时；在金属物件上作业的手持电动工具使用10mA动作电流、无延时漏电保护开关。\t电池随处进行充电，未按照公司《电池安全防护规范》进行充电及记录。',
#   0),
#  (316,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t涂装一车间小地线电箱没张贴“警示标志”',
#   0),
#  (323,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t因老化原因部分通电式安全出口标志不亮',
#   0),
#  (324,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防栓下面堆放物料',
#   0),
#  (326,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急指示灯损坏，已更换',
#   0),
#  (330,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有临时堆放货物   ',
#   0),
#  (331,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器停放过长粉不足，已充足，',
#   0),
#  (333,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线乱拉乱接',
#   0),
#  (334,
#   '工业/危化品类（选项）—2016版\t（五）特种设备\t2、压力容器\t3、安全阀有有效的检验报告及铅封标记。压力表有有效的检定证书及标记。\t有车间压力表快到期/及时安排人员在有效期内进行更换',
#   0),
#  (336,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t堆放有杂物',
#   0),
#  (338,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t安全疏散通道堵塞',
#   0),
#  (340,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器位置未放到位。未按时检查',
#   0),
#  (341,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t消房通道放物品',
#   0),
#  (344,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防铲掉落',
#   0),
#  (345,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道被档住；',
#   0),
#  (347,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防器材。以整改',
#   1),
#  (350,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\tC栋一楼封边机操作人员未佩戴劳动防护用品（耳塞）',
#   0),
#  (351,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯不亮',
#   0),
#  (355,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t消防安全标志不全',
#   0),
#  (356,
#   '商贸服务教文卫类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t未贴操作指南',
#   0),
#  (361,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道划线模糊',
#   0),
#  (364,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t应急照明灯损坏',
#   0),
#  (366,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材检查表未更新',
#   0),
#  (369,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t“当心触电”安全警示标志脱落',
#   0),
#  (370,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器已过期，现场已更换。',
#   0),
#  (371,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有物品占用。',
#   0),
#  (372,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门关闭',
#   0),
#  (386, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器未定期检查', 0),
#  (389,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门未常闭',
#   0),
#  (391,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防水带捆绑不正确且老化，需更新',
#   0),
#  (395,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道堆放货物',
#   0),
#  (397, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器不够，新增几个', 0),
#  (398,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t后堂配电箱内存在灰尘，已处理',
#   0),
#  (401,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间通道被货物堵塞',
#   0),
#  (406,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱(柜)门未张贴有“当心触电”安全警示标志',
#   0),
#  (409,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t电梯出口有货物存放，已立即整改',
#   0),
#  (410, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志', 1),
#  (411,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有些门口未装置应急照明灯',
#   0),
#  (414,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有及时组织应急演练，2019年11月25日组织了应急演练',
#   0),
#  (415,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道标示线',
#   0),
#  (419, '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t1、临时用电必须经过审批。\t不足', 1),
#  (421,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t地面安全通道标识有缺损，',
#   0),
#  (426,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全标志不完整',
#   0),
#  (427,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有一盏应急照明灯损坏，已立即更换整改。',
#   0),
#  (432,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (433,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (435,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t未建立应急预案',
#   0),
#  (439,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t设置的当心触电标志脱落，立即更换新的标志',
#   0),
#  (443,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t发现闭门器坏了',
#   0),
#  (448,
#   '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t1、库房内储存物品应分类、分堆、限额存放。\t仓库物品摆放过高，不符合“五距”要求。',
#   0),
#  (462,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t一处落地扇电源线未使用双层绝缘电线。',
#   0),
#  (463,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t未张贴安全警示标志',
#   0),
#  (465,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t插座相接，用电有隐患',
#   0),
#  (466,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器翻倒',
#   0),
#  (468,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t未检查灭火器材配置及有效情况；',
#   0),
#  (470,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有即将过有效期，要求定期更换ABC干粉灭火器',
#   0),
#  (484,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t赤湾港区21#小叉车灭火器点检表缺少8月份的检点记录',
#   0),
#  (485,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏通道放有少许杂物，已清理。',
#   0),
#  (499,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全疏散指示标志',
#   1),
#  (501, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t卸油口盖静电接地线线头脱落', 0),
#  (502,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有废弃物阻挡部分通道，现已清理；有安全通道地标损坏，现已更换',
#   0),
#  (503,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防灭火器检查清洗',
#   1),
#  (505,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t配电室电源线箱跨接线，已整改。',
#   0),
#  (508,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散通道不畅通',
#   0),
#  (510,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t三楼镭射机没有安装红外线防护。',
#   0),
#  (512,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接。\t已整改',
#   1),
#  (516,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物',
#   0),
#  (519,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t消防通道停放自行车',
#   0),
#  (520,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器失效',
#   0),
#  (521,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材大部分已过期或失效，立即购买新的灭火器。',
#   0),
#  (523,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道有时候有清洁阿姨堆砌了一些纸箱杂物，未及时挪开，已告知阿姨不要堆杂物。',
#   0),
#  (525,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好',
#   1),
#  (529,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t多余线未处理',
#   0),
#  (530,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t未能按时检查及签名记录',
#   0),
#  (532,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t通道标识线有磨损现象',
#   0),
#  (537, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t二楼调油房气味刺鼻，通风不良', 0),
#  (553,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口指示灯不亮。',
#   0),
#  (559,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t ',
#   1),
#  (560,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t检查安全出口，疏散通道标志为荧光的，现已更换为通电带灯罩形。',
#   0),
#  (562,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道阻塞',
#   0),
#  (563,
#   '建筑施工类（基础）—2016版\t（五）安全管理档案\t4、特种设备及操作人员管理记录\t3、各种特种设备的运行记录和维修保养记录齐全。\t1.4号塔吊运行记录填写过于简单。',
#   0),
#  (565,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t2、危险化学品生产、储存单位\t1、生产企业应当提供与其生产的危险化学品相符的化学品安全技术说明书，并在危险化学品包装（包括外包装件）上粘贴或者拴挂与包装内危险化学品相符的化学品安全标签。\t设备部化学品容器未张贴安全标签；',
#   0),
#  (568, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器前放置拖车', 0),
#  (569,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道安全出口指示牌故障，已经更换新的安全出口指示牌。',
#   0),
#  (570,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器被遮挡，隐患已整改，遮挡灭火器的杂物已清理。',
#   0),
#  (575,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t车间机械设备未粘贴操作说明',
#   0),
#  (578,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t后区应急照明灯损坏，已经重新购买',
#   0),
#  (584,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器缺失，已填补并确认有效、正常！',
#   0),
#  (585,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t卸油区有树叶，已立即清理。',
#   0),
#  (588,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物已整改',
#   0),
#  (589,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防栓堵塞',
#   0),
#  (590,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电度表安装在木板可燃物上面。',
#   0),
#  (592,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道堵塞变窄。',
#   0),
#  (599,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防疏散指示灯坏，需换新。',
#   0),
#  (608,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t电箱无张贴有点危险标示',
#   0),
#  (611,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t皮带轮未加防护照',
#   0),
#  (615,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道堆放货物',
#   0),
#  (616,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t疏散通道有被占用情况，提出后已整改！',
#   0),
#  (625,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t巡查发现仓库外墙人行通道偏窗户处放了两叉板货，影响消防安全通道畅通事项，立即整改OK.',
#   0),
#  (632,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t未贴消防指示标识  已整改',
#   0),
#  (636,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t仓库的危险品没有贴严禁烟火标识。立马改善OK',
#   0),
#  (637,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t必须及时更新安全记录，并存档',
#   0),
#  (638, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t忘记巡查', 0),
#  (639, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t消防器材没按规定摆放', 0),
#  (657,
#   '三小场所（现场）—2016版\t（二）电气安全\t3、电气线路\t1、电气线路应穿金属管或阻燃型PVC管保护，不得使用双绞线（俗称花线）。\t线管风化，漏花线',
#   0),
#  (659, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t车间灭火器配备的数量不足', 0),
#  (660,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t电线连接处不安全',
#   0),
#  (665,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志模糊不清',
#   0),
#  (666,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t有两个应急照明灯损坏·已及时更换',
#   0),
#  (670,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t ',
#   1),
#  (672,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t照明灯不亮',
#   0),
#  (673,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱没有夸介线',
#   0),
#  (676,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全无标志',
#   0),
#  (678, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器增加', 1),
#  (680,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器有四个气压过低已更换。',
#   0),
#  (684,
#   '商贸服务教文卫类（选项）—2016版\t（一）娱乐场所\t1、场地设置\t1、场地设置应符合《娱乐场所管理条例》及有关消防标准规范要求。\t商圈楼上为住宅区',
#   0),
#  (688, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电箱遮挡缺失', 0),
#  (690,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间部分插座未接地线',
#   0),
#  (691,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t年初未组织应急演练，立即组织演练。',
#   0),
#  (692,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电室杂物堆放',
#   0),
#  (698,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t饮水机水桶霸占消防通道，已经整理完毕。',
#   0),
#  (702,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t疏散指示标志灯不亮，应急照明灯不亮，已更换',
#   0),
#  (710,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t半成品仓灭火器配置不足。',
#   0),
#  (712,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t15栋北侧消防车通道被车辆堵塞，现场立即疏通',
#   0),
#  (713,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t厨房电箱开关无警示标识',
#   0),
#  (715,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处打开状态',
#   0),
#  (721, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t防火巡查情况；', 1),
#  (723, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t已整改', 1),
#  (724,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器消防器材未检查，立即检查标注。',
#   0),
#  (728,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。',
#   1),
#  (740,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全标识不到位，厂内没有设置禁止吸烟标志，立即整改',
#   0),
#  (743,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t灭火器未定期检查',
#   0),
#  (745,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全门未打开',
#   0),
#  (748,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急灯故障，已及时更换新的应急灯',
#   0),
#  (752,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口不明显',
#   0),
#  (755, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t ', 1),
#  (757,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯有坏',
#   0),
#  (761,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电箱旁有杂物堆放，立刻清理整改',
#   0),
#  (765,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道堆积杂物',
#   0),
#  (767,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道上有架子',
#   0),
#  (773,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t工人不了解将钥匙放在配电箱里面，经发现对其进行教育已整改',
#   0),
#  (778,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t后门消防通道堵塞',
#   0),
#  (781,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t车间内两处放置灭火器的位置灭火器缺失。',
#   0),
#  (783,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口指示牌不亮，更换新的安全疏散指示牌。',
#   0),
#  (785,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t个别新员工消防知识掌握不熟练',
#   0),
#  (787,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t被检查部门负责人有一处漏签名确认，已确认。',
#   0),
#  (788,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下面有杂物摆放,已整改,',
#   0),
#  (795,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t9、瓶装工业气体经营\t6、气体经营单位储存乙炔气体，储存量超过30立方米(相当于5瓶)时，应用非燃烧体或难燃烧体隔离出单独的储存间，其中一面应为固定墙壁。乙炔气的储存量超过240立方米(相当于40瓶)时，与建筑物的防火间距不应小于10米，否则应以防火墙隔开。\t按要求执行',
#   1),
#  (799, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t无记录', 0),
#  (802,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t杂物圈占消防设备',
#   0),
#  (803,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全通道堵塞',
#   0),
#  (806,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有杂物',
#   0),
#  (810, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t未配备', 0),
#  (820,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全标志脱落',
#   0),
#  (822,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；\t配电箱金属箱门与金属箱体链接线链接不规范',
#   0),
#  (829,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯，安全出口标志不齐全',
#   0),
#  (835,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t及时查询灭火器，及其他安全通道，消防器材的有效性！已立即整改完毕！隐患排除！',
#   0),
#  (836, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器过期了', 0),
#  (837,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防安全门口放有凳子挡住，门关闭着。已责令责任人立即搬离并教育。',
#   0),
#  (843,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t一台机器下堆放易燃物，，已当时整改 。',
#   0),
#  (846,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道有障碍物，已整改。',
#   0),
#  (848,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t作业通道有什物,已整改.',
#   0),
#  (857,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t宾馆二楼大厅疏散指示标志损坏，已申购进行更换。',
#   0),
#  (865,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器同一检查，过期不合格的全部更换',
#   0),
#  (866,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t装配部与货仓之间的常闭式防火门 不处于关闭状态',
#   0),
#  (871,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t防火检查无填写检查记录',
#   0),
#  (875,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t5月3日-4日，没有进行每日防火巡查',
#   0),
#  (878,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全指示标志损坏，已换新',
#   0),
#  (882,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器压力不足',
#   0),
#  (886,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材消防安全标志移位，已整改',
#   0),
#  (888,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道被占用，及时整改。',
#   0),
#  (889,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t住宿3楼无安全疏散指示灯',
#   0),
#  (894,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯不亮，马上通知物业更换立即整改',
#   0),
#  (895,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明坏了',
#   0),
#  (900,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t部分消防通道堵塞，要求立即整改',
#   0),
#  (903, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t部分灭火器没有检查记录表', 0),
#  (907,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防栓漏水，已通知物业整改。',
#   0),
#  (909,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口货物堵塞',
#   0),
#  (910, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t私接插座一个', 0),
#  (914,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t货物阻挡安全出口，立即整改。',
#   0),
#  (920,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防栓前放置物品',
#   0),
#  (922,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯位置不合理',
#   0),
#  (924,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t定期点检卡因潮湿，字迹模糊，重新更换。',
#   0),
#  (928,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t1消防通道放杂物 2。电源开关放杂物',
#   0),
#  (929,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座直接安装在地面上',
#   0),
#  (931,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间楼道口没有按装安全出口灯',
#   0),
#  (935,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间通道未标志明显的边线',
#   0),
#  (937,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全通道堵塞',
#   0),
#  (938,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t乙炔气瓶用纸皮遮挡',
#   0),
#  (944,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵塞安全出口',
#   0),
#  (945,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全通道有上放置纸箱与胶料袋，阻碍安全通道畅通.',
#   0),
#  (947,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t电风扇没有上防护套。立即整改',
#   0),
#  (948,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯不亮',
#   0),
#  (949,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已经整改',
#   1),
#  (951, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t打钉机位有一个灭火器失效', 0),
#  (952,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t2、配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。\t没有警示',
#   0),
#  (954,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道标识破损',
#   0),
#  (956,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t灭火器点检不及时',
#   0),
#  (961, '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t连线乱接', 0),
#  (963, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有隐患', 1),
#  (966,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道堵塞',
#   0),
#  (969, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t园区联合义务消防队演练使用水龙', 1),
#  (970,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t11栋5楼东边楼梯口消防逃生牌不显示，需要更换。',
#   0),
#  (976, '建筑施工类（选项）—2016版\t（十八）施工机具\t4、钢筋机械\t3、是否设置安全作业棚。\t电动切割机未设置挡火防护罩', 0),
#  (979, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t未定期进行应急演练', 0),
#  (983,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有杂物',
#   0),
#  (985,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t车间部分电源开关盒未张贴安全警示标志',
#   0),
#  (988,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t四楼过道一处疏散指示灯不亮',
#   0),
#  (992,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t防爆灯有一个不亮了，已立即更换。',
#   0),
#  (995,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t可燃气体报警系统未接电源',
#   0),
#  (997, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t当日未举行防火巡查', 0),
#  (998,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯故障',
#   0),
#  (1000,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t疏散指示标志未贴',
#   0),
#  (1003,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有时被占用，已清理',
#   0),
#  (1004,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散指示标志破损',
#   0),
#  (1006,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t食堂门口的灭火器已过期，已经更换',
#   0),
#  (1011,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器部分马上到期，立即更换，立即整改',
#   0),
#  (1014,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器倒塌，以及货架阻挡。现已整改完毕。',
#   0),
#  (1017, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器罐体腐蚀', 0),
#  (1023,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\t一楼电动葫芦电源线路多处破损；',
#   0),
#  (1026,
#   '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t1、库房内储存物品应分类、分堆、限额存放。\t辅料堆放不规范！偶有堵塞安全通道的情况。',
#   0),
#  (1031,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道堆放杂物',
#   0),
#  (1032,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t消防栓备用水带老化，已做更换',
#   0),
#  (1033, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t堆垛堆距应符合要求。', 1),
#  (1036, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一个灭火器有效期已过', 0),
#  (1037,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有杂物阻碍消防通道，已经立即搬离',
#   0),
#  (1041,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t砂轮机没有防护罩',
#   0),
#  (1043,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t安全教育培训档案未完善',
#   0),
#  (1044, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器没有定期校验', 0),
#  (1046,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t加装两个应急灯和安全出口指示牌',
#   1),
#  (1048,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t消防安全标志完好',
#   1),
#  (1051,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t电箱盖未盖好，有堆放物件',
#   0),
#  (1052,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t较多纸皮放置在灭火器上，造成灭火器使用不方便，立即整改',
#   0),
#  (1054,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t射骨机红外线坏，更换',
#   0),
#  (1062,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全指示灯不亮',
#   0),
#  (1068, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t5、消防安全重点部位的人员在岗情况；\t已整改', 1),
#  (1070,
#   '商贸服务教文卫类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t二楼中一班增加电器防护罩',
#   1),
#  (1074,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t三楼一板货物挤占疏散通道——已立即移开',
#   0),
#  (1076, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有损坏没及时补上', 0),
#  (1085,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t有缺失的会议记录',
#   0),
#  (1086,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未实施全员参与的安全教育计划。',
#   0),
#  (1087,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t临时堆放杂物,',
#   0),
#  (1090,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t制衣车间培训记录不完整',
#   0),
#  (1107,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口、疏散通道堵塞',
#   0),
#  (1117,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t危化品没有安全标识资料',
#   0),
#  (1118,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t成品仓库包装好的货物未出,堵塞通道.',
#   0),
#  (1120,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t一楼车间喷漆部份电气线路及灯具非整体防爆',
#   0),
#  (1122, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t5、消防安全重点部位的人员在岗情况；\t隐患', 1),
#  (1125, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期', 0),
#  (1126,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t灭火器乱放，未放置在指定区域',
#   0),
#  (1132,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t整改前作业通道不畅通，整改后作业通道已畅通。',
#   0),
#  (1136,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t检查安全疏散通道上有一辆拉货小车占用',
#   0),
#  (1137,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t4、插拔插头时，应保证电气设备和电气装置处于非工作状态，同时人体不得接触及插头的导电极，并避免对电源线施加外力。\t工作人员下班前未能及时拔掉插头',
#   0),
#  (1140,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t没有应急灯',
#   0),
#  (1147, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t一楼壹时尚灭火器过期', 0),
#  (1151,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器及时更换，重新配置新的灭火器安全箱',
#   0),
#  (1152,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下方放了空胶箱，立即移走',
#   0),
#  (1153,
#   '工业/危化品类（选项）—2016版\t（二）仓库\t2、照明要求\t1、丙类仓库应使用小于60W的低功率的照明灯具，其发热部分应采取隔热设施，并应设置在通道正上方。\t使用小于60W的低功率的照明灯具',
#   1),
#  (1154,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t阻碍通道',
#   0),
#  (1158,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道堵塞',
#   0),
#  (1159, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器放在地上', 0),
#  (1161,
#   '商贸服务教文卫类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t3、安全管理机构和管理人员配备及履职情况\t1、安全管理机构、安全管理人员配备及依法履行安全管理职责\t学校新建的综合楼的自动火警报警装置没有专人负责。',
#   0),
#  (1162, '商贸服务教文卫类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有定期组织消防演练', 0),
#  (1169, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t超压', 0),
#  (1172,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防通道有堆杂物，发现后已立即清楚。',
#   0),
#  (1176, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有2瓶过期灭火器', 0),
#  (1177,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t安全教育培训档案不全，两天内补齐',
#   0),
#  (1178,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t机器未做检查保养记录卡，需落实每周机器检查维修保养记录登记。',
#   0),
#  (1180,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t安全出口灯异常（不亮）。',
#   0),
#  (1181,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防柱有杂物档住',
#   0),
#  (1183,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有1PCS灭火器保险插梢遗失，要求更换灭火器',
#   0),
#  (1187,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱、开关箱内未放置任何杂物，但配电开关箱下方放置有杂物。',
#   0),
#  (1188,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t车床操作无防护罩，不符合危险设备的安全，需整改',
#   0),
#  (1198,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t部分插座老化，已经更换新插座',
#   0),
#  (1200,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t消防安全标志损坏',
#   0),
#  (1202,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯不亮',
#   0),
#  (1206,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口灯坏了',
#   0),
#  (1210,
#   '交通运输类（选项）—2016版\t（十）客运码头企业\t2、安全管理机构和人员\t1、设置安全生产管理机构或配备专职安全生产管理人员。\t安全处口为安装',
#   1),
#  (1219,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材未贴定期保养表（已整改贴上定期保养表）',
#   0),
#  (1225, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t未点检', 0),
#  (1231,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急照明灯出现故障',
#   0),
#  (1234,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t2、配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。\t已整改',
#   1),
#  (1250,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t堵塞消防通道，已整改并告知以后不允许堆放杂物1！',
#   0),
#  (1251,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器材配置及有效情况。',
#   1),
#  (1257,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防专用电话损坏',
#   0),
#  (1258, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t不符合五距要求', 0),
#  (1259,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不畅通',
#   0),
#  (1260,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明损坏',
#   0),
#  (1262,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼7号楼梯模板堵塞安全口处，人员无法正常迅速疏散逃生。',
#   0),
#  (1268,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器已过期，已申请购买新灭火器',
#   0),
#  (1270,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t春节长假后，后门口的应急照明灯坏了',
#   0),
#  (1271,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t火灾隐患的整改情况以及防范措施的落实情况不到位',
#   0),
#  (1272,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t1楼PVD区域施工具挡住消防栓',
#   0),
#  (1276,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t机床按钮损坏',
#   0),
#  (1277,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t部分新入人员未产加安全教育培训计划',
#   0),
#  (1280,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t常闭式防火门闭门器失效，应更换新的闭门器',
#   0),
#  (1284,
#   '工业/危化品类（基础）—2016版\t（一）消防验收\t1、消防验收文件\t1、取得消防验收文件意见书。\t厂房由于历史遗留问题，无消防验收批文；',
#   0),
#  (1286,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱未张贴“当心触电”安全标志，已经整改',
#   0),
#  (1287,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志不全',
#   0),
#  (1288,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改完成',
#   1),
#  (1290,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器没有定期校验',
#   0),
#  (1291,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散通道有放杂物，但已搬走',
#   0),
#  (1292,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t堆放纸箱处的防爆灯损坏',
#   0),
#  (1293,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t3、职业卫生培训\t1、对职业病危害严重的岗位的劳动者，进行专门的职业卫生培训，经培训合格后方可上岗作业。\t焊锡岗位无戴防尘口罩',
#   0),
#  (1295, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t插头无地线，立即整改', 0),
#  (1296, '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器缺失一个，已立即整改', 0),
#  (1297,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散指示标志、应急照明设置不规范',
#   0),
#  (1298,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t未配备应急照明灯、灭火器',
#   0),
#  (1299, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况', 1),
#  (1301,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t1、危险化学品从业单位通用要求\t5、可能产生易燃易爆气体的场所，必须设置可燃气体的检测和自动报警装置。\t没有自动报警装置',
#   0),
#  (1302,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t整改',
#   1),
#  (1305,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器未按指定地方摆放',
#   0),
#  (1309,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯一个不亮，已整改',
#   0),
#  (1311,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施',
#   1),
#  (1314,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t注塑技工未穿劳保鞋',
#   0),
#  (1315,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t4、职业卫生管理档案\t1、存在职业病危害的生产经营单位，须建立健全职业卫生档案资料。\t没有建立健全职业卫生档案资料',
#   0),
#  (1316,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t泡沫塑料',
#   0),
#  (1317,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处于打开状态',
#   0),
#  (1318,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t标识不清楚/脱落',
#   0),
#  (1321,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志不清楚，已整 改',
#   0),
#  (1322,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t没有建立事故隐患排查治理档案',
#   0),
#  (1325,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线裸露',
#   0),
#  (1327,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散指示标志不清晰',
#   0),
#  (1328,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t二幢车间楼梯应急照明已坏',
#   0),
#  (1329,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\t花线裸露',
#   0),
#  (1330,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器快过期了，责令马上更换新的。',
#   0),
#  (1331,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道有放货。',
#   0),
#  (1338,
#   '工业/危化品类（选项）—2016版\t（七）重点监管工艺及场所\t7、锂电池生产或储存\t8、每块电池（电芯）的正（负）极位置必须有绝缘防止短路保护措施。\t不良品电池未归回入不良品区域',
#   0),
#  (1339,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱内掉有螺丝',
#   0),
#  (1340,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t1-2楼目前还处于装修阶段，暂未配备灭火器材',
#   0),
#  (1346,
#   '工业/危化品类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t2、分管负责人履职情况\t1、分管负责人依法履行安全管理职责（存在职业健康危害的单位需自查职业卫生履职情况）。\t最近一个季度没有组织安全演练',
#   0),
#  (1348,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急照明灯有一个坏了',
#   0),
#  (1349, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器压力不正常', 0),
#  (1353,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t未检查消防安全重点部位的管理情况；',
#   0),
#  (1354, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器干粉用尽，已充满', 0),
#  (1355,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t吊机和员工车位都重新安装自动跳闸开关。',
#   0),
#  (1359,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端',
#   1),
#  (1360,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t1栋1楼磷铁窑炉区域手报脱落，需重新固定',
#   0),
#  (1369, '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器材配置不足', 0),
#  (1371,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道被货物堵塞',
#   0),
#  (1372,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t封口机用后未拔电源',
#   0),
#  (1375,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有杂物',
#   0),
#  (1378, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期，已经整改。', 0),
#  (1397, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t没有进行演练及记录', 0),
#  (1399,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一个灭火器支架铆钉松脱，现已加固稳定',
#   0),
#  (1405,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t二栋7楼D座，疏散指示牌周围堆放物料，影响使用',
#   0),
#  (1413,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t指示标识不明显',
#   0),
#  (1414,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t啤机电源连接线无保护套管，可能会破损漏电，现场已加装电线套管固定好。',
#   0),
#  (1418, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t饮水机旁边有电线外露。', 0),
#  (1419,
#   '三小场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、生产经营场所应按规定配备足够、性能适用的灭火器；不得使用淘汰及禁止使用的灭火器；灭火器固定摆放，定期校验，过期必须及时更换\t灭火器摆放不当',
#   0),
#  (1422, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防通道占用', 0),
#  (1426,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\t手磨机电缆线有损坏，已经换新的',
#   0),
#  (1427,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t电动自行车随意放置办公室',
#   0),
#  (1429,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t封闭门没及时关上',
#   0),
#  (1430,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有杂物',
#   0),
#  (1432,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t一台设备防护罩未装好',
#   0),
#  (1438,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；',
#   1),
#  (1439, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t单瓶灭火器压力不足', 0),
#  (1440,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器上放有杂物，及时清开',
#   0),
#  (1449,
#   '建筑施工类（基础）—2016版\t（五）安全管理档案\t6、安全生产奖惩记录\t1、建立安全生产奖惩记录。\t检查时发现安全资料并不太完善，已作整改',
#   0),
#  (1459,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t没有安全疏通指示标志，没有应急照明灯',
#   0),
#  (1460,
# ...
#   0),
#  (2794, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t包装部配电箱前方货物遮挡', 0),
#  (2797,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t农科商务办公楼二楼西面消防楼梯防火门未处于常闭状态。',
#   0),
#  (2799, '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t还未进行安全培训', 0),
#  (2800,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t数码印刷房、CTP房、公司后门应急照明灯测试未开启',
#   0),
#  (2801,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有货物阻塞',
#   0),
#  (2803,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t无检查记录',
#   0),
#  (2806,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t没有制定安全教育培训计划，确保全员参与培训，并建立安全培训档案',
#   0),
#  (2808,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t物品暂放于疏散外侧，不利于人员疏散要求',
#   0),
#  (2809,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱请勿遮挡',
#   0),
#  (2811,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t记录',
#   1),
#  (2815,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道上有废弃木板',
#   0),
#  (2816, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t已做定期校验', 0),
#  (2817,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防器材缺失',
#   0),
#  (2823,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t责任制',
#   1),
#  (2834,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\tA栋一楼车间偶尔有物料占用通道现象',
#   0),
#  (2838,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t生产部 出货组 风扇插座未接地',
#   0),
#  (2844,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t仓库安全通道被来的货物临时堵塞，出货后及时清理了通道。',
#   0),
#  (2847,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道货物临时占道，发现后立即对相关人员进行批评，立即改正',
#   0),
#  (2848,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t己整改',
#   1),
#  (2854,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口有垃圾',
#   0),
#  (2856,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t二楼作业区一台排气散未开启，已经开启，对当事员工进行批评教育。',
#   0),
#  (2857, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一处灭火器失效', 0),
#  (2858,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座没有按规定位置摆放',
#   0),
#  (2859, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t仓库有堆放物品太高', 0),
#  (2868,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t没有疏散标志，已经安装',
#   0),
#  (2870, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t办公室区域灭火器配置不够', 0),
#  (2881,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t没关闭好常用防火门',
#   0),
#  (2887,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有异物堵塞',
#   0),
#  (2891,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t在巡查时 发现个别宿舍有乱接插座现象 已及时整改',
#   0),
#  (2892,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座、电源插头应按规定正确接线。',
#   1),
#  (2893,
#   '工业/危化品类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t3、安全管理机构和管理人员履职情况\t1、安全生产管理机构、安全生产管理人员依法履行安全生产管理职责（存在职业健康危害的单位，包括职卫管理机构及职卫管理人员）。\t安全生产管理人员依法履行安全生产管理职责',
#   1),
#  (2895,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t商铺简单生活配电箱旁边放置货物',
#   0),
#  (2896,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t闭门气没有装好，已整改',
#   0),
#  (2903,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防安全标志不完整',
#   0),
#  (2904,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t杂物堆放',
#   0),
#  (2906, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t ', 1),
#  (2908, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t工人有违规用电情况', 0),
#  (2909,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t杂物',
#   1),
#  (2913,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t1、建立并保存事故隐患排查治理档案。',
#   1),
#  (2915,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不通畅',
#   0),
#  (2919,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道有临时堆放货物',
#   0),
#  (2922,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱有杂物',
#   0),
#  (2923,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t电源总开关损坏，更换新的开关',
#   0),
#  (2925,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t3、高度低于2.4m照明灯具电源插座回路均应安装额定剩余动作电流不大于30mA、一般型（无延时）的剩余电流保护装置。\t高度低于2.4m照明灯具电源插座回路没按要求安装，需整改。',
#   0),
#  (2939,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t无建立健全的安全生产制度',
#   0),
#  (2944,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t配电箱接地线连接金属部分不合格,已整改',
#   0),
#  (2945,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t过道堵塞',
#   0),
#  (2953,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t指示灯没亮',
#   0),
#  (2955, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器被东西遮挡', 0),
#  (2956,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材没有巡检记录或不完整',
#   0),
#  (2957,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未及时进行安全培训，隐患已整改',
#   0),
#  (2962,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t安全指示标志已坏，已整改更换',
#   0),
#  (2977,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有杂物。',
#   0),
#  (2978,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t雕刻机旁气枪用后未归位',
#   0),
#  (2980, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器未及时点检', 0),
#  (2981,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t针车大门安全出口有坏',
#   0),
#  (2982,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t配电箱已设置“当心触电”安全警示标志',
#   0),
#  (2990,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t ',
#   1),
#  (2998, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况', 1),
#  (3002,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t佩戴劳保用品保护自身安全',
#   1),
#  (3003, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t配置数量少,立即购买', 0),
#  (3005,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道，临时堆放货物',
#   0),
#  (3006,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t网吧进行新员工入职消防培训后，员工遗忘将消防水带枪头归位。（备注：已将消防水带枪头放回消火栓箱内备用）',
#   0),
#  (3008,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t2、配电箱内裸露带电体应设置屏护板，电气开关应安装在不燃材料上。\t电箱门未关闭，电线杂乱，线槽无盖板裸露在外',
#   0),
#  (3009,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t常闭式防火门人为打开，已整改。',
#   0),
#  (3010,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱(柜)门张贴“当心触电”安全警示标志有个别模糊不清，要求更换整改。',
#   0),
#  (3014,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散指示标志摆放问题',
#   0),
#  (3015, '商贸服务教文卫类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有定期组织应急演练。', 0),
#  (3018,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t插座“有电危险”的警示标志未配备齐全，现已全部整改完成，均贴有“有电危险”的警示标签',
#   0),
#  (3028,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t5楼通道荧光疏散指示脱落',
#   0),
#  (3031,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道堵塞',
#   0),
#  (3038, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t..', 1),
#  (3049,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼左侧安全门口放有栈板，须立即整改，对当事人进行处罚。',
#   0),
#  (3050,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t发现一个灭火器无粉，已加',
#   0),
#  (3051, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器及消防栓定期检查', 0),
#  (3054, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t防火巡查记录不完善', 0),
#  (3056,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t警示标志年久，字体不清晰。重新更换',
#   0),
#  (3059,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处于开启状态，有物品阻塞，已整改',
#   0),
#  (3060,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t巡查中发现安全出口楼道处堆放两个旧轮胎，当即移走，保证安全出口畅通。',
#   0),
#  (3068,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t制定并实施全员参与的安全教育培训计划',
#   1),
#  (3070,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防管道有漏水，已经上报村委维修',
#   0),
#  (3088,
#   '工业/危化品类（选项）—2016版\t（五）特种设备\t5、起重机械\t3、设备上应悬挂安全操作规程、交接班记录和安全检查记录。\t打包机无安全操作规程',
#   0),
#  (3094,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、用火、用电有无违章情况。\t工作完成后电线未及时收纳好，已把电视放回工具箱。整改完毕',
#   0),
#  (3101,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堆放货物已清空',
#   0),
#  (3105,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t2、危险化学品生产、储存单位\t5、危险化学品的储存方式、方法以及储存数量应当符合国家标准或者国家有关规定。\t废水站违规摆放油漆，清理走违规摆放的油漆',
#   0),
#  (3112,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道有台物料车',
#   0),
#  (3117,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t二楼办公室消费安全标志破损，要求立即整改',
#   0),
#  (3121,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座面板损坏致使电线外露，有触电风险',
#   0),
#  (3125,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t三楼有一个胶筐放在通道上',
#   0),
#  (3130,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t车间走线的线管脱落',
#   0),
#  (3131,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；\t有一处插座开关未接地线，已接好',
#   0),
#  (3135,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t一处应急照明灯损坏',
#   0),
#  (3136,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t部分冲压设备相关安全警示标识不健全或未做风险告知',
#   0),
#  (3143,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t个别配电箱安全警示标志脱落',
#   0),
#  (3147,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t机器停用',
#   1),
#  (3151, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t已整改', 1),
#  (3153,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t三楼机粘部风扇插座没接地线',
#   0),
#  (3155,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t新员工未培训',
#   0),
#  (3157,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t一楼到负一楼通道疏散指示牌损坏，已更换',
#   0),
#  (3158,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞，后面整改疏通',
#   0),
#  (3163,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t注塑机未张贴警示标志',
#   0),
#  (3165,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t车间检查有用矿泉水瓶装化学品。以要求车间整改',
#   0),
#  (3166,
#   '建筑施工类（基础）—2016版\t（二）安全管理机构和人员\t1、安全管理机构\t1、设立与本企业资质、规模相符的安全管理机构。\t有安群管理框架图',
#   0),
#  (3167,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t仓库有一扇常闭式防火门没有关上',
#   0),
#  (3168,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口有货物堵塞',
#   0),
#  (3175,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t无警示标志',
#   0),
#  (3176,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有堵塞',
#   0),
#  (3177,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散指示标志不清析',
#   0),
#  (3188,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t盆栽挡住通道口',
#   0),
#  (3190,
#   '交通运输类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱“当心触电”安全警示标志缺失',
#   0),
#  (3205,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t有',
#   1),
#  (3222,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器发现一瓶过期，其他均在有效期内，立即更换一瓶新的',
#   0),
#  (3230,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t2个应急照明灯不亮',
#   0),
#  (3232,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道被货物堵塞',
#   0),
#  (3234,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器安全标志',
#   1),
#  (3238, '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t已进行培训', 1),
#  (3241,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t小型库房防爆抽排风机已坏。立即更换抽排风机，保持空气流通。',
#   0),
#  (3247,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t砂轮机无防尘挡板',
#   0),
#  (3248,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\tK栋二楼车间一具灭火器过期',
#   0),
#  (3249, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t灭火器前有障碍物', 0),
#  (3251,
#   '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t清理占用垃圾，已清理。',
#   0),
#  (3257,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t排插座不可安装在易燃材质上',
#   0),
#  (3259,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (3260,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯异常,不通电，已整改',
#   0),
#  (3262, '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱有遮挡', 0),
#  (3265,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t ',
#   1),
#  (3267,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t灯具有损坏的,已整改更换',
#   0),
#  (3274,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t有多条电源插座连接风扇的情况，',
#   0),
#  (3282,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道堵塞',
#   0),
#  (3287,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有装有杂物的废纸箱，发现隐患后已经立即进行清理，已整改完毕！',
#   0),
#  (3291, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器乱移动', 0),
#  (3297,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t二楼楼梯应急灯故障鸣叫',
#   0),
#  (3302,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t灭火器检查有过期，已换',
#   0),
#  (3304,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t1.二栋厂房8楼D座，芯片房排插私拉串联使用，且未按要求固定；2.一栋5楼C区，电箱周围对方易燃物品；',
#   0),
#  (3305,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\tA3包装车间焊接岗位旁放置可燃物，立即清理可燃物',
#   0),
#  (3308,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道衣柜未固定安置好',
#   0),
#  (3309,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t楼梯口没有应急消防灯，车间一个应急消防灯不亮，立马整改。',
#   0),
#  (3315,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t疏散指示牌脱落',
#   0),
#  (3316,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道堵塞',
#   0),
#  (3321,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器失效1个，已安排换新',
#   0),
#  (3326,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t配电箱需要没有盖子，需及时整改。',
#   0),
#  (3328,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t4楼锦囊青年酒店消防通道杂物阻挡',
#   0),
#  (3329,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t复印室旁消防指示牌故障，已更换整改完毕',
#   0),
#  (3331,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道需要重新画线',
#   0),
#  (3333,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t未张贴当心触电标志',
#   0),
#  (3340,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓前放置杂物\n',
#   0),
#  (3341,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器配备充足，有效情况正常，但是没有及时更新检查表',
#   0),
#  (3345,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t开关箱内放有杂物',
#   0),
#  (3346,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯不亮',
#   0),
#  (3353,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t仓库于11月1日未进行日常安全检查',
#   0),
#  (3360,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有部份消防设施、器材未在位，摆放不够稳固，高度不合理。消防安全标志完整；',
#   0),
#  (3365,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t4楼消防楼梯安全出口指示牌坏',
#   0),
#  ...]

# %%
len(train_data)
# Out:
# 8403

# %%
class data_generator(DataGenerator):
    """数据生成器
    """
    def __iter__(self, random=False):
        batch_token_ids, batch_segment_ids, batch_labels = [], [], []
        for is_end, (id, text, label) in self.sample(random):
            token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
            batch_token_ids.append(token_ids)
            batch_segment_ids.append(segment_ids)
            batch_labels.append([label])
            if len(batch_token_ids) == self.batch_size or is_end:
                batch_token_ids = sequence_padding(batch_token_ids)
                batch_segment_ids = sequence_padding(batch_segment_ids)
                batch_labels = sequence_padding(batch_labels)
                yield [batch_token_ids, batch_segment_ids], batch_labels
                batch_token_ids, batch_segment_ids, batch_labels = [], [], []

# %%
# 转换数据集
train_generator = data_generator(train_data, batch_size)
valid_generator = data_generator(valid_data, batch_size)

# %%
valid_data
# Out:
# [(5,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t防爆柜里面稀释剂，机油费混装',
#   0),
#  (8,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t已整改',
#   1),
#  (17,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堆满货物',
#   0),
#  (20,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t走廊通道有一个灭火器到期，立即整改',
#   0),
#  (22,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散指示灯故障',
#   0),
#  (29,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t一楼四号常闭式防火门，经常被杂物堆放，责令清洁部，清理干净保持防火门关闭状态',
#   0),
#  (30,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t上月检查时灭火器表并未及时更新，现已更新完毕，整改完成。',
#   0),
#  (31, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器未点检', 0),
#  (35, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t没有安装防爆灯，已整改。', 0),
#  (37,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t尾部和车间的消防通道堵塞，要马上清理；成品箱码的超高不安全要调整。',
#   0),
#  (39,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t配电室的门、窗关闭应密合',
#   1),
#  (46,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t部分安全出口指示标志脱落。',
#   0),
#  (47,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防栓门口被桶装水堵塞。',
#   0),
#  (49,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t12号机后边通道有一卡板货压线',
#   0),
#  (56,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防标志不明晰',
#   0),
#  (58, '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器过期', 0),
#  (61,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t临时堆放货物，已整改',
#   0),
#  (62,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t杂物堆放消防通道，已马上整改。',
#   0),
#  (63,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道指示线不清晰',
#   0),
#  (64,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t公司三楼办公楼走北侧楼梯间灭火器标志脱落，已贴好。',
#   0),
#  (70,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t未放置防爆柜子里',
#   0),
#  (73,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t28栋7楼安全出口堵塞，现场已整改',
#   0),
#  (77,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散通道堆放杂物',
#   0),
#  (79,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t4、插拔插头时，应保证电气设备和电气装置处于非工作状态，同时人体不得接触及插头的导电极，并避免对电源线施加外力。\t立式空调电源无地线',
#   0),
#  (81,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\tG1栋2楼车间内工作台照明电源线套管破损（已整改）。',
#   0),
#  (82,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t有两个配电箱门未张贴“当心触电”安全警示标志。立即张贴',
#   0),
#  (87,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (102,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (103,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t机器设备放置纸板属于已燃物品',
#   0),
#  (110, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器过期已更换新', 0),
#  (116,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t乐群楼17楼应急灯无电源',
#   0),
#  (118, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t下雨，厂房墙面垮倒', 0),
#  (120,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口堵塞',
#   0),
#  (121,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t有3个灭火器压力偏底，要更换',
#   0),
#  (123,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t占用、堵塞、封闭',
#   0),
#  (126,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电箱上有杂物',
#   0),
#  (127,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t缺少本季度安全生产会议记录，已整改。',
#   0),
#  (128,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱旁放了几个纸箱',
#   0),
#  (129,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物乱堆放，阻塞逃生通道',
#   0),
#  (133,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改',
#   1),
#  (136,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全标志掉落；立即整改，张贴完好。',
#   0),
#  (141,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t甩干机没有作业指导书',
#   0),
#  (142,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t电池仓库货架接地不规范，需螺栓连接或焊接 压接',
#   0),
#  (143,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；',
#   1),
#  (146,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t一楼A4区灭火器下面堆放杂物',
#   0),
#  (147,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t下沙新村潮歌苑4栋1单元1楼防火门敞开',
#   1),
#  (151,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口有堆放货物，隐患已整改，通道货物已挪开',
#   0),
#  (152,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t有',
#   1),
#  (153,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t标志',
#   1),
#  (155,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t部分灭火器材过期未能正常使用。',
#   0),
#  (157,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t作业场所通风不好',
#   0),
#  (161,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t本单元重新整改装修，装修后消防门摆放了较大的绿植物',
#   0),
#  (164,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有障碍',
#   0),
#  (165,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t仓库通道一个灭火器被移动位置',
#   0),
#  (174,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t临时用电没有安装漏电保护装置，立即安装',
#   0),
#  (176,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵塞消防通道',
#   0),
#  (179,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器有损坏，立即购买新的更换。',
#   0),
#  (186, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器失效', 0),
#  (187,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道有隐患',
#   0),
#  (188,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间消防通道有被货物堵塞，现已作出整改',
#   0),
#  (189,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t9楼，一防火门上“安全出口”标识非常亮状态',
#   0),
#  (190,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t大厦东面外围楼梯角落有杂物堆放，即时叫人搬离',
#   0),
#  (192,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯损坏',
#   0),
#  (193,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000\t宿舍楼下临时停放电车',
#   0),
#  (194,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t补充2个新的灭火器',
#   0),
#  (201, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器未点检', 0),
#  (203, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t9层东区放杂物', 0),
#  (205,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线线皮破损',
#   0),
#  (206,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道货物已清理已畅通',
#   1),
#  (208,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t新员工有一人未完成班组级安全教育，就安排上岗。',
#   0),
#  (210,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t没有张贴安全标识',
#   0),
#  (213,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t办公室灭火器没有定期检查签字',
#   0),
#  (215,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t指示灯不亮',
#   0),
#  (218,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱未张贴“当心触电”安全警示标志',
#   0),
#  (221,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\tC型钢压型机器轴承破、购新轴承更换',
#   0),
#  (222,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火卷帘下堆放物品',
#   0),
#  (230,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t楼梯消防门闭门器损坏',
#   0),
#  (235,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道堆放杂物',
#   0),
#  (238,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t没有疏散通道、安全出口设置应急照明灯和疏散指示标志',
#   0),
#  (239,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未制定2019年年度培训计划',
#   0),
#  (242,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t有两个电源开关接触不良，已购买更换',
#   0),
#  (243,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火卷帘处堆放纸箱及货物',
#   0),
#  (251,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t     ',
#   1),
#  (252,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t没有经过安全教育培训',
#   0),
#  (253,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t点检表欠缺，未点检。',
#   0),
#  (254,
#   '交通运输类（选项）—2016版\t（六）普通货运企业\t6、集装箱运输\t1、在集装箱运输车辆上安装有导航系统功能的行驶记录仪。\t未见装行车记录仪，马上配备装上。确保安全记录。',
#   0),
#  (261,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有障碍物',
#   0),
#  (264,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t注塑部一楼车间消防通道被临时堆放的货物堵塞，马上整改完成。',
#   0),
#  (268,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口指示牌故障。已更换。',
#   0),
#  (273,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t走廊消防通道被货物堵塞',
#   0),
#  (277,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散应急灯不亮',
#   0),
#  (279,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t更换新的灭火器，检查灭火器的作用',
#   0),
#  (286,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有隐患',
#   1),
#  (289,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道上摆放有产品，存有安全隐患。已整改。',
#   0),
#  (295,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t一楼车间裁床电箱内放有废手套等杂物',
#   0),
#  (296, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防车通道有杂物堆积', 0),
#  (299,
#   '工业/危化品类（选项）—2016版\t（五）特种设备\t5、起重机械\t3、设备上应悬挂安全操作规程、交接班记录和安全检查记录。\t操作行车处未见安全操作规程',
#   0),
#  (300,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口堵',
#   0),
#  (302,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t工厂内有一配电箱未安装防护板',
#   0),
#  (304,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全标志不完整',
#   0),
#  (308,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t2019年02月起，未建立隐患排查档案',
#   0),
#  (313,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t安全通道堆放货物，存在安全隐患',
#   0),
#  (315,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t2、手持式电动工具、移动电器等设备应优先选用额定剩余动作电流不大于30mA、一般型（无延时）的剩余电流保护装置；潮湿场所的电气设备使用16-30mA动作电流、无延时；在金属物件上作业的手持电动工具使用10mA动作电流、无延时漏电保护开关。\t电池随处进行充电，未按照公司《电池安全防护规范》进行充电及记录。',
#   0),
#  (316,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t涂装一车间小地线电箱没张贴“警示标志”',
#   0),
#  (323,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t因老化原因部分通电式安全出口标志不亮',
#   0),
#  (324,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防栓下面堆放物料',
#   0),
#  (326,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急指示灯损坏，已更换',
#   0),
#  (330,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有临时堆放货物   ',
#   0),
#  (331,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器停放过长粉不足，已充足，',
#   0),
#  (333,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线乱拉乱接',
#   0),
#  (334,
#   '工业/危化品类（选项）—2016版\t（五）特种设备\t2、压力容器\t3、安全阀有有效的检验报告及铅封标记。压力表有有效的检定证书及标记。\t有车间压力表快到期/及时安排人员在有效期内进行更换',
#   0),
#  (336,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t堆放有杂物',
#   0),
#  (338,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t安全疏散通道堵塞',
#   0),
#  (340,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器位置未放到位。未按时检查',
#   0),
#  (341,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t消房通道放物品',
#   0),
#  (344,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防铲掉落',
#   0),
#  (345,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道被档住；',
#   0),
#  (347,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防器材。以整改',
#   1),
#  (350,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\tC栋一楼封边机操作人员未佩戴劳动防护用品（耳塞）',
#   0),
#  (351,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯不亮',
#   0),
#  (355,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t消防安全标志不全',
#   0),
#  (356,
#   '商贸服务教文卫类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t未贴操作指南',
#   0),
#  (361,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道划线模糊',
#   0),
#  (364,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t应急照明灯损坏',
#   0),
#  (366,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材检查表未更新',
#   0),
#  (369,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t“当心触电”安全警示标志脱落',
#   0),
#  (370,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器已过期，现场已更换。',
#   0),
#  (371,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有物品占用。',
#   0),
#  (372,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门关闭',
#   0),
#  (386, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器未定期检查', 0),
#  (389,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门未常闭',
#   0),
#  (391,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防水带捆绑不正确且老化，需更新',
#   0),
#  (395,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道堆放货物',
#   0),
#  (397, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器不够，新增几个', 0),
#  (398,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t后堂配电箱内存在灰尘，已处理',
#   0),
#  (401,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间通道被货物堵塞',
#   0),
#  (406,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱(柜)门未张贴有“当心触电”安全警示标志',
#   0),
#  (409,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t电梯出口有货物存放，已立即整改',
#   0),
#  (410, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志', 1),
#  (411,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有些门口未装置应急照明灯',
#   0),
#  (414,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有及时组织应急演练，2019年11月25日组织了应急演练',
#   0),
#  (415,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道标示线',
#   0),
#  (419, '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t1、临时用电必须经过审批。\t不足', 1),
#  (421,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t地面安全通道标识有缺损，',
#   0),
#  (426,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全标志不完整',
#   0),
#  (427,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有一盏应急照明灯损坏，已立即更换整改。',
#   0),
#  (432,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (433,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (435,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t未建立应急预案',
#   0),
#  (439,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t设置的当心触电标志脱落，立即更换新的标志',
#   0),
#  (443,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t发现闭门器坏了',
#   0),
#  (448,
#   '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t1、库房内储存物品应分类、分堆、限额存放。\t仓库物品摆放过高，不符合“五距”要求。',
#   0),
#  (462,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t一处落地扇电源线未使用双层绝缘电线。',
#   0),
#  (463,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t未张贴安全警示标志',
#   0),
#  (465,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t插座相接，用电有隐患',
#   0),
#  (466,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器翻倒',
#   0),
#  (468,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t未检查灭火器材配置及有效情况；',
#   0),
#  (470,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有即将过有效期，要求定期更换ABC干粉灭火器',
#   0),
#  (484,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t赤湾港区21#小叉车灭火器点检表缺少8月份的检点记录',
#   0),
#  (485,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏通道放有少许杂物，已清理。',
#   0),
#  (499,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全疏散指示标志',
#   1),
#  (501, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t卸油口盖静电接地线线头脱落', 0),
#  (502,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有废弃物阻挡部分通道，现已清理；有安全通道地标损坏，现已更换',
#   0),
#  (503,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防灭火器检查清洗',
#   1),
#  (505,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t配电室电源线箱跨接线，已整改。',
#   0),
#  (508,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散通道不畅通',
#   0),
#  (510,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t三楼镭射机没有安装红外线防护。',
#   0),
#  (512,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接。\t已整改',
#   1),
#  (516,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物',
#   0),
#  (519,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t消防通道停放自行车',
#   0),
#  (520,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器失效',
#   0),
#  (521,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材大部分已过期或失效，立即购买新的灭火器。',
#   0),
#  (523,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道有时候有清洁阿姨堆砌了一些纸箱杂物，未及时挪开，已告知阿姨不要堆杂物。',
#   0),
#  (525,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好',
#   1),
#  (529,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t多余线未处理',
#   0),
#  (530,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t未能按时检查及签名记录',
#   0),
#  (532,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t通道标识线有磨损现象',
#   0),
#  (537, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t二楼调油房气味刺鼻，通风不良', 0),
#  (553,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口指示灯不亮。',
#   0),
#  (559,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t ',
#   1),
#  (560,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t检查安全出口，疏散通道标志为荧光的，现已更换为通电带灯罩形。',
#   0),
#  (562,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道阻塞',
#   0),
#  (563,
#   '建筑施工类（基础）—2016版\t（五）安全管理档案\t4、特种设备及操作人员管理记录\t3、各种特种设备的运行记录和维修保养记录齐全。\t1.4号塔吊运行记录填写过于简单。',
#   0),
#  (565,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t2、危险化学品生产、储存单位\t1、生产企业应当提供与其生产的危险化学品相符的化学品安全技术说明书，并在危险化学品包装（包括外包装件）上粘贴或者拴挂与包装内危险化学品相符的化学品安全标签。\t设备部化学品容器未张贴安全标签；',
#   0),
#  (568, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器前放置拖车', 0),
#  (569,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道安全出口指示牌故障，已经更换新的安全出口指示牌。',
#   0),
#  (570,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器被遮挡，隐患已整改，遮挡灭火器的杂物已清理。',
#   0),
#  (575,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t车间机械设备未粘贴操作说明',
#   0),
#  (578,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t后区应急照明灯损坏，已经重新购买',
#   0),
#  (584,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器缺失，已填补并确认有效、正常！',
#   0),
#  (585,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t卸油区有树叶，已立即清理。',
#   0),
#  (588,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物已整改',
#   0),
#  (589,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防栓堵塞',
#   0),
#  (590,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电度表安装在木板可燃物上面。',
#   0),
#  (592,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道堵塞变窄。',
#   0),
#  (599,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防疏散指示灯坏，需换新。',
#   0),
#  (608,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t电箱无张贴有点危险标示',
#   0),
#  (611,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t皮带轮未加防护照',
#   0),
#  (615,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道堆放货物',
#   0),
#  (616,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t疏散通道有被占用情况，提出后已整改！',
#   0),
#  (625,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t巡查发现仓库外墙人行通道偏窗户处放了两叉板货，影响消防安全通道畅通事项，立即整改OK.',
#   0),
#  (632,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t未贴消防指示标识  已整改',
#   0),
#  (636,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t仓库的危险品没有贴严禁烟火标识。立马改善OK',
#   0),
#  (637,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t必须及时更新安全记录，并存档',
#   0),
#  (638, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t忘记巡查', 0),
#  (639, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t消防器材没按规定摆放', 0),
#  (657,
#   '三小场所（现场）—2016版\t（二）电气安全\t3、电气线路\t1、电气线路应穿金属管或阻燃型PVC管保护，不得使用双绞线（俗称花线）。\t线管风化，漏花线',
#   0),
#  (659, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t车间灭火器配备的数量不足', 0),
#  (660,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t电线连接处不安全',
#   0),
#  (665,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志模糊不清',
#   0),
#  (666,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t有两个应急照明灯损坏·已及时更换',
#   0),
#  (670,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t ',
#   1),
#  (672,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t照明灯不亮',
#   0),
#  (673,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱没有夸介线',
#   0),
#  (676,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全无标志',
#   0),
#  (678, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器增加', 1),
#  (680,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器有四个气压过低已更换。',
#   0),
#  (684,
#   '商贸服务教文卫类（选项）—2016版\t（一）娱乐场所\t1、场地设置\t1、场地设置应符合《娱乐场所管理条例》及有关消防标准规范要求。\t商圈楼上为住宅区',
#   0),
#  (688, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电箱遮挡缺失', 0),
#  (690,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间部分插座未接地线',
#   0),
#  (691,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t年初未组织应急演练，立即组织演练。',
#   0),
#  (692,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电室杂物堆放',
#   0),
#  (698,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t饮水机水桶霸占消防通道，已经整理完毕。',
#   0),
#  (702,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t疏散指示标志灯不亮，应急照明灯不亮，已更换',
#   0),
#  (710,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t半成品仓灭火器配置不足。',
#   0),
#  (712,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t15栋北侧消防车通道被车辆堵塞，现场立即疏通',
#   0),
#  (713,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t厨房电箱开关无警示标识',
#   0),
#  (715,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处打开状态',
#   0),
#  (721, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t防火巡查情况；', 1),
#  (723, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t已整改', 1),
#  (724,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器消防器材未检查，立即检查标注。',
#   0),
#  (728,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。',
#   1),
#  (740,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全标识不到位，厂内没有设置禁止吸烟标志，立即整改',
#   0),
#  (743,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t灭火器未定期检查',
#   0),
#  (745,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全门未打开',
#   0),
#  (748,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急灯故障，已及时更换新的应急灯',
#   0),
#  (752,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口不明显',
#   0),
#  (755, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t ', 1),
#  (757,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯有坏',
#   0),
#  (761,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电箱旁有杂物堆放，立刻清理整改',
#   0),
#  (765,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道堆积杂物',
#   0),
#  (767,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道上有架子',
#   0),
#  (773,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t工人不了解将钥匙放在配电箱里面，经发现对其进行教育已整改',
#   0),
#  (778,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t后门消防通道堵塞',
#   0),
#  (781,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t车间内两处放置灭火器的位置灭火器缺失。',
#   0),
#  (783,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口指示牌不亮，更换新的安全疏散指示牌。',
#   0),
#  (785,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t个别新员工消防知识掌握不熟练',
#   0),
#  (787,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t被检查部门负责人有一处漏签名确认，已确认。',
#   0),
#  (788,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下面有杂物摆放,已整改,',
#   0),
#  (795,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t9、瓶装工业气体经营\t6、气体经营单位储存乙炔气体，储存量超过30立方米(相当于5瓶)时，应用非燃烧体或难燃烧体隔离出单独的储存间，其中一面应为固定墙壁。乙炔气的储存量超过240立方米(相当于40瓶)时，与建筑物的防火间距不应小于10米，否则应以防火墙隔开。\t按要求执行',
#   1),
#  (799, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t无记录', 0),
#  (802,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t杂物圈占消防设备',
#   0),
#  (803,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全通道堵塞',
#   0),
#  (806,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有杂物',
#   0),
#  (810, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t未配备', 0),
#  (820,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全标志脱落',
#   0),
#  (822,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；\t配电箱金属箱门与金属箱体链接线链接不规范',
#   0),
#  (829,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯，安全出口标志不齐全',
#   0),
#  (835,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t及时查询灭火器，及其他安全通道，消防器材的有效性！已立即整改完毕！隐患排除！',
#   0),
#  (836, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器过期了', 0),
#  (837,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防安全门口放有凳子挡住，门关闭着。已责令责任人立即搬离并教育。',
#   0),
#  (843,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t一台机器下堆放易燃物，，已当时整改 。',
#   0),
#  (846,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道有障碍物，已整改。',
#   0),
#  (848,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t作业通道有什物,已整改.',
#   0),
#  (857,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t宾馆二楼大厅疏散指示标志损坏，已申购进行更换。',
#   0),
#  (865,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器同一检查，过期不合格的全部更换',
#   0),
#  (866,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t装配部与货仓之间的常闭式防火门 不处于关闭状态',
#   0),
#  (871,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t防火检查无填写检查记录',
#   0),
#  (875,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t5月3日-4日，没有进行每日防火巡查',
#   0),
#  (878,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全指示标志损坏，已换新',
#   0),
#  (882,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器压力不足',
#   0),
#  (886,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材消防安全标志移位，已整改',
#   0),
#  (888,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道被占用，及时整改。',
#   0),
#  (889,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t住宿3楼无安全疏散指示灯',
#   0),
#  (894,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯不亮，马上通知物业更换立即整改',
#   0),
#  (895,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明坏了',
#   0),
#  (900,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t部分消防通道堵塞，要求立即整改',
#   0),
#  (903, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t部分灭火器没有检查记录表', 0),
#  (907,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防栓漏水，已通知物业整改。',
#   0),
#  (909,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口货物堵塞',
#   0),
#  (910, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t私接插座一个', 0),
#  (914,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t货物阻挡安全出口，立即整改。',
#   0),
#  (920,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防栓前放置物品',
#   0),
#  (922,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯位置不合理',
#   0),
#  (924,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t定期点检卡因潮湿，字迹模糊，重新更换。',
#   0),
#  (928,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t1消防通道放杂物 2。电源开关放杂物',
#   0),
#  (929,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座直接安装在地面上',
#   0),
#  (931,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间楼道口没有按装安全出口灯',
#   0),
#  (935,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间通道未标志明显的边线',
#   0),
#  (937,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全通道堵塞',
#   0),
#  (938,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t乙炔气瓶用纸皮遮挡',
#   0),
#  (944,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵塞安全出口',
#   0),
#  (945,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全通道有上放置纸箱与胶料袋，阻碍安全通道畅通.',
#   0),
#  (947,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t电风扇没有上防护套。立即整改',
#   0),
#  (948,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯不亮',
#   0),
#  (949,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已经整改',
#   1),
#  (951, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t打钉机位有一个灭火器失效', 0),
#  (952,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t2、配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。\t没有警示',
#   0),
#  (954,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道标识破损',
#   0),
#  (956,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t灭火器点检不及时',
#   0),
#  (961, '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t连线乱接', 0),
#  (963, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有隐患', 1),
#  (966,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道堵塞',
#   0),
#  (969, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t园区联合义务消防队演练使用水龙', 1),
#  (970,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t11栋5楼东边楼梯口消防逃生牌不显示，需要更换。',
#   0),
#  (976, '建筑施工类（选项）—2016版\t（十八）施工机具\t4、钢筋机械\t3、是否设置安全作业棚。\t电动切割机未设置挡火防护罩', 0),
#  (979, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t未定期进行应急演练', 0),
#  (983,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有杂物',
#   0),
#  (985,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t车间部分电源开关盒未张贴安全警示标志',
#   0),
#  (988,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t四楼过道一处疏散指示灯不亮',
#   0),
#  (992,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t防爆灯有一个不亮了，已立即更换。',
#   0),
#  (995,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t可燃气体报警系统未接电源',
#   0),
#  (997, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t当日未举行防火巡查', 0),
#  (998,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯故障',
#   0),
#  (1000,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t疏散指示标志未贴',
#   0),
#  (1003,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有时被占用，已清理',
#   0),
#  (1004,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散指示标志破损',
#   0),
#  (1006,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t食堂门口的灭火器已过期，已经更换',
#   0),
#  (1011,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器部分马上到期，立即更换，立即整改',
#   0),
#  (1014,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器倒塌，以及货架阻挡。现已整改完毕。',
#   0),
#  (1017, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器罐体腐蚀', 0),
#  (1023,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\t一楼电动葫芦电源线路多处破损；',
#   0),
#  (1026,
#   '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t1、库房内储存物品应分类、分堆、限额存放。\t辅料堆放不规范！偶有堵塞安全通道的情况。',
#   0),
#  (1031,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道堆放杂物',
#   0),
#  (1032,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t消防栓备用水带老化，已做更换',
#   0),
#  (1033, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t堆垛堆距应符合要求。', 1),
#  (1036, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一个灭火器有效期已过', 0),
#  (1037,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有杂物阻碍消防通道，已经立即搬离',
#   0),
#  (1041,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t砂轮机没有防护罩',
#   0),
#  (1043,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t安全教育培训档案未完善',
#   0),
#  (1044, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器没有定期校验', 0),
#  (1046,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t加装两个应急灯和安全出口指示牌',
#   1),
#  (1048,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t消防安全标志完好',
#   1),
#  (1051,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t电箱盖未盖好，有堆放物件',
#   0),
#  (1052,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t较多纸皮放置在灭火器上，造成灭火器使用不方便，立即整改',
#   0),
#  (1054,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t射骨机红外线坏，更换',
#   0),
#  (1062,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全指示灯不亮',
#   0),
#  (1068, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t5、消防安全重点部位的人员在岗情况；\t已整改', 1),
#  (1070,
#   '商贸服务教文卫类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t二楼中一班增加电器防护罩',
#   1),
#  (1074,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t三楼一板货物挤占疏散通道——已立即移开',
#   0),
#  (1076, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有损坏没及时补上', 0),
#  (1085,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t有缺失的会议记录',
#   0),
#  (1086,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未实施全员参与的安全教育计划。',
#   0),
#  (1087,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t临时堆放杂物,',
#   0),
#  (1090,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t制衣车间培训记录不完整',
#   0),
#  (1107,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口、疏散通道堵塞',
#   0),
#  (1117,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t危化品没有安全标识资料',
#   0),
#  (1118,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t成品仓库包装好的货物未出,堵塞通道.',
#   0),
#  (1120,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t一楼车间喷漆部份电气线路及灯具非整体防爆',
#   0),
#  (1122, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t5、消防安全重点部位的人员在岗情况；\t隐患', 1),
#  (1125, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期', 0),
#  (1126,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t灭火器乱放，未放置在指定区域',
#   0),
#  (1132,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t整改前作业通道不畅通，整改后作业通道已畅通。',
#   0),
#  (1136,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t检查安全疏散通道上有一辆拉货小车占用',
#   0),
#  (1137,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t4、插拔插头时，应保证电气设备和电气装置处于非工作状态，同时人体不得接触及插头的导电极，并避免对电源线施加外力。\t工作人员下班前未能及时拔掉插头',
#   0),
#  (1140,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t没有应急灯',
#   0),
#  (1147, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t一楼壹时尚灭火器过期', 0),
#  (1151,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器及时更换，重新配置新的灭火器安全箱',
#   0),
#  (1152,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下方放了空胶箱，立即移走',
#   0),
#  (1153,
#   '工业/危化品类（选项）—2016版\t（二）仓库\t2、照明要求\t1、丙类仓库应使用小于60W的低功率的照明灯具，其发热部分应采取隔热设施，并应设置在通道正上方。\t使用小于60W的低功率的照明灯具',
#   1),
#  (1154,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t阻碍通道',
#   0),
#  (1158,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道堵塞',
#   0),
#  (1159, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器放在地上', 0),
#  (1161,
#   '商贸服务教文卫类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t3、安全管理机构和管理人员配备及履职情况\t1、安全管理机构、安全管理人员配备及依法履行安全管理职责\t学校新建的综合楼的自动火警报警装置没有专人负责。',
#   0),
#  (1162, '商贸服务教文卫类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有定期组织消防演练', 0),
#  (1169, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t超压', 0),
#  (1172,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防通道有堆杂物，发现后已立即清楚。',
#   0),
#  (1176, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有2瓶过期灭火器', 0),
#  (1177,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t安全教育培训档案不全，两天内补齐',
#   0),
#  (1178,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t机器未做检查保养记录卡，需落实每周机器检查维修保养记录登记。',
#   0),
#  (1180,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t安全出口灯异常（不亮）。',
#   0),
#  (1181,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防柱有杂物档住',
#   0),
#  (1183,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有1PCS灭火器保险插梢遗失，要求更换灭火器',
#   0),
#  (1187,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱、开关箱内未放置任何杂物，但配电开关箱下方放置有杂物。',
#   0),
#  (1188,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t车床操作无防护罩，不符合危险设备的安全，需整改',
#   0),
#  (1198,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t部分插座老化，已经更换新插座',
#   0),
#  (1200,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t消防安全标志损坏',
#   0),
#  (1202,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯不亮',
#   0),
#  (1206,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口灯坏了',
#   0),
#  (1210,
#   '交通运输类（选项）—2016版\t（十）客运码头企业\t2、安全管理机构和人员\t1、设置安全生产管理机构或配备专职安全生产管理人员。\t安全处口为安装',
#   1),
#  (1219,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材未贴定期保养表（已整改贴上定期保养表）',
#   0),
#  (1225, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t未点检', 0),
#  (1231,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急照明灯出现故障',
#   0),
#  (1234,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t2、配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。\t已整改',
#   1),
#  (1250,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t堵塞消防通道，已整改并告知以后不允许堆放杂物1！',
#   0),
#  (1251,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器材配置及有效情况。',
#   1),
#  (1257,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防专用电话损坏',
#   0),
#  (1258, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t不符合五距要求', 0),
#  (1259,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不畅通',
#   0),
#  (1260,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明损坏',
#   0),
#  (1262,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼7号楼梯模板堵塞安全口处，人员无法正常迅速疏散逃生。',
#   0),
#  (1268,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器已过期，已申请购买新灭火器',
#   0),
#  (1270,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t春节长假后，后门口的应急照明灯坏了',
#   0),
#  (1271,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t火灾隐患的整改情况以及防范措施的落实情况不到位',
#   0),
#  (1272,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t1楼PVD区域施工具挡住消防栓',
#   0),
#  (1276,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t机床按钮损坏',
#   0),
#  (1277,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t部分新入人员未产加安全教育培训计划',
#   0),
#  (1280,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t常闭式防火门闭门器失效，应更换新的闭门器',
#   0),
#  (1284,
#   '工业/危化品类（基础）—2016版\t（一）消防验收\t1、消防验收文件\t1、取得消防验收文件意见书。\t厂房由于历史遗留问题，无消防验收批文；',
#   0),
#  (1286,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱未张贴“当心触电”安全标志，已经整改',
#   0),
#  (1287,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志不全',
#   0),
#  (1288,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改完成',
#   1),
#  (1290,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器没有定期校验',
#   0),
#  (1291,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散通道有放杂物，但已搬走',
#   0),
#  (1292,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t堆放纸箱处的防爆灯损坏',
#   0),
#  (1293,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t3、职业卫生培训\t1、对职业病危害严重的岗位的劳动者，进行专门的职业卫生培训，经培训合格后方可上岗作业。\t焊锡岗位无戴防尘口罩',
#   0),
#  (1295, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t插头无地线，立即整改', 0),
#  (1296, '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器缺失一个，已立即整改', 0),
#  (1297,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散指示标志、应急照明设置不规范',
#   0),
#  (1298,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t未配备应急照明灯、灭火器',
#   0),
#  (1299, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况', 1),
#  (1301,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t1、危险化学品从业单位通用要求\t5、可能产生易燃易爆气体的场所，必须设置可燃气体的检测和自动报警装置。\t没有自动报警装置',
#   0),
#  (1302,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t整改',
#   1),
#  (1305,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器未按指定地方摆放',
#   0),
#  (1309,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯一个不亮，已整改',
#   0),
#  (1311,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施',
#   1),
#  (1314,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t注塑技工未穿劳保鞋',
#   0),
#  (1315,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t4、职业卫生管理档案\t1、存在职业病危害的生产经营单位，须建立健全职业卫生档案资料。\t没有建立健全职业卫生档案资料',
#   0),
#  (1316,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t泡沫塑料',
#   0),
#  (1317,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处于打开状态',
#   0),
#  (1318,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t标识不清楚/脱落',
#   0),
#  (1321,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t标志不清楚，已整 改',
#   0),
#  (1322,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t没有建立事故隐患排查治理档案',
#   0),
#  (1325,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线裸露',
#   0),
#  (1327,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散指示标志不清晰',
#   0),
#  (1328,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t二幢车间楼梯应急照明已坏',
#   0),
#  (1329,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\t花线裸露',
#   0),
#  (1330,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器快过期了，责令马上更换新的。',
#   0),
#  (1331,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道有放货。',
#   0),
#  (1338,
#   '工业/危化品类（选项）—2016版\t（七）重点监管工艺及场所\t7、锂电池生产或储存\t8、每块电池（电芯）的正（负）极位置必须有绝缘防止短路保护措施。\t不良品电池未归回入不良品区域',
#   0),
#  (1339,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱内掉有螺丝',
#   0),
#  (1340,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t1-2楼目前还处于装修阶段，暂未配备灭火器材',
#   0),
#  (1346,
#   '工业/危化品类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t2、分管负责人履职情况\t1、分管负责人依法履行安全管理职责（存在职业健康危害的单位需自查职业卫生履职情况）。\t最近一个季度没有组织安全演练',
#   0),
#  (1348,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急照明灯有一个坏了',
#   0),
#  (1349, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器压力不正常', 0),
#  (1353,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t未检查消防安全重点部位的管理情况；',
#   0),
#  (1354, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器干粉用尽，已充满', 0),
#  (1355,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t吊机和员工车位都重新安装自动跳闸开关。',
#   0),
#  (1359,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端',
#   1),
#  (1360,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t1栋1楼磷铁窑炉区域手报脱落，需重新固定',
#   0),
#  (1369, '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器材配置不足', 0),
#  (1371,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道被货物堵塞',
#   0),
#  (1372,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t封口机用后未拔电源',
#   0),
#  (1375,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有杂物',
#   0),
#  (1378, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期，已经整改。', 0),
#  (1397, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t没有进行演练及记录', 0),
#  (1399,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一个灭火器支架铆钉松脱，现已加固稳定',
#   0),
#  (1405,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t二栋7楼D座，疏散指示牌周围堆放物料，影响使用',
#   0),
#  (1413,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t指示标识不明显',
#   0),
#  (1414,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t啤机电源连接线无保护套管，可能会破损漏电，现场已加装电线套管固定好。',
#   0),
#  (1418, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t饮水机旁边有电线外露。', 0),
#  (1419,
#   '三小场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、生产经营场所应按规定配备足够、性能适用的灭火器；不得使用淘汰及禁止使用的灭火器；灭火器固定摆放，定期校验，过期必须及时更换\t灭火器摆放不当',
#   0),
#  (1422, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防通道占用', 0),
#  (1426,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\t手磨机电缆线有损坏，已经换新的',
#   0),
#  (1427,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t电动自行车随意放置办公室',
#   0),
#  (1429,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t封闭门没及时关上',
#   0),
#  (1430,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有杂物',
#   0),
#  (1432,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t一台设备防护罩未装好',
#   0),
#  (1438,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；',
#   1),
#  (1439, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t单瓶灭火器压力不足', 0),
#  (1440,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器上放有杂物，及时清开',
#   0),
#  (1449,
#   '建筑施工类（基础）—2016版\t（五）安全管理档案\t6、安全生产奖惩记录\t1、建立安全生产奖惩记录。\t检查时发现安全资料并不太完善，已作整改',
#   0),
#  (1459,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t没有安全疏通指示标志，没有应急照明灯',
#   0),
#  (1460,
# ...
#   0),
#  (2794, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t包装部配电箱前方货物遮挡', 0),
#  (2797,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t农科商务办公楼二楼西面消防楼梯防火门未处于常闭状态。',
#   0),
#  (2799, '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t还未进行安全培训', 0),
#  (2800,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t数码印刷房、CTP房、公司后门应急照明灯测试未开启',
#   0),
#  (2801,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有货物阻塞',
#   0),
#  (2803,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t无检查记录',
#   0),
#  (2806,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t没有制定安全教育培训计划，确保全员参与培训，并建立安全培训档案',
#   0),
#  (2808,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t物品暂放于疏散外侧，不利于人员疏散要求',
#   0),
#  (2809,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱请勿遮挡',
#   0),
#  (2811,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t记录',
#   1),
#  (2815,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道上有废弃木板',
#   0),
#  (2816, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t已做定期校验', 0),
#  (2817,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防器材缺失',
#   0),
#  (2823,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t责任制',
#   1),
#  (2834,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\tA栋一楼车间偶尔有物料占用通道现象',
#   0),
#  (2838,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t生产部 出货组 风扇插座未接地',
#   0),
#  (2844,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t仓库安全通道被来的货物临时堵塞，出货后及时清理了通道。',
#   0),
#  (2847,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道货物临时占道，发现后立即对相关人员进行批评，立即改正',
#   0),
#  (2848,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t己整改',
#   1),
#  (2854,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口有垃圾',
#   0),
#  (2856,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t二楼作业区一台排气散未开启，已经开启，对当事员工进行批评教育。',
#   0),
#  (2857, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一处灭火器失效', 0),
#  (2858,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座没有按规定位置摆放',
#   0),
#  (2859, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t仓库有堆放物品太高', 0),
#  (2868,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t没有疏散标志，已经安装',
#   0),
#  (2870, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t办公室区域灭火器配置不够', 0),
#  (2881,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t没关闭好常用防火门',
#   0),
#  (2887,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道有异物堵塞',
#   0),
#  (2891,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t在巡查时 发现个别宿舍有乱接插座现象 已及时整改',
#   0),
#  (2892,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座、电源插头应按规定正确接线。',
#   1),
#  (2893,
#   '工业/危化品类（基础）—2016版\t（二）主要负责人、分管负责人及管理人员履职情况\t3、安全管理机构和管理人员履职情况\t1、安全生产管理机构、安全生产管理人员依法履行安全生产管理职责（存在职业健康危害的单位，包括职卫管理机构及职卫管理人员）。\t安全生产管理人员依法履行安全生产管理职责',
#   1),
#  (2895,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t商铺简单生活配电箱旁边放置货物',
#   0),
#  (2896,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t闭门气没有装好，已整改',
#   0),
#  (2903,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防安全标志不完整',
#   0),
#  (2904,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t杂物堆放',
#   0),
#  (2906, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t ', 1),
#  (2908, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t工人有违规用电情况', 0),
#  (2909,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t杂物',
#   1),
#  (2913,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t1、建立并保存事故隐患排查治理档案。',
#   1),
#  (2915,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不通畅',
#   0),
#  (2919,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道有临时堆放货物',
#   0),
#  (2922,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱有杂物',
#   0),
#  (2923,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t电源总开关损坏，更换新的开关',
#   0),
#  (2925,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t3、高度低于2.4m照明灯具电源插座回路均应安装额定剩余动作电流不大于30mA、一般型（无延时）的剩余电流保护装置。\t高度低于2.4m照明灯具电源插座回路没按要求安装，需整改。',
#   0),
#  (2939,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t无建立健全的安全生产制度',
#   0),
#  (2944,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t配电箱接地线连接金属部分不合格,已整改',
#   0),
#  (2945,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t过道堵塞',
#   0),
#  (2953,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t指示灯没亮',
#   0),
#  (2955, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器被东西遮挡', 0),
#  (2956,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材没有巡检记录或不完整',
#   0),
#  (2957,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未及时进行安全培训，隐患已整改',
#   0),
#  (2962,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t安全指示标志已坏，已整改更换',
#   0),
#  (2977,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有杂物。',
#   0),
#  (2978,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t雕刻机旁气枪用后未归位',
#   0),
#  (2980, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器未及时点检', 0),
#  (2981,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t针车大门安全出口有坏',
#   0),
#  (2982,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t配电箱已设置“当心触电”安全警示标志',
#   0),
#  (2990,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t ',
#   1),
#  (2998, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况', 1),
#  (3002,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t佩戴劳保用品保护自身安全',
#   1),
#  (3003, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t配置数量少,立即购买', 0),
#  (3005,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道，临时堆放货物',
#   0),
#  (3006,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t网吧进行新员工入职消防培训后，员工遗忘将消防水带枪头归位。（备注：已将消防水带枪头放回消火栓箱内备用）',
#   0),
#  (3008,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t2、配电箱内裸露带电体应设置屏护板，电气开关应安装在不燃材料上。\t电箱门未关闭，电线杂乱，线槽无盖板裸露在外',
#   0),
#  (3009,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t常闭式防火门人为打开，已整改。',
#   0),
#  (3010,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱(柜)门张贴“当心触电”安全警示标志有个别模糊不清，要求更换整改。',
#   0),
#  (3014,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散指示标志摆放问题',
#   0),
#  (3015, '商贸服务教文卫类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有定期组织应急演练。', 0),
#  (3018,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t插座“有电危险”的警示标志未配备齐全，现已全部整改完成，均贴有“有电危险”的警示标签',
#   0),
#  (3028,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t5楼通道荧光疏散指示脱落',
#   0),
#  (3031,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道堵塞',
#   0),
#  (3038, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t..', 1),
#  (3049,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼左侧安全门口放有栈板，须立即整改，对当事人进行处罚。',
#   0),
#  (3050,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t发现一个灭火器无粉，已加',
#   0),
#  (3051, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器及消防栓定期检查', 0),
#  (3054, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t防火巡查记录不完善', 0),
#  (3056,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t警示标志年久，字体不清晰。重新更换',
#   0),
#  (3059,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处于开启状态，有物品阻塞，已整改',
#   0),
#  (3060,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t巡查中发现安全出口楼道处堆放两个旧轮胎，当即移走，保证安全出口畅通。',
#   0),
#  (3068,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t制定并实施全员参与的安全教育培训计划',
#   1),
#  (3070,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防管道有漏水，已经上报村委维修',
#   0),
#  (3088,
#   '工业/危化品类（选项）—2016版\t（五）特种设备\t5、起重机械\t3、设备上应悬挂安全操作规程、交接班记录和安全检查记录。\t打包机无安全操作规程',
#   0),
#  (3094,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、用火、用电有无违章情况。\t工作完成后电线未及时收纳好，已把电视放回工具箱。整改完毕',
#   0),
#  (3101,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堆放货物已清空',
#   0),
#  (3105,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t2、危险化学品生产、储存单位\t5、危险化学品的储存方式、方法以及储存数量应当符合国家标准或者国家有关规定。\t废水站违规摆放油漆，清理走违规摆放的油漆',
#   0),
#  (3112,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道有台物料车',
#   0),
#  (3117,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t二楼办公室消费安全标志破损，要求立即整改',
#   0),
#  (3121,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座面板损坏致使电线外露，有触电风险',
#   0),
#  (3125,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t三楼有一个胶筐放在通道上',
#   0),
#  (3130,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t车间走线的线管脱落',
#   0),
#  (3131,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；\t有一处插座开关未接地线，已接好',
#   0),
#  (3135,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t一处应急照明灯损坏',
#   0),
#  (3136,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t部分冲压设备相关安全警示标识不健全或未做风险告知',
#   0),
#  (3143,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t个别配电箱安全警示标志脱落',
#   0),
#  (3147,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t机器停用',
#   1),
#  (3151, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t已整改', 1),
#  (3153,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t三楼机粘部风扇插座没接地线',
#   0),
#  (3155,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t新员工未培训',
#   0),
#  (3157,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t一楼到负一楼通道疏散指示牌损坏，已更换',
#   0),
#  (3158,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞，后面整改疏通',
#   0),
#  (3163,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t注塑机未张贴警示标志',
#   0),
#  (3165,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t车间检查有用矿泉水瓶装化学品。以要求车间整改',
#   0),
#  (3166,
#   '建筑施工类（基础）—2016版\t（二）安全管理机构和人员\t1、安全管理机构\t1、设立与本企业资质、规模相符的安全管理机构。\t有安群管理框架图',
#   0),
#  (3167,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t仓库有一扇常闭式防火门没有关上',
#   0),
#  (3168,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口有货物堵塞',
#   0),
#  (3175,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t无警示标志',
#   0),
#  (3176,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有堵塞',
#   0),
#  (3177,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散指示标志不清析',
#   0),
#  (3188,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t盆栽挡住通道口',
#   0),
#  (3190,
#   '交通运输类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱“当心触电”安全警示标志缺失',
#   0),
#  (3205,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t有',
#   1),
#  (3222,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器发现一瓶过期，其他均在有效期内，立即更换一瓶新的',
#   0),
#  (3230,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t2个应急照明灯不亮',
#   0),
#  (3232,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道被货物堵塞',
#   0),
#  (3234,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器安全标志',
#   1),
#  (3238, '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t已进行培训', 1),
#  (3241,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t小型库房防爆抽排风机已坏。立即更换抽排风机，保持空气流通。',
#   0),
#  (3247,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t砂轮机无防尘挡板',
#   0),
#  (3248,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\tK栋二楼车间一具灭火器过期',
#   0),
#  (3249, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t灭火器前有障碍物', 0),
#  (3251,
#   '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t清理占用垃圾，已清理。',
#   0),
#  (3257,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t排插座不可安装在易燃材质上',
#   0),
#  (3259,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (3260,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯异常,不通电，已整改',
#   0),
#  (3262, '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱有遮挡', 0),
#  (3265,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t ',
#   1),
#  (3267,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t灯具有损坏的,已整改更换',
#   0),
#  (3274,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t有多条电源插座连接风扇的情况，',
#   0),
#  (3282,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道堵塞',
#   0),
#  (3287,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有装有杂物的废纸箱，发现隐患后已经立即进行清理，已整改完毕！',
#   0),
#  (3291, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器乱移动', 0),
#  (3297,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t二楼楼梯应急灯故障鸣叫',
#   0),
#  (3302,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t灭火器检查有过期，已换',
#   0),
#  (3304,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t1.二栋厂房8楼D座，芯片房排插私拉串联使用，且未按要求固定；2.一栋5楼C区，电箱周围对方易燃物品；',
#   0),
#  (3305,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\tA3包装车间焊接岗位旁放置可燃物，立即清理可燃物',
#   0),
#  (3308,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道衣柜未固定安置好',
#   0),
#  (3309,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t楼梯口没有应急消防灯，车间一个应急消防灯不亮，立马整改。',
#   0),
#  (3315,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t疏散指示牌脱落',
#   0),
#  (3316,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道堵塞',
#   0),
#  (3321,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器失效1个，已安排换新',
#   0),
#  (3326,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t配电箱需要没有盖子，需及时整改。',
#   0),
#  (3328,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t4楼锦囊青年酒店消防通道杂物阻挡',
#   0),
#  (3329,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t复印室旁消防指示牌故障，已更换整改完毕',
#   0),
#  (3331,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道需要重新画线',
#   0),
#  (3333,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t未张贴当心触电标志',
#   0),
#  (3340,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓前放置杂物\n',
#   0),
#  (3341,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器配备充足，有效情况正常，但是没有及时更新检查表',
#   0),
#  (3345,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t开关箱内放有杂物',
#   0),
#  (3346,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯不亮',
#   0),
#  (3353,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t仓库于11月1日未进行日常安全检查',
#   0),
#  (3360,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有部份消防设施、器材未在位，摆放不够稳固，高度不合理。消防安全标志完整；',
#   0),
#  (3365,
#   '三小场所（现场）—2016版\t（一）消防安全\t2、消防通道和疏散\t2、疏散通道、安全出口设置应急照明灯和疏散指示标志。\t4楼消防楼梯安全出口指示牌坏',
#   0),
#  ...]

# %% [markdown]
# # 验证和预测

# %%
def evaluate(data):
    total, right = 0., 0.
    for x_true, y_true in data:
        y_pred = model.predict(x_true).argmax(axis=1)
        y_true = y_true[:, 0]
        total += len(y_true)
        right += (y_true == y_pred).sum()
    return right / total

# %%
class Evaluator(keras.callbacks.Callback):
    """评估与保存
    """
    def __init__(self):
        self.best_val_acc = 0.

    def on_epoch_end(self, epoch, logs=None):
        val_acc = evaluate(valid_generator)
        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            model.save_weights('best_model.weights')
#         test_acc = evaluate(test_generator)
#         print(
#             u'val_acc: %.5f, best_val_acc: %.5f, test_acc: %.5f\n' %
#             (val_acc, self.best_val_acc, test_acc)
#         )
        test_acc = evaluate(valid_generator)
        print(
            u'val_acc: %.5f, best_val_acc: %.5f, test_acc: %.5f\n' %
            (val_acc, self.best_val_acc, test_acc)
        )

# %%
def data_pred(test_data):
    id_ids, y_pred_ids = [], []
    for id, text, label in test_data:
        token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
        token_ids = sequence_padding([token_ids])
        segment_ids = sequence_padding([segment_ids])
        y_pred = model.predict([token_ids, segment_ids]).argmax(axis=1)
        id_ids.append(id)
        y_pred_ids.append(y_pred)
    return id_ids, y_pred_ids

# %%
def data_pred2(test_data):
    id_ids, y_pred_ids = [], []
    batch_token_ids, batch_segment_ids = [], []
    for id, text, label in test_data:
        token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
        batch_token_ids.append(token_ids)
        batch_segment_ids.append(batch_segment_ids)
        id_ids.append(id)
    token_ids = sequence_padding(batch_token_ids)
    segment_ids = sequence_padding(batch_segment_ids)
    y_pred_ids = model.predict([token_ids, segment_ids]).argmax(axis=1)
    return id_ids, y_pred_ids

# %%
## 修改代码

# %%
def data_pred3(test_data):
    id_ids, y_pred_ids = [], []
    for id, text, label in test_data:
        token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
        token_ids = sequence_padding([token_ids])
        segment_ids = sequence_padding([segment_ids])
        y_pred = int(model.predict([token_ids, segment_ids]).argmax(axis=1)[0])
        id_ids.append(id)
        y_pred_ids.append(y_pred)
    return id_ids, y_pred_ids

# %%
def data_pred4(test_data):
    id_ids, y_pred_ids = [], []
    batch_token_ids, batch_segment_ids = [], []
    for id, text, label in test_data:
        token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
        batch_token_ids.append(token_ids)
        batch_segment_ids.append(batch_segment_ids)
        id_ids.append(id)
    token_ids = sequence_padding(batch_token_ids)
    segment_ids = sequence_padding(batch_segment_ids)
    y_pred_ids = model.predict([token_ids, segment_ids]).argmax(axis=1)[:,0]
    return id_ids, list(y_pred_ids)

# %% [markdown]
# # 训练和验证

# %%
evaluator = Evaluator()

# %%
model.fit(
        train_generator.forfit(),
        steps_per_epoch=len(train_generator),
        epochs=2,
        callbacks=[evaluator]
    )
# Out:
# /Users/hongpengfei/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/2
#  64/263 [======>.......................] - ETA: 7:42 - loss: 0.3566 - accuracy: 0.8911
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-bfe27940105a> in <module>
#       3         steps_per_epoch=len(train_generator),
#       4         epochs=2,
# ----> 5         callbacks=[evaluator]
#       6     )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1145                 use_multiprocessing=use_multiprocessing,
#    1146                 shuffle=shuffle,
# -> 1147                 initial_epoch=initial_epoch)
#    1148
#    1149         # Case 2: Symbolic tensors or Numpy array-like.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3790         value = math_ops.cast(value, tensor.dtype)
#    3791       converted_inputs.append(value)
# -> 3792     outputs = self._graph_fn(*converted_inputs)
#    3793
#    3794     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    1603       TypeError: For invalid positional/keyword argument combinations.
#    1604     """
# -> 1605     return self._call_impl(args, kwargs)
#    1606
#    1607   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1643       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1644           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1645     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1646
#    1647   def _filtered_call(self, args, kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model.load_weights('best_model.weights')
# print(u'final test acc: %05f\n' % (evaluate(test_generator)))
print(u'final test acc: %05f\n' % (evaluate(valid_generator)))
# Out:
# final test acc: 0.981651

# %%
print(u'final test acc: %05f\n' % (evaluate(train_generator)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-5230f49ba7f5> in <module>
# ----> 1 print(u'final test acc: %05f\n' % (evaluate(train_generator)))
#
# <ipython-input-14-2b25555d3bab> in evaluate(data)
#       2     total, right = 0., 0.
#       3     for x_true, y_true in data:
# ----> 4         y_pred = model.predict(x_true).argmax(axis=1)
#       5         y_true = y_true[:, 0]
#       6         total += len(y_true)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3790         value = math_ops.cast(value, tensor.dtype)
#    3791       converted_inputs.append(value)
# -> 3792     outputs = self._graph_fn(*converted_inputs)
#    3793
#    3794     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    1603       TypeError: For invalid positional/keyword argument combinations.
#    1604     """
# -> 1605     return self._call_impl(args, kwargs)
#    1606
#    1607   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1643       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1644           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1645     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1646
#    1647   def _filtered_call(self, args, kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # 模型预测保存结果

# %%
id_ids, y_pred_ids = data_pred3(test_data)

# %%
df_save = pd.DataFrame()
df_save['id'] = id_ids
df_save['label'] = y_pred_ids

# %%
df_save.to_csv('result.csv')
