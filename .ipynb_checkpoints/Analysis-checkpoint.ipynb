# %%
import pandas as pd

# %%
# !ls dataset/
# Out:
# test.csv  train.csv

# %%
content = pd.read_csv('dataset/train.csv')

# %%
len(content)
# Out:
# 53360

# %%
content.head()
# Out:
#    id  label    label_desc                                        sentence
# 0   0    108      news_edu    上课时学生手机响个不停，老师一怒之下把手机摔了，家长拿发票让老师赔，大家怎么看待这种事？
# 1   1    104  news_finance  商赢环球股份有限公司关于延期回复上海证券交易所对公司2017年年度报告的事后审核问询函的公告
# 2   2    106    news_house                通过中介公司买了二手房，首付都付了，现在卖家不想卖了。怎么处理？
# 3   3    112   news_travel                             2018年去俄罗斯看世界杯得花多少钱？
# 4   4    109     news_tech                           剃须刀的个性革新，雷明登天猫定制版新品首发

# %%
from collections import defaultdict

# %%
from collections import Counter

# %%
id_counter = Counter(content.label.values)

# %%
len(id_counter)
# Out:
# 15

# %%
id_counter
# Out:
# Counter({108: 3437,
#          104: 5200,
#          106: 2107,
#          112: 3368,
#          109: 5955,
#          103: 3991,
#          116: 3390,
#          101: 4081,
#          107: 4118,
#          100: 1111,
#          102: 4976,
#          110: 3632,
#          115: 2886,
#          113: 4851,
#          114: 257})

# %%
id(id_counter)
# Out:
# 140217532163704

# %%
a = 1

# %%
b = 2

# %%
id(a)
# Out:
# 4414047648

# %%
id(b)
# Out:
# 4414047680

# %%
a = 3

# %%
id(a)
# Out:
# 4414047712

# %%
alist = [1, 2, 3]

# %%
id(alist)
# Out:
# 140217504417608

# %%
alist.append(4)

# %%
id(alist)
# Out:
# 140217504417608

# %%
position = dict()

# %%
p1, p2, p3 = (2, 3), (4, 5), (6, 7)

# %%
p4 = [7, 8]

# %% [markdown]
# ## Python dictionary and hashable

# %%
a = 1

# %%
position[a] = 'GoodA'

# %%
b = 1

# %%
position[b]
# Out:
# 'GoodA'

# %% [markdown]
# dictionary:
#
# a_dictionary[key] = value
#
# ==>  key's id (hash) => address => value
#
# # 可变变量

# %% [markdown]
# list, set, dictionary

# %% [markdown]
# a_dictionary = [value -> hasble]
# if var is mutable: hash(var'address)
# var value => hash(var'address) => is same

# %%
a_list = [.... ]

# %%
position[p1] = 'red'

# %%
position[p2] = 'blue'

# %%
position[frozenset({2, 3})] = 'white'

# %%
position['2, 3'] = 'black'

# %%
id_counter
# Out:
# Counter({108: 3437,
#          104: 5200,
#          106: 2107,
#          112: 3368,
#          109: 5955,
#          103: 3991,
#          116: 3390,
#          101: 4081,
#          107: 4118,
#          100: 1111,
#          102: 4976,
#          110: 3632,
#          115: 2886,
#          113: 4851,
#          114: 257})

# %%
for _id, value in id_counter.items():
    print(_id, value / len(content) * 100, '%')
# Out:
# 108 6.441154422788606 %
# 104 9.745127436281859 %
# 106 3.948650674662669 %
# 112 6.31184407796102 %
# 109 11.160044977511244 %
# 103 7.479385307346327 %
# 116 6.353073463268366 %
# 101 7.648050974512744 %
# 107 7.717391304347826 %
# 100 2.0820839580209896 %
# 102 9.325337331334332 %
# 110 6.806596701649176 %
# 115 5.408545727136431 %
# 113 9.091079460269864 %
# 114 0.48163418290854576 %

# %% [markdown]
# 15分类的问题，Model 是work的，请问。你model在测试集上，准确度，最起码需要时多少？

# %%
content[content['label'] == 109]
# Out:
#           id  label label_desc                                     sentence
# 4          4    109  news_tech                        剃须刀的个性革新，雷明登天猫定制版新品首发
# 6          6    109  news_tech              三农盾SACC-全球首个推出：互联网+区块链+农产品的电商平台
# 10        10    109  news_tech                       凌云研发的国产两轮电动车怎么样，有什么惊喜？
# 33        33    109  news_tech                              小白如何做好自媒体的几个信念？
# 44        44    109  news_tech                  听说最近联通搅乱了北京宽带市场价格，比小运营商的还低？
# 45        45    109  news_tech              我的焕驰前减震有异响，过凹凸不平的时候会咣当一声，是什么原因？
# 49        49    109  news_tech                                  哪种POS机适合养卡？
# 53        53    109  news_tech                           为创业的你准备的（2018年新商机）
# 55        55    109  news_tech                 阿里巴巴区块链专利排名全球第一，阿里都有哪些区块链应用？
# 62        62    109  news_tech                        2018年教育科技技术新主题——AR+教育
# 66        66    109  news_tech         PS4比SWITCH销量高，而且游戏画面好，为什么还有人买SWITCH？
# 71        71    109  news_tech                                海航资本助力海南自贸区建设
# 107      107    109  news_tech                            为什么日本的精密制造领域那么发达？
# 109      109    109  news_tech                          听说了吗？16岁的高中生已经在学AI了
# 112      112    109  news_tech                           为什么网吧的电脑配置低，速度却很快？
# 113      113    109  news_tech           NASA，Uber探索未来城市空域的安全性和效率，飞车这就比较舒服了
# 118      118    109  news_tech                            互联网资讯快爆｜5月12日 星期六
# 133      133    109  news_tech              「AI名利场」高仙完成A轮千万级美元融资，赋能机器人生态化发展
# 148      148    109  news_tech                           小米跟vivo抢线下市场，有机会吗？
# 157      157    109  news_tech                        iPhone6SPLUS现在还值不值得买？
# 163      163    109  news_tech                         德国人水平尺不离手 安装地下排水管都要用
# 165      165    109  news_tech                 小伙子获得神奇遥控器，随意控制时间快慢，这功能太强大了！
# 168      168    109  news_tech            GMIC迷思：数字化产品日新月异，A股新贵万兴科技为何能勇立潮头？
# 181      181    109  news_tech                      火影影刃Z5和机械师F117-B1哪款产品好？
# 188      188    109  news_tech                           预算5000，最优主机的方案是什么？
# 193      193    109  news_tech                          美国CNN再次聚焦贵州，只因为这些成就
# 196      196    109  news_tech                   同为叱咤风云的斗鱼四美，冯提莫红的发紫，她却籍籍无名
# 197      197    109  news_tech                       「智慧了 我的津」“嘟”声一响 “行”不可挡
# 200      200    109  news_tech               怎么看因取消订单遭滴滴司机殴打，被打者曾给滴滴投资百万美金？
# 201      201    109  news_tech                                  三无人员如何申请信用卡
# ...      ...    ...        ...                                          ...
# 53128  53128    109  news_tech                            有没有什么能提高图片辨析率的软件？
# 53135  53135    109  news_tech                        现在哪个系列或型号的大疆无人机性价比更高？
# 53144  53144    109  news_tech                             2018纳什币开启金融市场第二春
# 53151  53151    109  news_tech                                  商标使用有地域限制吗？
# 53163  53163    109  news_tech                    阿里巴巴卖导弹？以色列总理这番话把马云都吓了一跳！
# 53167  53167    109  news_tech                       人工智能+大数据 名商网商标智能查询系统发布
# 53183  53183    109  news_tech                               微信拉黑与删除的区别是什么？
# 53185  53185    109  news_tech                      不想打工了？大家分析一下四个创业方案哪个可行？
# 53188  53188    109  news_tech                                 怎么对激光进行外力干预？
# 53197  53197    109  news_tech               人们在日常的沟通和信息交流中，语言的表达很重要，广告亦是如此
# 53207  53207    109  news_tech   Instagram上线支付功能可在APP内直接购物，为什么社交软件巨头纷纷布局电商？
# 53219  53219    109  news_tech                              区块链信息 之每日一币 量子链
# 53222  53222    109  news_tech                              自媒体视频素材哪里找，怎么做？
# 53228  53228    109  news_tech  「科技早报」科技部成立新一代人工智能发展研究中心 京东2018年第一季度净利润15亿元
# 53231  53231    109  news_tech               刚刚，西飞高调披露新型神秘机型，或年内首飞，又超出美军的预测
# 53232  53232    109  news_tech                                区块链为什么需要共识机制？
# 53249  53249    109  news_tech                       最新！中通快递发布行业首份区块链技术研究报告
# 53264  53264    109  news_tech                 麒麟970处理器那么强，为什么国产手机不用华为而选高通？
# 53266  53266    109  news_tech                        家电营销模式升级，消费模式即将“随心所欲”
# 53275  53275    109  news_tech                 140米高超级雷达究竟有多厉害？开机八秒干扰一次全球通信
# 53277  53277    109  news_tech                                    广州有哪些大企业？
# 53284  53284    109  news_tech                           用手机支付宝或微信乘公交车怎么操作？
# 53285  53285    109  news_tech                              微信有时候登不上了应该怎么办？
# 53304  53304    109  news_tech                         新势力造车是不是骗子忽悠傻子？与青主论战
# 53308  53308    109  news_tech                 现如今去韩国或者日本从事互联网是否会比在国内有发展前景？
# 53316  53316    109  news_tech                         微软亚研院洪小文：今天的AI只是一个黑盒
# 53323  53323    109  news_tech                   分辨OPPO真假，只需输入几个代码，就知道手机是真假
# 53330  53330    109  news_tech                  小米估值连遭下调：最低至600亿美元，较早期削减近4成
# 53339  53339    109  news_tech                                  宝贝钱袋成就您的创业梦
# 53351  53351    109  news_tech     NBA直播权被腾讯买断了，那么CCTV5直播的NBA比赛，是不是也要付钱给腾讯？
#
# [5955 rows x 4 columns]

# %%
content['sentence_len'] = content['sentence'].apply(len)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
np.max(content['sentence_len'])
# Out:
# 145

# %%
np.mean(content['sentence_len'])
# Out:
# 22.13124062968516

# %%
np.std(content['sentence_len'])
# Out:
# 7.3097918579505325

# %%
len(np.where(content['sentence_len'] < 22 + 7.3 * 1.5)[0]) / len(content)
# Out:
# 0.9512368815592204

# %%
plt.hist(content['sentence_len'], bins=50)b
# Out:
# (array([2.200e+01, 6.210e+02, 2.313e+03, 4.475e+03, 5.769e+03, 6.698e+03,
#         6.917e+03, 4.824e+03, 7.290e+03, 9.416e+03, 2.974e+03, 9.350e+02,
#         5.870e+02, 3.000e+02, 1.140e+02, 4.600e+01, 3.500e+01, 1.000e+01,
#         6.000e+00, 5.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  2.  ,   4.86,   7.72,  10.58,  13.44,  16.3 ,  19.16,  22.02,
#          24.88,  27.74,  30.6 ,  33.46,  36.32,  39.18,  42.04,  44.9 ,
#          47.76,  50.62,  53.48,  56.34,  59.2 ,  62.06,  64.92,  67.78,
#          70.64,  73.5 ,  76.36,  79.22,  82.08,  84.94,  87.8 ,  90.66,
#          93.52,  96.38,  99.24, 102.1 , 104.96, 107.82, 110.68, 113.54,
#         116.4 , 119.26, 122.12, 124.98, 127.84, 130.7 , 133.56, 136.42,
#         139.28, 142.14, 145.  ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# ## 我们为什么要关注这个长度呢？

# %% [markdown]
# ### model -> x 向量化
# ### 加速计划：[t1x, t2x, ... tNx] x向量的长度就一定得一样
# ### 极端情况：所有的长度就按照最短那个文章来
# ###  如何我们把所有的x向量的长度按照最长的长度来，会引发什么问题？

# %% [markdown]
# w *  x + b => 参数特别多 => 过拟合就会变严重！！！！

# %%
import jieba

# %%
def cut(string): return list(jieba.cut(string))

# %%
content['words'] = content['sentence'].apply(lambda s: ' '.join(cut(s)))

# %%
content['words_len'] = content['words'].apply(lambda s: len(s.split()))

# %%
words_len = content['words_len']

# %%
np.mean(words_len)
# Out:
# 12.766323088455772

# %%
np.std(words_len)
# Out:
# 4.53395337227558

# %%
np.max(words_len)
# Out:
# 81

# %%
len(np.where(words_len <= 20)[0]) / len(content)
# Out:
# 0.9625187406296851

# %%
plt.hist(content['words_len'], bins=50)
# Out:
# (array([5.200e+01, 9.590e+02, 1.304e+03, 4.841e+03, 3.254e+03, 7.498e+03,
#         8.194e+03, 3.936e+03, 7.619e+03, 3.795e+03, 6.458e+03, 3.450e+03,
#         7.860e+02, 6.690e+02, 1.700e+02, 2.520e+02, 7.400e+01, 1.400e+01,
#         2.500e+01, 3.000e+00, 3.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([ 1. ,  2.6,  4.2,  5.8,  7.4,  9. , 10.6, 12.2, 13.8, 15.4, 17. ,
#         18.6, 20.2, 21.8, 23.4, 25. , 26.6, 28.2, 29.8, 31.4, 33. , 34.6,
#         36.2, 37.8, 39.4, 41. , 42.6, 44.2, 45.8, 47.4, 49. , 50.6, 52.2,
#         53.8, 55.4, 57. , 58.6, 60.2, 61.8, 63.4, 65. , 66.6, 68.2, 69.8,
#         71.4, 73. , 74.6, 76.2, 77.8, 79.4, 81. ]),
#  <a list of 50 Patch objects>)

# %%
content['words_keep'] = content['words'].apply(lambda s: ' '.join(s.split()[:20]))

# %%
content.to_csv('train_after_analysis.csv')

# %%
from functools import reduce

# %%
sentences = content['words_keep'].tolist()

# %%
sentences = list(map(lambda s: s.split(), sentences))

# %% [markdown]
# ## func: reduce(func, list, [init])

# %%
all_words = reduce(lambda a, b: a + b, sentences)

# %%
words_count = Counter(all_words)

# %%
sorted(words_count.values(), reverse=True)
# Out:
# [34665,
#  23205,
#  21634,
#  9332,
#  7684,
#  6694,
#  5824,
#  5551,
#  5471,
#  4839,
#  4042,
#  3987,
#  3686,
#  3059,
#  2930,
#  2790,
#  2679,
#  2481,
#  2447,
#  2260,
#  2175,
#  2137,
#  2130,
#  2127,
#  2125,
#  1840,
#  1769,
#  1757,
#  1755,
#  1698,
#  1601,
#  1477,
#  1457,
#  1442,
#  1441,
#  1415,
#  1399,
#  1291,
#  1272,
#  1271,
#  1267,
#  1256,
#  1255,
#  1251,
#  1234,
#  1232,
#  1184,
#  1180,
#  1173,
#  1064,
#  1060,
#  1005,
#  996,
#  988,
#  981,
#  981,
#  980,
#  972,
#  969,
#  928,
#  926,
#  924,
#  913,
#  906,
#  885,
#  871,
#  863,
#  852,
#  847,
#  844,
#  838,
#  819,
#  818,
#  813,
#  810,
#  808,
#  807,
#  789,
#  780,
#  775,
#  739,
#  731,
#  725,
#  720,
#  717,
#  711,
#  710,
#  695,
#  686,
#  672,
#  666,
#  659,
#  645,
#  641,
#  630,
#  630,
#  628,
#  628,
#  623,
#  621,
#  613,
#  610,
#  610,
#  606,
#  596,
#  592,
#  581,
#  580,
#  580,
#  575,
#  567,
#  565,
#  564,
#  564,
#  561,
#  551,
#  542,
#  540,
#  535,
#  523,
#  521,
#  516,
#  492,
#  485,
#  481,
#  480,
#  472,
#  471,
#  471,
#  471,
#  466,
#  464,
#  464,
#  463,
#  463,
#  459,
#  457,
#  456,
#  447,
#  441,
#  441,
#  436,
#  436,
#  434,
#  431,
#  430,
#  417,
#  417,
#  416,
#  416,
#  415,
#  414,
#  414,
#  409,
#  406,
#  406,
#  403,
#  401,
#  396,
#  387,
#  385,
#  384,
#  382,
#  375,
#  374,
#  371,
#  366,
#  365,
#  363,
#  362,
#  360,
#  357,
#  355,
#  348,
#  345,
#  342,
#  339,
#  339,
#  339,
#  337,
#  335,
#  332,
#  329,
#  328,
#  328,
#  327,
#  324,
#  323,
#  323,
#  319,
#  318,
#  316,
#  315,
#  310,
#  308,
#  306,
#  305,
#  305,
#  305,
#  304,
#  301,
#  300,
#  300,
#  300,
#  299,
#  297,
#  296,
#  296,
#  293,
#  291,
#  291,
#  290,
#  290,
#  290,
#  289,
#  288,
#  286,
#  285,
#  285,
#  285,
#  285,
#  283,
#  282,
#  282,
#  281,
#  280,
#  280,
#  279,
#  279,
#  278,
#  277,
#  276,
#  274,
#  274,
#  268,
#  266,
#  265,
#  264,
#  263,
#  262,
#  262,
#  261,
#  261,
#  261,
#  260,
#  260,
#  259,
#  258,
#  258,
#  257,
#  255,
#  252,
#  252,
#  252,
#  251,
#  251,
#  251,
#  250,
#  249,
#  249,
#  248,
#  247,
#  246,
#  246,
#  245,
#  241,
#  241,
#  241,
#  241,
#  240,
#  239,
#  238,
#  238,
#  237,
#  234,
#  228,
#  227,
#  227,
#  226,
#  225,
#  225,
#  225,
#  225,
#  224,
#  223,
#  223,
#  222,
#  221,
#  221,
#  221,
#  221,
#  219,
#  218,
#  213,
#  213,
#  213,
#  213,
#  213,
#  213,
#  211,
#  211,
#  209,
#  209,
#  208,
#  208,
#  207,
#  207,
#  206,
#  206,
#  206,
#  205,
#  204,
#  204,
#  203,
#  203,
#  202,
#  202,
#  202,
#  201,
#  201,
#  201,
#  200,
#  200,
#  200,
#  199,
#  198,
#  198,
#  198,
#  197,
#  196,
#  195,
#  195,
#  195,
#  194,
#  194,
#  193,
#  193,
#  193,
#  193,
#  192,
#  192,
#  192,
#  189,
#  189,
#  189,
#  189,
#  188,
#  188,
#  188,
#  187,
#  186,
#  186,
#  186,
#  186,
#  185,
#  185,
#  185,
#  184,
#  183,
#  183,
#  182,
#  182,
#  181,
#  181,
#  181,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  179,
#  178,
#  178,
#  178,
#  178,
#  178,
#  177,
#  177,
#  177,
#  177,
#  177,
#  176,
#  176,
#  176,
#  176,
#  175,
#  175,
#  175,
#  175,
#  174,
#  174,
#  174,
#  173,
#  173,
#  173,
#  173,
#  173,
#  172,
#  172,
#  172,
#  172,
#  171,
#  171,
#  170,
#  170,
#  170,
#  169,
#  169,
#  169,
#  168,
#  168,
#  168,
#  168,
#  168,
#  167,
#  167,
#  166,
#  166,
#  166,
#  165,
#  165,
#  164,
#  164,
#  164,
#  164,
#  164,
#  164,
#  163,
#  163,
#  163,
#  162,
#  162,
#  162,
#  162,
#  162,
#  162,
#  161,
#  161,
#  161,
#  160,
#  159,
#  159,
#  159,
#  159,
#  159,
#  159,
#  158,
#  158,
#  158,
#  158,
#  158,
#  157,
#  157,
#  157,
#  156,
#  156,
#  156,
#  156,
#  155,
#  155,
#  155,
#  155,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  153,
#  153,
#  153,
#  152,
#  152,
#  152,
#  152,
#  151,
#  151,
#  151,
#  150,
#  149,
#  149,
#  148,
#  148,
#  148,
#  148,
#  147,
#  147,
#  147,
#  147,
#  147,
#  146,
#  145,
#  145,
#  144,
#  144,
#  144,
#  144,
#  144,
#  143,
#  143,
#  142,
#  142,
#  142,
#  142,
#  141,
#  141,
#  141,
#  141,
#  140,
#  140,
#  140,
#  139,
#  139,
#  139,
#  139,
#  139,
#  139,
#  138,
#  138,
#  138,
#  137,
#  136,
#  136,
#  136,
#  135,
#  135,
#  135,
#  134,
#  134,
#  134,
#  133,
#  133,
#  133,
#  133,
#  132,
#  132,
#  132,
#  132,
#  132,
#  131,
#  131,
#  131,
#  131,
#  131,
#  130,
#  130,
#  130,
#  130,
#  130,
#  129,
#  129,
#  128,
#  128,
#  128,
#  127,
#  127,
#  127,
#  127,
#  126,
#  126,
#  125,
#  125,
#  125,
#  125,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  123,
#  123,
#  123,
#  123,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  119,
#  119,
#  119,
#  119,
#  119,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  117,
#  117,
#  117,
#  117,
#  117,
#  116,
#  116,
#  116,
#  116,
#  116,
#  115,
#  115,
#  115,
#  115,
#  114,
#  114,
#  114,
#  114,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  110,
#  110,
#  110,
#  110,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  107,
#  107,
#  107,
#  107,
#  107,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  77,
#  77,
#  77,
#  77,
#  77,
#  77,
#  ...]

# %%
sorted(words_count.items(), key=lambda kv: kv[1], reverse=True)[:300]
# Out:
# [('，', 34665),
#  ('？', 23205),
#  ('的', 21634),
#  ('！', 9332),
#  ('：', 7684),
#  ('了', 6694),
#  ('是', 5824),
#  ('“', 5551),
#  ('”', 5471),
#  ('你', 4839),
#  ('有', 4042),
#  ('在', 3987),
#  ('吗', 3686),
#  ('什么', 3059),
#  ('中国', 2930),
#  ('为什么', 2790),
#  ('如何', 2679),
#  ('都', 2481),
#  ('和', 2447),
#  ('人', 2260),
#  ('怎么', 2175),
#  ('《', 2137),
#  ('被', 2130),
#  ('不', 2127),
#  ('》', 2125),
#  ('、', 1840),
#  ('会', 1769),
#  ('对', 1757),
#  ('我', 1755),
#  ('美国', 1698),
#  ('年', 1601),
#  ('上', 1477),
#  ('—', 1457),
#  ('最', 1442),
#  ('看', 1441),
#  ('能', 1415),
#  ('这', 1399),
#  ('一个', 1291),
#  ('要', 1272),
#  ('好', 1271),
#  ('还', 1267),
#  ('就', 1256),
#  ('将', 1255),
#  ('后', 1251),
#  ('与', 1234),
#  ('大', 1232),
#  ('中', 1184),
#  ('让', 1180),
#  ('哪些', 1173),
#  ('5', 1064),
#  ('他', 1060),
#  ('世界', 1005),
#  ('却', 996),
#  ('去', 988),
#  ('新', 981),
#  ('到', 981),
#  ('月', 980),
#  ('2018', 972),
#  ('谁', 969),
#  ('可以', 928),
#  ('多', 926),
#  ('说', 924),
#  ('也', 913),
#  ('又', 906),
#  ('上联', 885),
#  ('个', 871),
#  ('来', 863),
#  ('网友', 852),
#  ('如果', 847),
#  ('手机', 844),
#  ('下联', 838),
#  ('日本', 819),
#  ('做', 818),
#  ('用', 813),
#  ('没有', 810),
#  ('还是', 808),
#  ('万', 807),
#  ('现在', 789),
#  ('为', 780),
#  ('农村', 775),
#  ('为何', 739),
#  ('买', 731),
#  ('…', 725),
#  ('「', 720),
#  ('」', 717),
#  ('给', 711),
#  ('这个', 710),
#  ('3', 695),
#  ('把', 686),
#  ('岁', 672),
#  ('-', 666),
#  ('怎样', 659),
#  ('呢', 645),
#  ('多少', 641),
#  ('一', 630),
#  ('｜', 630),
#  ('10', 628),
#  ('（', 628),
#  ('很', 623),
#  ('）', 621),
#  ('国家', 613),
#  ('到底', 610),
#  ('哪个', 610),
#  ('知道', 606),
#  ('更', 596),
#  ('她', 592),
#  ('俄罗斯', 581),
#  ('4', 580),
#  ('真的', 580),
#  ('想', 575),
#  ('日', 567),
#  ('游戏', 565),
#  ('我们', 564),
#  ('小', 564),
#  ('过', 561),
#  ('下', 551),
#  ('自己', 542),
#  ('里', 540),
#  ('这些', 535),
#  ('2', 523),
#  ('怎么样', 521),
#  ('钱', 516),
#  ('从', 492),
#  ('城市', 485),
#  ('未来', 481),
#  ('这么', 480),
#  ('1', 472),
#  ('亿', 471),
#  ('王者', 471),
#  ('成为', 471),
#  ('公司', 466),
#  ('没', 464),
#  ('汽车', 464),
#  ('孩子', 463),
#  ('发展', 463),
#  ('吃', 459),
#  ('打', 457),
#  ('车', 456),
#  ('8', 447),
#  ('看待', 441),
#  ('荣耀', 441),
#  ('伊朗', 436),
#  ('再', 436),
#  ('活动', 434),
#  ('该', 431),
#  ('6', 430),
#  ('以色列', 417),
#  ('比', 417),
#  ('高', 416),
#  ('旅游', 416),
#  ('着', 415),
#  ('这样', 414),
#  ('出', 414),
#  ('才', 409),
#  ('第一', 406),
#  ('时', 406),
#  ('那么', 403),
#  ('不是', 401),
#  ('全球', 396),
#  ('前', 387),
#  ('美', 385),
#  ('市场', 384),
#  ('之', 382),
#  ('企业', 375),
#  ('英雄', 374),
#  ('20', 371),
#  ('生活', 366),
#  ('或', 365),
#  ('还有', 363),
#  ('投资', 362),
#  ('只', 360),
#  ('特朗普', 357),
#  ('·', 355),
#  ('就是', 348),
#  ('小米', 345),
#  ('不能', 342),
#  ('哪', 339),
#  ('需要', 339),
#  ('而', 339),
#  ('印度', 337),
#  ('技术', 335),
#  ('评价', 332),
#  ('7', 329),
#  ('等', 328),
#  ('选择', 328),
#  ('+', 327),
#  ('科技', 324),
#  ('链', 323),
#  ('教育', 323),
#  ('已', 319),
#  ('他们', 318),
#  ('它', 316),
#  ('可能', 315),
#  ('喜欢', 310),
#  ('北京', 308),
#  ('当', 306),
#  ('区块', 305),
#  ('国际', 305),
#  ('上市', 305),
#  ('马云', 304),
#  ('联想', 301),
#  ('但', 300),
#  ('玩', 300),
#  ('成', 300),
#  ('吧', 299),
#  ('房子', 297),
#  ('学生', 296),
#  ('行业', 296),
#  ('创业', 293),
#  ('哪里', 291),
#  ('元', 291),
#  ('协议', 290),
#  ('开', 290),
#  ('品牌', 290),
#  ('走', 289),
#  ('9', 288),
#  ('怎么办', 286),
#  ('房价', 285),
#  ('地方', 285),
#  ('影响', 285),
#  ('带', 285),
#  ('得', 283),
#  ('最后', 282),
#  ('不会', 282),
#  ('们', 281),
#  ('原因', 280),
#  ('成功', 280),
#  ('最大', 279),
#  ('太', 279),
#  ('即将', 278),
#  ('是否', 277),
#  ('价格', 276),
#  ('老师', 274),
#  ('腾讯', 274),
#  ('经济', 268),
#  ('可', 266),
#  ('应该', 265),
#  ('卖', 264),
#  ('看看', 263),
#  ('比较', 262),
#  ('叙利亚', 262),
#  ('时候', 261),
#  ('银行', 261),
#  ('大家', 261),
#  ('拿', 260),
#  ('十年', 260),
#  ('问题', 259),
#  ('故事', 258),
#  ('值得', 258),
#  ('微信', 257),
#  ('时代', 255),
#  ('全国', 252),
#  ('历史', 252),
#  ('项目', 252),
#  ('开始', 251),
#  ('工作', 251),
#  ('华为', 251),
#  ('已经', 250),
#  ('上海', 249),
#  ('文化', 249),
#  ('老', 248),
#  ('你们', 247),
#  ('万元', 246),
#  ('推荐', 246),
#  ('。', 245),
#  ('买房', 241),
#  ('联盟', 241),
#  ('普京', 241),
#  ('很多', 241),
#  ('求生', 240),
#  ('绝地', 239),
#  ('退出', 238),
#  ('韩国', 238),
#  ('升级', 237),
#  ('跑', 234),
#  ('火箭', 228),
#  ('苹果', 227),
#  ('发布', 227),
#  ('只有', 226),
#  ('号', 225),
#  ('向', 225),
#  ('出现', 225),
#  ('厉害', 225),
#  ('今年', 224),
#  ('比赛', 223),
#  ('什么样', 223),
#  ('国内', 222),
#  ('平台', 221),
#  ('跟', 221),
#  ('30', 221),
#  ('最好', 221),
#  ('分', 219),
#  ('12', 218),
#  ('快', 213),
#  ('币', 213),
#  ('爱', 213),
#  ('体验', 213),
#  ('汶川', 213),
#  ('家', 213),
#  ('适合', 211)]

# %%
stopwords = [w for w, _ in sorted(words_count.items(), key=lambda kv: kv[1], reverse=True)[:300]]

# %%
with open('dataset/stopwords.txt', 'w') as f:
    for w in stopwords:
        f.write(w + '\n')

# %%
plt.plot(list(map(lambda n: np.log(n), sorted(words_count.values(), reverse=True)[300:8000])))
