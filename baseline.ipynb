# %% [markdown]
# # 导入工具包

# %%
import random
import numpy as np
import pandas as pd
from bert4keras.backend import keras, set_gelu
from bert4keras.tokenizers import Tokenizer
from bert4keras.models import build_transformer_model
from bert4keras.optimizers import Adam, extend_with_piecewise_linear_lr
from bert4keras.snippets import sequence_padding, DataGenerator
from bert4keras.snippets import open
from keras.layers import Lambda, Dense

# %%
# !pip install bert4keras -i http://mirrors.aliyun.com/pypi/simple/ --trusted-host mirrors.aliyun.com
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: bert4keras in /root/anaconda3/lib/python3.8/site-packages (0.10.6)
# Requirement already satisfied: keras<=2.3.1 in /root/anaconda3/lib/python3.8/site-packages (from bert4keras) (2.3.1)
# Requirement already satisfied: six>=1.9.0 in /root/anaconda3/lib/python3.8/site-packages (from keras<=2.3.1->bert4keras) (1.15.0)
# Requirement already satisfied: scipy>=0.14 in /root/anaconda3/lib/python3.8/site-packages (from keras<=2.3.1->bert4keras) (1.4.1)
# Requirement already satisfied: h5py in /root/anaconda3/lib/python3.8/site-packages (from keras<=2.3.1->bert4keras) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /root/anaconda3/lib/python3.8/site-packages (from keras<=2.3.1->bert4keras) (1.20.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /root/anaconda3/lib/python3.8/site-packages (from keras<=2.3.1->bert4keras) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /root/anaconda3/lib/python3.8/site-packages (from keras<=2.3.1->bert4keras) (1.0.8)
# Requirement already satisfied: pyyaml in /root/anaconda3/lib/python3.8/site-packages (from keras<=2.3.1->bert4keras) (5.3.1)

# %%
# !pip install tensorflow-gpu==1.14.0 -i http://mirrors.aliyun.com/pypi/simple/ --trusted-host mirrors.aliyun.com
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# ERROR: Could not find a version that satisfies the requirement tensorflow-gpu==1.14.0 (from versions: 2.2.0rc1, 2.2.0rc2, 2.2.0rc3, 2.2.0rc4, 2.2.0, 2.2.1, 2.2.2, 2.3.0rc0, 2.3.0rc1, 2.3.0rc2, 2.3.0, 2.3.1, 2.3.2, 2.4.0rc0, 2.4.0rc1, 2.4.0rc2, 2.4.0rc3, 2.4.0rc4, 2.4.0, 2.4.1, 2.5.0rc0, 2.5.0rc1, 2.5.0rc2, 2.5.0rc3, 2.5.0)
# ERROR: No matching distribution found for tensorflow-gpu==1.14.0

# %%
# !pip install tensorflow-gpu==2.2.0 -i http://mirrors.aliyun.com/pypi/simple/ --trusted-host mirrors.aliyun.com
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: tensorflow-gpu==2.2.0 in /root/anaconda3/lib/python3.8/site-packages (2.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.20.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (0.35.1)
# Requirement already satisfied: protobuf>=3.8.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (3.15.8)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.15.0)
# Requirement already satisfied: astunparse==1.6.3 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (2.2.0)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (2.2.2)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.4.1)
# Requirement already satisfied: gast==0.3.3 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (0.3.3)
# Requirement already satisfied: absl-py>=0.7.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (0.12.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.1 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.11.2)
# Requirement already satisfied: grpcio>=1.8.6 in /root/anaconda3/lib/python3.8/site-packages (from tensorflow-gpu==2.2.0) (1.37.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /root/anaconda3/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (2.24.0)
# Requirement already satisfied: setuptools>=41.0.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (50.3.1.post20201107)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /root/anaconda3/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (0.4.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /root/anaconda3/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /root/anaconda3/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /root/anaconda3/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.29.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /root/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /root/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /root/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /root/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /root/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /root/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /root/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /root/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (4.7.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /root/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /root/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu==2.2.0) (0.4.8)

# %% [markdown]
# # 设置参数

# %%
set_gelu('tanh')  # 切换gelu版本

# %%
# num_classes = 2
# maxlen = 128
# batch_size = 32
# config_path = '../model/albert_small_zh_google/albert_config_small_google.json'
# checkpoint_path = '../model/albert_small_zh_google/albert_model.ckpt'
# dict_path = '../model/albert_small_zh_google/vocab.txt'

# # 建立分词器
# tokenizer = Tokenizer(dict_path, do_lower_case=True)

# %%
num_classes = 2
maxlen = 128
batch_size = 32
config_path = '../model/chinese_wwm_ext_L-12_H-768_A-12/bert_config.json'
checkpoint_path = '../model/chinese_wwm_ext_L-12_H-768_A-12/bert_model.ckpt'
dict_path = '../model/chinese_wwm_ext_L-12_H-768_A-12/vocab.txt'

# 建立分词器
tokenizer = Tokenizer(dict_path, do_lower_case=True)

# %% [markdown]
# # 定义模型

# %%
# # 加载预训练模型
# bert = build_transformer_model(
#     config_path=config_path,
#     checkpoint_path=checkpoint_path,
#     model='albert',
#     return_keras_model=False,
# )
# 加载预训练模型
bert = build_transformer_model(
    config_path=config_path,
    checkpoint_path=checkpoint_path,
    model='roberta',
    return_keras_model=False,
)

# %%
output = Lambda(lambda x: x[:, 0], name='CLS-token')(bert.model.output)
output = Dense(
    units=num_classes,
    activation='softmax',
    kernel_initializer=bert.initializer
)(output)

model = keras.models.Model(bert.model.input, output)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input-Token (InputLayer)        (None, None)         0
# __________________________________________________________________________________________________
# Input-Segment (InputLayer)      (None, None)         0
# __________________________________________________________________________________________________
# Embedding-Token (Embedding)     (None, None, 768)    16226304    Input-Token[0][0]
# __________________________________________________________________________________________________
# Embedding-Segment (Embedding)   (None, None, 768)    1536        Input-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Token-Segment (Add)   (None, None, 768)    0           Embedding-Token[0][0]
#                                                                  Embedding-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Position (PositionEmb (None, None, 768)    393216      Embedding-Token-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Norm (LayerNormalizat (None, None, 768)    1536        Embedding-Position[0][0]
# __________________________________________________________________________________________________
# Embedding-Dropout (Dropout)     (None, None, 768)    0           Embedding-Norm[0][0]
# __________________________________________________________________________________________________
# Transformer-0-MultiHeadSelfAtte (None, None, 768)    2362368     Embedding-Dropout[0][0]
#                                                                  Embedding-Dropout[0][0]
#                                                                  Embedding-Dropout[0][0]
# __________________________________________________________________________________________________
# Transformer-0-MultiHeadSelfAtte (None, None, 768)    0           Transformer-0-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-0-MultiHeadSelfAtte (None, None, 768)    0           Embedding-Dropout[0][0]
#                                                                  Transformer-0-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-0-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-0-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-0-FeedForward (Feed (None, None, 768)    4722432     Transformer-0-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-0-FeedForward-Dropo (None, None, 768)    0           Transformer-0-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-0-FeedForward-Add ( (None, None, 768)    0           Transformer-0-MultiHeadSelfAttent
#                                                                  Transformer-0-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-0-FeedForward-Norm  (None, None, 768)    1536        Transformer-0-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-1-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-0-FeedForward-Norm[0]
#                                                                  Transformer-0-FeedForward-Norm[0]
#                                                                  Transformer-0-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-1-MultiHeadSelfAtte (None, None, 768)    0           Transformer-1-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-1-MultiHeadSelfAtte (None, None, 768)    0           Transformer-0-FeedForward-Norm[0]
#                                                                  Transformer-1-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-1-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-1-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-1-FeedForward (Feed (None, None, 768)    4722432     Transformer-1-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-1-FeedForward-Dropo (None, None, 768)    0           Transformer-1-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-1-FeedForward-Add ( (None, None, 768)    0           Transformer-1-MultiHeadSelfAttent
#                                                                  Transformer-1-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-1-FeedForward-Norm  (None, None, 768)    1536        Transformer-1-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-2-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-1-FeedForward-Norm[0]
#                                                                  Transformer-1-FeedForward-Norm[0]
#                                                                  Transformer-1-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-2-MultiHeadSelfAtte (None, None, 768)    0           Transformer-2-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-2-MultiHeadSelfAtte (None, None, 768)    0           Transformer-1-FeedForward-Norm[0]
#                                                                  Transformer-2-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-2-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-2-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-2-FeedForward (Feed (None, None, 768)    4722432     Transformer-2-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-2-FeedForward-Dropo (None, None, 768)    0           Transformer-2-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-2-FeedForward-Add ( (None, None, 768)    0           Transformer-2-MultiHeadSelfAttent
#                                                                  Transformer-2-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-2-FeedForward-Norm  (None, None, 768)    1536        Transformer-2-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-3-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-2-FeedForward-Norm[0]
#                                                                  Transformer-2-FeedForward-Norm[0]
#                                                                  Transformer-2-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-3-MultiHeadSelfAtte (None, None, 768)    0           Transformer-3-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-3-MultiHeadSelfAtte (None, None, 768)    0           Transformer-2-FeedForward-Norm[0]
#                                                                  Transformer-3-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-3-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-3-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-3-FeedForward (Feed (None, None, 768)    4722432     Transformer-3-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-3-FeedForward-Dropo (None, None, 768)    0           Transformer-3-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-3-FeedForward-Add ( (None, None, 768)    0           Transformer-3-MultiHeadSelfAttent
#                                                                  Transformer-3-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-3-FeedForward-Norm  (None, None, 768)    1536        Transformer-3-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-4-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-3-FeedForward-Norm[0]
#                                                                  Transformer-3-FeedForward-Norm[0]
#                                                                  Transformer-3-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-4-MultiHeadSelfAtte (None, None, 768)    0           Transformer-4-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-4-MultiHeadSelfAtte (None, None, 768)    0           Transformer-3-FeedForward-Norm[0]
#                                                                  Transformer-4-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-4-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-4-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-4-FeedForward (Feed (None, None, 768)    4722432     Transformer-4-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-4-FeedForward-Dropo (None, None, 768)    0           Transformer-4-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-4-FeedForward-Add ( (None, None, 768)    0           Transformer-4-MultiHeadSelfAttent
#                                                                  Transformer-4-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-4-FeedForward-Norm  (None, None, 768)    1536        Transformer-4-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-5-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-4-FeedForward-Norm[0]
#                                                                  Transformer-4-FeedForward-Norm[0]
#                                                                  Transformer-4-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-5-MultiHeadSelfAtte (None, None, 768)    0           Transformer-5-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-5-MultiHeadSelfAtte (None, None, 768)    0           Transformer-4-FeedForward-Norm[0]
#                                                                  Transformer-5-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-5-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-5-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-5-FeedForward (Feed (None, None, 768)    4722432     Transformer-5-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-5-FeedForward-Dropo (None, None, 768)    0           Transformer-5-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-5-FeedForward-Add ( (None, None, 768)    0           Transformer-5-MultiHeadSelfAttent
#                                                                  Transformer-5-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-5-FeedForward-Norm  (None, None, 768)    1536        Transformer-5-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-6-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-5-FeedForward-Norm[0]
#                                                                  Transformer-5-FeedForward-Norm[0]
#                                                                  Transformer-5-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-6-MultiHeadSelfAtte (None, None, 768)    0           Transformer-6-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-6-MultiHeadSelfAtte (None, None, 768)    0           Transformer-5-FeedForward-Norm[0]
#                                                                  Transformer-6-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-6-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-6-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-6-FeedForward (Feed (None, None, 768)    4722432     Transformer-6-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-6-FeedForward-Dropo (None, None, 768)    0           Transformer-6-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-6-FeedForward-Add ( (None, None, 768)    0           Transformer-6-MultiHeadSelfAttent
#                                                                  Transformer-6-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-6-FeedForward-Norm  (None, None, 768)    1536        Transformer-6-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-7-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-6-FeedForward-Norm[0]
#                                                                  Transformer-6-FeedForward-Norm[0]
#                                                                  Transformer-6-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-7-MultiHeadSelfAtte (None, None, 768)    0           Transformer-7-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-7-MultiHeadSelfAtte (None, None, 768)    0           Transformer-6-FeedForward-Norm[0]
#                                                                  Transformer-7-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-7-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-7-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-7-FeedForward (Feed (None, None, 768)    4722432     Transformer-7-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-7-FeedForward-Dropo (None, None, 768)    0           Transformer-7-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-7-FeedForward-Add ( (None, None, 768)    0           Transformer-7-MultiHeadSelfAttent
#                                                                  Transformer-7-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-7-FeedForward-Norm  (None, None, 768)    1536        Transformer-7-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-8-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-7-FeedForward-Norm[0]
#                                                                  Transformer-7-FeedForward-Norm[0]
#                                                                  Transformer-7-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-8-MultiHeadSelfAtte (None, None, 768)    0           Transformer-8-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-8-MultiHeadSelfAtte (None, None, 768)    0           Transformer-7-FeedForward-Norm[0]
#                                                                  Transformer-8-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-8-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-8-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-8-FeedForward (Feed (None, None, 768)    4722432     Transformer-8-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-8-FeedForward-Dropo (None, None, 768)    0           Transformer-8-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-8-FeedForward-Add ( (None, None, 768)    0           Transformer-8-MultiHeadSelfAttent
#                                                                  Transformer-8-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-8-FeedForward-Norm  (None, None, 768)    1536        Transformer-8-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-9-MultiHeadSelfAtte (None, None, 768)    2362368     Transformer-8-FeedForward-Norm[0]
#                                                                  Transformer-8-FeedForward-Norm[0]
#                                                                  Transformer-8-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-9-MultiHeadSelfAtte (None, None, 768)    0           Transformer-9-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-9-MultiHeadSelfAtte (None, None, 768)    0           Transformer-8-FeedForward-Norm[0]
#                                                                  Transformer-9-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-9-MultiHeadSelfAtte (None, None, 768)    1536        Transformer-9-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-9-FeedForward (Feed (None, None, 768)    4722432     Transformer-9-MultiHeadSelfAttent
# __________________________________________________________________________________________________
# Transformer-9-FeedForward-Dropo (None, None, 768)    0           Transformer-9-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-9-FeedForward-Add ( (None, None, 768)    0           Transformer-9-MultiHeadSelfAttent
#                                                                  Transformer-9-FeedForward-Dropout
# __________________________________________________________________________________________________
# Transformer-9-FeedForward-Norm  (None, None, 768)    1536        Transformer-9-FeedForward-Add[0][
# __________________________________________________________________________________________________
# Transformer-10-MultiHeadSelfAtt (None, None, 768)    2362368     Transformer-9-FeedForward-Norm[0]
#                                                                  Transformer-9-FeedForward-Norm[0]
#                                                                  Transformer-9-FeedForward-Norm[0]
# __________________________________________________________________________________________________
# Transformer-10-MultiHeadSelfAtt (None, None, 768)    0           Transformer-10-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-10-MultiHeadSelfAtt (None, None, 768)    0           Transformer-9-FeedForward-Norm[0]
#                                                                  Transformer-10-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-10-MultiHeadSelfAtt (None, None, 768)    1536        Transformer-10-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-10-FeedForward (Fee (None, None, 768)    4722432     Transformer-10-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-10-FeedForward-Drop (None, None, 768)    0           Transformer-10-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-10-FeedForward-Add  (None, None, 768)    0           Transformer-10-MultiHeadSelfAtten
#                                                                  Transformer-10-FeedForward-Dropou
# __________________________________________________________________________________________________
# Transformer-10-FeedForward-Norm (None, None, 768)    1536        Transformer-10-FeedForward-Add[0]
# __________________________________________________________________________________________________
# Transformer-11-MultiHeadSelfAtt (None, None, 768)    2362368     Transformer-10-FeedForward-Norm[0
#                                                                  Transformer-10-FeedForward-Norm[0
#                                                                  Transformer-10-FeedForward-Norm[0
# __________________________________________________________________________________________________
# Transformer-11-MultiHeadSelfAtt (None, None, 768)    0           Transformer-11-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-11-MultiHeadSelfAtt (None, None, 768)    0           Transformer-10-FeedForward-Norm[0
#                                                                  Transformer-11-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-11-MultiHeadSelfAtt (None, None, 768)    1536        Transformer-11-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-11-FeedForward (Fee (None, None, 768)    4722432     Transformer-11-MultiHeadSelfAtten
# __________________________________________________________________________________________________
# Transformer-11-FeedForward-Drop (None, None, 768)    0           Transformer-11-FeedForward[0][0]
# __________________________________________________________________________________________________
# Transformer-11-FeedForward-Add  (None, None, 768)    0           Transformer-11-MultiHeadSelfAtten
#                                                                  Transformer-11-FeedForward-Dropou
# __________________________________________________________________________________________________
# Transformer-11-FeedForward-Norm (None, None, 768)    1536        Transformer-11-FeedForward-Add[0]
# __________________________________________________________________________________________________
# CLS-token (Lambda)              (None, 768)          0           Transformer-11-FeedForward-Norm[0
# __________________________________________________________________________________________________
# dense_146 (Dense)               (None, 2)            1538        CLS-token[0][0]
# ==================================================================================================
# Total params: 101,678,594
# Trainable params: 101,678,594
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 派生为带分段线性学习率的优化器。
# 其中name参数可选，但最好填入，以区分不同的派生优化器。
# AdamLR = extend_with_piecewise_linear_lr(Adam, name='AdamLR')

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=Adam(1e-5),  # 用足够小的学习率
#     optimizer=AdamLR(learning_rate=1e-4, lr_schedule={
#         1000: 1,
#         2000: 0.1
#     }),
    metrics=['accuracy'],
)

# %% [markdown]
# # 生成数据

# %%
def load_data(valid_rate=0.3):
    train_file = "../data/train.csv"
    test_file = "../data/test.csv"
    
    df_train_data = pd.read_csv("../data/train.csv")
    df_test_data = pd.read_csv("../data/test.csv")
    
    train_data, valid_data, test_data = [], [], []
    
    for row_i, data in df_train_data.iterrows():
        id, level_1, level_2, level_3, level_4, content, label = data
        
        id, text, label = id, str(level_1) + '\t' + str(level_2) + '\t' + \
        str(level_3) + '\t' + str(level_4) + '\t' + str(content), label
        
        if random.random() > valid_rate:
            train_data.append( (id, text, int(label)) )
        else:
            valid_data.append( (id, text, int(label)) )
            
    for row_i, data in df_test_data.iterrows():
        id, level_1, level_2, level_3, level_4, content = data
        
        id, text, label = id, str(level_1) + '\t' + str(level_2) + '\t' + \
        str(level_3) + '\t' + str(level_4) + '\t' + str(content), 0
        
        test_data.append( (id, text, int(label)) )
    return train_data, valid_data, test_data

# %%
train_data, valid_data, test_data = load_data(valid_rate=0.3)

# %%
valid_data.
# Out:
# [(2,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t消防知识要加强',
#   0),
#  (13,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t三楼车间天花板脱落，找人维修',
#   0),
#  (18, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t未进行消防演练', 0),
#  (21,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t巡查中发现紧急疏散指示灯故障，已经更换',
#   0),
#  (22,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散指示灯故障',
#   0),
#  (26,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插头应按规定正确接线',
#   1),
#  (29,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t一楼四号常闭式防火门，经常被杂物堆放，责令清洁部，清理干净保持防火门关闭状态',
#   0),
#  (35, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t没有安装防爆灯，已整改。', 0),
#  (36, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器压力不足', 0),
#  (38,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堆积杂物，已清理',
#   0),
#  (40,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散通道不畅通',
#   0),
#  (47,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防栓门口被桶装水堵塞。',
#   0),
#  (50,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未实施新员安全教育培训',
#   0),
#  (52,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t一栋四楼B消防通道堆放杂物',
#   0),
#  (53,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t灭火器过期',
#   0),
#  (60,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t有杂物',
#   0),
#  (63,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道指示线不清晰',
#   0),
#  (77,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散通道堆放杂物',
#   0),
#  (78,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t有一盏应急照明灯故障，需更换',
#   0),
#  (80,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t黄色地标线模糊，补地标线，把超出的货物摆放整齐。',
#   0),
#  (81,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\tG1栋2楼车间内工作台照明电源线套管破损（已整改）。',
#   0),
#  (86,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t1、安全警示标志\t1、应当在易燃、易爆、腐蚀、粉尘、高温、毒物、辐射、电力设施、可能发生坠落、挤压以及其他各类有较大危险因素的工作场所和设备、设施上设置明显的安全警示标志。\t安全警示标志不清晰，已整改',
#   0),
#  (89,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t安全警示标志太糊，有损坏',
#   0),
#  (90,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t灭火器未点检',
#   0),
#  (92,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\t员工没配戴眼罩，已整改',
#   0),
#  (96,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t检查馥轩厨房防毒面具过期。北区三楼精英教育城喷淋头破裂。',
#   0),
#  (97, '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t一般隐患', 1),
#  (98,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t立式注塑机旁墙壁排气扇无末端漏电保护开关',
#   0),
#  (100,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t消防栓缺少消防管接头',
#   0),
#  (101,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道货车架子堵塞，已经清理走',
#   0),
#  (104,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\tABC灭火器压力不足，修理后正常',
#   0),
#  (106,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱内放置杂物，要求立即整改',
#   0),
#  (108,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t货物比较多，来不及上架，通道有点堵',
#   0),
#  (109,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t三楼保安室方向防火门处于半敞开状态，责令立即整改',
#   0),
#  (111,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t经巡查三栋4楼安全出口灯撞坏，相关人员立即通知维修人员重新更换新的安全出口灯。',
#   0),
#  (115,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t已消除隐患',
#   1),
#  (118, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t下雨，厂房墙面垮倒', 0),
#  (120,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口堵塞',
#   0),
#  (123,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t占用、堵塞、封闭',
#   0),
#  (128,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱旁放了几个纸箱',
#   0),
#  (130,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\t未安装漏电保护开关',
#   0),
#  (133,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改',
#   1),
#  (141,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t甩干机没有作业指导书',
#   0),
#  (144,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防设施、器材和消防安全标志不完整。',
#   0),
#  (146,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t一楼A4区灭火器下面堆放杂物',
#   0),
#  (147,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t下沙新村潮歌苑4栋1单元1楼防火门敞开',
#   1),
#  (151,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口有堆放货物，隐患已整改，通道货物已挪开',
#   0),
#  (152,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t有',
#   1),
#  (155,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t部分灭火器材过期未能正常使用。',
#   0),
#  (157,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t作业场所通风不好',
#   0),
#  (158,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t灭火器失交效',
#   0),
#  (160,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t货物阻挡通道',
#   0),
#  (163,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道应急灯未连通电源',
#   0),
#  (165,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t仓库通道一个灭火器被移动位置',
#   0),
#  (167, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器未合理分布', 0),
#  (169,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t隐患安全出口不亮，已经整改完毕。',
#   0),
#  (174,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t临时用电没有安装漏电保护装置，立即安装',
#   0),
#  (179,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器有损坏，立即购买新的更换。',
#   0),
#  (192,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯损坏',
#   0),
#  (195,
#   '商贸服务教文卫类（基础）—2016版\t（三）安全管理规章制度\t1、安全管理责任制\t1、建立、健全安全管理责任制，明确各岗位的责任人员、责任范围和考核标准等内容。\t建立、健全安全管理责任制，明确各岗位的责任人员、责任范围和考核标准等内容。',
#   1),
#  (198,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t单发螺纹机（挨着10T冲压机这台）插座盒盖子损坏',
#   0),
#  (203, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t9层东区放杂物', 0),
#  (209,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况。\t电线裸露，已整改',
#   0),
#  (210,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t没有张贴安全标识',
#   0),
#  (211,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物堆放。已整改。',
#   0),
#  (214, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器没有固定摆放', 0),
#  (217,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器摆放不整齐，已整改。',
#   0),
#  (220,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯不亮',
#   0),
#  (222,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火卷帘下堆放物品',
#   0),
#  (233,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t安全生产管理制度、培训演练、职责书、隐患整改制度及应急方案，均已完善',
#   0),
#  (235,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道堆放杂物',
#   0),
#  (242,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t有两个电源开关接触不良，已购买更换',
#   0),
#  (246,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱堆放杂物，现已整改',
#   0),
#  (248,
#   '三小场所（现场）—2016版\t（二）电气安全\t2、电气设备、设施的金属接地或接零\t1、电气设备金属外壳需接地保护。\t有一处电线裸露,将裸露电线套管。',
#   0),
#  (251,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t     ',
#   1),
#  (252,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t没有经过安全教育培训',
#   0),
#  (255,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道堵塞，通道堆放物品',
#   0),
#  (257, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t用火、用电有违章情况', 0),
#  (259,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t全安通道堆放有杂物',
#   0),
#  (262,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器材分布较密集，已调整合理分布！',
#   0),
#  (270, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线裸露', 0),
#  (272, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改', 1),
#  (274,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；\t配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；',
#   1),
#  (275,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t知识掌握较少',
#   0),
#  (277,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散应急灯不亮',
#   0),
#  (278,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t空压机皮带以受损，立即更换。',
#   0),
#  (285,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t个别标识掉落',
#   0),
#  (292,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全出口堵塞',
#   0),
#  (293,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯不亮   已重新按装新的应急照明灯   已整改',
#   0),
#  (298,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下、周围堆放杂物',
#   0),
#  (305,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯失效',
#   0),
#  (323,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t因老化原因部分通电式安全出口标志不亮',
#   0),
#  (324,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防栓下面堆放物料',
#   0),
#  (326,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急指示灯损坏，已更换',
#   0),
#  (327, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t冰箱插座无地线。', 0),
#  (329,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不畅通',
#   0),
#  (330,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有临时堆放货物   ',
#   0),
#  (340,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器位置未放到位。未按时检查',
#   0),
#  (344,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防铲掉落',
#   0),
#  (348,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t缺警示标识牌',
#   0),
#  (350,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\tC栋一楼封边机操作人员未佩戴劳动防护用品（耳塞）',
#   0),
#  (351,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯不亮',
#   0),
#  (354,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门不在常闭状态',
#   0),
#  (356,
#   '商贸服务教文卫类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t未贴操作指南',
#   0),
#  (358,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t地库防火门，，，有杂物，已清理、',
#   0),
#  (363, '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t会议记录', 1),
#  (364,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t应急照明灯损坏',
#   0),
#  (367,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t个别应急灯不亮，已及时修复',
#   0),
#  (368,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t安全通道门未打开',
#   0),
#  (370,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器已过期，现场已更换。',
#   0),
#  (372,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门关闭',
#   0),
#  (373,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t车间配电箱堆放大量纸屑',
#   0),
#  (374, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t无定期进行应急演练', 0),
#  (376,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t1、安全警示标志\t1、应当在易燃、易爆、腐蚀、粉尘、高温、毒物、辐射、电力设施、可能发生坠落、挤压以及其他各类有较大危险因素的工作场所和设备、设施上设置明显的安全警示标志。\t电源插座“有电危险”警示牌脱落，现已经更换',
#   0),
#  (379,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t2、配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。\t配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。',
#   1),
#  (384,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\t水吧旁边一个插座没有接地线',
#   0),
#  (389,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门未常闭',
#   0),
#  (402,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间包装台部分区域未接地线存在安全隐患，已及时处理并整改完成。',
#   0),
#  (403,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材未按规定位置摆放',
#   0),
#  (404,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有物品挡在消防通道口，立即清走',
#   0),
#  (415,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道标示线',
#   0),
#  (421,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t地面安全通道标识有缺损，',
#   0),
#  (427,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有一盏应急照明灯损坏，已立即更换整改。',
#   0),
#  (429, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t车间个别灭火器被挡', 0),
#  (430,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t常闭门闭门器脱落',
#   0),
#  (431,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t出口应急灯坏，已更新',
#   0),
#  (438,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道临时堆放货物',
#   0),
#  (441,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间1个插座未装漏电保护装置',
#   0),
#  (450,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t车间一处安全疏散指示标志脱落，需重新张贴固定到位以示警醒。',
#   0),
#  (451,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t车间工业风扇未接地保护',
#   0),
#  (452,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有一安全疏散标识模糊不清',
#   0),
#  (458,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t出入口指示灯标示不清楚',
#   0),
#  (459,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防出口灯损坏',
#   0),
#  (461,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物挡住通道',
#   0),
#  (462,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t一处落地扇电源线未使用双层绝缘电线。',
#   0),
#  (464,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯坏',
#   0),
#  (468,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t未检查灭火器材配置及有效情况；',
#   0),
#  (472,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t车间消防栓上面放有杂物，现已移走。',
#   0),
#  (476,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓前堆放物品，现已搬离',
#   0),
#  (480,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t点检表缺失',
#   0),
#  (481,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼的右边楼梯口的应急灯损坏',
#   0),
#  (482,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t电箱未安装挡护板',
#   0),
#  (487,
#   '建筑施工类（选项）—2016版\t（十七）起重吊装\t2、实体安全\t5、起重吊装作业是否符合要求。\tB座二十三层铝模未使用料斗吊装',
#   0),
#  (488,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t技术部转角门口堆放了纸箱',
#   0),
#  (489,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t南区球车库消防栓水带腐蚀',
#   0),
#  (491,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t车间安全出口灯损坏一个，需立即更换',
#   0),
#  (493,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t地面疏散指示标志数量不足，需添加',
#   0),
#  (495,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t地上有坑',
#   0),
#  (497,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t没有设置“当心触电”安全警示标志。',
#   0),
#  (499,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全疏散指示标志',
#   1),
#  (507,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t紧急出口灯不亮了',
#   0),
#  (510,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t三楼镭射机没有安装红外线防护。',
#   0),
#  (511,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t16个消防安全应急灯故障，已及时更换。',
#   0),
#  (513,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t当心触电标志掉落',
#   0),
#  (520,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器失效',
#   0),
#  (524,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t车间通道画线不清晰',
#   0),
#  (527,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物堵住前台通道',
#   0),
#  (528,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t卫生大扫除时挪动了灭火器，没有放回原来位置',
#   0),
#  (529,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t多余线未处理',
#   0),
#  (532,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t通道标识线有磨损现象',
#   0),
#  (533,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t未按规定摆放加工物料',
#   0),
#  (535,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有一个灭火器过期，即购买',
#   0),
#  (542,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防器材不完整',
#   0),
#  (545,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t公司经理上班发现本企业逃生通道货物堵塞，立即整改',
#   0),
#  (555,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t焊锡工作台采用接线板接线，改为长期固定的电源插座。',
#   0),
#  (558,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t堆放杂物',
#   0),
#  (559,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t ',
#   1),
#  (560,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t检查安全出口，疏散通道标志为荧光的，现已更换为通电带灯罩形。',
#   0),
#  (561,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t在些灭火器过期了',
#   0),
#  (575,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t车间机械设备未粘贴操作说明',
#   0),
#  (581, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t近期组织安全演练培训。', 1),
#  (585,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t卸油区有树叶，已立即清理。',
#   0),
#  (588,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物已整改',
#   0),
#  (589,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防栓堵塞',
#   0),
#  (591,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道黄色线标明不明显。',
#   0),
#  (593,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t灯坏，已修复',
#   0),
#  (595,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t消火栓前放置杂物，影响消防器材使用',
#   0),
#  (601,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道被堵',
#   0),
#  (606,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t检查电箱无防护栏，并更新警示标示，整改',
#   0),
#  (607,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道有货物堆积',
#   0),
#  (611,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t皮带轮未加防护照',
#   0),
#  (613,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\tN座三楼有一处安口指示标的线没有套完全',
#   0),
#  (620, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t未进行有限空间的演练', 0),
#  (625,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t巡查发现仓库外墙人行通道偏窗户处放了两叉板货，影响消防安全通道畅通事项，立即整改OK.',
#   0),
#  (626,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t员工安全培训会议，讲解用电安全，操机安全，防火安全，正确使用灭火器，站好年前最后一班安全岗',
#   1),
#  (632,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t未贴消防指示标识  已整改',
#   0),
#  (633,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t部分灯管有损坏',
#   0),
#  (638, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t忘记巡查', 0),
#  (640,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口指示牌有时亮灯有时不亮接触不良',
#   0),
#  (641,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线未安装线巢',
#   0),
#  (642,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t灭火器过期更换',
#   0),
#  (649,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t2号楼五楼南侧墙壁电源插座相临零线接反',
#   0),
#  (658,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t车间通道上堆放货物堵塞，已搬离。已整改。',
#   0),
#  (659, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t车间灭火器配备的数量不足', 0),
#  (660,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t电线连接处不安全',
#   0),
#  (662,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间有杂物堵住通道，已整改',
#   0),
#  (664,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口旁堆有少量水桶，已整改拿开。',
#   0),
#  (671,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (676,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全无标志',
#   0),
#  (677, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器未检查', 0),
#  (682,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器不合格',
#   0),
#  (684,
#   '商贸服务教文卫类（选项）—2016版\t（一）娱乐场所\t1、场地设置\t1、场地设置应符合《娱乐场所管理条例》及有关消防标准规范要求。\t商圈楼上为住宅区',
#   0),
#  (687,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散指示标志补磨损，已更换。',
#   0),
#  (688, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电箱遮挡缺失', 0),
#  (696,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道上有物品堆积，立即移走，恢复通畅',
#   0),
#  (698,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t饮水机水桶霸占消防通道，已经整理完毕。',
#   0),
#  (700,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t碰焊机用的插座未接地线',
#   0),
#  (703,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防器材自检漏检',
#   0),
#  (706,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堆放部分杂物，已即刻整改',
#   0),
#  (707,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t值班室有一灭火器合格标签上有效期已过，已责令维护人员更换并进行安全教育。',
#   0),
#  (711,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道被堵塞',
#   0),
#  (713,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t厨房电箱开关无警示标识',
#   0),
#  (720, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线祼露', 0),
#  (726,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t八栋一楼车间有一个应急灯冲不了电，断电2分钟后不亮，已立即通知工程部维修。',
#   0),
#  (730,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t安全管理人员未持证（已报名学习）',
#   0),
#  (735,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t亚克力粘合胶水未按要求放置在防爆柜里，即时放回',
#   0),
#  (737,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道堵塞',
#   0),
#  (740,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全标识不到位，厂内没有设置禁止吸烟标志，立即整改',
#   0),
#  (743,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t灭火器未定期检查',
#   0),
#  (748,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急灯故障，已及时更换新的应急灯',
#   0),
#  (749,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器需充粉',
#   0),
#  (750, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t消防栓下面堆放物品，已及时清理', 0),
#  (751,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t9楼946房门口消火栓贴纸脱落，现场更换，已整改',
#   0),
#  (759,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t没张贴警示标志',
#   0),
#  (761,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电箱旁有杂物堆放，立刻清理整改',
#   0),
#  (762,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t传动齿轮没有防护罩',
#   0),
#  (763,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t1、安全警示标志\t1、应当在易燃、易爆、腐蚀、粉尘、高温、毒物、辐射、电力设施、可能发生坠落、挤压以及其他各类有较大危险因素的工作场所和设备、设施上设置明显的安全警示标志。\t有灰尘',
#   0),
#  (766,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t废材没有及时清理',
#   0),
#  (772, '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t1、临时用电必须经过审批。\t临时用电必须经过审批。', 1),
#  (774, '交通运输类（基础）—2016版\t（六）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有定期组织应急演练。', 0),
#  (777, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器欠压', 0),
#  (791, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t个别灭火器已过期。', 0),
#  (802,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t杂物圈占消防设备',
#   0),
#  (805,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t有物料呆放在消防栓前面了,,要求立即移开',
#   0),
#  (806,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有杂物',
#   0),
#  (812,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t厨房安全出口指示灯不会亮，重新更换。',
#   0),
#  (813,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器没有及时检查更新记录。',
#   0),
#  (814,
#   '商贸服务教文卫类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育\t1、制定安全教育培训计划，确保全员参与培训，并建立安全培训档案。\t制定安全教育培训计划，确保全员参与培训，并建立安全培训档案。',
#   1),
#  (815,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道堵塞,灭火器未放灭火器箱',
#   0),
#  (817,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t生产车间一台商标印刷机传动链轮外露部分安全防护装置不完整，未设置明显的“当心机械伤人”警示标志',
#   0),
#  (818,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门没关',
#   0),
#  (821, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t消防栓旁边堆放物品', 0),
#  (827,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散标志脱落',
#   0),
#  (829,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯，安全出口标志不齐全',
#   0),
#  (832,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t有的未贴当心触电标识',
#   0),
#  (836, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器过期了', 0),
#  (838,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全疏散指示标志方向不正确',
#   0),
#  (841,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t开关箱内有杂物',
#   0),
#  (842,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防通道车辆堵住，已经改善责令开走，恢复消防通道畅通',
#   0),
#  (845,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t灭火器消火栓堵塞，已整改',
#   0),
#  (846,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道有障碍物，已整改。',
#   0),
#  (849,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口灯不亮',
#   0),
#  (854,
#   '工业/危化品类（选项）—2016版\t（七）重点监管工艺及场所\t7、锂电池生产或储存\t11、电芯、电池库房温度应控制在摄氏-5℃至35℃范围内，相对湿度不超过75。库房内应整洁、干燥，通风良好。不得将危险化学品、热（火）源存放其中。\t不能放太多',
#   0),
#  (861,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t漏电保护装置少了一个，现已安装',
#   0),
#  (864,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有隐患',
#   1),
#  (868,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t安全会议记录不齐全',
#   0),
#  (870,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t配电箱安全警示标志脱落，已重新张贴并加固',
#   0),
#  (872, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t消火栓被 堵塞', 0),
#  (877,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全出口未设置应急灯',
#   0),
#  (880,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t已整改',
#   1),
#  (881,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口赌塞',
#   0),
#  (887,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t未接地',
#   0),
#  (888,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道被占用，及时整改。',
#   0),
#  (890, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、用火、用电有无违章情况。\t厨房不能明火', 0),
#  (905,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱未粘贴“当心触电”安全警示标志',
#   0),
#  (910, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t私接插座一个', 0),
#  (916,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堆积物料，即刻整理，整理完毕。',
#   0),
#  (917,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t未贴，已贴好。',
#   0),
#  (921,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间',
#   1),
#  (923,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱有杂物',
#   0),
#  (926,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t出口指示灯不亮，当天处理完善。',
#   0),
#  (934,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯故障不亮灯，电工已更换，问题已解决',
#   0),
#  (935,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间通道未标志明显的边线',
#   0),
#  (937,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全通道堵塞',
#   0),
#  (938,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t乙炔气瓶用纸皮遮挡',
#   0),
#  (939,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t摆放货物在疏散通道上',
#   0),
#  (941,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道堆积杂物，已整改',
#   0),
#  (947,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t电风扇没有上防护套。立即整改',
#   0),
#  (949,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已经整改',
#   1),
#  (953,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门未开启',
#   0),
#  (954,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道标识破损',
#   0),
#  (956,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t灭火器点检不及时',
#   0),
#  (971,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t11栋1楼消防通道堵塞，要求立即搬离。',
#   0),
#  (973,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t电源插座松脱',
#   0),
#  (975,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物暂存区疏散通道被堵塞',
#   0),
#  (977,
#   '三小场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t主要负责人及从业人员没有安全培训记录。',
#   0),
#  (978,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼车间通道放置货物，已整改',
#   0),
#  (980,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (981,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱的安全警示标志遗失，需立即补上',
#   0),
#  (985,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t车间部分电源开关盒未张贴安全警示标志',
#   0),
#  (986,
#   '建筑施工类（基础）—2016版\t（五）安全管理档案\t6、安全生产奖惩记录\t1、建立安全生产奖惩记录。\t生产安全奖惩记录不完整',
#   0),
#  (988,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t四楼过道一处疏散指示灯不亮',
#   0),
#  (990,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (992,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t防爆灯有一个不亮了，已立即更换。',
#   0),
#  (996,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t已经整改',
#   1),
#  (997, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t当日未举行防火巡查', 0),
#  (998,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯故障',
#   0),
#  (1002,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口标志故障',
#   0),
#  (1003,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有时被占用，已清理',
#   0),
#  (1004,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散指示标志破损',
#   0),
#  (1005,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有个应急照明灯坏了，已经更换新的。',
#   0),
#  (1009,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t车间配电箱箱门与箱体跨接地线脱落',
#   0),
#  (1015, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t2、堆垛堆距应符合要求。', 1),
#  (1019,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防栓有货物挡住',
#   0),
#  (1026,
#   '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t1、库房内储存物品应分类、分堆、限额存放。\t辅料堆放不规范！偶有堵塞安全通道的情况。',
#   0),
#  (1027, '交通运输类（现场）—2016版\t（一）消防安全\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t已整改', 1),
#  (1029,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道、疏散指示标志脱落需重新购买张贴。',
#   0),
#  (1040,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防水泵房安全出口指示灯坏，已立即更换',
#   0),
#  (1042,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t1楼消火栓被货物遮挡，现场已整改，清理货物。',
#   0),
#  (1045,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道上有物品',
#   0),
#  (1046,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t加装两个应急灯和安全出口指示牌',
#   1),
#  (1047,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t二楼一个配电箱外未张贴（当心触电警示标志）',
#   0),
#  (1054,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t射骨机红外线坏，更换',
#   0),
#  (1057,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t车间配电箱警示标志脱落',
#   0),
#  (1060,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t四楼楼梯口堆放纸箱',
#   0),
#  (1064,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t压缩空气管道未标示流向和介质。',
#   0),
#  (1069,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t有两个员工未的安全教育培训未进行记录，立即重新培训进行记录',
#   0),
#  (1071,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t员工已把货物堆放超过黄线，已经整改。',
#   0),
#  (1075, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线裸露，责令整改', 0),
#  (1076, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有损坏没及时补上', 0),
#  (1077,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t织带车间一楼水带漏水。',
#   0),
#  (1078,
#   '商贸服务教文卫类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育\t1、制定安全教育培训计划，确保全员参与培训，并建立安全培训档案。\t系统—联系人无安全管理人员证',
#   0),
#  (1080, '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱有占用', 0),
#  (1081,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t3月份未建立安全档案',
#   0),
#  (1082,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座已老化烧坏',
#   0),
#  (1085,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t有缺失的会议记录',
#   0),
#  (1087,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t临时堆放杂物,',
#   0),
#  (1088,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓无标示',
#   0),
#  (1089,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道有临时堆放货物，改整改',
#   0),
#  (1091,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯修理效果不佳',
#   0),
#  (1093,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t已整改',
#   1),
#  (1096, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t杂乱摆放', 1),
#  (1098,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t临时有堆货物品',
#   0),
#  (1108,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、用火、用电有无违章情况。\t水吧插座老旧，不合安全要求。立即更换',
#   0),
#  (1111, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防车通道有杂物堆积', 0),
#  (1112,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器分布重新调配',
#   0),
#  (1118,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t成品仓库包装好的货物未出,堵塞通道.',
#   0),
#  (1119,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堵塞',
#   0),
#  (1122, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t5、消防安全重点部位的人员在岗情况；\t隐患', 1),
#  (1126,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t灭火器乱放，未放置在指定区域',
#   0),
#  (1127,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器充粉后，检查记录和标识未及时张贴。',
#   0),
#  (1130,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；',
#   1),
#  (1131, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有效期已过，未及时维修', 0),
#  (1132,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t整改前作业通道不畅通，整改后作业通道已畅通。',
#   0),
#  (1134,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道放了东西',
#   0),
#  (1135,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t每次生产加工时安全通道不畅通',
#   0),
#  (1138,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t2、危险作业\t1、凡涉及动火、高空、有限空间、密闭容器、起重、施工动土、临时用电等危险作业，应明确危险作业的申请、审批权限、职责和程序，办理作业票证；安排专门人员进行现场安全管理。\t奥特莱斯更换广告牌未办理审批手续，现场要求停工，并补办了相关手续。',
#   0),
#  (1139,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t有一顾客加油时使用手机，现场管理人员已立即劝阻。',
#   0),
#  (1144,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t宿舍通道安全指示牌损坏。消防栓通道堵。',
#   0),
#  (1146, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t没有定期校验。', 0),
#  (1147, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t一楼壹时尚灭火器过期', 0),
#  (1148,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t一楼冲压冲床缺失防护罩',
#   0),
#  (1150,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\tc栋9楼安全疏散指示牌需固定',
#   0),
#  (1159, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器放在地上', 0),
#  (1162, '商贸服务教文卫类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有定期组织消防演练', 0),
#  (1165,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t线头没有归整好',
#   0),
#  (1168,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t仓库所有的安全出口灯与应急照明灯不亮（跳闸）',
#   0),
#  (1171,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t已整改，已配护罩',
#   0),
#  (1173, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t4楼有个灭火器气压不足', 0),
#  (1176, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有2瓶过期灭火器', 0),
#  (1177,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t安全教育培训档案不全，两天内补齐',
#   0),
#  (1181,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防柱有杂物档住',
#   0),
#  (1184,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况。\t消防通道有业主放置杂物',
#   0),
#  (1185,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间安全通道不畅通',
#   0),
#  (1191, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况；', 1),
#  (1194,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t已整改',
#   1),
#  (1195, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t货物堆放不整齐，容易堵塞通道', 0),
#  (1196,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t电箱盖脱落',
#   0),
#  (1201,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改',
#   1),
#  (1205,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散指示未整顿好',
#   0),
#  (1206,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口灯坏了',
#   0),
#  (1209,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t定期组织员工培训，消防安全培训',
#   0),
#  (1211, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器未检查', 0),
#  (1214,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道被小推车堵塞',
#   0),
#  (1215,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t杂物堆放',
#   0),
#  (1217,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t仓库一个应急照明灯断电不亮，已经整改完毕。',
#   0),
#  (1220,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t物品堵塞消防栓',
#   0),
#  (1222,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼与二楼厂房各有一处应急灯不灯，已马上更换',
#   0),
#  (1229,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t一楼机器档护没有安装',
#   0),
#  (1233,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t2、无铠装电缆在屋内明敷，水平敷设时，其至地面的距离不应小于2.5m；垂直敷设时，其至地面的距离不应小于1.8m。当不能满足上述要求时应有防止电缆机械损伤的措施。沿地敷设的电缆应穿钢管保护。穿管的内径不应小于电缆外径的1.5倍。\t甲类仓库后可燃气体探测器电源线管脱落',
#   0),
#  (1238,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物堵塞安全出口通道',
#   0),
#  (1240,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口、疏散通道有堵塞，已经现场移开，保持畅通',
#   0),
#  (1241,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t2、灭火器应合理分布，无固定摆放并定期校验。',
#   1),
#  (1243,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t防爆灯掉落',
#   0),
#  (1245,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有隐患',
#   1),
#  (1247,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口，过道有货物堆积。当场已整改。',
#   0),
#  (1248,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t酒精瓶没有告知卡',
#   0),
#  (1251,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器材配置及有效情况。',
#   1),
#  (1254,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道不畅通',
#   0),
#  (1255,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t车间垃圾堵塞安全通道，已整改',
#   0),
#  (1258, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t不符合五距要求', 0),
#  (1262,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼7号楼梯模板堵塞安全口处，人员无法正常迅速疏散逃生。',
#   0),
#  (1263,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t未在电池仓库内粘贴“严禁烟火 ”标志',
#   0),
#  (1270,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t春节长假后，后门口的应急照明灯坏了',
#   0),
#  (1272,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t1楼PVD区域施工具挡住消防栓',
#   0),
#  (1276,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t机床按钮损坏',
#   0),
#  (1278, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t已购置完毕', 1),
#  (1279, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线裸露', 0),
#  (1283,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t电房增加防火标识',
#   1),
#  (1288,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改完成',
#   1),
#  (1296, '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器缺失一个，已立即整改', 0),
#  (1300,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器压力不足，已更换',
#   0),
#  (1301,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t1、危险化学品从业单位通用要求\t5、可能产生易燃易爆气体的场所，必须设置可燃气体的检测和自动报警装置。\t没有自动报警装置',
#   0),
#  (1304,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有一处照明指示灯损坏',
#   0),
#  (1306,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t仓库里的灭火器被移动了，已整改',
#   0),
#  (1311,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施',
#   1),
#  (1316,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t泡沫塑料',
#   0),
#  (1318,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t标识不清楚/脱落',
#   0),
#  (1320, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器压力不足。', 0),
#  (1324,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t玻璃门不是防火\n\n现已安装防火门',
#   0),
#  (1325,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线裸露',
#   0),
#  (1330,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器快过期了，责令马上更换新的。',
#   0),
#  (1331,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道有放货。',
#   0),
#  (1333,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t机器皮带传动装置缺少安全保护。',
#   0),
#  (1340,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t1-2楼目前还处于装修阶段，暂未配备灭火器材',
#   0),
#  (1345, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t应急灯缺失', 0),
#  (1350, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期，存在隐患', 0),
#  (1353,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t未检查消防安全重点部位的管理情况；',
#   0),
#  (1354, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器干粉用尽，已充满', 0),
#  (1356,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t楼道口停放电动车，堆放货物。  发现后，立即通知相关人员处理。',
#   0),
#  (1361,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t2、危险作业\t1、凡涉及动火、高空、有限空间、密闭容器、起重、施工动土、临时用电等危险作业，应明确危险作业的申请、审批权限、职责和程序，办理作业票证，安排专门人员进行现场安全管理。\t1. :5栋1楼登高梯台处无“当心坠落”警示标志；2. :5栋1楼部分配电盒处无“当心触电”警示标志；',
#   0),
#  (1363,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵塞消防通道，已整改',
#   0),
#  (1366,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道堆放杂物',
#   0),
#  (1368,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器没有进行检查，查验是否合格，有一个失效',
#   0),
#  (1371,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道被货物堵塞',
#   0),
#  (1372,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t封口机用后未拔电源',
#   0),
#  (1379,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t桥架插座走线不规范',
#   0),
#  (1381,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有隐患',
#   1),
#  (1382, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器', 1),
#  (1383,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t1.現場塗料桶未夾靜電接地夾。2.電器線路上面有易燃物。3.開關蓋板沒鎖好。',
#   0),
#  (1385,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t电风扇电线没有装套管',
#   0),
#  (1399,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一个灭火器支架铆钉松脱，现已加固稳定',
#   0),
#  (1409,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道是否畅通',
#   1),
#  (1412,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口疏散指示标志，应急照明灯不亮。',
#   0),
#  (1416,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t大会议室一个灭火器压力位为红色区域',
#   0),
#  (1417,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t有两个灭火器失压，已经更换好',
#   0),
#  (1418, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t饮水机旁边有电线外露。', 0),
#  (1426,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\t手磨机电缆线有损坏，已经换新的',
#   0),
#  (1436,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线有裸露情况，立即整改！           整改完成！',
#   0),
#  (1440,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器上放有杂物，及时清开',
#   0),
#  (1441,
#   '商贸服务教文卫类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t手压台皮带轮外露，无防护罩',
#   0),
#  (1442,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座、电源插头应按规定正确接线。',
#   1),
#  (1444,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t1、特种设备档案\t1、特种设备(及安全附件)检测报告齐全，并在有效期内。运行记录和维修保养记录齐全。\t空压机安全检查维护记录表被雨淋湿，重新放置，已整改',
#   0),
#  (1446,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t未建立全员安全生产责任制',
#   0),
#  (1447,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全标志缺失',
#   0),
#  (1454,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t部分指示标志不到位，需要再贴标示明确',
#   0),
#  (1460,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t1、特种设备档案\t1、特种设备(及安全附件)检测报告齐全，并在有效期内。运行记录和维修保养记录齐全。\t电箱没有挡板，需要增加挡板',
#   0),
#  (1461,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器摆放位置不对，重新固定新位置',
#   0),
#  (1464, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t9、消防（控制室）值班情况和设施运行、记录情况；\t无', 1),
#  (1466,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t仓库堆放不整齐',
#   0),
#  (1467,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口有阻碍物',
#   0),
#  (1468,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t无记录',
#   0),
#  (1471,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t灭火器压力不够，已经更换',
#   0),
#  (1474,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t年底地面黄色警戒线已经模糊不清，计划在春节放假期间重刷油漆。',
#   0),
#  (1480, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况；', 1),
#  (1481,
# ...
#   0),
#  (2784,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t三楼车间的疏散通道被货物堵塞，发现后立即安排人员清理',
#   0),
#  (2794, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t包装部配电箱前方货物遮挡', 0),
#  (2795,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t个别应急照明灯损坏',
#   0),
#  (2796,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\t.个别员工未佩戴劳动防护用品。',
#   0),
#  (2797,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t农科商务办公楼二楼西面消防楼梯防火门未处于常闭状态。',
#   0),
#  (2799, '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t还未进行安全培训', 0),
#  (2805,
#   '交通运输类（现场）—2016版\t（一）消防安全\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器未定期检查',
#   0),
#  (2813,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t电箱盒打开没及时关好',
#   0),
#  (2817,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防器材缺失',
#   0),
#  (2818,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t一般隐患',
#   1),
#  (2827, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器损坏，已更换', 0),
#  (2837,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t车间安全标志脱落，立即整改还原。',
#   0),
#  (2842, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况。\t用电有违章情况。', 0),
#  (2844,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t仓库安全通道被来的货物临时堵塞，出货后及时清理了通道。',
#   0),
#  (2846,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t应急处置卡内容未完善，需立即处理。',
#   0),
#  (2848,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t己整改',
#   1),
#  (2852,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t1、技术中心实验室门上依马田政府安监要求增加安全出口洒及应急灯，增加安装正常化。具体见上传图片。',
#   1),
#  (2853,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t出货人员将消防通道堵塞，立即整改。',
#   0),
#  (2854,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口有垃圾',
#   0),
#  (2858,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座没有按规定位置摆放',
#   0),
#  (2864,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t一楼电箱下放可燃物，已通知员工清走。',
#   0),
#  (2867,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t部分员工对安全防火防范意识不够强，需进一步加强培训',
#   0),
#  (2870, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t办公室区域灭火器配置不够', 0),
#  (2883,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t三厂三楼自动机台下方链条转动处防护门缺失，需更换或维修',
#   0),
#  (2889,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t配电箱没有设置“当心触电”安全警示标志',
#   0),
#  (2902,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t805门口安全疏散指示标志脱落',
#   0),
#  (2903,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防安全标志不完整',
#   0),
#  (2910, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器上面有东西盖住了', 0),
#  (2922,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱有杂物',
#   0),
#  (2927,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口、疏散通道旁堆放杂物',
#   0),
#  (2928,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t应急预案需再完善',
#   0),
#  (2929,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t5号安装包装货物挡住配电箱',
#   0),
#  (2931,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有机器设备堵住通道',
#   0),
#  (2932,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t前台应急灯不亮，待更换',
#   0),
#  (2936,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱、开关箱放置了杂物',
#   0),
#  (2949, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线裸露，未装入线槽', 0),
#  (2963,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (2965, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、用火、用电有无违章情况。\t现场整改', 1),
#  (2966,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t有可能人接触，可能触电区域是否有安全设施及醒目警示标志。现已整改。',
#   1),
#  (2967,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t多台加温设备无“当心高温”安全警示标志；',
#   0),
#  (2971,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\t插座故障 立即整改',
#   0),
#  (2973,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座、电源插头应按规定正确接线。',
#   1),
#  (2974,
#   '三小场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t没有主要负责人及从业人员有安全培训记录。',
#   0),
#  (2977,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有杂物。',
#   0),
#  (2985,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t1、危险化学品从业单位通用要求\t7、危险化学品专用仓库、专用场地须报公安、消防部门批准。\t临时仓库需要安装防火门',
#   0),
#  (2988, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有物品遮挡', 0),
#  (2992, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t1、库房内储存物品应分类、分堆、限额存放。\t堆放杂乱', 0),
#  (2996,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t未安装防护罩',
#   0),
#  (2998, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况', 1),
#  (3000,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱当心触电标志脱落',
#   0),
#  (3001,
#   '工业/危化品类（选项）—2016版\t（六）危险设备\t1、注塑机械\t1、根据工艺要求操作口前安全门有行程开关等设施实现电气连锁，确保前门打开时部件停止运动。\t电动小推车停用时未拔钥匙',
#   0),
#  (3003, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t配置数量少,立即购买', 0),
#  (3004,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\tF7栋3楼防火卷帘下对方杂物影响消防安全。',
#   0),
#  (3013, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一瓶灭火器压力不够', 0),
#  (3014,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散指示标志摆放问题',
#   0),
#  (3016,
#   '交通运输类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座接地应符合下列规定：a.对于单相两孔插座，面对插座的右孔或上孔应与相线连接，左孔或下孔应与中性导体（N）连接；对于单相三孔插座，面对插座的右孔应与相线连接，左孔应与中性导体（N）连接。b.单相三孔、三相四孔与三相五孔插座的保护接地与导体（PE）应接在上孔；插座的保护接地导体端子不得与中性导体端子连接；同一场所的三相插座，其接线的相序应一致。c.保护接地导体（PE）在插座之间不得串接连接。d.相线与中性导体（N）不应利用插座本体的接线端子转接供电。\t现场整改',
#   1),
#  (3017,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t卡板放得太乱，督促车间派人重新整理好',
#   0),
#  (3019,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道临时堆放货物',
#   0),
#  (3030,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t甲类分装区地板未采取防静电措施，可能会产 生静电火花，引起火灾隐患。',
#   0),
#  (3031,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道堵塞',
#   0),
#  (3032, '三小场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t未定期进行应急演练。', 0),
#  (3034,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t月常规安全检查发现有15个灭火器已到期，已经重新充装完成。',
#   0),
#  (3036,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道阻塞',
#   0),
#  (3037, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t防火巡查记录表未按时更新', 0),
#  (3040,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t一楼有一处消防器被货物阻挡',
#   0),
#  (3042,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t新员工消防器材不会使用',
#   0),
#  (3047,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯电源开关被关闭，已立即开启。',
#   0),
#  (3048, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t演练记录未及时更新', 0),
#  (3050,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t发现一个灭火器无粉，已加',
#   0),
#  (3051, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器及消防栓定期检查', 0),
#  (3056,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t警示标志年久，字体不清晰。重新更换',
#   0),
#  (3057,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t大板车间吊机刹车打滑，需更换刹车圈1个',
#   0),
#  (3059,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处于开启状态，有物品阻塞，已整改',
#   0),
#  (3065,
#   '商贸服务教文卫类（选项）—2016版\t（四）仓库\t2、照明\t2、库房内不得设置移动照明灯具，照明灯具下方不准堆放物品，其垂直下方与储存物品水平间距不得小于0.5米。\t物品堆放不规范',
#   0),
#  (3066,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下放置易燃物品',
#   0),
#  (3068,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t制定并实施全员参与的安全教育培训计划',
#   1),
#  (3069, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器被遮挡', 0),
#  (3076,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口临时堆放有物品，立即清理。',
#   0),
#  (3078,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t安全出口堆放货物',
#   0),
#  (3080, '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t无', 1),
#  (3085,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t防爆柜未粘贴责任人和电话,未粘贴安全技术说明书(MSDS),无出入库记录',
#   0),
#  (3095,
#   '三小场所（现场）—2016版\t（二）电气安全\t2、电气设备、设施的金属接地或接零\t1、电气设备金属外壳需接地保护。\t坐地风扇加装防护网',
#   0),
#  (3096,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散标识牌陈旧，立即给换新的',
#   0),
#  (3097,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t防爆柜无MSDS报告。旁边放杂物。',
#   0),
#  (3098,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有一处消防疏散通道被货物挡到',
#   0),
#  (3099,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道上摆放机器。要求立即将机器挪开，通道禁止堵塞。',
#   0),
#  (3101,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堆放货物已清空',
#   0),
#  (3102,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t有些通道未用黄线标明。立即用黄线注明',
#   0),
#  (3106,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物堆垛与墙之间少于0.3米',
#   0),
#  (3112,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道有台物料车',
#   0),
#  (3115,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯没亮',
#   0),
#  (3121,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座面板损坏致使电线外露，有触电风险',
#   0),
#  (3124,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t无记录',
#   0),
#  (3125,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t三楼有一个胶筐放在通道上',
#   0),
#  (3126,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间插座已安装漏电保护开关',
#   0),
#  (3129,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业区有卡板',
#   0),
#  (3132,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施、器材和消防安全标志是否在位、完整',
#   1),
#  (3133,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器材存放处有物料堵塞',
#   0),
#  (3134, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t过期，己更换', 0),
#  (3136,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t部分冲压设备相关安全警示标识不健全或未做风险告知',
#   0),
#  (3138,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好',
#   1),
#  (3139,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t车间有一处灭火器被阻挡，已按要求现场处理',
#   0),
#  (3141, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t演练人员记录不详细', 0),
#  (3143,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t个别配电箱安全警示标志脱落',
#   0),
#  (3146,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t灭火器、配电箱前堆货物',
#   0),
#  (3147,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t机器停用',
#   1),
#  (3150,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有一组灭火器压力不足，立即更换',
#   0),
#  (3156,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明损坏,立即更换',
#   0),
#  (3157,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t一楼到负一楼通道疏散指示牌损坏，已更换',
#   0),
#  (3158,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞，后面整改疏通',
#   0),
#  (3166,
#   '建筑施工类（基础）—2016版\t（二）安全管理机构和人员\t1、安全管理机构\t1、设立与本企业资质、规模相符的安全管理机构。\t有安群管理框架图',
#   0),
#  (3167,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t仓库有一扇常闭式防火门没有关上',
#   0),
#  (3168,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口有货物堵塞',
#   0),
#  (3169,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t后门常闭式防火门，闭门器门，处予打开状态，立即找人维修',
#   0),
#  (3178, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t已整改', 1),
#  (3179,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t对外来施工人员的安全教育需加强',
#   0),
#  (3180,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t2、特种设备作业人员和特种作业人员培训\t1、特种设备作业人员、特种作业人员经专业培训取得相应资格证书并有效。\t1、没有定期组织应急演练。',
#   0),
#  (3183,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t有电线氧化，导致接触不良',
#   0),
#  (3185,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t电瓶手动叉车未贴操作规程',
#   0),
#  (3186,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t二楼切机没有防护罩。     已整改',
#   0),
#  (3187,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t小一班门口干粉灭火器压力不足，马上更换新的灭火器。',
#   0),
#  (3188,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t盆栽挡住通道口',
#   0),
#  (3190,
#   '交通运输类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱“当心触电”安全警示标志缺失',
#   0),
#  (3193,
#   '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t8楼1疏散指示标志不亮',
#   0),
#  (3194, '建筑施工类（选项）—2016版\t（十二）施工用电\t2、实体安全\t6、现场照明是否符合要求。\t基坑照明灯具离地高度小于3米', 0),
#  (3197,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全应急灯不亮，更换新的',
#   0),
#  (3199,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t631组一处电线槽接口电线不规范、一处线槽盖脱位。',
#   0),
#  (3201,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t、安全疏散通道、疏散指示标志',
#   1),
#  (3206, '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t无安全培训记录', 0),
#  (3208,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t生产货物摆放不规整超过黄线',
#   0),
#  (3212,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯摆位有些斜，即时纠正',
#   0),
#  (3213,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防栓前面有桶装水遮挡',
#   0),
#  (3215, '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t灯管损坏', 0),
#  (3217, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期，己更换', 0),
#  (3224,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口指示灯损坏，以及时整改。',
#   0),
#  (3225, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t已整改', 1),
#  (3226, '三小场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t灭火器已过期', 0),
#  (3229,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t一、C区五楼胶架A部一条安全通道被货架堵塞；二、写字楼一楼一处安全出口灯不亮',
#   0),
#  (3230,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t2个应急照明灯不亮',
#   0),
#  (3232,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道被货物堵塞',
#   0),
#  (3233, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有效情况异常', 0),
#  (3242,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t记录',
#   1),
#  (3248,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\tK栋二楼车间一具灭火器过期',
#   0),
#  (3249, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t灭火器前有障碍物', 0),
#  (3256,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应紧灯在正常情况下亮灯，已修好改善',
#   1),
#  (3261,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t照明灯已坏',
#   0),
#  (3262, '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱有遮挡', 0),
#  (3266,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱前操作空间被遮挡。',
#   0),
#  (3268,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t所有灭火器2019-3-18都已拿到消防中队隔壁店面进行年审及更换',
#   0),
#  (3269,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口，已整改畅通\n',
#   0),
#  (3270,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t生产车间开关盒脱落',
#   0),
#  (3272,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口指示灯损坏，已经及时更换新的安全出口指示灯',
#   0),
#  ...]

# %%
len(train_data)
# Out:
# 8345

# %%
class data_generator(DataGenerator):
    """数据生成器
    """
    def __iter__(self, random=False):
        batch_token_ids, batch_segment_ids, batch_labels = [], [], []
        for is_end, (id, text, label) in self.sample(random):
            token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
            batch_token_ids.append(token_ids)
            batch_segment_ids.append(segment_ids)
            batch_labels.append([label])
            if len(batch_token_ids) == self.batch_size or is_end:
                batch_token_ids = sequence_padding(batch_token_ids)
                batch_segment_ids = sequence_padding(batch_segment_ids)
                batch_labels = sequence_padding(batch_labels)
                yield [batch_token_ids, batch_segment_ids], batch_labels
                batch_token_ids, batch_segment_ids, batch_labels = [], [], []

# %%
# 转换数据集
train_generator = data_generator(train_data, batch_size)
valid_generator = data_generator(valid_data, batch_size)

# %%
valid_data
# Out:
# [(2,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t消防知识要加强',
#   0),
#  (13,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t三楼车间天花板脱落，找人维修',
#   0),
#  (18, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t未进行消防演练', 0),
#  (21,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t巡查中发现紧急疏散指示灯故障，已经更换',
#   0),
#  (22,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散指示灯故障',
#   0),
#  (26,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插头应按规定正确接线',
#   1),
#  (29,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t一楼四号常闭式防火门，经常被杂物堆放，责令清洁部，清理干净保持防火门关闭状态',
#   0),
#  (35, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t没有安装防爆灯，已整改。', 0),
#  (36, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器压力不足', 0),
#  (38,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堆积杂物，已清理',
#   0),
#  (40,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t疏散通道不畅通',
#   0),
#  (47,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防栓门口被桶装水堵塞。',
#   0),
#  (50,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t未实施新员安全教育培训',
#   0),
#  (52,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t一栋四楼B消防通道堆放杂物',
#   0),
#  (53,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t灭火器过期',
#   0),
#  (60,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t有杂物',
#   0),
#  (63,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道指示线不清晰',
#   0),
#  (77,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散通道堆放杂物',
#   0),
#  (78,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t有一盏应急照明灯故障，需更换',
#   0),
#  (80,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t黄色地标线模糊，补地标线，把超出的货物摆放整齐。',
#   0),
#  (81,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\tG1栋2楼车间内工作台照明电源线套管破损（已整改）。',
#   0),
#  (86,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t1、安全警示标志\t1、应当在易燃、易爆、腐蚀、粉尘、高温、毒物、辐射、电力设施、可能发生坠落、挤压以及其他各类有较大危险因素的工作场所和设备、设施上设置明显的安全警示标志。\t安全警示标志不清晰，已整改',
#   0),
#  (89,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t安全警示标志太糊，有损坏',
#   0),
#  (90,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t灭火器未点检',
#   0),
#  (92,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\t员工没配戴眼罩，已整改',
#   0),
#  (96,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t检查馥轩厨房防毒面具过期。北区三楼精英教育城喷淋头破裂。',
#   0),
#  (97, '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t一般隐患', 1),
#  (98,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t立式注塑机旁墙壁排气扇无末端漏电保护开关',
#   0),
#  (100,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t消防栓缺少消防管接头',
#   0),
#  (101,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道货车架子堵塞，已经清理走',
#   0),
#  (104,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\tABC灭火器压力不足，修理后正常',
#   0),
#  (106,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱内放置杂物，要求立即整改',
#   0),
#  (108,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t货物比较多，来不及上架，通道有点堵',
#   0),
#  (109,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t三楼保安室方向防火门处于半敞开状态，责令立即整改',
#   0),
#  (111,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t经巡查三栋4楼安全出口灯撞坏，相关人员立即通知维修人员重新更换新的安全出口灯。',
#   0),
#  (115,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t已消除隐患',
#   1),
#  (118, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t下雨，厂房墙面垮倒', 0),
#  (120,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口堵塞',
#   0),
#  (123,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t占用、堵塞、封闭',
#   0),
#  (128,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱旁放了几个纸箱',
#   0),
#  (130,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\t未安装漏电保护开关',
#   0),
#  (133,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改',
#   1),
#  (141,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t甩干机没有作业指导书',
#   0),
#  (144,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防设施、器材和消防安全标志不完整。',
#   0),
#  (146,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t一楼A4区灭火器下面堆放杂物',
#   0),
#  (147,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t下沙新村潮歌苑4栋1单元1楼防火门敞开',
#   1),
#  (151,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口有堆放货物，隐患已整改，通道货物已挪开',
#   0),
#  (152,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t有',
#   1),
#  (155,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t部分灭火器材过期未能正常使用。',
#   0),
#  (157,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t作业场所通风不好',
#   0),
#  (158,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t灭火器失交效',
#   0),
#  (160,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t货物阻挡通道',
#   0),
#  (163,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道应急灯未连通电源',
#   0),
#  (165,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t仓库通道一个灭火器被移动位置',
#   0),
#  (167, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器未合理分布', 0),
#  (169,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t隐患安全出口不亮，已经整改完毕。',
#   0),
#  (174,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t临时用电没有安装漏电保护装置，立即安装',
#   0),
#  (179,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器有损坏，立即购买新的更换。',
#   0),
#  (192,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯损坏',
#   0),
#  (195,
#   '商贸服务教文卫类（基础）—2016版\t（三）安全管理规章制度\t1、安全管理责任制\t1、建立、健全安全管理责任制，明确各岗位的责任人员、责任范围和考核标准等内容。\t建立、健全安全管理责任制，明确各岗位的责任人员、责任范围和考核标准等内容。',
#   1),
#  (198,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t单发螺纹机（挨着10T冲压机这台）插座盒盖子损坏',
#   0),
#  (203, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t9层东区放杂物', 0),
#  (209,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况。\t电线裸露，已整改',
#   0),
#  (210,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t没有张贴安全标识',
#   0),
#  (211,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物堆放。已整改。',
#   0),
#  (214, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器没有固定摆放', 0),
#  (217,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器摆放不整齐，已整改。',
#   0),
#  (220,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯不亮',
#   0),
#  (222,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火卷帘下堆放物品',
#   0),
#  (233,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t安全生产管理制度、培训演练、职责书、隐患整改制度及应急方案，均已完善',
#   0),
#  (235,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t通道堆放杂物',
#   0),
#  (242,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t有两个电源开关接触不良，已购买更换',
#   0),
#  (246,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱堆放杂物，现已整改',
#   0),
#  (248,
#   '三小场所（现场）—2016版\t（二）电气安全\t2、电气设备、设施的金属接地或接零\t1、电气设备金属外壳需接地保护。\t有一处电线裸露,将裸露电线套管。',
#   0),
#  (251,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t     ',
#   1),
#  (252,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t没有经过安全教育培训',
#   0),
#  (255,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道堵塞，通道堆放物品',
#   0),
#  (257, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t用火、用电有违章情况', 0),
#  (259,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t全安通道堆放有杂物',
#   0),
#  (262,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器材分布较密集，已调整合理分布！',
#   0),
#  (270, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线裸露', 0),
#  (272, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改', 1),
#  (274,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t2、配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；\t配电箱(柜)进出线中的N线必须通过N线端子板连接，接地线必须通过接地线端子板连接；',
#   1),
#  (275,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t知识掌握较少',
#   0),
#  (277,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散应急灯不亮',
#   0),
#  (278,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t空压机皮带以受损，立即更换。',
#   0),
#  (285,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t个别标识掉落',
#   0),
#  (292,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全出口堵塞',
#   0),
#  (293,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯不亮   已重新按装新的应急照明灯   已整改',
#   0),
#  (298,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下、周围堆放杂物',
#   0),
#  (305,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯失效',
#   0),
#  (323,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t因老化原因部分通电式安全出口标志不亮',
#   0),
#  (324,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防栓下面堆放物料',
#   0),
#  (326,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急指示灯损坏，已更换',
#   0),
#  (327, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t冰箱插座无地线。', 0),
#  (329,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道不畅通',
#   0),
#  (330,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有临时堆放货物   ',
#   0),
#  (340,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器位置未放到位。未按时检查',
#   0),
#  (344,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防铲掉落',
#   0),
#  (348,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t缺警示标识牌',
#   0),
#  (350,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\tC栋一楼封边机操作人员未佩戴劳动防护用品（耳塞）',
#   0),
#  (351,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯不亮',
#   0),
#  (354,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门不在常闭状态',
#   0),
#  (356,
#   '商贸服务教文卫类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t未贴操作指南',
#   0),
#  (358,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t地库防火门，，，有杂物，已清理、',
#   0),
#  (363, '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t会议记录', 1),
#  (364,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t应急照明灯损坏',
#   0),
#  (367,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t个别应急灯不亮，已及时修复',
#   0),
#  (368,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t安全通道门未打开',
#   0),
#  (370,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器已过期，现场已更换。',
#   0),
#  (372,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门关闭',
#   0),
#  (373,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t车间配电箱堆放大量纸屑',
#   0),
#  (374, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t无定期进行应急演练', 0),
#  (376,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t1、安全警示标志\t1、应当在易燃、易爆、腐蚀、粉尘、高温、毒物、辐射、电力设施、可能发生坠落、挤压以及其他各类有较大危险因素的工作场所和设备、设施上设置明显的安全警示标志。\t电源插座“有电危险”警示牌脱落，现已经更换',
#   0),
#  (379,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t2、配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。\t配电房内电缆线应放置在电缆沟内，并应加设盖板。配电柜前后面应放置绝缘垫，其绝缘垫的长度应大于配电柜的宽度。',
#   1),
#  (384,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\t水吧旁边一个插座没有接地线',
#   0),
#  (389,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门未常闭',
#   0),
#  (402,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间包装台部分区域未接地线存在安全隐患，已及时处理并整改完成。',
#   0),
#  (403,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防器材未按规定位置摆放',
#   0),
#  (404,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有物品挡在消防通道口，立即清走',
#   0),
#  (415,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道标示线',
#   0),
#  (421,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t地面安全通道标识有缺损，',
#   0),
#  (427,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有一盏应急照明灯损坏，已立即更换整改。',
#   0),
#  (429, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t车间个别灭火器被挡', 0),
#  (430,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t常闭门闭门器脱落',
#   0),
#  (431,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t出口应急灯坏，已更新',
#   0),
#  (438,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道临时堆放货物',
#   0),
#  (441,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间1个插座未装漏电保护装置',
#   0),
#  (450,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t车间一处安全疏散指示标志脱落，需重新张贴固定到位以示警醒。',
#   0),
#  (451,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t车间工业风扇未接地保护',
#   0),
#  (452,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有一安全疏散标识模糊不清',
#   0),
#  (458,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t出入口指示灯标示不清楚',
#   0),
#  (459,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防出口灯损坏',
#   0),
#  (461,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物挡住通道',
#   0),
#  (462,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t一处落地扇电源线未使用双层绝缘电线。',
#   0),
#  (464,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯坏',
#   0),
#  (468,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t未检查灭火器材配置及有效情况；',
#   0),
#  (472,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t车间消防栓上面放有杂物，现已移走。',
#   0),
#  (476,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓前堆放物品，现已搬离',
#   0),
#  (480,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t点检表缺失',
#   0),
#  (481,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼的右边楼梯口的应急灯损坏',
#   0),
#  (482,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t电箱未安装挡护板',
#   0),
#  (487,
#   '建筑施工类（选项）—2016版\t（十七）起重吊装\t2、实体安全\t5、起重吊装作业是否符合要求。\tB座二十三层铝模未使用料斗吊装',
#   0),
#  (488,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t技术部转角门口堆放了纸箱',
#   0),
#  (489,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t南区球车库消防栓水带腐蚀',
#   0),
#  (491,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t车间安全出口灯损坏一个，需立即更换',
#   0),
#  (493,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t地面疏散指示标志数量不足，需添加',
#   0),
#  (495,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t地上有坑',
#   0),
#  (497,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t没有设置“当心触电”安全警示标志。',
#   0),
#  (499,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全疏散指示标志',
#   1),
#  (507,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t紧急出口灯不亮了',
#   0),
#  (510,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t三楼镭射机没有安装红外线防护。',
#   0),
#  (511,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t16个消防安全应急灯故障，已及时更换。',
#   0),
#  (513,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t当心触电标志掉落',
#   0),
#  (520,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器失效',
#   0),
#  (524,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t车间通道画线不清晰',
#   0),
#  (527,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物堵住前台通道',
#   0),
#  (528,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t卫生大扫除时挪动了灭火器，没有放回原来位置',
#   0),
#  (529,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t多余线未处理',
#   0),
#  (532,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t通道标识线有磨损现象',
#   0),
#  (533,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t未按规定摆放加工物料',
#   0),
#  (535,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有一个灭火器过期，即购买',
#   0),
#  (542,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防器材不完整',
#   0),
#  (545,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t公司经理上班发现本企业逃生通道货物堵塞，立即整改',
#   0),
#  (555,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t焊锡工作台采用接线板接线，改为长期固定的电源插座。',
#   0),
#  (558,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t堆放杂物',
#   0),
#  (559,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t ',
#   1),
#  (560,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t检查安全出口，疏散通道标志为荧光的，现已更换为通电带灯罩形。',
#   0),
#  (561,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t在些灭火器过期了',
#   0),
#  (575,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t车间机械设备未粘贴操作说明',
#   0),
#  (581, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t近期组织安全演练培训。', 1),
#  (585,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t卸油区有树叶，已立即清理。',
#   0),
#  (588,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口有货物已整改',
#   0),
#  (589,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防栓堵塞',
#   0),
#  (591,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道黄色线标明不明显。',
#   0),
#  (593,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t灯坏，已修复',
#   0),
#  (595,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t消火栓前放置杂物，影响消防器材使用',
#   0),
#  (601,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道被堵',
#   0),
#  (606,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t检查电箱无防护栏，并更新警示标示，整改',
#   0),
#  (607,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道有货物堆积',
#   0),
#  (611,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t皮带轮未加防护照',
#   0),
#  (613,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\tN座三楼有一处安口指示标的线没有套完全',
#   0),
#  (620, '工业/危化品类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t未进行有限空间的演练', 0),
#  (625,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t巡查发现仓库外墙人行通道偏窗户处放了两叉板货，影响消防安全通道畅通事项，立即整改OK.',
#   0),
#  (626,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t员工安全培训会议，讲解用电安全，操机安全，防火安全，正确使用灭火器，站好年前最后一班安全岗',
#   1),
#  (632,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t未贴消防指示标识  已整改',
#   0),
#  (633,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t部分灯管有损坏',
#   0),
#  (638, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t忘记巡查', 0),
#  (640,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口指示牌有时亮灯有时不亮接触不良',
#   0),
#  (641,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线未安装线巢',
#   0),
#  (642,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t灭火器过期更换',
#   0),
#  (649,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t2号楼五楼南侧墙壁电源插座相临零线接反',
#   0),
#  (658,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t车间通道上堆放货物堵塞，已搬离。已整改。',
#   0),
#  (659, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t车间灭火器配备的数量不足', 0),
#  (660,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t电线连接处不安全',
#   0),
#  (662,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间有杂物堵住通道，已整改',
#   0),
#  (664,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口旁堆有少量水桶，已整改拿开。',
#   0),
#  (671,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (676,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全无标志',
#   0),
#  (677, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器未检查', 0),
#  (682,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器不合格',
#   0),
#  (684,
#   '商贸服务教文卫类（选项）—2016版\t（一）娱乐场所\t1、场地设置\t1、场地设置应符合《娱乐场所管理条例》及有关消防标准规范要求。\t商圈楼上为住宅区',
#   0),
#  (687,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散指示标志补磨损，已更换。',
#   0),
#  (688, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电箱遮挡缺失', 0),
#  (696,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道上有物品堆积，立即移走，恢复通畅',
#   0),
#  (698,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t饮水机水桶霸占消防通道，已经整理完毕。',
#   0),
#  (700,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t碰焊机用的插座未接地线',
#   0),
#  (703,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防器材自检漏检',
#   0),
#  (706,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堆放部分杂物，已即刻整改',
#   0),
#  (707,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t值班室有一灭火器合格标签上有效期已过，已责令维护人员更换并进行安全教育。',
#   0),
#  (711,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道被堵塞',
#   0),
#  (713,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t厨房电箱开关无警示标识',
#   0),
#  (720, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线祼露', 0),
#  (726,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t八栋一楼车间有一个应急灯冲不了电，断电2分钟后不亮，已立即通知工程部维修。',
#   0),
#  (730,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t安全管理人员未持证（已报名学习）',
#   0),
#  (735,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t亚克力粘合胶水未按要求放置在防爆柜里，即时放回',
#   0),
#  (737,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道堵塞',
#   0),
#  (740,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防安全标识不到位，厂内没有设置禁止吸烟标志，立即整改',
#   0),
#  (743,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t5、漏电保护\t1、低压配电线路应根据具体情况采用二级或三级保护，在总电源端、分支线首端或线路末端安装漏电保护装置。\t灭火器未定期检查',
#   0),
#  (748,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t应急灯故障，已及时更换新的应急灯',
#   0),
#  (749,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器需充粉',
#   0),
#  (750, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t消防栓下面堆放物品，已及时清理', 0),
#  (751,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t9楼946房门口消火栓贴纸脱落，现场更换，已整改',
#   0),
#  (759,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t没张贴警示标志',
#   0),
#  (761,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t电箱旁有杂物堆放，立刻清理整改',
#   0),
#  (762,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t传动齿轮没有防护罩',
#   0),
#  (763,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t1、安全警示标志\t1、应当在易燃、易爆、腐蚀、粉尘、高温、毒物、辐射、电力设施、可能发生坠落、挤压以及其他各类有较大危险因素的工作场所和设备、设施上设置明显的安全警示标志。\t有灰尘',
#   0),
#  (766,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t废材没有及时清理',
#   0),
#  (772, '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t7、临时用电\t1、临时用电必须经过审批。\t临时用电必须经过审批。', 1),
#  (774, '交通运输类（基础）—2016版\t（六）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有定期组织应急演练。', 0),
#  (777, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器欠压', 0),
#  (791, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t个别灭火器已过期。', 0),
#  (802,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t杂物圈占消防设备',
#   0),
#  (805,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t有物料呆放在消防栓前面了,,要求立即移开',
#   0),
#  (806,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t疏散通道有杂物',
#   0),
#  (812,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t厨房安全出口指示灯不会亮，重新更换。',
#   0),
#  (813,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器没有及时检查更新记录。',
#   0),
#  (814,
#   '商贸服务教文卫类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育\t1、制定安全教育培训计划，确保全员参与培训，并建立安全培训档案。\t制定安全教育培训计划，确保全员参与培训，并建立安全培训档案。',
#   1),
#  (815,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道堵塞,灭火器未放灭火器箱',
#   0),
#  (817,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t生产车间一台商标印刷机传动链轮外露部分安全防护装置不完整，未设置明显的“当心机械伤人”警示标志',
#   0),
#  (818,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门没关',
#   0),
#  (821, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t消防栓旁边堆放物品', 0),
#  (827,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散标志脱落',
#   0),
#  (829,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急灯，安全出口标志不齐全',
#   0),
#  (832,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t有的未贴当心触电标识',
#   0),
#  (836, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有一个灭火器过期了', 0),
#  (838,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全疏散指示标志方向不正确',
#   0),
#  (841,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t开关箱内有杂物',
#   0),
#  (842,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防通道车辆堵住，已经改善责令开走，恢复消防通道畅通',
#   0),
#  (845,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t灭火器消火栓堵塞，已整改',
#   0),
#  (846,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t消防通道有障碍物，已整改。',
#   0),
#  (849,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口灯不亮',
#   0),
#  (854,
#   '工业/危化品类（选项）—2016版\t（七）重点监管工艺及场所\t7、锂电池生产或储存\t11、电芯、电池库房温度应控制在摄氏-5℃至35℃范围内，相对湿度不超过75。库房内应整洁、干燥，通风良好。不得将危险化学品、热（火）源存放其中。\t不能放太多',
#   0),
#  (861,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t漏电保护装置少了一个，现已安装',
#   0),
#  (864,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有隐患',
#   1),
#  (868,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t安全会议记录不齐全',
#   0),
#  (870,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t配电箱安全警示标志脱落，已重新张贴并加固',
#   0),
#  (872, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t消火栓被 堵塞', 0),
#  (877,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t安全出口未设置应急灯',
#   0),
#  (880,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t已整改',
#   1),
#  (881,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口赌塞',
#   0),
#  (887,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t未接地',
#   0),
#  (888,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道被占用，及时整改。',
#   0),
#  (890, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、用火、用电有无违章情况。\t厨房不能明火', 0),
#  (905,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱未粘贴“当心触电”安全警示标志',
#   0),
#  (910, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t私接插座一个', 0),
#  (916,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堆积物料，即刻整理，整理完毕。',
#   0),
#  (917,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t未贴，已贴好。',
#   0),
#  (921,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间',
#   1),
#  (923,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱有杂物',
#   0),
#  (926,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t出口指示灯不亮，当天处理完善。',
#   0),
#  (934,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯故障不亮灯，电工已更换，问题已解决',
#   0),
#  (935,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间通道未标志明显的边线',
#   0),
#  (937,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全通道堵塞',
#   0),
#  (938,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t乙炔气瓶用纸皮遮挡',
#   0),
#  (939,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t摆放货物在疏散通道上',
#   0),
#  (941,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道堆积杂物，已整改',
#   0),
#  (947,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t电风扇没有上防护套。立即整改',
#   0),
#  (949,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已经整改',
#   1),
#  (953,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门未开启',
#   0),
#  (954,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道标识破损',
#   0),
#  (956,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t灭火器点检不及时',
#   0),
#  (971,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况。 \t11栋1楼消防通道堵塞，要求立即搬离。',
#   0),
#  (973,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t电源插座松脱',
#   0),
#  (975,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物暂存区疏散通道被堵塞',
#   0),
#  (977,
#   '三小场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t主要负责人及从业人员没有安全培训记录。',
#   0),
#  (978,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼车间通道放置货物，已整改',
#   0),
#  (980,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (981,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱的安全警示标志遗失，需立即补上',
#   0),
#  (985,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t车间部分电源开关盒未张贴安全警示标志',
#   0),
#  (986,
#   '建筑施工类（基础）—2016版\t（五）安全管理档案\t6、安全生产奖惩记录\t1、建立安全生产奖惩记录。\t生产安全奖惩记录不完整',
#   0),
#  (988,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t四楼过道一处疏散指示灯不亮',
#   0),
#  (990,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞',
#   0),
#  (992,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t防爆灯有一个不亮了，已立即更换。',
#   0),
#  (996,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t已经整改',
#   1),
#  (997, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t当日未举行防火巡查', 0),
#  (998,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯故障',
#   0),
#  (1002,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口标志故障',
#   0),
#  (1003,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有时被占用，已清理',
#   0),
#  (1004,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t疏散指示标志破损',
#   0),
#  (1005,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有个应急照明灯坏了，已经更换新的。',
#   0),
#  (1009,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t车间配电箱箱门与箱体跨接地线脱落',
#   0),
#  (1015, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t2、堆垛堆距应符合要求。', 1),
#  (1019,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防栓有货物挡住',
#   0),
#  (1026,
#   '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t1、库房内储存物品应分类、分堆、限额存放。\t辅料堆放不规范！偶有堵塞安全通道的情况。',
#   0),
#  (1027, '交通运输类（现场）—2016版\t（一）消防安全\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t已整改', 1),
#  (1029,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散通道、疏散指示标志脱落需重新购买张贴。',
#   0),
#  (1040,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防水泵房安全出口指示灯坏，已立即更换',
#   0),
#  (1042,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t1楼消火栓被货物遮挡，现场已整改，清理货物。',
#   0),
#  (1045,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道上有物品',
#   0),
#  (1046,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t加装两个应急灯和安全出口指示牌',
#   1),
#  (1047,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t二楼一个配电箱外未张贴（当心触电警示标志）',
#   0),
#  (1054,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t射骨机红外线坏，更换',
#   0),
#  (1057,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t车间配电箱警示标志脱落',
#   0),
#  (1060,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t四楼楼梯口堆放纸箱',
#   0),
#  (1064,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t压缩空气管道未标示流向和介质。',
#   0),
#  (1069,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t有两个员工未的安全教育培训未进行记录，立即重新培训进行记录',
#   0),
#  (1071,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t员工已把货物堆放超过黄线，已经整改。',
#   0),
#  (1075, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线裸露，责令整改', 0),
#  (1076, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有损坏没及时补上', 0),
#  (1077,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t织带车间一楼水带漏水。',
#   0),
#  (1078,
#   '商贸服务教文卫类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育\t1、制定安全教育培训计划，确保全员参与培训，并建立安全培训档案。\t系统—联系人无安全管理人员证',
#   0),
#  (1080, '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱有占用', 0),
#  (1081,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t3月份未建立安全档案',
#   0),
#  (1082,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座已老化烧坏',
#   0),
#  (1085,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t有缺失的会议记录',
#   0),
#  (1087,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t临时堆放杂物,',
#   0),
#  (1088,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防栓无标示',
#   0),
#  (1089,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道有临时堆放货物，改整改',
#   0),
#  (1091,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急灯修理效果不佳',
#   0),
#  (1093,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t已整改',
#   1),
#  (1096, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t杂乱摆放', 1),
#  (1098,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t临时有堆货物品',
#   0),
#  (1108,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、用火、用电有无违章情况。\t水吧插座老旧，不合安全要求。立即更换',
#   0),
#  (1111, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况；\t消防车通道有杂物堆积', 0),
#  (1112,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器分布重新调配',
#   0),
#  (1118,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t成品仓库包装好的货物未出,堵塞通道.',
#   0),
#  (1119,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道堵塞',
#   0),
#  (1122, '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t5、消防安全重点部位的人员在岗情况；\t隐患', 1),
#  (1126,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况；\t灭火器乱放，未放置在指定区域',
#   0),
#  (1127,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器充粉后，检查记录和标识未及时张贴。',
#   0),
#  (1130,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；',
#   1),
#  (1131, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有效期已过，未及时维修', 0),
#  (1132,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t整改前作业通道不畅通，整改后作业通道已畅通。',
#   0),
#  (1134,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t消防通道放了东西',
#   0),
#  (1135,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t每次生产加工时安全通道不畅通',
#   0),
#  (1138,
#   '商贸服务教文卫类（基础）—2016版\t（六）危险作业与风险管控\t2、危险作业\t1、凡涉及动火、高空、有限空间、密闭容器、起重、施工动土、临时用电等危险作业，应明确危险作业的申请、审批权限、职责和程序，办理作业票证；安排专门人员进行现场安全管理。\t奥特莱斯更换广告牌未办理审批手续，现场要求停工，并补办了相关手续。',
#   0),
#  (1139,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。防火巡查人员应当及时纠正违章行为，妥善处置火灾危险，无法当场处置的，应当立即报告。发现初起火灾应当立即报警并及时扑救。\t有一顾客加油时使用手机，现场管理人员已立即劝阻。',
#   0),
#  (1144,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t宿舍通道安全指示牌损坏。消防栓通道堵。',
#   0),
#  (1146, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t没有定期校验。', 0),
#  (1147, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t一楼壹时尚灭火器过期', 0),
#  (1148,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t一楼冲压冲床缺失防护罩',
#   0),
#  (1150,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\tc栋9楼安全疏散指示牌需固定',
#   0),
#  (1159, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器放在地上', 0),
#  (1162, '商贸服务教文卫类（基础）—2016版\t（七）应急管理\t2、应急演练\t1、定期组织应急演练。\t没有定期组织消防演练', 0),
#  (1165,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t线头没有归整好',
#   0),
#  (1168,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t仓库所有的安全出口灯与应急照明灯不亮（跳闸）',
#   0),
#  (1171,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t已整改，已配护罩',
#   0),
#  (1173, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t4楼有个灭火器气压不足', 0),
#  (1176, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有2瓶过期灭火器', 0),
#  (1177,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t安全教育培训档案不全，两天内补齐',
#   0),
#  (1181,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防柱有杂物档住',
#   0),
#  (1184,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t3、消防车通道、消防水源情况。\t消防通道有业主放置杂物',
#   0),
#  (1185,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t车间安全通道不畅通',
#   0),
#  (1191, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况；', 1),
#  (1194,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t已整改',
#   1),
#  (1195, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t货物堆放不整齐，容易堵塞通道', 0),
#  (1196,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t电箱盖脱落',
#   0),
#  (1201,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t已整改',
#   1),
#  (1205,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散指示未整顿好',
#   0),
#  (1206,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口灯坏了',
#   0),
#  (1209,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t定期组织员工培训，消防安全培训',
#   0),
#  (1211, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器未检查', 0),
#  (1214,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道被小推车堵塞',
#   0),
#  (1215,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t杂物堆放',
#   0),
#  (1217,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t仓库一个应急照明灯断电不亮，已经整改完毕。',
#   0),
#  (1220,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t物品堵塞消防栓',
#   0),
#  (1222,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼与二楼厂房各有一处应急灯不灯，已马上更换',
#   0),
#  (1229,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t一楼机器档护没有安装',
#   0),
#  (1233,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t2、无铠装电缆在屋内明敷，水平敷设时，其至地面的距离不应小于2.5m；垂直敷设时，其至地面的距离不应小于1.8m。当不能满足上述要求时应有防止电缆机械损伤的措施。沿地敷设的电缆应穿钢管保护。穿管的内径不应小于电缆外径的1.5倍。\t甲类仓库后可燃气体探测器电源线管脱落',
#   0),
#  (1238,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物堵塞安全出口通道',
#   0),
#  (1240,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口、疏散通道有堵塞，已经现场移开，保持畅通',
#   0),
#  (1241,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t2、灭火器应合理分布，无固定摆放并定期校验。',
#   1),
#  (1243,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t防爆灯掉落',
#   0),
#  (1245,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有隐患',
#   1),
#  (1247,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口，过道有货物堆积。当场已整改。',
#   0),
#  (1248,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t酒精瓶没有告知卡',
#   0),
#  (1251,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器材配置及有效情况。',
#   1),
#  (1254,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道不畅通',
#   0),
#  (1255,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t车间垃圾堵塞安全通道，已整改',
#   0),
#  (1258, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t2、堆垛堆距应符合要求。\t不符合五距要求', 0),
#  (1262,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t一楼7号楼梯模板堵塞安全口处，人员无法正常迅速疏散逃生。',
#   0),
#  (1263,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t未在电池仓库内粘贴“严禁烟火 ”标志',
#   0),
#  (1270,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t春节长假后，后门口的应急照明灯坏了',
#   0),
#  (1272,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t1楼PVD区域施工具挡住消防栓',
#   0),
#  (1276,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t12、其他需要检查的内容。\u3000\u3000防火检查需填写检查记录。检查人员和被检查部门负责人在检查记录上签名。\t机床按钮损坏',
#   0),
#  (1278, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t已购置完毕', 1),
#  (1279, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线裸露', 0),
#  (1283,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t11、消防安全标志的设置情况和完好、有效情况。\t电房增加防火标识',
#   1),
#  (1288,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t已整改完成',
#   1),
#  (1296, '交通运输类（现场）—2016版\t（一）消防安全\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器缺失一个，已立即整改', 0),
#  (1300,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器压力不足，已更换',
#   0),
#  (1301,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t1、危险化学品从业单位通用要求\t5、可能产生易燃易爆气体的场所，必须设置可燃气体的检测和自动报警装置。\t没有自动报警装置',
#   0),
#  (1304,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有一处照明指示灯损坏',
#   0),
#  (1306,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t仓库里的灭火器被移动了，已整改',
#   0),
#  (1311,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施',
#   1),
#  (1316,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t泡沫塑料',
#   0),
#  (1318,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t标识不清楚/脱落',
#   0),
#  (1320, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器压力不足。', 0),
#  (1324,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t玻璃门不是防火\n\n现已安装防火门',
#   0),
#  (1325,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线裸露',
#   0),
#  (1330,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器快过期了，责令马上更换新的。',
#   0),
#  (1331,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道有放货。',
#   0),
#  (1333,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t机器皮带传动装置缺少安全保护。',
#   0),
#  (1340,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t1-2楼目前还处于装修阶段，暂未配备灭火器材',
#   0),
#  (1345, '工业/危化品类（现场）—2016版\t（四）作业环境\t2、通风与照明\t1、作业场所通风良好。\t应急灯缺失', 0),
#  (1350, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期，存在隐患', 0),
#  (1353,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t未检查消防安全重点部位的管理情况；',
#   0),
#  (1354, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器干粉用尽，已充满', 0),
#  (1356,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t楼道口停放电动车，堆放货物。  发现后，立即通知相关人员处理。',
#   0),
#  (1361,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t2、危险作业\t1、凡涉及动火、高空、有限空间、密闭容器、起重、施工动土、临时用电等危险作业，应明确危险作业的申请、审批权限、职责和程序，办理作业票证，安排专门人员进行现场安全管理。\t1. :5栋1楼登高梯台处无“当心坠落”警示标志；2. :5栋1楼部分配电盒处无“当心触电”警示标志；',
#   0),
#  (1363,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t堵塞消防通道，已整改',
#   0),
#  (1366,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业通道堆放杂物',
#   0),
#  (1368,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器没有进行检查，查验是否合格，有一个失效',
#   0),
#  (1371,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道被货物堵塞',
#   0),
#  (1372,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t封口机用后未拔电源',
#   0),
#  (1379,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t7、临时用电\t2、临时用电的配电箱和电气设备，必须安装漏电保护装置。线路敷设应符合电气装置设置及安装规范，室内不低于2.5m，室外不低于4.5m，道路上方不低于6m。\t桥架插座走线不规范',
#   0),
#  (1381,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有隐患',
#   1),
#  (1382, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器', 1),
#  (1383,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t1.現場塗料桶未夾靜電接地夾。2.電器線路上面有易燃物。3.開關蓋板沒鎖好。',
#   0),
#  (1385,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t电风扇电线没有装套管',
#   0),
#  (1399,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一个灭火器支架铆钉松脱，现已加固稳定',
#   0),
#  (1409,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道是否畅通',
#   1),
#  (1412,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口疏散指示标志，应急照明灯不亮。',
#   0),
#  (1416,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t大会议室一个灭火器压力位为红色区域',
#   0),
#  (1417,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t有两个灭火器失压，已经更换好',
#   0),
#  (1418, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t饮水机旁边有电线外露。', 0),
#  (1426,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t6、移动用电产品、电动工具及照明\t1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。\t手磨机电缆线有损坏，已经换新的',
#   0),
#  (1436,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电线有裸露情况，立即整改！           整改完成！',
#   0),
#  (1440,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器上放有杂物，及时清开',
#   0),
#  (1441,
#   '商贸服务教文卫类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t手压台皮带轮外露，无防护罩',
#   0),
#  (1442,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座、电源插头应按规定正确接线。',
#   1),
#  (1444,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t1、特种设备档案\t1、特种设备(及安全附件)检测报告齐全，并在有效期内。运行记录和维修保养记录齐全。\t空压机安全检查维护记录表被雨淋湿，重新放置，已整改',
#   0),
#  (1446,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t未建立全员安全生产责任制',
#   0),
#  (1447,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全标志缺失',
#   0),
#  (1454,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t部分指示标志不到位，需要再贴标示明确',
#   0),
#  (1460,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t1、特种设备档案\t1、特种设备(及安全附件)检测报告齐全，并在有效期内。运行记录和维修保养记录齐全。\t电箱没有挡板，需要增加挡板',
#   0),
#  (1461,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器摆放位置不对，重新固定新位置',
#   0),
#  (1464, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t9、消防（控制室）值班情况和设施运行、记录情况；\t无', 1),
#  (1466,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、消防安全重点单位应当进行每日防火巡查，并确定巡查的人员、内容、部位和频次。其他单位可以根据需要组织防火巡查。巡查的内容应当包括：1、用火、用电有无违章情况；\t仓库堆放不整齐',
#   0),
#  (1467,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口有阻碍物',
#   0),
#  (1468,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t无记录',
#   0),
#  (1471,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t1、办公场所应按规定配备ABC类干粉灭火器（每50平方米需配备2具4公斤ABC干粉灭火器）。\t灭火器压力不够，已经更换',
#   0),
#  (1474,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t年底地面黄色警戒线已经模糊不清，计划在春节放假期间重刷油漆。',
#   0),
#  (1480, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况；', 1),
#  (1481,
# ...
#   0),
#  (2784,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t三楼车间的疏散通道被货物堵塞，发现后立即安排人员清理',
#   0),
#  (2794, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t包装部配电箱前方货物遮挡', 0),
#  (2795,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t个别应急照明灯损坏',
#   0),
#  (2796,
#   '工业/危化品类（选项）—2016版\t（一）职业健康与劳动保护\t2、职业危害作业场所要求\t5、采用有效的安全防护设施(包括职业病、职业中毒、职业伤害等)。提供符合国家标准的防护用品，并确保劳动者正确使用。\t.个别员工未佩戴劳动防护用品。',
#   0),
#  (2797,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用。\t农科商务办公楼二楼西面消防楼梯防火门未处于常闭状态。',
#   0),
#  (2799, '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t还未进行安全培训', 0),
#  (2805,
#   '交通运输类（现场）—2016版\t（一）消防安全\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t灭火器未定期检查',
#   0),
#  (2813,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t1、配电房\t1、配电室的门、窗关闭应密合；门应向外开启，但通向高压配电室的门应为双向开启门。与室外相通的洞、通风孔应设防止鼠、蛇类等小动物进入安全防护措施（如采用金属网时，网格不得大于10㎜*10㎜）。室内电缆沟需采取防水和排水措施。\t电箱盒打开没及时关好',
#   0),
#  (2817,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防器材缺失',
#   0),
#  (2818,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t1、配电房\t3、配电室长度超过7m时，应设两个出口，并宜布置在配电室的两端。配电室应配备绝缘垫、绝缘棒、绝缘手套、绝缘鞋等防护用品，以及应急照明和灭火器材。\t一般隐患',
#   1),
#  (2827, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器损坏，已更换', 0),
#  (2837,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t车间安全标志脱落，立即整改还原。',
#   0),
#  (2842, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况。\t用电有违章情况。', 0),
#  (2844,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t仓库安全通道被来的货物临时堵塞，出货后及时清理了通道。',
#   0),
#  (2846,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t应急处置卡内容未完善，需立即处理。',
#   0),
#  (2848,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t己整改',
#   1),
#  (2852,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t1、技术中心实验室门上依马田政府安监要求增加安全出口洒及应急灯，增加安装正常化。具体见上传图片。',
#   1),
#  (2853,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t出货人员将消防通道堵塞，立即整改。',
#   0),
#  (2854,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口有垃圾',
#   0),
#  (2858,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座没有按规定位置摆放',
#   0),
#  (2864,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t一楼电箱下放可燃物，已通知员工清走。',
#   0),
#  (2867,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t部分员工对安全防火防范意识不够强，需进一步加强培训',
#   0),
#  (2870, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t办公室区域灭火器配置不够', 0),
#  (2883,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t1、危险机械设备\t1、冲、剪、压机械、木工机械、砂轮机、注塑机械、压痕机、粉碎机、抛光机等危险设备的安全防护装置完好齐全。\t三厂三楼自动机台下方链条转动处防护门缺失，需更换或维修',
#   0),
#  (2889,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t配电箱没有设置“当心触电”安全警示标志',
#   0),
#  (2902,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t805门口安全疏散指示标志脱落',
#   0),
#  (2903,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整。\t消防安全标志不完整',
#   0),
#  (2910, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t灭火器上面有东西盖住了', 0),
#  (2922,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱有杂物',
#   0),
#  (2927,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好。\t安全出口、疏散通道旁堆放杂物',
#   0),
#  (2928,
#   '工业/危化品类（基础）—2016版\t（七）应急管理\t1、应急预案\t1、结合本单位实际，切实开展风险评估和应急资源调查，编制应急预案。重点岗位制定应急处置卡。\t应急预案需再完善',
#   0),
#  (2929,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t5号安装包装货物挡住配电箱',
#   0),
#  (2931,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t有机器设备堵住通道',
#   0),
#  (2932,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t前台应急灯不亮，待更换',
#   0),
#  (2936,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱、开关箱放置了杂物',
#   0),
#  (2949, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t5、用火、用电有无违章情况；\t电线裸露，未装入线槽', 0),
#  (2963,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t通道堵塞',
#   0),
#  (2965, '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t1、用火、用电有无违章情况。\t现场整改', 1),
#  (2966,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t1、配电箱应设置“当心触电”安全警示标志。箱门与箱体应跨接并接地。\t有可能人接触，可能触电区域是否有安全设施及醒目警示标志。现已整改。',
#   1),
#  (2967,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t多台加温设备无“当心高温”安全警示标志；',
#   0),
#  (2971,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t4、配电箱、电源插座回路、移动电源插座、低于2.4m照明灯具开关需安装漏电保护器。\t插座故障 立即整改',
#   0),
#  (2973,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座、电源插头应按规定正确接线。',
#   1),
#  (2974,
#   '三小场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t没有主要负责人及从业人员有安全培训记录。',
#   0),
#  (2977,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道有杂物。',
#   0),
#  (2985,
#   '工业/危化品类（选项）—2016版\t（四）危险化学品\t1、危险化学品从业单位通用要求\t7、危险化学品专用仓库、专用场地须报公安、消防部门批准。\t临时仓库需要安装防火门',
#   0),
#  (2988, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t有物品遮挡', 0),
#  (2992, '工业/危化品类（选项）—2016版\t（二）仓库\t1、一般要求\t1、库房内储存物品应分类、分堆、限额存放。\t堆放杂乱', 0),
#  (2996,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t未安装防护罩',
#   0),
#  (2998, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器材配置及有效情况', 1),
#  (3000,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t配电箱当心触电标志脱落',
#   0),
#  (3001,
#   '工业/危化品类（选项）—2016版\t（六）危险设备\t1、注塑机械\t1、根据工艺要求操作口前安全门有行程开关等设施实现电气连锁，确保前门打开时部件停止运动。\t电动小推车停用时未拔钥匙',
#   0),
#  (3003, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t配置数量少,立即购买', 0),
#  (3004,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\tF7栋3楼防火卷帘下对方杂物影响消防安全。',
#   0),
#  (3013, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t一瓶灭火器压力不够', 0),
#  (3014,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全疏散指示标志摆放问题',
#   0),
#  (3016,
#   '交通运输类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座接地应符合下列规定：a.对于单相两孔插座，面对插座的右孔或上孔应与相线连接，左孔或下孔应与中性导体（N）连接；对于单相三孔插座，面对插座的右孔应与相线连接，左孔应与中性导体（N）连接。b.单相三孔、三相四孔与三相五孔插座的保护接地与导体（PE）应接在上孔；插座的保护接地导体端子不得与中性导体端子连接；同一场所的三相插座，其接线的相序应一致。c.保护接地导体（PE）在插座之间不得串接连接。d.相线与中性导体（N）不应利用插座本体的接线端子转接供电。\t现场整改',
#   1),
#  (3017,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t1、防火巡查\t6、其他消防安全情况。\t卡板放得太乱，督促车间派人重新整理好',
#   0),
#  (3019,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道临时堆放货物',
#   0),
#  (3030,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t1、火灾隐患的整改情况以及防范措施的落实情况；\t甲类分装区地板未采取防静电措施，可能会产 生静电火花，引起火灾隐患。',
#   0),
#  (3031,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t通道堵塞',
#   0),
#  (3032, '三小场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t未定期进行应急演练。', 0),
#  (3034,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t月常规安全检查发现有15个灭火器已到期，已经重新充装完成。',
#   0),
#  (3036,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全通道阻塞',
#   0),
#  (3037, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t10、防火巡查情况；\t防火巡查记录表未按时更新', 0),
#  (3040,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t一楼有一处消防器被货物阻挡',
#   0),
#  (3042,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t6、重点工种人员以及其他员工消防知识的掌握情况；\t新员工消防器材不会使用',
#   0),
#  (3047,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明灯电源开关被关闭，已立即开启。',
#   0),
#  (3048, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t演练记录未及时更新', 0),
#  (3050,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t发现一个灭火器无粉，已加',
#   0),
#  (3051, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器及消防栓定期检查', 0),
#  (3056,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t警示标志年久，字体不清晰。重新更换',
#   0),
#  (3057,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t大板车间吊机刹车打滑，需更换刹车圈1个',
#   0),
#  (3059,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t防火门处于开启状态，有物品阻塞，已整改',
#   0),
#  (3065,
#   '商贸服务教文卫类（选项）—2016版\t（四）仓库\t2、照明\t2、库房内不得设置移动照明灯具，照明灯具下方不准堆放物品，其垂直下方与储存物品水平间距不得小于0.5米。\t物品堆放不规范',
#   0),
#  (3066,
#   '商贸服务教文卫类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱下放置易燃物品',
#   0),
#  (3068,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t制定并实施全员参与的安全教育培训计划',
#   1),
#  (3069, '纯办公场所（现场）—2016版\t（一）消防安全\t1、灭火器材\t2、灭火器应合理分布，固定摆放并定期校验。\t灭火器被遮挡', 0),
#  (3076,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口临时堆放有物品，立即清理。',
#   0),
#  (3078,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t安全出口堆放货物',
#   0),
#  (3080, '工业/危化品类（基础）—2016版\t（五）安全管理档案\t3、隐患排查记录\t1、建立并保存事故隐患排查治理档案。\t无', 1),
#  (3085,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t防爆柜未粘贴责任人和电话,未粘贴安全技术说明书(MSDS),无出入库记录',
#   0),
#  (3095,
#   '三小场所（现场）—2016版\t（二）电气安全\t2、电气设备、设施的金属接地或接零\t1、电气设备金属外壳需接地保护。\t坐地风扇加装防护网',
#   0),
#  (3096,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全疏散标识牌陈旧，立即给换新的',
#   0),
#  (3097,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；\t防爆柜无MSDS报告。旁边放杂物。',
#   0),
#  (3098,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t有一处消防疏散通道被货物挡到',
#   0),
#  (3099,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t通道上摆放机器。要求立即将机器挪开，通道禁止堵塞。',
#   0),
#  (3101,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堆放货物已清空',
#   0),
#  (3102,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t有些通道未用黄线标明。立即用黄线注明',
#   0),
#  (3106,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t货物堆垛与墙之间少于0.3米',
#   0),
#  (3112,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道有台物料车',
#   0),
#  (3115,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯没亮',
#   0),
#  (3121,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t电源插座面板损坏致使电线外露，有触电风险',
#   0),
#  (3124,
#   '工业/危化品类（基础）—2016版\t（五）安全管理档案\t2、安全生产会议记录\t1、安全生产会议记录包括：（1）安全生产例会记录。（2）安全生产专项会议记录。（3）安全生产奖惩记录。\t无记录',
#   0),
#  (3125,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t三楼有一个胶筐放在通道上',
#   0),
#  (3126,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t车间插座已安装漏电保护开关',
#   0),
#  (3129,
#   '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t作业区有卡板',
#   0),
#  (3132,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t消防设施、器材和消防安全标志是否在位、完整',
#   1),
#  (3133,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t灭火器材存放处有物料堵塞',
#   0),
#  (3134, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t过期，己更换', 0),
#  (3136,
#   '工业/危化品类（基础）—2016版\t（六）警示标志与危险作业\t1、风险公告\t1、对有较大危险因素的生产经营场所和有关设施、设备进行辨识，设置明显的安全警示标志，制定防范措施。\t部分冲压设备相关安全警示标识不健全或未做风险告知',
#   0),
#  (3138,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好',
#   1),
#  (3139,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t车间有一处灭火器被阻挡，已按要求现场处理',
#   0),
#  (3141, '纯办公场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t演练人员记录不详细', 0),
#  (3143,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t1、配电箱(柜)门张贴有“当心触电”安全警示标志。金属箱(柜)门与金属箱(柜)体必须通过采用编织软铜线做电气连接。\t个别配电箱安全警示标志脱落',
#   0),
#  (3146,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t灭火器、配电箱前堆货物',
#   0),
#  (3147,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t机器停用',
#   1),
#  (3150,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t3、消防设施、器材和消防安全标志是否在位、完整；\t有一组灭火器压力不足，立即更换',
#   0),
#  (3156,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应急照明损坏,立即更换',
#   0),
#  (3157,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。\t一楼到负一楼通道疏散指示牌损坏，已更换',
#   0),
#  (3158,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t消防通道堵塞，后面整改疏通',
#   0),
#  (3166,
#   '建筑施工类（基础）—2016版\t（二）安全管理机构和人员\t1、安全管理机构\t1、设立与本企业资质、规模相符的安全管理机构。\t有安群管理框架图',
#   0),
#  (3167,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t仓库有一扇常闭式防火门没有关上',
#   0),
#  (3168,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口有货物堵塞',
#   0),
#  (3169,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；\t后门常闭式防火门，闭门器门，处予打开状态，立即找人维修',
#   0),
#  (3178, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t已整改', 1),
#  (3179,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t1、员工安全教育及外来人员培训教育\t1、制定并实施全员参与的安全教育培训计划，并建立档案。对外来施工、工作和参访人员进行安全教育和安全告知并建立档案。\t对外来施工人员的安全教育需加强',
#   0),
#  (3180,
#   '工业/危化品类（基础）—2016版\t（四）安全教育培训\t2、特种设备作业人员和特种作业人员培训\t1、特种设备作业人员、特种作业人员经专业培训取得相应资格证书并有效。\t1、没有定期组织应急演练。',
#   0),
#  (3183,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t4、保护接地\t电气装置的金属部分，均应做好保护接地。保护接地线应采用焊接、压接、螺栓连接或其他可靠方法连接，严禁缠绕或钩挂。电缆（线）中的绿/黄双色线在任何情况下只能用作保护接地线。中间不允许有接头及破损。\t有电线氧化，导致接触不良',
#   0),
#  (3185,
#   '工业/危化品类（基础）—2016版\t（三）责任制、管理制度及操作规程\t1、责任制、管理制度及操作规程\t1、建立、健全安全生产责任制、安全生产规章制度和操作规程。\t电瓶手动叉车未贴操作规程',
#   0),
#  (3186,
#   '工业/危化品类（现场）—2016版\t（三）机械设备安全防护\t2、人身防护\t1、皮带轮、齿轮、凸轮、曲柄连杆机构等外露的转动和运动部件应有防护罩。\t二楼切机没有防护罩。     已整改',
#   0),
#  (3187,
#   '商贸服务教文卫类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况。\t小一班门口干粉灭火器压力不足，马上更换新的灭火器。',
#   0),
#  (3188,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t盆栽挡住通道口',
#   0),
#  (3190,
#   '交通运输类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t配电箱“当心触电”安全警示标志缺失',
#   0),
#  (3193,
#   '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t8楼1疏散指示标志不亮',
#   0),
#  (3194, '建筑施工类（选项）—2016版\t（十二）施工用电\t2、实体安全\t6、现场照明是否符合要求。\t基坑照明灯具离地高度小于3米', 0),
#  (3197,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全应急灯不亮，更换新的',
#   0),
#  (3199,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t3、电气线路及电源插头插座\t3、电源插座、电源插头应按规定正确接线。\t631组一处电线槽接口电线不规范、一处线槽盖脱位。',
#   0),
#  (3201,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t、安全疏散通道、疏散指示标志',
#   1),
#  (3206, '纯办公场所（基础）—2016版\t（一）基础管理\t1、安全培训\t1、主要负责人及从业人员有安全培训记录。\t无安全培训记录', 0),
#  (3208,
#   '工业/危化品类（现场）—2016版\t（四）作业环境\t1、作业通道\t1、作业通道应保持畅通，禁止临时堆放货物；通道以黄色或者白色线标明。凡有地坑、壕、池的地方,应设置盖板或护栏。\t生产货物摆放不规整超过黄线',
#   0),
#  (3212,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t应急照明灯摆位有些斜，即时纠正',
#   0),
#  (3213,
#   '纯办公场所（现场）—2016版\t（一）消防安全\t2、消防通道\t1、疏散通道无占用、堵塞、封闭等现象。安全出口不得上锁。\t消防栓前面有桶装水遮挡',
#   0),
#  (3215, '商贸服务教文卫类（现场）—2016版\t（四）场所环境\t2、通风与照明\t1、作业场所通风良好，灯管灯具完好无损。\t灯管损坏', 0),
#  (3217, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器过期，己更换', 0),
#  (3224,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口指示灯损坏，以及时整改。',
#   0),
#  (3225, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t已整改', 1),
#  (3226, '三小场所（基础）—2016版\t（一）基础管理\t2、应急管理\t1、定期进行应急演练，有演练记录。\t灭火器已过期', 0),
#  (3229,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t一、C区五楼胶架A部一条安全通道被货架堵塞；二、写字楼一楼一处安全出口灯不亮',
#   0),
#  (3230,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t2个应急照明灯不亮',
#   0),
#  (3232,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t疏散通道被货物堵塞',
#   0),
#  (3233, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t灭火器有效情况异常', 0),
#  (3242,
#   '商贸服务教文卫类（基础）—2016版\t（五）安全管理档案\t1、安全生产会议记录\t1、保存安全会议记录，包括：（1）安全例会记录。（2）安全专项会议记录。（3）安全奖惩记录。\t记录',
#   1),
#  (3248,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\tK栋二楼车间一具灭火器过期',
#   0),
#  (3249, '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t7、消防安全重点部位的管理情况；\t灭火器前有障碍物', 0),
#  (3256,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t应紧灯在正常情况下亮灯，已修好改善',
#   1),
#  (3261,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t照明灯已坏',
#   0),
#  (3262, '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱有遮挡', 0),
#  (3266,
#   '纯办公场所（现场）—2016版\t（二）电气安全\t1、配电箱（柜、板）\t3、配电箱前操作空间不得占用或遮挡。\t配电箱前操作空间被遮挡。',
#   0),
#  (3268,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t4、灭火器材配置及有效情况；\t所有灭火器2019-3-18都已拿到消防中队隔壁店面进行年审及更换',
#   0),
#  (3269,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t1、防火巡查\t2、安全出口、疏散通道是否畅通，安全疏散指示标志、应急照明是否完好；\t安全出口，已整改畅通\n',
#   0),
#  (3270,
#   '工业/危化品类（现场）—2016版\t（二）电气安全\t2、配电箱（柜、板）\t3、配电箱、开关箱内不得放置任何杂物，电器元件不可安装在可燃材料上。\t生产车间开关盒脱落',
#   0),
#  (3272,
#   '工业/危化品类（现场）—2016版\t（一）消防检查\t2、防火检查\t2、安全疏散通道、疏散指示标志、应急照明和安全出口情况；\t安全出口指示灯损坏，已经及时更换新的安全出口指示灯',
#   0),
#  ...]

# %% [markdown]
# # 验证和预测

# %%
def evaluate(data):
    total, right = 0., 0.
    for x_true, y_true in data:
        y_pred = model.predict(x_true).argmax(axis=1)
        y_true = y_true[:, 0]
        total += len(y_true)
        right += (y_true == y_pred).sum()
    return right / total

# %%
class Evaluator(keras.callbacks.Callback):
    """评估与保存
    """
    def __init__(self):
        self.best_val_acc = 0.

    def on_epoch_end(self, epoch, logs=None):
        val_acc = evaluate(valid_generator)
        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            model.save_weights('best_model.weights')
#         test_acc = evaluate(test_generator)
#         print(
#             u'val_acc: %.5f, best_val_acc: %.5f, test_acc: %.5f\n' %
#             (val_acc, self.best_val_acc, test_acc)
#         )
        test_acc = evaluate(valid_generator)
        print(
            u'val_acc: %.5f, best_val_acc: %.5f, test_acc: %.5f\n' %
            (val_acc, self.best_val_acc, test_acc)
        )

# %%
def data_pred(test_data):
    id_ids, y_pred_ids = [], []
    for id, text, label in test_data:
        token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
        token_ids = sequence_padding([token_ids])
        segment_ids = sequence_padding([segment_ids])
        y_pred = model.predict([token_ids, segment_ids]).argmax(axis=1)
        id_ids.append(id)
        y_pred_ids.append(y_pred)
    return id_ids, y_pred_ids

# %%
def data_pred2(test_data):
    id_ids, y_pred_ids = [], []
    batch_token_ids, batch_segment_ids = [], []
    for id, text, label in test_data:
        token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
        batch_token_ids.append(token_ids)
        batch_segment_ids.append(batch_segment_ids)
        id_ids.append(id)
    token_ids = sequence_padding(batch_token_ids)
    segment_ids = sequence_padding(batch_segment_ids)
    y_pred_ids = model.predict([token_ids, segment_ids]).argmax(axis=1)
    return id_ids, y_pred_ids

# %%
## 修改代码

# %%
def data_pred3(test_data):
    id_ids, y_pred_ids = [], []
    for id, text, label in test_data:
        token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
        token_ids = sequence_padding([token_ids])
        segment_ids = sequence_padding([segment_ids])
        y_pred = int(model.predict([token_ids, segment_ids]).argmax(axis=1)[0])
        id_ids.append(id)
        y_pred_ids.append(y_pred)
    return id_ids, y_pred_ids

# %%
def data_pred4(test_data):
    id_ids, y_pred_ids = [], []
    batch_token_ids, batch_segment_ids = [], []
    for id, text, label in test_data:
        token_ids, segment_ids = tokenizer.encode(text, maxlen=maxlen)
        batch_token_ids.append(token_ids)
        batch_segment_ids.append(batch_segment_ids)
        id_ids.append(id)
    token_ids = sequence_padding(batch_token_ids)
    segment_ids = sequence_padding(batch_segment_ids)
    y_pred_ids = model.predict([token_ids, segment_ids]).argmax(axis=1)[:,0]
    return id_ids, list(y_pred_ids)

# %% [markdown]
# # 训练和验证

# %%
evaluator = Evaluator()

# %%
model.fit(
        train_generator.forfit(),
        steps_per_epoch=len(train_generator),
        epochs=10,
        callbacks=[evaluator]
    )
# Out:
# /root/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# Epoch 1/10
# 261/261 [==============================] - 2122s 8s/step - loss: 0.1280 - accuracy: 0.9542
# val_acc: 0.97866, best_val_acc: 0.97866, test_acc: 0.97866
#
# Epoch 2/10
# 261/261 [==============================] - 2093s 8s/step - loss: 0.0523 - accuracy: 0.9818
# val_acc: 0.98057, best_val_acc: 0.98057, test_acc: 0.98057
#
# Epoch 3/10
# 261/261 [==============================] - 2107s 8s/step - loss: 0.0351 - accuracy: 0.9884
# val_acc: 0.97784, best_val_acc: 0.98057, test_acc: 0.97784
#
# Epoch 4/10
# 261/261 [==============================] - 2105s 8s/step - loss: 0.0245 - accuracy: 0.9915
# val_acc: 0.97975, best_val_acc: 0.98057, test_acc: 0.97975
#
# Epoch 5/10
# 261/261 [==============================] - 2103s 8s/step - loss: 0.0150 - accuracy: 0.9951
# val_acc: 0.97893, best_val_acc: 0.98057, test_acc: 0.97893
#
# Epoch 6/10
# 261/261 [==============================] - 2117s 8s/step - loss: 0.0109 - accuracy: 0.9969
# val_acc: 0.98057, best_val_acc: 0.98057, test_acc: 0.98057
#
# Epoch 7/10
# 261/261 [==============================] - 2104s 8s/step - loss: 0.0087 - accuracy: 0.9975
# val_acc: 0.97975, best_val_acc: 0.98057, test_acc: 0.97975
#
# Epoch 8/10
# 261/261 [==============================] - 2117s 8s/step - loss: 0.0106 - accuracy: 0.9970
# val_acc: 0.97893, best_val_acc: 0.98057, test_acc: 0.97893
#
# Epoch 9/10
# 261/261 [==============================] - 2112s 8s/step - loss: 0.0131 - accuracy: 0.9954
# val_acc: 0.97729, best_val_acc: 0.98057, test_acc: 0.97729
#
# Epoch 10/10
# 261/261 [==============================] - 2108s 8s/step - loss: 0.0117 - accuracy: 0.9964
# val_acc: 0.97893, best_val_acc: 0.98057, test_acc: 0.97893

# %%
model.load_weights('best_model.weights')
# print(u'final test acc: %05f\n' % (evaluate(test_generator)))
print(u'final test acc: %05f\n' % (evaluate(valid_generator)))
# Out:
# final test acc: 0.980575

# %%
print(u'final test acc: %05f\n' % (evaluate(train_generator)))
# Out:
# final test acc: 0.991612

# %% [markdown]
# # 模型预测保存结果

# %%
id_ids, y_pred_ids = data_pred3(test_data)

# %%
df_save = pd.DataFrame()
df_save['id'] = id_ids
df_save['label'] = y_pred_ids

# %%
df_save.to_csv('result.csv')
